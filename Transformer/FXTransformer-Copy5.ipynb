# %%
import pickle
import numpy as np
from tensorflow import keras
import pandas as pd
import os, datetime
from utils import data_read_dict, data_read_concat, data_merge
import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
print('Tensorflow version: {}'.format(tf.__version__))

import matplotlib.pyplot as plt
plt.style.use('seaborn')

import warnings
warnings.filterwarnings('ignore')
# Out:
# Tensorflow version: 2.4.1

# %%
import platform
if platform.node() == "msbq":
    from tensorflow.python.client import device_lib
    print(device_lib.list_local_devices())
    print(tf.__version__)
    print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
    tf.config.list_physical_devices('GPU')
    # !python --version

#     tf.config.list_physical_devices('GPU')
#     gpus = tf.config.experimental.list_physical_devices('GPU')
#     if gpus:
#       # Restrict TensorFlow to only allocate 4GB of memory on the first GPU
#       try:
#         tf.config.experimental.set_virtual_device_configuration(
#             gpus[0],
#             [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4096)])
#         logical_gpus = tf.config.experimental.list_logical_devices('GPU')
#         print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#       except RuntimeError as e:
#         # Virtual devices must be set before GPUs have been initialized
#         print(e)
#         print('asdf')

# %% [markdown]
# ## Hyperparameters

# %%
batch_size = 32
seq_len = 128

d_k = 256
d_v = 256
n_heads = 12
ff_dim = 256

# %% [markdown]
# ## Load data

# %%
IBM_path = '../data/10min Dataset.csv'

# df = pd.read_csv(IBM_path, delimiter=';', usecols=['Dates', 'EURUSD BGNE Curncy Bid Open', 'EURUSD BGNE Curncy Bid Close', 'EURUSD BGNE Curncy Bid High', 'EURUSD BGNE Curncy Bid Low', 'EURUSD BGNE Curncy Bid Number Ticks', 'EURUSD BGNE Curncy Ask Open', 'EURUSD BGNE Curncy Ask Close', 'EURUSD BGNE Curncy Ask High', 'EURUSD BGNE Curncy Ask Low', 'EURUSD BGNE Curncy Ask Number Ticks', 'USDJPY BGNE Curncy Bid Open', 'USDJPY BGNE Curncy Bid Close', 'USDJPY BGNE Curncy Bid High', 'USDJPY BGNE Curncy Bid Low', 'USDJPY BGNE Curncy Bid Number Ticks', 'USDJPY BGNE Curncy Ask Open', 'USDJPY BGNE Curncy Ask Close', 'USDJPY BGNE Curncy Ask High', 'USDJPY BGNE Curncy Ask Low', 'USDJPY BGNE Curncy Ask Number Ticks', 'GBPUSD BGNE Curncy Bid Open', 'GBPUSD BGNE Curncy Bid Close', 'GBPUSD BGNE Curncy Bid High', 'GBPUSD BGNE Curncy Bid Low', 'GBPUSD BGNE Curncy Bid Number Ticks', 'GBPUSD BGNE Curncy Ask Open', 'GBPUSD BGNE Curncy Ask Close', 'GBPUSD BGNE Curncy Ask High', 'GBPUSD BGNE Curncy Ask Low', 'GBPUSD BGNE Curncy Ask Number Ticks', 'AUDUSD BGNE Curncy Bid Open', 'AUDUSD BGNE Curncy Bid Close', 'AUDUSD BGNE Curncy Bid High', 'AUDUSD BGNE Curncy Bid Low', 'AUDUSD BGNE Curncy Bid Number Ticks', 'AUDUSD BGNE Curncy Ask Open', 'AUDUSD BGNE Curncy Ask Close', 'AUDUSD BGNE Curncy Ask High', 'AUDUSD BGNE Curncy Ask Low', 'AUDUSD BGNE Curncy Ask Number Ticks', 'USDCAD BGNE Curncy Bid Open', 'USDCAD BGNE Curncy Bid Close', 'USDCAD BGNE Curncy Bid High', 'USDCAD BGNE Curncy Bid Low', 'USDCAD BGNE Curncy Bid Number Ticks', 'USDCAD BGNE Curncy Ask Open', 'US
df = pd.read_csv(IBM_path, delimiter=';')

# Replace 0 to avoid dividing by 0 later on
df.replace(to_replace=0, method='ffill', inplace=True) 
df.drop('UXA1 Comdty Trade Open', axis=1, inplace=True)
df['Dates'] = pd.to_datetime(df['Dates'], format='%d.%m.%y %H:%M')
df.sort_values('Dates', inplace=True)
df.sort_values('Dates')
df.index = df['Dates']
df.tail()
# Out:
#                                   Dates  EURUSD BGNE Curncy Bid Open  \
# Dates
# 2021-03-22 23:10:00 2021-03-22 23:10:00                      1.19315
# 2021-03-22 23:20:00 2021-03-22 23:20:00                      1.19338
# 2021-03-22 23:30:00 2021-03-22 23:30:00                      1.19327
# 2021-03-22 23:40:00 2021-03-22 23:40:00                      1.19327
# 2021-03-22 23:50:00 2021-03-22 23:50:00                      1.19335
#
#                      EURUSD BGNE Curncy Bid Close  \
# Dates
# 2021-03-22 23:10:00                       1.19339
# 2021-03-22 23:20:00                       1.19327
# 2021-03-22 23:30:00                       1.19330
# 2021-03-22 23:40:00                       1.19335
# 2021-03-22 23:50:00                       1.19335
#
#                      EURUSD BGNE Curncy Bid High  EURUSD BGNE Curncy Bid Low  \
# Dates
# 2021-03-22 23:10:00                      1.19348                     1.19313
# 2021-03-22 23:20:00                      1.19343                     1.19326
# 2021-03-22 23:30:00                      1.19344                     1.19320
# 2021-03-22 23:40:00                      1.19345                     1.19324
# 2021-03-22 23:50:00                      1.19341                     1.19330
#
#                      EURUSD BGNE Curncy Bid Number Ticks  \
# Dates
# 2021-03-22 23:10:00                                  952
# 2021-03-22 23:20:00                                  958
# 2021-03-22 23:30:00                                 1002
# 2021-03-22 23:40:00                                 1039
# 2021-03-22 23:50:00                                 1083
#
#                      EURUSD BGNE Curncy Ask Open  \
# Dates
# 2021-03-22 23:10:00                      1.19326
# 2021-03-22 23:20:00                      1.19349
# 2021-03-22 23:30:00                      1.19336
# 2021-03-22 23:40:00                      1.19334
# 2021-03-22 23:50:00                      1.19343
#
#                      EURUSD BGNE Curncy Ask Close  \
# Dates
# 2021-03-22 23:10:00                       1.19348
# 2021-03-22 23:20:00                       1.19337
# 2021-03-22 23:30:00                       1.19333
# 2021-03-22 23:40:00                       1.19341
# 2021-03-22 23:50:00                       1.19340
#
#                      EURUSD BGNE Curncy Ask High  EURUSD BGNE Curncy Ask Low  \
# Dates
# 2021-03-22 23:10:00                      1.19355                     1.19320
# 2021-03-22 23:20:00                      1.19351                     1.19332
# 2021-03-22 23:30:00                      1.19350                     1.19325
# 2021-03-22 23:40:00                      1.19351                     1.19330
# 2021-03-22 23:50:00                      1.19348                     1.19336
#
#                      ...  G 1 Comdty Trade Open  UB1 Comdty Trade Open  \
# Dates                ...
# 2021-03-22 23:10:00  ...                 128.55                 205.64
# 2021-03-22 23:20:00  ...                 128.55                 205.64
# 2021-03-22 23:30:00  ...                 128.55                 205.64
# 2021-03-22 23:40:00  ...                 128.55                 205.64
# 2021-03-22 23:50:00  ...                 128.55                 205.64
#
#                      FF1 Comdty Trade Open  OE1 Comdty Trade Open  \
# Dates
# 2021-03-22 23:10:00                  99.93                 135.19
# 2021-03-22 23:20:00                  99.93                 135.19
# 2021-03-22 23:30:00                  99.93                 135.19
# 2021-03-22 23:40:00                  99.93                 135.19
# 2021-03-22 23:50:00                  99.93                 135.19
#
#                      TU1 Comdty Trade Open  KE1 Comdty Trade Open  \
# Dates
# 2021-03-22 23:10:00               110.4375                 110.81
# 2021-03-22 23:20:00               110.4375                 110.81
# 2021-03-22 23:30:00               110.4375                 110.81
# 2021-03-22 23:40:00               110.4375                 110.81
# 2021-03-22 23:50:00               110.4375                 110.81
#
#                      DU1 Comdty Trade Open  UXY1 Comdty Trade Open  \
# Dates
# 2021-03-22 23:10:00                112.125              144.468750
# 2021-03-22 23:20:00                112.125              144.531250
# 2021-03-22 23:30:00                112.125              144.531250
# 2021-03-22 23:40:00                112.125              144.562500
# 2021-03-22 23:50:00                112.125              144.640625
#
#                      CN1 Comdty Trade Open  KAA1 Comdty Trade Open
# Dates
# 2021-03-22 23:10:00                 140.89                  126.25
# 2021-03-22 23:20:00                 140.89                  126.25
# 2021-03-22 23:30:00                 140.89                  126.25
# 2021-03-22 23:40:00                 140.89                  126.25
# 2021-03-22 23:50:00                 140.89                  126.25
#
# [5 rows x 434 columns]

# %%
df_metrics = data_merge(data_read_dict('../data/bbg/'))
df_metrics = df_metrics.iloc[::-1, :].bfill().iloc[::-1, :]
df_metrics.shape
# Out:
# (15926, 840)

# %%
df_merged = pd.merge(df, df_metrics, left_index=True, right_index=True, how='outer')
df_merged = df_merged.loc[df_merged.index <= max(df.Dates),:]
d = pd.isna(df_metrics).any(axis=1)
df_merged = df_merged.loc[df_merged.index >= df_metrics.loc[~d].index.min()]
df_merged.loc[~pd.isna(df_merged).any(axis=1)]
# Out:
#                                   Dates  EURUSD BGNE Curncy Bid Open  \
# Dates
# 2020-11-02 08:20:00 2020-11-02 08:20:00                      1.16400
# 2020-11-02 08:30:00 2020-11-02 08:30:00                      1.16389
# 2020-11-02 08:40:00 2020-11-02 08:40:00                      1.16320
# 2020-11-02 08:50:00 2020-11-02 08:50:00                      1.16380
# 2020-11-02 09:00:00 2020-11-02 09:00:00                      1.16298
# ...                                 ...                          ...
# 2021-03-22 23:10:00 2021-03-22 23:10:00                      1.19315
# 2021-03-22 23:20:00 2021-03-22 23:20:00                      1.19338
# 2021-03-22 23:30:00 2021-03-22 23:30:00                      1.19327
# 2021-03-22 23:40:00 2021-03-22 23:40:00                      1.19327
# 2021-03-22 23:50:00 2021-03-22 23:50:00                      1.19335
#
#                      EURUSD BGNE Curncy Bid Close  \
# Dates
# 2020-11-02 08:20:00                       1.16389
# 2020-11-02 08:30:00                       1.16320
# 2020-11-02 08:40:00                       1.16386
# 2020-11-02 08:50:00                       1.16301
# 2020-11-02 09:00:00                       1.16312
# ...                                           ...
# 2021-03-22 23:10:00                       1.19339
# 2021-03-22 23:20:00                       1.19327
# 2021-03-22 23:30:00                       1.19330
# 2021-03-22 23:40:00                       1.19335
# 2021-03-22 23:50:00                       1.19335
#
#                      EURUSD BGNE Curncy Bid High  EURUSD BGNE Curncy Bid Low  \
# Dates
# 2020-11-02 08:20:00                      1.16422                     1.16371
# 2020-11-02 08:30:00                      1.16391                     1.16302
# 2020-11-02 08:40:00                      1.16389                     1.16308
# 2020-11-02 08:50:00                      1.16398                     1.16269
# 2020-11-02 09:00:00                      1.16322                     1.16251
# ...                                          ...                         ...
# 2021-03-22 23:10:00                      1.19348                     1.19313
# 2021-03-22 23:20:00                      1.19343                     1.19326
# 2021-03-22 23:30:00                      1.19344                     1.19320
# 2021-03-22 23:40:00                      1.19345                     1.19324
# 2021-03-22 23:50:00                      1.19341                     1.19330
#
#                      EURUSD BGNE Curncy Bid Number Ticks  \
# Dates
# 2020
# 2020-11-02 09:00:00         83.964706           104.763179
# ...                               ...                  ...
# 2021-03-22 23:10:00         91.595516           108.802835
# 2021-03-22 23:20:00         88.484848           108.802835
# 2021-03-22 23:30:00         82.747475           108.802835
# 2021-03-22 23:40:00         74.862915           108.802835
# 2021-03-22 23:50:00         65.439153           108.802835
#
#                      usdjpy___TRENDER_DN  usdjpy___TMAVG  usdjpy___VMAVG  \
# Dates
# 2020-11-02 08:20:00           104.576931      104.754444      104.730164
# 2020-11-02 08:30:00           104.576931      104.764444      104.733712
# 2020-11-02 08:40:00           104.576931      104.777778      104.738813
# 2020-11-02 08:50:00           104.576931      104.795556      104.746303
# 2020-11-02 09:00:00           104.576931      104.816667      104.756070
# ...                                  ...             ...             ...
# 2021-03-22 23:10:00           108.751982      108.835556      108.811932
# 2021-03-22 23:20:00           108.751982      108.826667      108.811868
# 2021-03-22 23:30:00           108.860237      108.816667      108.811405
# 2021-03-22 23:40:00           108.852871      108.808889      108.810871
# 2021-03-22 23:50:00           108.846162      108.804444      108.810824
#
#                      usdjpy___WMAVG  usdjpy___WLPR
# Dates
# 2020-11-02 08:20:00      104.762000       0.000000
# 2020-11-02 08:30:00      104.773333       0.000000
# 2020-11-02 08:40:00      104.788000      -7.692308
# 2020-11-02 08:50:00      104.812000      -5.882353
# 2020-11-02 09:00:00      104.832667       0.000000
# ...                             ...            ...
# 2021-03-22 23:10:00      108.828000     -80.000000
# 2021-03-22 23:20:00      108.820000     -80.000000
# 2021-03-22 23:30:00      108.811333    -100.000000
# 2021-03-22 23:40:00      108.805333     -83.333333
# 2021-03-22 23:50:00      108.805333     -66.666667
#
# [14701 rows x 1274 columns]

# %%
df = df_merged[:]
df.shape
# Out:
# (20254, 1274)

# %% [markdown]
# ## Plot 10min EURUSD closing prices and volatility

# %%
fig = plt.figure(figsize=(15,10))
st = fig.suptitle("EURUSD Spot Rate", fontsize=20)
st.set_y(0.92)

ax1 = fig.add_subplot(211)
# ax1.plot(df['EURUSD BGNE Curncy Bid Close'], label='EURUSD BGNE Curncy Bid Close')
ax1.plot(df['Dates'], df['EURUSD BGNE Curncy Bid Close'], label='EURUSD BGNE Curncy Bid Close')
#ax1.set_xticks(range(0, df.shape[0], 1464))
#ax1.set_xticklabels(df['Dates'].loc[::1464])
ax1.set_ylabel('Close Price', fontsize=18)
ax1.legend(loc="upper left", fontsize=12)

ax2 = fig.add_subplot(212)
# ax2.plot(df['EURUSDV1Y Curncy Trade Open'], label='EURUSDV1Y Curncy Trade Open')
ax2.plot(df['Dates'], df['EURUSDV1Y Curncy Trade Open'], label='EURUSDV1Y Curncy Trade Open')
#ax2.set_xticks(range(0, df.shape[0], 1464))
#ax2.set_xticklabels(df['Dates'].loc[::1464])
ax2.set_ylabel('EURUSDV1Y Curncy Trade Open', fontsize=18)
ax2.legend(loc="upper left", fontsize=12)

# %% [markdown]
# ## Calculate normalized percentage change of all columns

# %%
'''Calculate percentage change'''
df = df.set_index('Dates')
df.pct_change()

df.dropna(how='any', axis=0, inplace=True) # Drop all rows with NaN values

# %%
'''Normalize price columns'''
df = (df - df.mean()) / (df.max() - df.min())
df.columns[np.isnan(df).any(axis=0)]
# Out:
# Index([], dtype='object')

# %%
#df.dropna(how='any', axis=0, inplace=True) # Drop all rows with NaN values
#np.isinf(df)
#df

# %% [markdown]
# ## Create training, validation and test split

# %%
times = sorted(df.index.values)
last_10pct = sorted(df.index.values)[-int(0.1*len(times))] # Last 10% of series
last_20pct = sorted(df.index.values)[-int(0.2*len(times))] # Last 20% of series

df_train = df[(df.index < last_20pct)]  # Training data are 80% of total data
df_val = df[(df.index >= last_20pct) & (df.index < last_10pct)]
df_test = df[(df.index >= last_10pct)]

# Convert pandas columns into arrays
train_data = df_train.values
val_data = df_val.values
test_data = df_test.values
print('Training data shape: {}'.format(train_data.shape))
print('Validation data shape: {}'.format(val_data.shape))
print('Test data shape: {}'.format(test_data.shape))

df_train.head()
# Out:
# Training data shape: (11761, 1273)
# Validation data shape: (1470, 1273)
# Test data shape: (1470, 1273)
#                      EURUSD BGNE Curncy Bid Open  \
# Dates
# 2020-11-02 08:20:00                    -0.559804
# 2020-11-02 08:30:00                    -0.561302
# 2020-11-02 08:40:00                    -0.570696
# 2020-11-02 08:50:00                    -0.562527
# 2020-11-02 09:00:00                    -0.573691
#
#                      EURUSD BGNE Curncy Bid Close  \
# Dates
# 2020-11-02 08:20:00                     -0.561330
# 2020-11-02 08:30:00                     -0.570724
# 2020-11-02 08:40:00                     -0.561738
# 2020-11-02 08:50:00                     -0.573311
# 2020-11-02 09:00:00                     -0.571813
#
#                      EURUSD BGNE Curncy Bid High  EURUSD BGNE Curncy Bid Low  \
# Dates
# 2020-11-02 08:20:00                    -0.568648                   -0.554952
# 2020-11-02 08:30:00                    -0.572929                   -0.564271
# 2020-11-02 08:40:00                    -0.573205                   -0.563461
# 2020-11-02 08:50:00                    -0.571962                   -0.568728
# 2020-11-02 09:00:00                    -0.582456                   -0.571160
#
#                      EURUSD BGNE Curncy Bid Number Ticks  \
# Dates
# 2020-11-02 08:20:00                             0.069035
# 2020-11-02 08:30:00                             0.080522
# 2020-11-02 08:40:00                             0.109816
# 2020-11-02 08:50:00                             0.079948
# 2020-11-02 09:00:00                             0.101200
#
#                      EURUSD BGNE Curncy Ask Open  \
# Dates
# 2020-11-02 08:20:00                    -0.560642
# 2020-11-02 08:30:00                    -0.562140
# 2020-11-02 08:40:00                    -0.571537
# 2020-11-02 08:50:00                    -0.563093
# 2020-11-02 09:00:00                    -0.574397
#
#                      EURUSD BGNE Curncy Ask Close  \
# Dates
# 2020-11-02 08:20:00                     -0.562526
# 2020-11-02 08:30:00                     -0.571930
# 2020-11-02 08:40:00                     -0.563208
# 2020-11-02 08:50:00                     -0.574655
# 2020-11-02 09:00:00                     -0.573429
#
#                      EURUSD BGNE Curncy Ask High  EURUSD BGNE Curncy Ask Low  \
# Dates
# 2020-11-02 08:20:00                    -0.570526                   -0.556325
# 2020-11-02 08:30:00                    -0.574533                   -0.565645
# 2020-11-02 08:40:00                    -0.574810                   -0.564700
# 2020-11-02 08:50:00                    -0.573566                   -0.569968
# 2020-11-02 09:00:00                    -0.584068                   -0.572264
#
#                      EURUSD BGNE Curncy Ask Number Ticks  ...  usdjpy___TAS_K  \
# Dates                                                     ...
# 2020-11-02 08:20:00                             0.069035  ...        0.492777
# 2020-11-02 08:30:00                             0.080522  ...        0.492777
# 2020-11-02 08:40:00                             0.109816  ...        0.415854
# 2020-11-02 08:50:00                             0.079948  ...        0.433953
# 2020-11-02 09:00:00                             0.101200  ...        0.492777
#
#                      usdjpy___TAS_D  usdjpy___TAS_DS  usdjpy___TAS_DSS  \
# Dates
# 2020-11-02 08:20:00        0.286028         0.210139          0.195253
# 2020-11-02 08:30:00        0.352695         0.242083          0.214519
# 2020-11-02 08:40:00        0.387310         0.284951          0.247597
# 2020-11-02 08:50:00        0.425546         0.336358          0.290013
# 2020-11-02 09:00:00        0.465546         0.388390          0.339179
#
#                      usdjpy___TRENDER_UP  usdjpy___TRENDER_DN  usdjpy___TMAVG  \
# Dates
# 2020-11-02 08:20:00            -0.035189            -0.050749       -0.026994
# 2020-11-02 08:30:00            -0.033524            -0.050749       -0.025499
# 2020-11-02 08:40:00            -0.031907            -0.050749       -0.023506
# 2020-11-02 08:50:00            -0.030413            -0.050749       -0.020849
# 2020-11-02 09:00:00            -0.027280            -0.050749       -0.017693
#
#                      usdjpy___VMAVG  usdjpy___WMAVG  usdjpy___WLPR
# Dates
# 2020-11-02 08:20:00       -0.030783       -0.025916       0.492415
# 2020-11-02 08:30:00       -0.030244       -0.024220       0.492415
# 2020-11-02 08:40:00       -0.029469       -0.022025       0.415492
# 2020-11-02 08:50:00       -0.028331       -0.018433       0.433592
# 2020-11-02 09:00:00       -0.026848       -0.015339       0.492415
#
# [5 rows x 1273 columns]

# %% [markdown]
# ## Plot daily changes of close prices and volatility

# %%
fig = plt.figure(figsize=(15,12))
st = fig.suptitle("Data Separation", fontsize=20)
st.set_y(0.95)

###############################################################################

ax1 = fig.add_subplot(211)
ax1.plot(np.arange(train_data.shape[0]), df_train['EURUSD BGNE Curncy Bid Close'], label='Training data')

ax1.plot(np.arange(train_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]), df_val['EURUSD BGNE Curncy Bid Close'], label='Validation data')

ax1.plot(np.arange(train_data.shape[0]+val_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]+test_data.shape[0]), df_test['EURUSD BGNE Curncy Bid Close'], label='Test data')
ax1.set_xlabel('Dates')
ax1.set_ylabel('Normalized Closing Returns')
ax1.set_title("Close Price", fontsize=18)
ax1.legend(loc="best", fontsize=12)

###############################################################################

ax2 = fig.add_subplot(212)
ax2.plot(np.arange(train_data.shape[0]), df_train['EURUSDV1Y Curncy Trade Open'], label='Training data')

ax2.plot(np.arange(train_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]), df_val['EURUSDV1Y Curncy Trade Open'], label='Validation data')

ax2.plot(np.arange(train_data.shape[0]+val_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]+test_data.shape[0]), df_test['EURUSDV1Y Curncy Trade Open'], label='Test data')
ax2.set_xlabel('Dates')
ax2.set_ylabel('Normalized Volatility Changes')
ax2.set_title("Volatility", fontsize=18)
ax2.legend(loc="best", fontsize=12)

# %% [markdown]
# ## Create chunks of training, validation and test data

# %%
# Training data
X_train, y_train = [], []
for i in range(seq_len, len(train_data)):
  X_train.append(train_data[i-seq_len:i]) # Chunks of training data with a length of 128 df-rows
  y_train.append(train_data[:, 3][i]) #Value of 4th column (Close Price) of df-row 128+1
X_train, y_train = np.array(X_train), np.array(y_train)

###############################################################################

# Validation data
X_val, y_val = [], []
for i in range(seq_len, len(val_data)):
    X_val.append(val_data[i-seq_len:i])
    y_val.append(val_data[:, 3][i])
X_val, y_val = np.array(X_val), np.array(y_val)

###############################################################################

# Test data
X_test, y_test = [], []
for i in range(seq_len, len(test_data)):
    X_test.append(test_data[i-seq_len:i])
    y_test.append(test_data[:, 3][i])    
X_test, y_test = np.array(X_test), np.array(y_test)

print('Training set shape', X_train.shape, y_train.shape)
print('Validation set shape', X_val.shape, y_val.shape)
print('Testing set shape' ,X_test.shape, y_test.shape)
# Out:
# Training set shape (11633, 128, 1273) (11633,)
# Validation set shape (1342, 128, 1273) (1342,)
# Testing set shape (1342, 128, 1273) (1342,)

# %% [markdown]
# ## TimeVector

# %%
class Time2Vector(Layer):
  def __init__(self, seq_len, **kwargs):
    super(Time2Vector, self).__init__()
    self.seq_len = seq_len

  def build(self, input_shape):
    '''Initialize weights and biases with shape (batch, seq_len)'''
    self.weights_linear = self.add_weight(name='weight_linear',
                                shape=(int(self.seq_len),),
                                initializer='uniform',
                                trainable=True)
    
    self.bias_linear = self.add_weight(name='bias_linear',
                                shape=(int(self.seq_len),),
                                initializer='uniform',
                                trainable=True)
    
    self.weights_periodic = self.add_weight(name='weight_periodic',
                                shape=(int(self.seq_len),),
                                initializer='uniform',
                                trainable=True)

    self.bias_periodic = self.add_weight(name='bias_periodic',
                                shape=(int(self.seq_len),),
                                initializer='uniform',
                                trainable=True)

  def call(self, x):
    '''Calculate linear and periodic time features'''
    x = tf.math.reduce_mean(x[:,:,:4], axis=-1) 
    time_linear = self.weights_linear * x + self.bias_linear # Linear time feature
    time_linear = tf.expand_dims(time_linear, axis=-1) # Add dimension (batch, seq_len, 1)
    
    time_periodic = tf.math.sin(tf.multiply(x, self.weights_periodic) + self.bias_periodic)
    time_periodic = tf.expand_dims(time_periodic, axis=-1) # Add dimension (batch, seq_len, 1)
    return tf.concat([time_linear, time_periodic], axis=-1) # shape = (batch, seq_len, 2)
   
  def get_config(self): # Needed for saving and loading model with custom layer
    config = super().get_config().copy()
    config.update({'seq_len': self.seq_len})
    return config

# %% [markdown]
# ## Transformer

# %%
class SingleAttention(Layer):
  def __init__(self, d_k, d_v):
    super(SingleAttention, self).__init__()
    self.d_k = d_k
    self.d_v = d_v

  def build(self, input_shape):
    self.query = Dense(self.d_k, 
                       input_shape=input_shape, 
                       kernel_initializer='glorot_uniform', 
                       bias_initializer='glorot_uniform')
    
    self.key = Dense(self.d_k, 
                     input_shape=input_shape, 
                     kernel_initializer='glorot_uniform', 
                     bias_initializer='glorot_uniform')
    
    self.value = Dense(self.d_v, 
                       input_shape=input_shape, 
                       kernel_initializer='glorot_uniform', 
                       bias_initializer='glorot_uniform')

  def call(self, inputs): # inputs = (in_seq, in_seq, in_seq)
    q = self.query(inputs[0])
    k = self.key(inputs[1])

    attn_weights = tf.matmul(q, k, transpose_b=True)
    attn_weights = tf.map_fn(lambda x: x/np.sqrt(self.d_k), attn_weights)
    attn_weights = tf.nn.softmax(attn_weights, axis=-1)
    
    v = self.value(inputs[2])
    attn_out = tf.matmul(attn_weights, v)
    return attn_out    

#############################################################################

class MultiAttention(Layer):
  def __init__(self, d_k, d_v, n_heads):
    super(MultiAttention, self).__init__()
    self.d_k = d_k
    self.d_v = d_v
    self.n_heads = n_heads
    self.attn_heads = list()

  def build(self, input_shape):
    for n in range(self.n_heads):
      self.attn_heads.append(SingleAttention(self.d_k, self.d_v))  
    
    # input_shape[0]=(batch, seq_len, 7), input_shape[0][-1]=7 
    self.linear = Dense(input_shape[0][-1], 
                        input_shape=input_shape, 
                        kernel_initializer='glorot_uniform', 
                        bias_initializer='glorot_uniform')

  def call(self, inputs):
    attn = [self.attn_heads[i](inputs) for i in range(self.n_heads)]
    concat_attn = tf.concat(attn, axis=-1)
    multi_linear = self.linear(concat_attn)
    return multi_linear   

#############################################################################

class TransformerEncoder(Layer):
  def __init__(self, d_k, d_v, n_heads, ff_dim, dropout=0.4, **kwargs):
    super(TransformerEncoder, self).__init__()
    self.d_k = d_k
    self.d_v = d_v
    self.n_heads = n_heads
    self.ff_dim = ff_dim
    self.attn_heads = list()
    self.dropout_rate = dropout

  def build(self, input_shape):
    self.attn_multi = MultiAttention(self.d_k, self.d_v, self.n_heads)
    self.attn_dropout = Dropout(self.dropout_rate)
    self.attn_normalize = LayerNormalization(input_shape=input_shape, epsilon=1e-6)

    self.ff_conv1D_1 = Conv1D(filters=self.ff_dim, kernel_size=1, activation='relu')
    # input_shape[0]=(batch, seq_len, 7), input_shape[0][-1] = 7 
    self.ff_conv1D_2 = Conv1D(filters=input_shape[0][-1], kernel_size=1) 
    self.ff_dropout = Dropout(self.dropout_rate)
    self.ff_normalize = LayerNormalization(input_shape=input_shape, epsilon=1e-6)    
  
  def call(self, inputs): # inputs = (in_seq, in_seq, in_seq)
    attn_layer = self.attn_multi(inputs)
    attn_layer = self.attn_dropout(attn_layer)
    attn_layer = self.attn_normalize(inputs[0] + attn_layer)

    ff_layer = self.ff_conv1D_1(attn_layer)
    ff_layer = self.ff_conv1D_2(ff_layer)
    ff_layer = self.ff_dropout(ff_layer)
    ff_layer = self.ff_normalize(inputs[0] + ff_layer)
    return ff_layer 

  def get_config(self): # Needed for saving and loading model with custom layer
    config = super().get_config().copy()
    config.update({'d_k': self.d_k,
                   'd_v': self.d_v,
                   'n_heads': self.n_heads,
                   'ff_dim': self.ff_dim,
                   'attn_heads': self.attn_heads,
                   'dropout_rate': self.dropout_rate})
    return config

# %% [markdown]
# ## Model

# %%
def create_model(input_shape):
  '''Initialize time and transformer layers'''
  time_embedding = Time2Vector(seq_len)
  attn_layer1 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)
  attn_layer2 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)
  attn_layer3 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)

  '''Construct model'''
  in_seq = Input(shape=(seq_len, input_shape))
  x = time_embedding(in_seq)
  x = Concatenate(axis=-1)([in_seq, x])
#   x = Concatenate(axis=-1)([Dense(64)(in_seq), x])
  x = attn_layer1((x, x, x))
  x = attn_layer2((x, x, x))
  x = attn_layer3((x, x, x))
  x = GlobalAveragePooling1D(data_format='channels_first')(x)
  x = Dropout(0.4)(x)
  x = Dense(64, activation='relu')(x)
  x = Dropout(0.4)(x)
  out = Dense(1, activation='linear')(x)

  model = Model(inputs=in_seq, outputs=out)
  opt = keras.optimizers.Adam(learning_rate=0.0001)
  model.compile(loss='mse', optimizer=opt, metrics=['mae', 'mape'])
  return model


model = create_model(df.shape[1])
model.summary()

callback = tf.keras.callbacks.ModelCheckpoint('../content/Transformer+TimeEmbedding-Copy5{epoch}.hdf5', 
                                              monitor='val_loss', 
                                              save_best_only=True, verbose=1)

es = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=8,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)


if True: 
    history = model.fit(X_train, y_train,
                        batch_size=batch_size, 
                        epochs=500, 
                        callbacks=[callback],
                        validation_data=(X_val, y_val))  
    with open('../content/history-Copy5.pkl', 'wb') as f:
        pickle.dump(history.history, f)
# else    
#    model.save(.h5)
#    model.load
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 1273)]  0
# __________________________________________________________________________________________________
# time2_vector (Time2Vector)      (None, 128, 2)       512         input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 128, 1275)    0           input_1[0][0]
#                                                                  time2_vector[0][0]
# __________________________________________________________________________________________________
# transformer_encoder (Transforme (None, 128, 1275)    16337122    concatenate[0][0]
#                                                                  concatenate[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# transformer_encoder_1 (Transfor (None, 128, 1275)    16337122    transformer_encoder[0][0]
#                                                                  transformer_encoder[0][0]
#                                                                  transformer_encoder[0][0]
# __________________________________________________________________________________________________
# transformer_encoder_2 (Transfor (None, 128, 1275)    16337122    transformer_encoder_1[0][0]
#                                                                  transformer_encoder_1[0][0]
#                                                                  transformer_encoder_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 128)          0           transformer_encoder_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128)          0           global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           8256        dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            65          dropout_1[0][0]
# ==================================================================================================
# Total params: 49,020,199
# Trainable params: 49,020,199
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/500
# 364/364 [==============================] - 595s 2s/step - loss: 0.0260 - mae: 0.1232 - mape: 94.9685 - val_loss: 0.0572 - val_mae: 0.2053 - val_mape: 1770.4296
#
# Epoch 00001: val_loss improved from inf to 0.05718, saving model to content/Transformer+TimeEmbedding-Copy51.hdf5
# Epoch 2/500
# 364/364 [==============================] - 569s 2s/step - loss: 0.0022 - mae: 0.0349 - mape: 51.2539 - val_loss: 0.1002 - val_mae: 0.2707 - val_mape: 2462.7134
#
# Epoch 00002: val_loss did not improve from 0.05718
# Epoch 3/500
# 364/364 [==============================] - 569s 2s/step - loss: 0.0018 - mae: 0.0313 - mape: 40.4745 - val_loss: 0.0776 - val_mae: 0.2355 - val_mape: 2026.4614
#
# Epoch 00003: val_loss did not improve from 0.05718
# Epoch 4/500
# 364/364 [==============================] - 561s 2s/step - loss: 0.0017 - mae: 0.0296 - mape: 35.4029 - val_loss: 0.1208 - val_mae: 0.3058 - val_mape: 2755.4202
#
# Epoch 00004: val_loss did not improve from 0.05718
# Epoch 5/500
# 364/364 [==============================] - 552s 2s/step - loss: 0.0016 - mae: 0.0289 - mape: 41.0964 - val_loss: 0.1284 - val_mae: 0.3087 - val_mape: 2775.6145
#
# Epoch 00005: val_loss did not improve from 0.05718
# Epoch 6/500
# 364/364 [==============================] - 580s 2s/step - loss: 0.0015 - mae: 0.0278 - mape: 31.9529 - val_loss: 0.1319 - val_mae: 0.3123 - val_mape: 2976.2976
#
# Epoch 00006: val_loss did not improve from 0.05718
# Epoch 7/500
# 364/364 [==============================] - 569s 2s/step - loss: 0.0015 - mae: 0.0282 - mape: 38.2834 - val_loss: 0.1409 - val_mae: 0.3227 - val_mape: 3092.2004
#
# Epoch 00007: val_loss did not improve from 0.05718
# Epoch 8/500
# 364/364 [==============================] - 682s 2s/step - loss: 0.0014 - mae: 0.0276 - mape: 33.0618 - val_loss: 0.2479 - val_mae: 0.4572 - val_mape: 3567.3125
#
# Epoch 00008: val_loss did not improve from 0.05718
# Epoch 9/500
# 364/364 [==============================] - 777s 2s/step - loss: 0.0014 - mae: 0.0265 - mape: 36.4516 - val_loss: 0.2575 - val_mae: 0.4668 - val_mape: 3584.5398
#
# Epoch 00009: val_loss did not improve from 0.05718
# Epoch 10/500
# 364/364 [==============================] - 786s 2s/step - loss: 0.0015 - mae: 0.0277 - mape: 35.4772 - val_loss: 0.2648 - val_mae: 0.4774 - val_mape: 3589.5332
#
# Epoch 00010: val_loss did not improve from 0.05718
# Epoch 11/500
# 364/364 [==============================] - 730s 2s/step - loss: 0.0015 - mae: 0.0273 - mape: 36.8961 - val_loss: 0.1899 - val_mae: 0.3760 - val_mape: 3483.7542
#
# Epoch 00011: val_loss did not improve from 0.05718
# Epoch 12/500
# 364/364 [==============================] - 778s 2s/step - loss: 0.0014 - mae: 0.0265 - mape: 30.6186 - val_loss: 0.0489 - val_mae: 0.1972 - val_mape: 1745.7784
#
# Epoch 00012: val_loss improved from 0.05718 to 0.04893, saving model to content/Transformer+TimeEmbedding-Copy512.hdf5
# Epoch 13/500
# 364/364 [==============================] - 789s 2s/step - loss: 0.0014 - mae: 0.0266 - mape: 37.4901 - val_loss: 0.1442 - val_mae: 0.3425 - val_mape: 2332.0042
#
# Epoch 00013: val_loss did not improve from 0.04893
# Epoch 14/500
# 364/364 [==============================] - 766s 2s/step - loss: 0.0014 - mae: 0.0264 - mape: 33.7650 - val_loss: 0.1756 - val_mae: 0.3850 - val_mape: 2747.6462
#
# Epoch 00014: val_loss did not improve from 0.04893
# Epoch 15/500
# 364/364 [==============================] - 770s 2s/step - loss: 0.0013 - mae: 0.0257 - mape: 30.1733 - val_loss: 0.2138 - val_mae: 0.4240 - val_mape: 3408.8203
#
# Epoch 00015: val_loss did not improve from 0.04893
# Epoch 16/500
# 364/364 [==============================] - 771s 2s/step - loss: 0.0013 - mae: 0.0260 - mape: 29.9948 - val_loss: 0.1879 - val_mae: 0.3973 - val_mape: 3232.5325
#
# Epoch 00016: val_loss did not improve from 0.04893
# Epoch 17/500
# 364/364 [==============================] - 786s 2s/step - loss: 0.0013 - mae: 0.0255 - mape: 32.2925 - val_loss: 0.1564 - val_mae: 0.3636 - val_mape: 2889.2666
#
# Epoch 00017: val_loss did not improve from 0.04893
# Epoch 18/500
# 364/364 [==============================] - 780s 2s/step - loss: 0.0013 - mae: 0.0264 - mape: 28.7102 - val_loss: 0.1804 - val_mae: 0.4023 - val_mape: 2952.1406
#
# Epoch 00018: val_loss did not improve from 0.04893
# Epoch 19/500
# 364/364 [==============================] - 786s 2s/step - loss: 0.0012 - mae: 0.0252 - mape: 29.2193 - val_loss: 0.1861 - val_mae: 0.4031 - val_mape: 3042.6326
#
# Epoch 00019: val_loss did not improve from 0.04893
# Epoch 20/500
# 364/364 [==============================] - 757s 2s/step - loss: 0.0013 - mae: 0.0258 - mape: 29.2306 - val_loss: 0.0100 - val_mae: 0.0781 - val_mape: 383.7978
#
# Epoch 00020: val_loss improved from 0.04893 to 0.00998, saving model to content/Transformer+TimeEmbedding-Copy520.hdf5
# Epoch 21/500
# 364/364 [==============================] - 767s 2s/step - loss: 0.0013 - mae: 0.0257 - mape: 33.2163 - val_loss: 0.1069 - val_mae: 0.2881 - val_mape: 2347.0708
# Epoch 00021: val_loss did not improve from 0.00998
# Epoch 22/500
# 364/364 [==============================] - 766s 2s/step - loss: 0.0012 - mae: 0.0247 - mape: 32.8636 - val_loss: 0.0227 - val_mae: 0.1336 - val_mape: 1016.8054
#
# Epoch 00022: val_loss did not improve from 0.00998
# Epoch 23/500
# 364/364 [==============================] - 786s 2s/step - loss: 0.0012 - mae: 0.0243 - mape: 25.4130 - val_loss: 0.0731 - val_mae: 0.2393 - val_mape: 1993.3933
#
# Epoch 00023: val_loss did not improve from 0.00998
# Epoch 24/500
# 364/364 [==============================] - 785s 2s/step - loss: 0.0013 - mae: 0.0255 - mape: 43.5552 - val_loss: 0.0570 - val_mae: 0.1990 - val_mape: 1952.7238
#
# Epoch 00024: val_loss did not improve from 0.00998
# Epoch 25/500
# 364/364 [==============================] - 780s 2s/step - loss: 0.0014 - mae: 0.0257 - mape: 27.9653 - val_loss: 0.0023 - val_mae: 0.0382 - val_mape: 173.3391
#
# Epoch 00025: val_loss improved from 0.00998 to 0.00231, saving model to content/Transformer+TimeEmbedding-Copy525.hdf5
# Epoch 26/500
#
# Epoch 00038: val_loss did not improve from 0.00210
# Epoch 39/500
# 364/364 [==============================] - 782s 2s/step - loss: 0.0012 - mae: 0.0241 - mape: 33.1637 - val_loss: 0.0299 - val_mae: 0.1506 - val_mape: 1340.5750
#
# Epoch 00039: val_loss did not improve from 0.00210
# Epoch 40/500
# 364/364 [==============================] - 777s 2s/step - loss: 0.0012 - mae: 0.0241 - mape: 25.6106 - val_loss: 0.0472 - val_mae: 0.1873 - val_mape: 1523.6570
#
# Epoch 00040: val_loss did not improve from 0.00210
# Epoch 41/500
# 364/364 [==============================] - 790s 2s/step - loss: 0.0012 - mae: 0.0242 - mape: 25.3056 - val_loss: 0.0802 - val_mae: 0.2181 - val_mape: 1251.3616
#
# Epoch 00041: val_loss did not improve from 0.00210
# Epoch 42/500
# 364/364 [==============================] - 787s 2s/step - loss: 0.0012 - mae: 0.0241 - mape: 27.3492 - val_loss: 0.0811 - val_mae: 0.2200 - val_mape: 1287.8993
#
# Epoch 00042: val_loss did not improve from 0.00210
# Epoch 43/500
# 364/364 [==============================] - 797s 2s/step - loss: 0.0011 - mae: 0.0240 - mape: 28.2373 - val_loss: 0.0708 - val_mae: 0.2076 - val_mape: 1197.8113
#
# Epoch 00043: val_loss did not improve from 0.00210
# Epoch 44/500
# 364/364 [==============================] - 783s 2s/step - loss: 0.0012 - mae: 0.0241 - mape: 27.1084 - val_loss: 0.0379 - val_mae: 0.1492 - val_mape: 857.5062
#
# Epoch 00044: val_loss did not improve from 0.00210
# Epoch 45/500
# 364/364 [==============================] - 771s 2s/step - loss: 0.0012 - mae: 0.0242 - mape: 26.4137 - val_loss: 0.0233 - val_mae: 0.1287 - val_mape: 1078.8002
#
# Epoch 00045: val_loss did not improve from 0.00210
# Epoch 46/500
# 364/364 [==============================] - 782s 2s/step - loss: 0.0012 - mae: 0.0240 - mape: 27.4484 - val_loss: 0.0751 - val_mae: 0.2399 - val_mape: 1817.1976
#
# Epoch 00046: val_loss did not improve from 0.00210
# Epoch 47/500
# 364/364 [==============================] - 782s 2s/step - loss: 0.0012 - mae: 0.0243 - mape: 27.6784 - val_loss: 0.0893 - val_mae: 0.2290 - val_mape: 1186.8685
#
# Epoch 00047: val_loss did not improve from 0.00210
# Epoch 48/500
# 364/364 [==============================] - 789s 2s/step - loss: 0.0012 - mae: 0.0243 - mape: 29.4910 - val_loss: 0.0680 - val_mae: 0.2028 - val_mape: 1106.8225
#
# Epoch 00048: val_loss did not improve from 0.00210
# Epoch 49/500
# 364/364 [==============================] - 786s 2s/step - loss: 0.0012 - mae: 0.0246 - mape: 29.8661 - val_loss: 0.1094 - val_mae: 0.2509 - val_mape: 1827.0057
#
# Epoch 00049: val_loss did not improve from 0.00210
# Epoch 50/500
# 364/364 [==============================] - 786s 2s/step - loss: 0.0012 - mae: 0.0240 - mape: 30.6560 - val_loss: 0.1001 - val_mae: 0.2447 - val_mape: 1900.9242
#
# Epoch 00050: val_loss did not improve from 0.00210
# Epoch 51/500
# 364/364 [==============================] - 760s 2s/step - loss: 0.0012 - mae: 0.0242 - mape: 34.8555 - val_loss: 0.0441 - val_mae: 0.1548 - val_mape: 806.3228
#
# Epoch 00051: val_loss did not improve from 0.00210
# Epoch 52/500
# 364/364 [==============================] - 775s 2s/step - loss: 0.0012 - mae: 0.0238 - mape: 28.6376 - val_loss: 0.0545 - val_mae: 0.1559 - val_mape: 576.7767
#
# Epoch 00052: val_loss did not improve from 0.00210
# Epoch 53/500
# 364/364 [==============================] - 796s 2s/step - loss: 0.0012 - mae: 0.0242 - mape: 27.5571 - val_loss: 0.0614 - val_mae: 0.1769 - val_mape: 781.5981
#
# Epoch 00053: val_loss did not improve from 0.00210
# Epoch 54/500
# 364/364 [==============================] - 790s 2s/step - loss: 0.0011 - mae: 0.0233 - mape: 26.2200 - val_loss: 0.0491 - val_mae: 0.1433 - val_mape: 479.2990
#
# Epoch 00054: val_loss did not improve from 0.00210
# Epoch 55/500
# 364/364 [==============================] - 795s 2s/step - loss: 0.0012 - mae: 0.0239 - mape: 26.3423 - val_loss: 0.0346 - val_mae: 0.1200 - val_mape: 496.6435
#
# Epoch 00055: val_loss did not improve from 0.00210
# Epoch 56/500
# 364/364 [==============================] - 774s 2s/step - loss: 0.0011 - mae: 0.0234 - mape: 25.0648 - val_loss: 0.0371 - val_mae: 0.1260 - val_mape: 511.2377
#
# Epoch 00056: val_loss did not improve from 0.00210
# Epoch 57/500
# 364/364 [==============================] - 786s 2s/step - loss: 0.0011 - mae: 0.0235 - mape: 23.8200 - val_loss: 0.0161 - val_mae: 0.1032 - val_mape: 678.9570
# Epoch 00057: val_loss did not improve from 0.00210
# Epoch 58/500
# 364/364 [==============================] - 781s 2s/step - loss: 0.0011 - mae: 0.0238 - mape: 30.2535 - val_loss: 0.0226 - val_mae: 0.1260 - val_mape: 943.7712
#
# Epoch 00058: val_loss did not improve from 0.00210
# Epoch 59/500
# 364/364 [==============================] - 794s 2s/step - loss: 0.0011 - mae: 0.0230 - mape: 27.8474 - val_loss: 0.0156 - val_mae: 0.1001 - val_mape: 655.7037
#
# Epoch 00059: val_loss did not improve from 0.00210
# Epoch 60/500
# 364/364 [==============================] - 776s 2s/step - loss: 0.0012 - mae: 0.0236 - mape: 28.5216 - val_loss: 0.0083 - val_mae: 0.0733 - val_mape: 519.7452
#
# Epoch 00060: val_loss did not improve from 0.00210
# Epoch 61/500
# 364/364 [==============================] - 801s 2s/step - loss: 0.0012 - mae: 0.0241 - mape: 27.0231 - val_loss: 0.0056 - val_mae: 0.0581 - val_mape: 428.8403
#
# Epoch 00061: val_loss did not improve from 0.00210
# Epoch 62/500
# 364/364 [==============================] - 796s 2s/step - loss: 0.0011 - mae: 0.0233 - mape: 23.5880 - val_loss: 0.0049 - val_mae: 0.0505 - val_mape: 288.9378
#
# Epoch 00062: val_loss did not improve from 0.00210
# Epoch 63/500
# 364/364 [==============================] - 777s 2s/step - loss: 0.0011 - mae: 0.0234 - mape: 25.4426 - val_loss: 0.0156 - val_mae: 0.0840 - val_mape: 329.4248
#
# Epoch 00063: val_loss did not improve from 0.00210
# Epoch 64/500
#
# Epoch 00076: val_loss did not improve from 0.00210
# Epoch 77/500
# 364/364 [==============================] - 627s 2s/step - loss: 0.0011 - mae: 0.0235 - mape: 26.2394 - val_loss: 0.0536 - val_mae: 0.1562 - val_mape: 632.8905
#
# Epoch 00077: val_loss did not improve from 0.00210
# Epoch 78/500
# 364/364 [==============================] - 610s 2s/step - loss: 0.0011 - mae: 0.0235 - mape: 28.2388 - val_loss: 0.0620 - val_mae: 0.1871 - val_mape: 914.4486
#
# Epoch 00078: val_loss did not improve from 0.00210
# Epoch 79/500
# 364/364 [==============================] - 610s 2s/step - loss: 0.0011 - mae: 0.0235 - mape: 30.6773 - val_loss: 0.0579 - val_mae: 0.1716 - val_mape: 693.0515
#
# Epoch 00079: val_loss did not improve from 0.00210
# Epoch 80/500
# 364/364 [==============================] - 578s 2s/step - loss: 0.0011 - mae: 0.0230 - mape: 34.6945 - val_loss: 0.0525 - val_mae: 0.1610 - val_mape: 603.4175
#
# Epoch 00080: val_loss did not improve from 0.00210
# Epoch 81/500
# 364/364 [==============================] - 591s 2s/step - loss: 0.0011 - mae: 0.0239 - mape: 30.3940 - val_loss: 0.0559 - val_mae: 0.1564 - val_mape: 587.4828
#
# Epoch 00081: val_loss did not improve from 0.00210
# Epoch 82/500
# 364/364 [==============================] - 599s 2s/step - loss: 0.0011 - mae: 0.0233 - mape: 23.4604 - val_loss: 0.0561 - val_mae: 0.1580 - val_mape: 637.4238
#
# Epoch 00082: val_loss did not improve from 0.00210
# Epoch 83/500
# 364/364 [==============================] - 570s 2s/step - loss: 0.0011 - mae: 0.0230 - mape: 27.6681 - val_loss: 0.0942 - val_mae: 0.2359 - val_mape: 1197.1494
#
# Epoch 00083: val_loss did not improve from 0.00210
# Epoch 84/500
# 364/364 [==============================] - 594s 2s/step - loss: 0.0011 - mae: 0.0232 - mape: 25.6161 - val_loss: 0.0540 - val_mae: 0.1642 - val_mape: 679.9727
#
# Epoch 00084: val_loss did not improve from 0.00210
# Epoch 85/500
# 364/364 [==============================] - 601s 2s/step - loss: 0.0011 - mae: 0.0229 - mape: 27.2568 - val_loss: 0.0495 - val_mae: 0.1560 - val_mape: 672.4510
#
# Epoch 00085: val_loss did not improve from 0.00210
# Epoch 86/500
# 364/364 [==============================] - 597s 2s/step - loss: 0.0011 - mae: 0.0233 - mape: 27.7279 - val_loss: 0.0316 - val_mae: 0.1365 - val_mape: 650.5562
#
# Epoch 00086: val_loss did not improve from 0.00210
# Epoch 87/500
# 364/364 [==============================] - 599s 2s/step - loss: 0.0011 - mae: 0.0234 - mape: 26.7564 - val_loss: 0.0146 - val_mae: 0.0939 - val_mape: 668.5683
#
# Epoch 00087: val_loss did not improve from 0.00210
# Epoch 88/500
# 364/364 [==============================] - 603s 2s/step - loss: 0.0011 - mae: 0.0229 - mape: 29.3794 - val_loss: 0.0292 - val_mae: 0.1291 - val_mape: 643.8489
#
# Epoch 00088: val_loss did not improve from 0.00210
# Epoch 89/500
# 364/364 [==============================] - 601s 2s/step - loss: 0.0011 - mae: 0.0231 - mape: 28.6281 - val_loss: 0.0551 - val_mae: 0.1659 - val_mape: 689.7485
#
# Epoch 00089: val_loss did not improve from 0.00210
# Epoch 90/500
# 364/364 [==============================] - 592s 2s/step - loss: 0.0011 - mae: 0.0228 - mape: 24.7665 - val_loss: 0.0491 - val_mae: 0.1515 - val_mape: 615.5810
#
# Epoch 00090: val_loss did not improve from 0.00210
# Epoch 91/500
# 364/364 [==============================] - 588s 2s/step - loss: 0.0012 - mae: 0.0240 - mape: 27.0512 - val_loss: 0.0168 - val_mae: 0.1092 - val_mape: 713.1923
#
# Epoch 00091: val_loss did not improve from 0.00210
# Epoch 92/500
# 364/364 [==============================] - 571s 2s/step - loss: 0.0011 - mae: 0.0233 - mape: 30.7641 - val_loss: 0.0142 - val_mae: 0.1004 - val_mape: 643.9604
#
# Epoch 00092: val_loss did not improve from 0.00210
# Epoch 93/500
# 364/364 [==============================] - 580s 2s/step - loss: 0.0011 - mae: 0.0228 - mape: 23.1098 - val_loss: 0.0151 - val_mae: 0.1065 - val_mape: 679.0717
#
# Epoch 00093: val_loss did not improve from 0.00210
# Epoch 94/500
# 364/364 [==============================] - 574s 2s/step - loss: 0.0011 - mae: 0.0233 - mape: 36.0266 - val_loss: 0.0215 - val_mae: 0.1281 - val_mape: 746.6074
#
# Epoch 00094: val_loss did not improve from 0.00210
# Epoch 95/500
# 364/364 [==============================] - 577s 2s/step - loss: 0.0011 - mae: 0.0232 - mape: 23.8269 - val_loss: 0.0329 - val_mae: 0.1585 - val_mape: 963.2829
#
# Epoch 00095: val_loss did not improve from 0.00210
# Epoch 96/500
# 364/364 [==============================] - 576s 2s/step - loss: 0.0011 - mae: 0.0233 - mape: 25.0277 - val_loss: 0.0254 - val_mae: 0.1423 - val_mape: 829.5528
#
# Epoch 00096: val_loss did not improve from 0.00210
# Epoch 97/500
# 364/364 [==============================] - 568s 2s/step - loss: 0.0011 - mae: 0.0225 - mape: 25.0175 - val_loss: 0.0226 - val_mae: 0.1297 - val_mape: 819.8657
#
# Epoch 00097: val_loss did not improve from 0.00210
# Epoch 98/500
# 364/364 [==============================] - 584s 2s/step - loss: 0.0011 - mae: 0.0229 - mape: 23.9127 - val_loss: 0.0134 - val_mae: 0.0934 - val_mape: 586.7964
#
# Epoch 00098: val_loss did not improve from 0.00210
# Epoch 99/500
# 364/364 [==============================] - 595s 2s/step - loss: 0.0011 - mae: 0.0227 - mape: 33.2310 - val_loss: 0.0089 - val_mae: 0.0794 - val_mape: 592.5701
#
# Epoch 00099: val_loss did not improve from 0.00210
# Epoch 100/500
# 364/364 [==============================] - 593s 2s/step - loss: 0.0012 - mae: 0.0230 - mape: 23.4043 - val_loss: 0.0139 - val_mae: 0.0994 - val_mape: 638.3478
#
# Epoch 00100: val_loss did not improve from 0.00210
# Epoch 101/500
# 364/364 [==============================] - 606s 2s/step - loss: 0.0011 - mae: 0.0227 - mape: 30.6629 - val_loss: 0.0166 - val_mae: 0.1051 - val_mape: 620.9830
#
# Epoch 00101: val_loss did not improve from 0.00210
# Epoch 102/500
# 364/364 [==============================] - 571s 2s/step - loss: 0.0011 - mae: 0.0229 - mape: 25.5063 - val_loss: 0.0151 - val_mae: 0.1017 - val_mape: 602.4578
#
# Epoch 00102: val_loss did not improve from 0.00210
# Epoch 103/500
# 364/364 [==============================] - 588s 2s/step - loss: 0.0011 - mae: 0.0227 - mape: 24.0394 - val_loss: 0.0178 - val_mae: 0.1102 - val_mape: 683.9637
#
# Epoch 00103: val_loss did not improve from 0.00210
# Epoch 104/500
# 364/364 [==============================] - 597s 2s/step - loss: 0.0011 - mae: 0.0227 - mape: 23.8196 - val_loss: 0.0144 - val_mae: 0.0966 - val_mape: 638.1328
#
# Epoch 00104: val_loss did not improve from 0.00210
# Epoch 105/500
# 364/364 [==============================] - 603s 2s/step - loss: 0.0010 - mae: 0.0224 - mape: 25.0571 - val_loss: 0.0059 - val_mae: 0.0591 - val_mape: 465.0961
#
# Epoch 00105: val_loss did not improve from 0.00210
# Epoch 106/500
# 364/364 [==============================] - 603s 2s/step - loss: 0.0011 - mae: 0.0235 - mape: 27.3967 - val_loss: 0.0242 - val_mae: 0.1377 - val_mape: 883.2744
#
# Epoch 00106: val_loss did not improve from 0.00210
# Epoch 107/500
# 364/364 [==============================] - 614s 2s/step - loss: 0.0011 - mae: 0.0228 - mape: 25.3108 - val_loss: 0.0269 - val_mae: 0.1454 - val_mape: 992.4570
#
# Epoch 00107: val_loss did not improve from 0.00210
# Epoch 108/500
# 364/364 [==============================] - 593s 2s/step - loss: 0.0011 - mae: 0.0226 - mape: 22.8066 - val_loss: 0.0282 - val_mae: 0.1249 - val_mape: 643.2878
#
# Epoch 00108: val_loss did not improve from 0.00210
# Epoch 109/500
# 364/364 [==============================] - 450s 1s/step - loss: 0.0011 - mae: 0.0226 - mape: 24.5380 - val_loss: 0.0171 - val_mae: 0.1150 - val_mape: 781.2420
#
# Epoch 00109: val_loss did not improve from 0.00210
# Epoch 110/500
# 364/364 [==============================] - 385s 1s/step - loss: 0.0011 - mae: 0.0224 - mape: 26.5864 - val_loss: 0.0126 - val_mae: 0.0988 - val_mape: 681.0153
#
# Epoch 00110: val_loss did not improve from 0.00210
# Epoch 111/500
# 364/364 [==============================] - 378s 1s/step - loss: 0.0011 - mae: 0.0231 - mape: 27.5118 - val_loss: 0.0106 - val_mae: 0.0859 - val_mape: 612.5142
#
# Epoch 00111: val_loss did not improve from 0.00210
# Epoch 112/500
# 364/364 [==============================] - 394s 1s/step - loss: 0.0011 - mae: 0.0229 - mape: 24.0217 - val_loss: 0.0187 - val_mae: 0.1184 - val_mape: 837.0632
#
# Epoch 00112: val_loss did not improve from 0.00210
# Epoch 113/500
# 364/364 [==============================] - 388s 1s/step - loss: 0.0010 - mae: 0.0225 - mape: 27.5810 - val_loss: 0.0243 - val_mae: 0.1365 - val_mape: 913.5580
#
# Epoch 00113: val_loss did not improve from 0.00210
# Epoch 114/500
# 364/364 [==============================] - 377s 1s/step - loss: 0.0010 - mae: 0.0222 - mape: 22.9106 - val_loss: 0.0311 - val_mae: 0.1551 - val_mape: 1064.8236
#
# Epoch 00114: val_loss did not improve from 0.00210
# Epoch 115/500
# 364/364 [==============================] - 390s 1s/step - loss: 0.0011 - mae: 0.0232 - mape: 26.6021 - val_loss: 0.0291 - val_mae: 0.1494 - val_mape: 1007.3794
#
# Epoch 00115: val_loss did not improve from 0.00210
# Epoch 116/500
# 364/364 [==============================] - 394s 1s/step - loss: 0.0011 - mae: 0.0224 - mape: 27.5537 - val_loss: 0.0268 - val_mae: 0.1442 - val_mape: 932.9361
#
# Epoch 00116: val_loss did not improve from 0.00210
# Epoch 117/500
# 364/364 [==============================] - 388s 1s/step - loss: 0.0011 - mae: 0.0233 - mape: 26.4321 - val_loss: 0.0219 - val_mae: 0.1285 - val_mape: 964.8619
#
# Epoch 00117: val_loss did not improve from 0.00210
# Epoch 118/500
# 364/364 [==============================] - 387s 1s/step - loss: 0.0011 - mae: 0.0231 - mape: 24.5613 - val_loss: 0.0245 - val_mae: 0.1351 - val_mape: 911.6918
#
# Epoch 00118: val_loss did not improve from 0.00210
# Epoch 119/500
# 364/364 [==============================] - 390s 1s/step - loss: 0.0011 - mae: 0.0230 - mape: 25.4035 - val_loss: 0.0145 - val_mae: 0.1055 - val_mape: 655.9575
#
# Epoch 00119: val_loss did not improve from 0.00210
# Epoch 120/500
# 364/364 [==============================] - 392s 1s/step - loss: 0.0011 - mae: 0.0230 - mape: 24.7027 - val_loss: 0.0092 - val_mae: 0.0796 - val_mape: 569.2409
#
# Epoch 00120: val_loss did not improve from 0.00210
# Epoch 121/500
# 364/364 [==============================] - 383s 1s/step - loss: 0.0010 - mae: 0.0225 - mape: 26.6277 - val_loss: 0.0166 - val_mae: 0.1057 - val_mape: 695.8677
#
# Epoch 00121: val_loss did not improve from 0.00210
# Epoch 122/500
# 364/364 [==============================] - 383s 1s/step - loss: 0.0011 - mae: 0.0228 - mape: 24.7601 - val_loss: 0.0181 - val_mae: 0.1164 - val_mape: 750.3858
#
# Epoch 00122: val_loss did not improve from 0.00210
# Epoch 123/500
# 364/364 [==============================] - 377s 1s/step - loss: 0.0011 - mae: 0.0223 - mape: 25.3034 - val_loss: 0.0188 - val_mae: 0.1189 - val_mape: 714.1597
#
# Epoch 00123: val_loss did not improve from 0.00210
# Epoch 124/500
# 364/364 [==============================] - 392s 1s/step - loss: 0.0011 - mae: 0.0229 - mape: 29.6229 - val_loss: 0.0161 - val_mae: 0.1077 - val_mape: 691.9527
#
# Epoch 00124: val_loss did not improve from 0.00210
# Epoch 125/500
# 364/364 [==============================] - 394s 1s/step - loss: 0.0011 - mae: 0.0229 - mape: 27.8835 - val_loss: 0.0154 - val_mae: 0.1028 - val_mape: 708.6158
#
# Epoch 00125: val_loss did not improve from 0.00210
# Epoch 126/500
# 364/364 [==============================] - 391s 1s/step - loss: 0.0011 - mae: 0.0232 - mape: 27.5341 - val_loss: 0.0114 - val_mae: 0.0882 - val_mape: 634.5246
#
# Epoch 00126: val_loss did not improve from 0.00210
# Epoch 127/500
# 364/364 [==============================] - 398s 1s/step - loss: 0.0011 - mae: 0.0228 - mape: 29.9954 - val_loss: 0.0098 - val_mae: 0.0836 - val_mape: 616.7564
#
# Epoch 00127: val_loss did not improve from 0.00210
# Epoch 128/500
# 364/364 [==============================] - 395s 1s/step - loss: 0.0011 - mae: 0.0227 - mape: 26.6116 - val_loss: 0.0127 - val_mae: 0.0947 - val_mape: 685.1416
#
# Epoch 00128: val_loss did not improve from 0.00210
# Epoch 129/500
# 364/364 [==============================] - 397s 1s/step - loss: 0.0011 - mae: 0.0232 - mape: 26.3278 - val_loss: 0.0172 - val_mae: 0.1106 - val_mape: 857.3373
#
# Epoch 00129: val_loss did not improve from 0.00210
# Epoch 130/500
# 364/364 [==============================] - 394s 1s/step - loss: 0.0011 - mae: 0.0230 - mape: 24.8526 - val_loss: 0.0216 - val_mae: 0.1267 - val_mape: 806.1934
#
# Epoch 00130: val_loss did not improve from 0.00210
# Epoch 131/500
# 364/364 [==============================] - 396s 1s/step - loss: 0.0010 - mae: 0.0227 - mape: 27.7383 - val_loss: 0.0057 - val_mae: 0.0529 - val_mape: 446.9681
#
# Epoch 00131: val_loss did not improve from 0.00210
# Epoch 132/500
# 364/364 [==============================] - 389s 1s/step - loss: 0.0011 - mae: 0.0231 - mape: 24.6727 - val_loss: 0.0094 - val_mae: 0.0797 - val_mape: 648.3599
#
# Epoch 00132: val_loss did not improve from 0.00210
# Epoch 133/500
# 364/364 [==============================] - 397s 1s/step - loss: 0.0011 - mae: 0.0226 - mape: 24.5856 - val_loss: 0.0055 - val_mae: 0.0587 - val_mape: 556.5460
#
# Epoch 00133: val_loss did not improve from 0.00210
# Epoch 134/500
# 364/364 [==============================] - 392s 1s/step - loss: 0.0011 - mae: 0.0228 - mape: 25.4975 - val_loss: 0.0061 - val_mae: 0.0611 - val_mape: 525.7723
#
# Epoch 00134: val_loss did not improve from 0.00210
# Epoch 135/500
# 364/364 [==============================] - 395s 1s/step - loss: 0.0011 - mae: 0.0228 - mape: 27.8377 - val_loss: 0.0122 - val_mae: 0.0792 - val_mape: 550.4998
#
# Epoch 00135: val_loss did not improve from 0.00210
# Epoch 136/500
# 364/364 [==============================] - 399s 1s/step - loss: 0.0011 - mae: 0.0225 - mape: 22.0595 - val_loss: 0.0278 - val_mae: 0.1205 - val_mape: 719.0903
#
# Epoch 00136: val_loss did not improve from 0.00210
# Epoch 137/500
# 364/364 [==============================] - 389s 1s/step - loss: 0.0011 - mae: 0.0229 - mape: 24.0519 - val_loss: 0.0288 - val_mae: 0.1309 - val_mape: 807.9940
#
# Epoch 00137: val_loss did not improve from 0.00210
# Epoch 138/500
# 364/364 [==============================] - 386s 1s/step - loss: 0.0010 - mae: 0.0225 - mape: 26.9347 - val_loss: 0.0332 - val_mae: 0.1408 - val_mape: 820.4931
#
# Epoch 00138: val_loss did not improve from 0.00210
# Epoch 139/500
# 364/364 [==============================] - 384s 1s/step - loss: 0.0010 - mae: 0.0224 - mape: 22.8703 - val_loss: 0.0274 - val_mae: 0.1311 - val_mape: 868.3877
#
# Epoch 00139: val_loss did not improve from 0.00210
# Epoch 140/500
# 364/364 [==============================] - 384s 1s/step - loss: 0.0011 - mae: 0.0229 - mape: 27.0012 - val_loss: 0.0342 - val_mae: 0.1485 - val_mape: 917.6609
#
# Epoch 00140: val_loss did not improve from 0.00210
# Epoch 141/500
# 364/364 [==============================] - 373s 1s/step - loss: 0.0010 - mae: 0.0226 - mape: 24.9767 - val_loss: 0.0308 - val_mae: 0.1266 - val_mape: 725.1161
#
# Epoch 00141: val_loss did not improve from 0.00210
# Epoch 142/500
# 364/364 [==============================] - 380s 1s/step - loss: 0.0010 - mae: 0.0222 - mape: 27.3121 - val_loss: 0.0294 - val_mae: 0.1300 - val_mape: 785.8849
#
# Epoch 00142: val_loss did not improve from 0.00210
# Epoch 143/500
# 364/364 [==============================] - 381s 1s/step - loss: 0.0011 - mae: 0.0227 - mape: 27.9136 - val_loss: 0.0146 - val_mae: 0.0954 - val_mape: 713.1646
#
# Epoch 00143: val_loss did not improve from 0.00210
# Epoch 144/500
# 364/364 [==============================] - 388s 1s/step - loss: 0.0011 - mae: 0.0224 - mape: 25.8848 - val_loss: 0.0128 - val_mae: 0.0961 - val_mape: 736.6027
#
# Epoch 00144: val_loss did not improve from 0.00210
# Epoch 145/500
# 364/364 [==============================] - 370s 1s/step - loss: 0.0011 - mae: 0.0231 - mape: 26.8196 - val_loss: 0.0210 - val_mae: 0.1100 - val_mape: 728.3318
#
# Epoch 00145: val_loss did not improve from 0.00210
# Epoch 146/500
# 364/364 [==============================] - 357s 980ms/step - loss: 0.0010 - mae: 0.0222 - mape: 27.1975 - val_loss: 0.0157 - val_mae: 0.1034 - val_mape: 856.8315
#
# Epoch 00146: val_loss did not improve from 0.00210
# Epoch 147/500
# 364/364 [==============================] - 375s 1s/step - loss: 0.0011 - mae: 0.0225 - mape: 22.3670 - val_loss: 0.0138 - val_mae: 0.0931 - val_mape: 782.9954
#
# Epoch 00147: val_loss did not improve from 0.00210
# Epoch 148/500
# 364/364 [==============================] - 371s 1s/step - loss: 0.0011 - mae: 0.0229 - mape: 25.9686 - val_loss: 0.0399 - val_mae: 0.1433 - val_mape: 729.2934
#
# Epoch 00148: val_loss did not improve from 0.00210
# Epoch 149/500
# 364/364 [==============================] - 380s 1s/step - loss: 0.0010 - mae: 0.0222 - mape: 27.1455 - val_loss: 0.0524 - val_mae: 0.1616 - val_mape: 607.5751
#
# Epoch 00149: val_loss did not improve from 0.00210
# Epoch 150/500
# 364/364 [==============================] - 390s 1s/step - loss: 0.0011 - mae: 0.0229 - mape: 27.9993 - val_loss: 0.0512 - val_mae: 0.1500 - val_mape: 592.0455
#
# Epoch 00150: val_loss did not improve from 0.00210
# Epoch 151/500
# 364/364 [==============================] - 388s 1s/step - loss: 0.0011 - mae: 0.0231 - mape: 26.2741 - val_loss: 0.0616 - val_mae: 0.1721 - val_mape: 715.7580
#
# Epoch 00151: val_loss did not improve from 0.00210
# Epoch 152/500
# 364/364 [==============================] - 386s 1s/step - loss: 0.0010 - mae: 0.0224 - mape: 25.3594 - val_loss: 0.0792 - val_mae: 0.2269 - val_mape: 1389.8706
#
# Epoch 00152: val_loss did not improve from 0.00210
# Epoch 153/500
# 364/364 [==============================] - 387s 1s/step - loss: 0.0011 - mae: 0.0227 - mape: 26.8882 - val_loss: 0.0937 - val_mae: 0.2304 - val_mape: 1231.7887
#
# Epoch 00153: val_loss did not improve from 0.00210
# Epoch 154/500
# 364/364 [==============================] - 388s 1s/step - loss: 0.0010 - mae: 0.0221 - mape: 27.8294 - val_loss: 0.0751 - val_mae: 0.1921 - val_mape: 805.4727
#
# Epoch 00154: val_loss did not improve from 0.00210
# Epoch 155/500
# 364/364 [==============================] - 391s 1s/step - loss: 0.0011 - mae: 0.0222 - mape: 26.2494 - val_loss: 0.0878 - val_mae: 0.2109 - val_mape: 991.5981
#
# Epoch 00155: val_loss did not improve from 0.00210
# Epoch 156/500
# 364/364 [==============================] - 385s 1s/step - loss: 0.0011 - mae: 0.0224 - mape: 26.8152 - val_loss: 0.0979 - val_mae: 0.2637 - val_mape: 1741.8917
#
# Epoch 00156: val_loss did not improve from 0.00210
# Epoch 157/500
# 364/364 [==============================] - 380s 1s/step - loss: 0.0011 - mae: 0.0224 - mape: 26.0726 - val_loss: 0.0519 - val_mae: 0.1627 - val_mape: 846.3549
#
# Epoch 00157: val_loss did not improve from 0.00210
# Epoch 158/500
# 364/364 [==============================] - 386s 1s/step - loss: 0.0011 - mae: 0.0227 - mape: 29.9965 - val_loss: 0.0568 - val_mae: 0.1617 - val_mape: 597.1147
#
# Epoch 00158: val_loss did not improve from 0.00210
# Epoch 159/500
# 364/364 [==============================] - 392s 1s/step - loss: 0.0011 - mae: 0.0228 - mape: 27.1720 - val_loss: 0.0667 - val_mae: 0.1716 - val_mape: 610.0022
#
# Epoch 00159: val_loss did not improve from 0.00210
# Epoch 160/500
# 364/364 [==============================] - 380s 1s/step - loss: 0.0010 - mae: 0.0223 - mape: 25.1145 - val_loss: 0.0357 - val_mae: 0.1246 - val_mape: 546.6319
#
# Epoch 00160: val_loss did not improve from 0.00210
# Epoch 161/500
# 364/364 [==============================] - 387s 1s/step - loss: 0.0011 - mae: 0.0227 - mape: 35.2463 - val_loss: 0.0740 - val_mae: 0.1947 - val_mape: 863.4405
#
# Epoch 00161: val_loss did not improve from 0.00210
# Epoch 162/500
# 364/364 [==============================] - 389s 1s/step - loss: 0.0010 - mae: 0.0225 - mape: 29.8873 - val_loss: 0.0569 - val_mae: 0.1812 - val_mape: 985.4172
#
# Epoch 00162: val_loss did not improve from 0.00210
# Epoch 163/500
# 364/364 [==============================] - 382s 1s/step - loss: 0.0011 - mae: 0.0225 - mape: 28.0405 - val_loss: 0.0882 - val_mae: 0.2197 - val_mape: 1025.1875
#
# Epoch 00163: val_loss did not improve from 0.00210
# Epoch 164/500
# 364/364 [==============================] - 381s 1s/step - loss: 0.0010 - mae: 0.0222 - mape: 32.9136 - val_loss: 0.1020 - val_mae: 0.2374 - val_mape: 1110.0236
#
# Epoch 00164: val_loss did not improve from 0.00210
# Epoch 165/500
# 364/364 [==============================] - 406s 1s/step - loss: 0.0011 - mae: 0.0226 - mape: 28.1633 - val_loss: 0.1010 - val_mae: 0.2300 - val_mape: 1133.8535
#
# Epoch 00165: val_loss did not improve from 0.00210
# Epoch 166/500
# 364/364 [==============================] - 589s 2s/step - loss: 0.0010 - mae: 0.0220 - mape: 22.8194 - val_loss: 0.0934 - val_mae: 0.2159 - val_mape: 959.1494
#
# Epoch 00166: val_loss did not improve from 0.00210
# Epoch 167/500
# 364/364 [==============================] - 617s 2s/step - loss: 9.8956e-04 - mae: 0.0219 - mape: 25.0202 - val_loss: 0.0904 - val_mae: 0.2197 - val_mape: 1028.2489
#
# Epoch 00167: val_loss did not improve from 0.00210
# Epoch 168/500
# 364/364 [==============================] - 731s 2s/step - loss: 0.0010 - mae: 0.0222 - mape: 32.5325 - val_loss: 0.0994 - val_mae: 0.2361 - val_mape: 1248.4912
#
# Epoch 00168: val_loss did not improve from 0.00210
# Epoch 169/500
# 364/364 [==============================] - 865s 2s/step - loss: 0.0011 - mae: 0.0223 - mape: 28.2902 - val_loss: 0.1379 - val_mae: 0.3159 - val_mape: 2156.4790
#
# Epoch 00169: val_loss did not improve from 0.00210
# Epoch 170/500
# 364/364 [==============================] - 862s 2s/step - loss: 0.0011 - mae: 0.0231 - mape: 27.9487 - val_loss: 0.1172 - val_mae: 0.2764 - val_mape: 1760.8174
#
# Epoch 00170: val_loss did not improve from 0.00210
# Epoch 171/500
# 364/364 [==============================] - 851s 2s/step - loss: 0.0011 - mae: 0.0228 - mape: 32.2177 - val_loss: 0.1007 - val_mae: 0.2396 - val_mape: 1319.3079
#
# Epoch 00171: val_loss did not improve from 0.00210
# Epoch 172/500
# 364/364 [==============================] - 859s 2s/step - loss: 0.0011 - mae: 0.0227 - mape: 31.1536 - val_loss: 0.0879 - val_mae: 0.2428 - val_mape: 1541.9059
#
# Epoch 00172: val_loss did not improve from 0.00210
# Epoch 173/500
# 364/364 [==============================] - 852s 2s/step - loss: 0.0011 - mae: 0.0229 - mape: 27.3245 - val_loss: 0.1211 - val_mae: 0.3085 - val_mape: 2113.9512
#
# Epoch 00173: val_loss did not improve from 0.00210
# Epoch 174/500
# 364/364 [==============================] - 845s 2s/step - loss: 0.0011 - mae: 0.0229 - mape: 28.5735 - val_loss: 0.0860 - val_mae: 0.2258 - val_mape: 1250.8969
#
# Epoch 00174: val_loss did not improve from 0.00210
# Epoch 175/500
# 364/364 [==============================] - 855s 2s/step - loss: 0.0011 - mae: 0.0227 - mape: 24.1044 - val_loss: 0.0456 - val_mae: 0.1674 - val_mape: 1093.2349
#
# Epoch 00175: val_loss did not improve from 0.00210
# Epoch 176/500
# 364/364 [==============================] - 884s 2s/step - loss: 0.0011 - mae: 0.0227 - mape: 26.4321 - val_loss: 0.0198 - val_mae: 0.1183 - val_mape: 802.9612
#
# Epoch 00176: val_loss did not improve from 0.00210
# Epoch 177/500
# 364/364 [==============================] - 843s 2s/step - loss: 0.0010 - mae: 0.0222 - mape: 26.3557 - val_loss: 0.0288 - val_mae: 0.1339 - val_mape: 909.8757
#
# Epoch 00177: val_loss did not improve from 0.00210
# Epoch 178/500
# 364/364 [==============================] - 847s 2s/step - loss: 0.0010 - mae: 0.0226 - mape: 28.9443 - val_loss: 0.0351 - val_mae: 0.1530 - val_mape: 1033.7922
#
# Epoch 00178: val_loss did not improve from 0.00210
# Epoch 179/500
# 364/364 [==============================] - 893s 2s/step - loss: 0.0011 - mae: 0.0228 - mape: 28.4039 - val_loss: 0.0380 - val_mae: 0.1610 - val_mape: 1134.5168
#
# Epoch 00179: val_loss did not improve from 0.00210
# Epoch 180/500
# 364/364 [==============================] - 864s 2s/step - loss: 0.0010 - mae: 0.0224 - mape: 25.2807 - val_loss: 0.0474 - val_mae: 0.1732 - val_mape: 1077.1553
#
# Epoch 00180: val_loss did not improve from 0.00210
# Epoch 181/500
# 364/364 [==============================] - 877s 2s/step - loss: 0.0011 - mae: 0.0225 - mape: 26.5123 - val_loss: 0.0507 - val_mae: 0.1815 - val_mape: 1123.7729
#
# Epoch 00181: val_loss did not improve from 0.00210
# Epoch 182/500
# 364/364 [==============================] - 869s 2s/step - loss: 0.0011 - mae: 0.0223 - mape: 23.6829 - val_loss: 0.0339 - val_mae: 0.1477 - val_mape: 995.3605
#
# Epoch 00182: val_loss did not improve from 0.00210
# Epoch 183/500
# 364/364 [==============================] - 877s 2s/step - loss: 0.0011 - mae: 0.0226 - mape: 30.6018 - val_loss: 0.0417 - val_mae: 0.1665 - val_mape: 1117.6815
#
# Epoch 00183: val_loss did not improve from 0.00210
# Epoch 184/500
# 364/364 [==============================] - 877s 2s/step - loss: 9.9372e-04 - mae: 0.0220 - mape: 26.4930 - val_loss: 0.0552 - val_mae: 0.1811 - val_mape: 995.9186
#
# Epoch 00184: val_loss did not improve from 0.00210
# Epoch 185/500
# 364/364 [==============================] - 842s 2s/step - loss: 0.0011 - mae: 0.0227 - mape: 28.8401 - val_loss: 0.0573 - val_mae: 0.1884 - val_mape: 1195.4373
#
# Epoch 00185: val_loss did not improve from 0.00210
# Epoch 186/500
# 364/364 [==============================] - 880s 2s/step - loss: 0.0010 - mae: 0.0225 - mape: 28.0636 - val_loss: 0.0851 - val_mae: 0.2208 - val_mape: 1193.3209
#
# Epoch 00186: val_loss did not improve from 0.00210
# Epoch 187/500
# 364/364 [==============================] - 898s 2s/step - loss: 0.0011 - mae: 0.0224 - mape: 25.3989 - val_loss: 0.0559 - val_mae: 0.1736 - val_mape: 873.1695
#
# Epoch 00187: val_loss did not improve from 0.00210
# Epoch 188/500
# 364/364 [==============================] - 878s 2s/step - loss: 0.0011 - mae: 0.0226 - mape: 28.9275 - val_loss: 0.0958 - val_mae: 0.2317 - val_mape: 1019.5124
#
# Epoch 00188: val_loss did not improve from 0.00210
# Epoch 189/500
# 364/364 [==============================] - 909s 2s/step - loss: 0.0010 - mae: 0.0224 - mape: 27.2347 - val_loss: 0.0665 - val_mae: 0.1968 - val_mape: 936.2661
#
# Epoch 00189: val_loss did not improve from 0.00210
# Epoch 190/500
# 364/364 [==============================] - 899s 2s/step - loss: 0.0010 - mae: 0.0220 - mape: 27.1133 - val_loss: 0.0819 - val_mae: 0.2283 - val_mape: 1410.4017
#
# Epoch 00190: val_loss did not improve from 0.00210
# Epoch 191/500
# 364/364 [==============================] - 872s 2s/step - loss: 0.0011 - mae: 0.0230 - mape: 26.3081 - val_loss: 0.0571 - val_mae: 0.1839 - val_mape: 1133.8798
#
# Epoch 00191: val_loss did not improve from 0.00210
# Epoch 192/500
# 364/364 [==============================] - 891s 2s/step - loss: 0.0011 - mae: 0.0224 - mape: 24.2102 - val_loss: 0.0842 - val_mae: 0.2438 - val_mape: 1589.6527
#
# Epoch 00192: val_loss did not improve from 0.00210
# Epoch 193/500
# 364/364 [==============================] - 897s 2s/step - loss: 0.0010 - mae: 0.0224 - mape: 24.6496 - val_loss: 0.0905 - val_mae: 0.2374 - val_mape: 1361.9368
#
# Epoch 00193: val_loss did not improve from 0.00210
# Epoch 194/500
# 364/364 [==============================] - 894s 2s/step - loss: 0.0011 - mae: 0.0226 - mape: 27.7274 - val_loss: 0.0733 - val_mae: 0.2114 - val_mape: 1153.7566
#
# Epoch 00194: val_loss did not improve from 0.00210
# Epoch 195/500
# 364/364 [==============================] - 897s 2s/step - loss: 0.0010 - mae: 0.0222 - mape: 25.9723 - val_loss: 0.0646 - val_mae: 0.1922 - val_mape: 1041.5770
#
# Epoch 00195: val_loss did not improve from 0.00210
# Epoch 196/500
# 364/364 [==============================] - 871s 2s/step - loss: 0.0010 - mae: 0.0219 - mape: 25.3330 - val_loss: 0.0396 - val_mae: 0.1542 - val_mape: 940.8633
#
# Epoch 00196: val_loss did not improve from 0.00210
# Epoch 197/500
# 364/364 [==============================] - 856s 2s/step - loss: 0.0011 - mae: 0.0229 - mape: 28.0963 - val_loss: 0.0348 - val_mae: 0.1420 - val_mape: 811.2819
#
# Epoch 00197: val_loss did not improve from 0.00210
# ...
#
# Epoch 00430: val_loss did not improve from 0.00210
# Epoch 431/500
# 364/364 [==============================] - 374s 1s/step - loss: 9.5989e-04 - mae: 0.0212 - mape: 27.7923 - val_loss: 0.0199 - val_mae: 0.1164 - val_mape: 725.1805
#
# Epoch 00431: val_loss did not improve from 0.00210
# Epoch 432/500
# 364/364 [==============================] - 378s 1s/step - loss: 0.0011 - mae: 0.0222 - mape: 31.4528 - val_loss: 0.0160 - val_mae: 0.1042 - val_mape: 592.5931
#
# Epoch 00432: val_loss did not improve from 0.00210
# Epoch 433/500
# 364/364 [==============================] - 376s 1s/step - loss: 9.5727e-04 - mae: 0.0210 - mape: 28.1219 - val_loss: 0.0153 - val_mae: 0.1033 - val_mape: 518.0665
#
# Epoch 00433: val_loss did not improve from 0.00210
# Epoch 434/500
# 364/364 [==============================] - 377s 1s/step - loss: 0.0011 - mae: 0.0226 - mape: 27.8788 - val_loss: 0.0147 - val_mae: 0.0977 - val_mape: 523.9860
#
# Epoch 00434: val_loss did not improve from 0.00210
# Epoch 435/500
# 364/364 [==============================] - 379s 1s/step - loss: 9.7253e-04 - mae: 0.0214 - mape: 31.0056 - val_loss: 0.0115 - val_mae: 0.0890 - val_mape: 543.7188
#
# Epoch 00435: val_loss did not improve from 0.00210
# Epoch 436/500
# 364/364 [==============================] - 372s 1s/step - loss: 0.0010 - mae: 0.0220 - mape: 27.1046 - val_loss: 0.0161 - val_mae: 0.1034 - val_mape: 545.7873
#
# Epoch 00436: val_loss did not improve from 0.00210
# Epoch 437/500
# 364/364 [==============================] - 371s 1s/step - loss: 0.0010 - mae: 0.0222 - mape: 33.7053 - val_loss: 0.0185 - val_mae: 0.1099 - val_mape: 526.5827
#
# Epoch 00437: val_loss did not improve from 0.00210
# Epoch 438/500
# 364/364 [==============================] - 374s 1s/step - loss: 0.0010 - mae: 0.0219 - mape: 26.8806 - val_loss: 0.0171 - val_mae: 0.1067 - val_mape: 580.4537
#
# Epoch 00438: val_loss did not improve from 0.00210
# Epoch 439/500
# 364/364 [==============================] - 379s 1s/step - loss: 9.9423e-04 - mae: 0.0217 - mape: 28.9980 - val_loss: 0.0119 - val_mae: 0.0931 - val_mape: 532.0104
#
# Epoch 00439: val_loss did not improve from 0.00210
# Epoch 440/500
# 364/364 [==============================] - 387s 1s/step - loss: 9.7682e-04 - mae: 0.0215 - mape: 30.5348 - val_loss: 0.0116 - val_mae: 0.0905 - val_mape: 476.3423
#
# Epoch 00440: val_loss did not improve from 0.00210
# Epoch 441/500
# 364/364 [==============================] - 380s 1s/step - loss: 9.9633e-04 - mae: 0.0217 - mape: 30.4336 - val_loss: 0.0134 - val_mae: 0.0972 - val_mape: 511.0921
#
# Epoch 00441: val_loss did not improve from 0.00210
# Epoch 442/500
# 364/364 [==============================] - 378s 1s/step - loss: 9.5997e-04 - mae: 0.0214 - mape: 24.5511 - val_loss: 0.0206 - val_mae: 0.1176 - val_mape: 672.5516
#
# Epoch 00442: val_loss did not improve from 0.00210
# Epoch 443/500
# 364/364 [==============================] - 384s 1s/step - loss: 0.0011 - mae: 0.0222 - mape: 25.3275 - val_loss: 0.0171 - val_mae: 0.1092 - val_mape: 620.5822
#
# Epoch 00443: val_loss did not improve from 0.00210
# Epoch 444/500
# 364/364 [==============================] - 382s 1s/step - loss: 0.0011 - mae: 0.0223 - mape: 27.2529 - val_loss: 0.0177 - val_mae: 0.1091 - val_mape: 531.2297
#
# Epoch 00444: val_loss did not improve from 0.00210
# Epoch 445/500
# 364/364 [==============================] - 444s 1s/step - loss: 0.0011 - mae: 0.0220 - mape: 32.0513 - val_loss: 0.0195 - val_mae: 0.1127 - val_mape: 678.3224
#
# Epoch 00445: val_loss did not improve from 0.00210
# Epoch 446/500
# 364/364 [==============================] - 450s 1s/step - loss: 0.0010 - mae: 0.0218 - mape: 38.0048 - val_loss: 0.0147 - val_mae: 0.0994 - val_mape: 547.2198
#
# Epoch 00446: val_loss did not improve from 0.00210
# Epoch 447/500
# 364/364 [==============================] - 419s 1s/step - loss: 9.9702e-04 - mae: 0.0217 - mape: 25.5912 - val_loss: 0.0168 - val_mae: 0.1078 - val_mape: 676.3737
#
# Epoch 00447: val_loss did not improve from 0.00210
# Epoch 448/500
# 364/364 [==============================] - 414s 1s/step - loss: 0.0010 - mae: 0.0220 - mape: 28.0206 - val_loss: 0.0147 - val_mae: 0.1002 - val_mape: 532.5484
#
# Epoch 00448: val_loss did not improve from 0.00210
# Epoch 449/500
# 364/364 [==============================] - 430s 1s/step - loss: 0.0010 - mae: 0.0218 - mape: 29.6479 - val_loss: 0.0126 - val_mae: 0.0932 - val_mape: 504.5720
#
# Epoch 00449: val_loss did not improve from 0.00210
# Epoch 450/500
# 364/364 [==============================] - 385s 1s/step - loss: 0.0010 - mae: 0.0221 - mape: 28.2535 - val_loss: 0.0163 - val_mae: 0.1056 - val_mape: 558.1188
#
# Epoch 00450: val_loss did not improve from 0.00210
# Epoch 451/500
# 364/364 [==============================] - 380s 1s/step - loss: 0.0010 - mae: 0.0219 - mape: 34.1789 - val_loss: 0.0161 - val_mae: 0.1089 - val_mape: 629.8771
#
# Epoch 00451: val_loss did not improve from 0.00210
# Epoch 452/500
# 364/364 [==============================] - 384s 1s/step - loss: 9.9174e-04 - mae: 0.0215 - mape: 28.5270 - val_loss: 0.0141 - val_mae: 0.1021 - val_mape: 622.8715
#
# Epoch 00452: val_loss did not improve from 0.00210
# Epoch 453/500
# 364/364 [==============================] - 384s 1s/step - loss: 0.0011 - mae: 0.0222 - mape: 28.9407 - val_loss: 0.0154 - val_mae: 0.1046 - val_mape: 592.8943
#
# Epoch 00453: val_loss did not improve from 0.00210
# Epoch 454/500
# 364/364 [==============================] - 386s 1s/step - loss: 0.0010 - mae: 0.0222 - mape: 29.0660 - val_loss: 0.0126 - val_mae: 0.0949 - val_mape: 544.8143
#
# Epoch 00454: val_loss did not improve from 0.00210
# Epoch 455/500
# 364/364 [==============================] - 395s 1s/step - loss: 9.8721e-04 - mae: 0.0218 - mape: 30.6670 - val_loss: 0.0176 - val_mae: 0.1120 - val_mape: 673.7950
#
# Epoch 00455: val_loss did not improve from 0.00210
# Epoch 456/500
# 364/364 [==============================] - 437s 1s/step - loss: 0.0011 - mae: 0.0219 - mape: 26.8387 - val_loss: 0.0145 - val_mae: 0.1033 - val_mape: 654.7936
#
# Epoch 00456: val_loss did not improve from 0.00210
# Epoch 457/500
# 364/364 [==============================] - 431s 1s/step - loss: 0.0010 - mae: 0.0219 - mape: 27.8921 - val_loss: 0.0190 - val_mae: 0.1146 - val_mape: 603.5670
#
# Epoch 00457: val_loss did not improve from 0.00210
# Epoch 458/500
# 364/364 [==============================] - 395s 1s/step - loss: 0.0010 - mae: 0.0218 - mape: 31.7392 - val_loss: 0.0148 - val_mae: 0.1019 - val_mape: 512.6728
#
# Epoch 00458: val_loss did not improve from 0.00210
# Epoch 459/500
# 364/364 [==============================] - 386s 1s/step - loss: 0.0011 - mae: 0.0225 - mape: 29.6087 - val_loss: 0.0167 - val_mae: 0.1070 - val_mape: 590.9291
#
# Epoch 00459: val_loss did not improve from 0.00210
# Epoch 460/500
# 364/364 [==============================] - 458s 1s/step - loss: 9.9142e-04 - mae: 0.0216 - mape: 28.1377 - val_loss: 0.0094 - val_mae: 0.0810 - val_mape: 442.1166
#
# Epoch 00460: val_loss did not improve from 0.00210
# Epoch 461/500
# 364/364 [==============================] - 448s 1s/step - loss: 9.4120e-04 - mae: 0.0210 - mape: 23.7582 - val_loss: 0.0130 - val_mae: 0.0950 - val_mape: 530.5248
#
# Epoch 00461: val_loss did not improve from 0.00210
# Epoch 462/500
# 364/364 [==============================] - 430s 1s/step - loss: 9.7231e-04 - mae: 0.0216 - mape: 25.6768 - val_loss: 0.0150 - val_mae: 0.0998 - val_mape: 528.2158
#
# Epoch 00462: val_loss did not improve from 0.00210
# Epoch 463/500
# 364/364 [==============================] - 453s 1s/step - loss: 0.0010 - mae: 0.0219 - mape: 27.5054 - val_loss: 0.0121 - val_mae: 0.0909 - val_mape: 497.7653
#
# Epoch 00463: val_loss did not improve from 0.00210
# Epoch 464/500
# 364/364 [==============================] - 420s 1s/step - loss: 9.9288e-04 - mae: 0.0217 - mape: 30.0634 - val_loss: 0.0135 - val_mae: 0.0974 - val_mape: 506.0695
#
# Epoch 00464: val_loss did not improve from 0.00210
# Epoch 465/500
# 364/364 [==============================] - 413s 1s/step - loss: 0.0011 - mae: 0.0224 - mape: 24.1069 - val_loss: 0.0125 - val_mae: 0.0962 - val_mape: 608.4471
#
# Epoch 00465: val_loss did not improve from 0.00210
# Epoch 466/500
# 364/364 [==============================] - 442s 1s/step - loss: 9.7557e-04 - mae: 0.0215 - mape: 25.3777 - val_loss: 0.0118 - val_mae: 0.0917 - val_mape: 482.8730
#
# Epoch 00466: val_loss did not improve from 0.00210
# Epoch 467/500
# 364/364 [==============================] - 419s 1s/step - loss: 0.0010 - mae: 0.0219 - mape: 27.9165 - val_loss: 0.0114 - val_mae: 0.0906 - val_mape: 479.9557
#
# Epoch 00467: val_loss did not improve from 0.00210
# Epoch 468/500
# 364/364 [==============================] - 433s 1s/step - loss: 0.0010 - mae: 0.0218 - mape: 25.8383 - val_loss: 0.0113 - val_mae: 0.0903 - val_mape: 496.2645
#
# Epoch 00468: val_loss did not improve from 0.00210
# Epoch 469/500
# 364/364 [==============================] - 408s 1s/step - loss: 0.0011 - mae: 0.0221 - mape: 32.9224 - val_loss: 0.0133 - val_mae: 0.0966 - val_mape: 508.2558
#
# Epoch 00469: val_loss did not improve from 0.00210
# Epoch 470/500
# 364/364 [==============================] - 450s 1s/step - loss: 9.7480e-04 - mae: 0.0213 - mape: 27.2560 - val_loss: 0.0150 - val_mae: 0.1032 - val_mape: 591.4637
#
# Epoch 00470: val_loss did not improve from 0.00210
# Epoch 471/500
# 364/364 [==============================] - 455s 1s/step - loss: 9.9245e-04 - mae: 0.0216 - mape: 30.0051 - val_loss: 0.0160 - val_mae: 0.1062 - val_mape: 566.2374
#
# Epoch 00471: val_loss did not improve from 0.00210
# Epoch 472/500
# 364/364 [==============================] - 459s 1s/step - loss: 0.0010 - mae: 0.0219 - mape: 26.6831 - val_loss: 0.0176 - val_mae: 0.1081 - val_mape: 565.9934
#
# Epoch 00472: val_loss did not improve from 0.00210
# Epoch 473/500
# 364/364 [==============================] - 458s 1s/step - loss: 9.8794e-04 - mae: 0.0216 - mape: 26.6328 - val_loss: 0.0235 - val_mae: 0.1267 - val_mape: 811.7659
#
# Epoch 00473: val_loss did not improve from 0.00210
# Epoch 474/500
# 364/364 [==============================] - 438s 1s/step - loss: 9.7581e-04 - mae: 0.0213 - mape: 31.0563 - val_loss: 0.0156 - val_mae: 0.1027 - val_mape: 517.8714
#
# Epoch 00474: val_loss did not improve from 0.00210
# Epoch 475/500
# 364/364 [==============================] - 373s 1s/step - loss: 0.0010 - mae: 0.0215 - mape: 28.5587 - val_loss: 0.0175 - val_mae: 0.1097 - val_mape: 575.6749
#
# Epoch 00475: val_loss did not improve from 0.00210
# Epoch 476/500
# 364/364 [==============================] - 381s 1s/step - loss: 0.0011 - mae: 0.0224 - mape: 28.7606 - val_loss: 0.0154 - val_mae: 0.1035 - val_mape: 587.1324
#
# Epoch 00476: val_loss did not improve from 0.00210
# Epoch 477/500
# 364/364 [==============================] - 375s 1s/step - loss: 9.7374e-04 - mae: 0.0215 - mape: 34.7390 - val_loss: 0.0176 - val_mae: 0.1097 - val_mape: 622.0432
#
# Epoch 00477: val_loss did not improve from 0.00210
# Epoch 478/500
# 364/364 [==============================] - 367s 1s/step - loss: 0.0011 - mae: 0.0223 - mape: 25.3019 - val_loss: 0.0138 - val_mae: 0.0980 - val_mape: 671.7177
#
# Epoch 00478: val_loss did not improve from 0.00210
# Epoch 479/500
# 364/364 [==============================] - 375s 1s/step - loss: 0.0010 - mae: 0.0219 - mape: 35.5216 - val_loss: 0.0142 - val_mae: 0.1025 - val_mape: 645.6718
#
# Epoch 00479: val_loss did not improve from 0.00210
# Epoch 480/500
# 364/364 [==============================] - 369s 1s/step - loss: 0.0010 - mae: 0.0218 - mape: 31.7297 - val_loss: 0.0192 - val_mae: 0.1164 - val_mape: 796.6974
#
# Epoch 00480: val_loss did not improve from 0.00210
# Epoch 481/500
# 364/364 [==============================] - 370s 1s/step - loss: 9.8648e-04 - mae: 0.0217 - mape: 25.5005 - val_loss: 0.0205 - val_mae: 0.1185 - val_mape: 615.1583
#
# Epoch 00481: val_loss did not improve from 0.00210
# Epoch 482/500
# 364/364 [==============================] - 373s 1s/step - loss: 9.7780e-04 - mae: 0.0215 - mape: 28.0164 - val_loss: 0.0164 - val_mae: 0.1048 - val_mape: 604.6177
#
# Epoch 00482: val_loss did not improve from 0.00210
# Epoch 483/500
# 364/364 [==============================] - 377s 1s/step - loss: 0.0011 - mae: 0.0224 - mape: 26.3191 - val_loss: 0.0197 - val_mae: 0.1145 - val_mape: 597.8407
#
# Epoch 00483: val_loss did not improve from 0.00210
# Epoch 484/500
# 364/364 [==============================] - 372s 1s/step - loss: 0.0010 - mae: 0.0219 - mape: 32.9618 - val_loss: 0.0161 - val_mae: 0.1049 - val_mape: 591.7285
#
# Epoch 00484: val_loss did not improve from 0.00210
# Epoch 485/500
# 364/364 [==============================] - 370s 1s/step - loss: 0.0010 - mae: 0.0220 - mape: 25.4140 - val_loss: 0.0179 - val_mae: 0.1103 - val_mape: 800.5062
#
# Epoch 00485: val_loss did not improve from 0.00210
# Epoch 486/500
# 364/364 [==============================] - 377s 1s/step - loss: 0.0010 - mae: 0.0218 - mape: 28.9721 - val_loss: 0.0199 - val_mae: 0.1177 - val_mape: 805.6484
#
# Epoch 00486: val_loss did not improve from 0.00210
# Epoch 487/500
# 364/364 [==============================] - 374s 1s/step - loss: 0.0010 - mae: 0.0220 - mape: 28.4894 - val_loss: 0.0217 - val_mae: 0.1226 - val_mape: 908.9481
#
# Epoch 00487: val_loss did not improve from 0.00210
# Epoch 488/500
# 364/364 [==============================] - 367s 1s/step - loss: 9.6306e-04 - mae: 0.0214 - mape: 28.6194 - val_loss: 0.0149 - val_mae: 0.1036 - val_mape: 573.7035
#
# Epoch 00488: val_loss did not improve from 0.00210
# Epoch 489/500
# 364/364 [==============================] - 369s 1s/step - loss: 9.3867e-04 - mae: 0.0208 - mape: 36.3737 - val_loss: 0.0178 - val_mae: 0.1088 - val_mape: 701.2341
#
# Epoch 00489: val_loss did not improve from 0.00210
# Epoch 490/500
# 364/364 [==============================] - 370s 1s/step - loss: 0.0011 - mae: 0.0223 - mape: 30.7709 - val_loss: 0.0169 - val_mae: 0.1070 - val_mape: 716.1718
#
# Epoch 00490: val_loss did not improve from 0.00210
# Epoch 491/500
# 364/364 [==============================] - 368s 1s/step - loss: 0.0010 - mae: 0.0221 - mape: 30.1665 - val_loss: 0.0189 - val_mae: 0.1095 - val_mape: 779.7734
#
# Epoch 00491: val_loss did not improve from 0.00210
# Epoch 492/500
# 364/364 [==============================] - 376s 1s/step - loss: 9.9040e-04 - mae: 0.0216 - mape: 29.4027 - val_loss: 0.0276 - val_mae: 0.1380 - val_mape: 1036.4098
#
# Epoch 00492: val_loss did not improve from 0.00210
# Epoch 493/500
# 364/364 [==============================] - 372s 1s/step - loss: 0.0011 - mae: 0.0220 - mape: 27.6922 - val_loss: 0.0205 - val_mae: 0.1178 - val_mape: 932.1489
#
# Epoch 00493: val_loss did not improve from 0.00210
# Epoch 494/500
# 364/364 [==============================] - 375s 1s/step - loss: 0.0010 - mae: 0.0218 - mape: 27.7055 - val_loss: 0.0188 - val_mae: 0.1122 - val_mape: 850.5530
#
# Epoch 00494: val_loss did not improve from 0.00210
# Epoch 495/500
# 364/364 [==============================] - 375s 1s/step - loss: 0.0010 - mae: 0.0222 - mape: 29.4317 - val_loss: 0.0132 - val_mae: 0.0966 - val_mape: 628.0217
#
# Epoch 00495: val_loss did not improve from 0.00210
# Epoch 496/500
# 364/364 [==============================] - 375s 1s/step - loss: 0.0010 - mae: 0.0215 - mape: 31.0884 - val_loss: 0.0183 - val_mae: 0.1115 - val_mape: 760.3207
#
# Epoch 00496: val_loss did not improve from 0.00210
# Epoch 497/500
# 364/364 [==============================] - 371s 1s/step - loss: 0.0011 - mae: 0.0219 - mape: 27.9947 - val_loss: 0.0181 - val_mae: 0.1107 - val_mape: 807.6328
#
# Epoch 00497: val_loss did not improve from 0.00210
# Epoch 498/500
# 364/364 [==============================] - 368s 1s/step - loss: 0.0010 - mae: 0.0218 - mape: 24.3369 - val_loss: 0.0209 - val_mae: 0.1186 - val_mape: 640.1939
#
# Epoch 00498: val_loss did not improve from 0.00210
# Epoch 499/500
# 364/364 [==============================] - 377s 1s/step - loss: 0.0011 - mae: 0.0221 - mape: 22.2899 - val_loss: 0.0244 - val_mae: 0.1289 - val_mape: 876.2973
#
# Epoch 00499: val_loss did not improve from 0.00210
# Epoch 500/500
# 364/364 [==============================] - 362s 995ms/step - loss: 0.0010 - mae: 0.0218 - mape: 27.0939 - val_loss: 0.0187 - val_mae: 0.1137 - val_mape: 736.0872
#
# Epoch 00500: val_loss did not improve from 0.00210

# %%
model_last = sorted([i for i in os.listdir('content') if 'hdf5' in i and 'Transformer+TimeEmbedding' in i])[-1]

# %%
model = tf.keras.models.load_model(
    os.path.join('content', model_last),
    custom_objects={
        'Time2Vector': Time2Vector,
        'SingleAttention': SingleAttention,
        'MultiAttention': MultiAttention,
        'TransformerEncoder': TransformerEncoder
    }
)
with open('../content/history-Copy5.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
###############################################################################
'''Calculate predictions and metrics'''

#Calculate predication for training, validation and test data
train_pred = model.predict(X_train)
val_pred = model.predict(X_val)
test_pred = model.predict(X_test)

#Print evaluation metrics for all datasets
train_eval = model.evaluate(X_train, y_train, verbose=0)
val_eval = model.evaluate(X_val, y_val, verbose=0)
test_eval = model.evaluate(X_test, y_test, verbose=0)
print(' ')
print('Evaluation metrics')
print('Training Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(train_eval[0], train_eval[1], train_eval[2]))
print('Validation Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(val_eval[0], val_eval[1], val_eval[2]))
print('Test Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(test_eval[0], test_eval[1], test_eval[2]))

###############################################################################
'''Display results'''

fig = plt.figure(figsize=(15,20))
st = fig.suptitle("Transformer + TimeEmbedding Model", fontsize=22)
st.set_y(0.92)

#Plot training data results
ax11 = fig.add_subplot(311)
ax11.plot(train_data[:, 3], label='EURUSD Closing Returns')
ax11.plot(np.arange(seq_len, train_pred.shape[0]+seq_len), train_pred, linewidth=3, label='Predicted EURUSD Closing Returns')
ax11.set_title("Training Data", fontsize=18)
ax11.set_xlabel('Dates')
ax11.set_ylabel('EURUSD Closing Returns')
ax11.legend(loc="best", fontsize=12)

#Plot validation data results
ax21 = fig.add_subplot(312)
ax21.plot(val_data[:, 3], label='EURUSD Closing Returns')
ax21.plot(np.arange(seq_len, val_pred.shape[0]+seq_len), val_pred, linewidth=3, label='Predicted EURUSD Closing Returns')
ax21.set_title("Validation Data", fontsize=18)
ax21.set_xlabel('Dates')
ax21.set_ylabel('EURUSD Closing Returns')
ax21.legend(loc="best", fontsize=12)

#Plot test data results
ax31 = fig.add_subplot(313)
ax31.plot(test_data[:, 3], label='EURUSD Closing Returns')
ax31.plot(np.arange(seq_len, test_pred.shape[0]+seq_len), test_pred, linewidth=3, label='Predicted EURUSD Closing Returns')
ax31.set_title("Test Data", fontsize=18)
ax31.set_xlabel('Dates')
ax31.set_ylabel('EURUSD Closing Returns')
ax31.legend(loc="best", fontsize=12)
# Out:
#
# Evaluation metrics
# Training Data - Loss: 0.0001, MAE: 0.0089, MAPE: 13.0869
# Validation Data - Loss: 0.0021, MAE: 0.0355, MAPE: 343.0058
# Test Data - Loss: 0.0023, MAE: 0.0392, MAPE: 22.2996

# %% [markdown]
# ## Model metrics

# %%
'''Display model metrics'''

fig = plt.figure(figsize=(15,20))
st = fig.suptitle("Transformer + TimeEmbedding Model Metrics", fontsize=22)
st.set_y(0.92)

#Plot model loss
ax1 = fig.add_subplot(311)
ax1.plot(history['loss'], label='Training loss (MSE)')
ax1.plot(history['val_loss'], label='Validation loss (MSE)')
ax1.set_title("Model loss", fontsize=18)
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss (MSE)')
ax1.legend(loc="best", fontsize=12)

#Plot MAE
ax2 = fig.add_subplot(312)
ax2.plot(history['mae'], label='Training MAE')
ax2.plot(history['val_mae'], label='Validation MAE')
ax2.set_title("Model metric - Mean average error (MAE)", fontsize=18)
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Mean average error (MAE)')
ax2.legend(loc="best", fontsize=12)

#Plot MAPE
ax3 = fig.add_subplot(313)
ax3.plot(history['mape'], label='Training MAPE')
ax3.plot(history['val_mape'], label='Validation MAPE')
ax3.set_title("Model metric - Mean average percentage error (MAPE)", fontsize=18)
ax3.set_xlabel('Epoch')
ax3.set_ylabel('Mean average percentage error (MAPE)')
ax3.legend(loc="best", fontsize=12)

# %% [markdown]
# ## Model architecture overview

# %%
tf.keras.utils.plot_model(
    model,
    to_file="EURUSD_Transformer+TimeEmbedding.png",
    show_shapes=True,
    show_layer_names=True,
    expand_nested=True,
    dpi=96,)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
