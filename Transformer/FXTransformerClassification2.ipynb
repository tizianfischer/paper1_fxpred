# %%
import pickle
import numpy as np
from tensorflow import keras
import pandas as pd
import os, datetime
from utils import get_fx_and_metric_data_wo_weekend
import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.losses import MSE, MAE, MAPE
print('Tensorflow version: {}'.format(tf.__version__))

from sklearn.preprocessing import StandardScaler
import scipy
    
import matplotlib.pyplot as plt
plt.style.use('seaborn')

import warnings
warnings.filterwarnings('ignore')
# Out:
# Tensorflow version: 2.4.1

# %% [markdown]
# ## Hyperparameter

# %%
batch_size = 32
seq_len = 256
d_k = 256
d_v = 256
n_heads = 12
ff_dim = 256

# %% [markdown]
# ## Data

# %%
from utils import get_fx_and_metric_data
df = get_fx_and_metric_data_wo_weekend(dtype=np.float32, directory='../data')
df
# Out:
#                      EURUSD BGNE Curncy Bid Open  \
# Dates
# 2020-11-01 19:10:00                     0.000000
# 2020-11-01 19:20:00                     0.000283
# 2020-11-01 19:30:00                     0.000172
# 2020-11-01 19:40:00                     0.000060
# 2020-11-01 19:50:00                    -0.000026
# ...                                          ...
# 2021-07-30 23:10:00                     0.000000
# 2021-07-30 23:20:00                     0.000000
# 2021-07-30 23:30:00                     0.000000
# 2021-07-30 23:40:00                     0.000000
# 2021-07-30 23:50:00                     0.000000
#
#                      EURUSD BGNE Curncy Bid Close  \
# Dates
# 2020-11-01 19:10:00                      0.000000
# 2020-11-01 19:20:00                      0.000275
# 2020-11-01 19:30:00                     -0.000069
# 2020-11-01 19:40:00                      0.000034
# 2020-11-01 19:50:00                      0.000026
# ...                                           ...
# 2021-07-30 23:10:00                      0.000000
# 2021-07-30 23:20:00                      0.000000
# 2021-07-30 23:30:00                      0.000000
# 2021-07-30 23:40:00                      0.000000
# 2021-07-30 23:50:00                      0.000000
#
#                      EURUSD BGNE Curncy Bid High  EURUSD BGNE Curncy Bid Low  \
# Dates
# 2020-11-01 19:10:00                     0.000000                    0.000000
# 2020-11-01 19:20:00                     0.000197                   -0.000507
# 2020-11-01 19:30:00                     0.000017                   -0.000215
# 2020-11-01 19:40:00                    -0.000172                    0.000636
# 2020-11-01 19:50:00                    -0.000026                    0.000584
# ...                                          ...                         ...
# 2021-07-30 23:10:00                     0.000000                    0.000000
# 2021-07-30 23:20:00                     0.000000                    0.000000
# 2021-07-30 23:30:00                     0.000000                    0.000000
# 2021-07-30 23:40:00                     0.000000                    0.000000
# 2021-07-30 23:50:00                     0.000000                    0.000000
#
#                      EURUSD BGNE Curncy Bid Number Ticks  \
# Dates
# 2020-11-01 19:10:00                             0.000000
# 2020-11-01 19:20:00                            -0.978125
# 2020-11-01 19:30:00                             0.380952
# 2020-11-01 19:40:00                             3.310345
# 2020-11-01 19:50:00                            -0.984000
# ...                                                  ...
# 2021-07-30 23:10:00                             0.000000
# 2021-07-30 23:20:00                             0.000000
# 2021-07-30 23:30:00                             0.000000
# 2021-07-30 23:40:00                             0.000000
# 2021-07-30 23:50:00                             0.000000
#
#                      EURUSD BGNE Curncy Ask Open  \
# Dates
# 2020-11-01 19:10:00                     0.000000
# 2020-11-01 19:20:00                     0.002121
# 2020-11-01 19:30:00                     0.000043
# 2020-11-01 19:40:00                    -0.000274
# 2020-11-01 19:50:00                    -0.000909
# ...                                          ...
# 2021-07-30 23:10:00                     0.000000
# 2021-07-30 23:20:00                     0.000000
# 2021-07-30 23:30:00                     0.000000
# 2021-07-30 23:40:00                     0.000000
# 2021-07-30 23:50:00                     0.000000
#
#                      EURUSD BGNE Curncy Ask Close  \
# Dates
# 2020-11-01 19:10:00                      0.000000
# 2020-11-01 19:20:00                      0.001597
# 2020-11-01 19:30:00                      0.000017
# 2020-11-01 19:40:00                     -0.001157
# 2020-11-01 19:50:00                     -0.000009
# ...                                           ...
# 2021-07-30 23:10:00                      0.000000
# 2021-07-30 23:20:00                      0.000000
# 2021-07-30 23:30:00                      0.000000
# 2021-07-30 23:40:00                      0.000000
# 2021-07-30 23:50:00                      0.000000
#
#                      EURUSD BGNE Curncy Ask High  EURUSD BGNE Curncy Ask Low  \
# Dates
# 2020-11-01 19:10:00                     0.000000                    0.000000
# 2020-11-01 19:20:00                     0.001631                    0.001761
# 2020-11-01 19:30:00                     0.000086                    0.000137
# 2020-11-01 19:40:00                    -0.000009                   -0.000926
# 2020-11-01 19:50:00                    -0.001268                    0.000017
# ...                                          ...                         ...
# 2021-07-30 23:10:00                     0.000000                    0.000000
# 2021-07-30 23:20:00                     0.000000                    0.000000
# 2021-07-30 23:30:00                     0.000000                    0.000000
# 2021-07-30 23:40:00                     0.000000                    0.000000
# 2021-07-30 23:50:00                     0.000000                    0.000000
#
#                      EURUSD BGNE Curncy Ask Number Ticks  ...  usdjpy___TAS_K  \
# Dates                                                     ...
# 2020-11-01 19:10:00                             0.000000  ...           40.00
# 2020-11-01 19:20:00                            -0.978125  ...           40.00
# 2020-11-01 19:30:00                             0.380952  ...           40.00
# 2020-11-01 19:40:00                             3.310345  ...           40.00
# 2020-11-01 19:50:00                            -0.984000  ...           40.00
# ...                                                  ...  ...             ...
# 2021-07-30 23:10:00                             0.000000  ...           43.75
# 2021-07-30 23:20:00                             0.000000  ...           43.75
# 2021-07-30 23:30:00                             0.000000  ...           43.75
# 2021-07-30 23:40:00                             0.000000  ...           43.75
# 2021-07-30 23:50:00                             0.000000  ...           43.75
#
#                      usdjpy___TAS_D  usdjpy___TAS_DS  usdjpy___TAS_DSS  \
# Dates
# 2020-11-01 19:10:00       56.000000        62.133335         67.244446
# 2020-11-01 19:20:00       56.000000        62.133335         67.244446
# 2020-11-01 19:30:00       56.000000        62.133335         67.244446
# 2020-11-01 19:40:00       56.000000        62.133335         67.244446
# 2020-11-01 19:50:00       56.000000        62.133335         67.244446
# ...                             ...              ...               ...
# 2021-07-30 23:10:00       20.178572        17.983767         17.992258
# 2021-07-30 23:20:00       20.178572        17.983767         17.992258
# 2021-07-30 23:30:00       20.178572        17.983767         17.992258
# 2021-07-30 23:40:00       20.178572        17.983767         17.992258
# 2021-07-30 23:50:00       20.178572        17.983767         17.992258
#
#                      usdjpy___TRENDER_UP  usdjpy___TRENDER_DN  usdjpy___TMAVG  \
# Dates
# 2020-11-01 19:10:00           104.536598           104.576935      104.551109
# 2020-11-01 19:20:00           104.536598           104.576935      104.551109
# 2020-11-01 19:30:00           104.536598           104.576935      104.551109
# 2020-11-01 19:40:00           104.536598           104.576935      104.551109
# 2020-11-01 19:50:00           104.536598           104.576935      104.552223
# ...                                  ...                  ...             ...
# 2021-07-30 23:10:00           109.763481           109.747704      109.705559
# 2021-07-30 23:20:00           109.763481           109.747704      109.705559
# 2021-07-30 23:30:00           109.763481           109.747704      109.705559
# 2021-07-30 23:40:00           109.763481           109.747704      109.705559
# 2021-07-30 23:50:00           109.763481           109.747704      109.705559
#
#                      usdjpy___VMAVG  usdjpy___WMAVG  usdjpy___WLPR
# Dates
# 2020-11-01 19:10:00      104.620003      104.553337     -66.666664
# 2020-11-01 19:20:00      104.620003      104.553337     -66.666664
# 2020-11-01 19:30:00      104.620003      104.553337     -66.666664
# 2020-11-01 19:40:00      104.620003      104.553337     -66.666664
# 2020-11-01 19:50:00      104.620003      104.552666     -66.666664
# ...                             ...             ...            ...
# 2021-07-30 23:10:00      109.735947      109.706001     -46.153847
# 2021-07-30 23:20:00      109.735947      109.706001     -46.153847
# 2021-07-30 23:30:00      109.735947      109.706001     -46.153847
# 2021-07-30 23:40:00      109.735947      109.706001     -46.153847
# 2021-07-30 23:50:00      109.735947      109.706001     -46.153847
#
# [29012 rows x 1231 columns]

# %%
# create a list of our conditions #!!! 
conditions = [
    (df['EURUSD BGNE Curncy Bid Close'] <= -0.00000001),
    (df['EURUSD BGNE Curncy Bid Close'] > -0.00000001) & (df['EURUSD BGNE Curncy Bid Close'] <= 0.00000001),
    (df['EURUSD BGNE Curncy Bid Close'] > 0.00000001)
    ]

# create a list of the values we want to assign for each condition #!!! 
values = [0, 1, 2]

# create a new column and use np.select to assign values to it using our lists as arguments #!!! 
df['strategy'] = np.select(conditions, values)

# display updated DataFrame #!!! 
df.head()
# Out:
#                      EURUSD BGNE Curncy Bid Open  \
# Dates
# 2020-11-01 19:10:00                     0.000000
# 2020-11-01 19:20:00                     0.000283
# 2020-11-01 19:30:00                     0.000172
# 2020-11-01 19:40:00                     0.000060
# 2020-11-01 19:50:00                    -0.000026
#
#                      EURUSD BGNE Curncy Bid Close  \
# Dates
# 2020-11-01 19:10:00                      0.000000
# 2020-11-01 19:20:00                      0.000275
# 2020-11-01 19:30:00                     -0.000069
# 2020-11-01 19:40:00                      0.000034
# 2020-11-01 19:50:00                      0.000026
#
#                      EURUSD BGNE Curncy Bid High  EURUSD BGNE Curncy Bid Low  \
# Dates
# 2020-11-01 19:10:00                     0.000000                    0.000000
# 2020-11-01 19:20:00                     0.000197                   -0.000507
# 2020-11-01 19:30:00                     0.000017                   -0.000215
# 2020-11-01 19:40:00                    -0.000172                    0.000636
# 2020-11-01 19:50:00                    -0.000026                    0.000584
#
#                      EURUSD BGNE Curncy Bid Number Ticks  \
# Dates
# 2020-11-01 19:10:00                             0.000000
# 2020-11-01 19:20:00                            -0.978125
# 2020-11-01 19:30:00                             0.380952
# 2020-11-01 19:40:00                             3.310345
# 2020-11-01 19:50:00                            -0.984000
#
#                      EURUSD BGNE Curncy Ask Open  \
# Dates
# 2020-11-01 19:10:00                     0.000000
# 2020-11-01 19:20:00                     0.002121
# 2020-11-01 19:30:00                     0.000043
# 2020-11-01 19:40:00                    -0.000274
# 2020-11-01 19:50:00                    -0.000909
#
#                      EURUSD BGNE Curncy Ask Close  \
# Dates
# 2020-11-01 19:10:00                      0.000000
# 2020-11-01 19:20:00                      0.001597
# 2020-11-01 19:30:00                      0.000017
# 2020-11-01 19:40:00                     -0.001157
# 2020-11-01 19:50:00                     -0.000009
#
#                      EURUSD BGNE Curncy Ask High  EURUSD BGNE Curncy Ask Low  \
# Dates
# 2020-11-01 19:10:00                     0.000000                    0.000000
# 2020-11-01 19:20:00                     0.001631                    0.001761
# 2020-11-01 19:30:00                     0.000086                    0.000137
# 2020-11-01 19:40:00                    -0.000009                   -0.000926
# 2020-11-01 19:50:00                    -0.001268                    0.000017
#
#                      EURUSD BGNE Curncy Ask Number Ticks  ...  usdjpy___TAS_D  \
# Dates                                                     ...
# 2020-11-01 19:10:00                             0.000000  ...            56.0
# 2020-11-01 19:20:00                            -0.978125  ...            56.0
# 2020-11-01 19:30:00                             0.380952  ...            56.0
# 2020-11-01 19:40:00                             3.310345  ...            56.0
# 2020-11-01 19:50:00                            -0.984000  ...            56.0
#
#                      usdjpy___TAS_DS  usdjpy___TAS_DSS  usdjpy___TRENDER_UP  \
# Dates
# 2020-11-01 19:10:00        62.133335         67.244446           104.536598
# 2020-11-01 19:20:00        62.133335         67.244446           104.536598
# 2020-11-01 19:30:00        62.133335         67.244446           104.536598
# 2020-11-01 19:40:00        62.133335         67.244446           104.536598
# 2020-11-01 19:50:00        62.133335         67.244446           104.536598
#
#                      usdjpy___TRENDER_DN  usdjpy___TMAVG  usdjpy___VMAVG  \
# Dates
# 2020-11-01 19:10:00           104.576935      104.551109      104.620003
# 2020-11-01 19:20:00           104.576935      104.551109      104.620003
# 2020-11-01 19:30:00           104.576935      104.551109      104.620003
# 2020-11-01 19:40:00           104.576935      104.551109      104.620003
# 2020-11-01 19:50:00           104.576935      104.552223      104.620003
#
#                      usdjpy___WMAVG  usdjpy___WLPR  strategy
# Dates
# 2020-11-01 19:10:00      104.553337     -66.666664         1
# 2020-11-01 19:20:00      104.553337     -66.666664         2
# 2020-11-01 19:30:00      104.553337     -66.666664         0
# 2020-11-01 19:40:00      104.553337     -66.666664         2
# 2020-11-01 19:50:00      104.552666     -66.666664         2
#
# [5 rows x 1232 columns]

# %%
target = 'strategy' #!!!

# %% [markdown]
# ## Create training, validation and test split

# %%
times = sorted(df.index.values)
last_10pct = sorted(df.index.values)[-int(0.1*len(times))] # Last 10% of series
last_20pct = sorted(df.index.values)[-int(0.2*len(times))] # Last 20% of series

df_train = df[(df.index < last_20pct)]  # Training data are 80% of total data
df_val = df[(df.index >= last_20pct) & (df.index < last_10pct)]
df_test = df[(df.index >= last_10pct)]

# Convert pandas columns into arrays
train_data = df_train.values
#!!! sc = StandardScaler().fit(train_data)
#!!! sc_target = StandardScaler().fit(df_train.loc[:, target].values.reshape(-1, 1))
#!!! train_data = sc.transform(train_data)
train_data_dates = df_train.index.values  

sc = train_data   #!!! 
sc_target = train_data   #!!! 

#!!! val_data = sc.transform(df_val.values)
val_data = df_val.values #!!! 
val_data_dates = df_val.index.values  

#!!! test_data = sc.transform(df_test.values)
test_data = df_test.values #!!! 
test_data_dates = df_test.index.values 

print('Training data shape: {}'.format(train_data.shape))
print('Validation data shape: {}'.format(val_data.shape))
print('Test data shape: {}'.format(test_data.shape))

df_train.head()
# Out:
# Training data shape: (23210, 1232)
# Validation data shape: (2901, 1232)
# Test data shape: (2901, 1232)
#                      EURUSD BGNE Curncy Bid Open  \
# Dates
# 2020-11-01 19:10:00                     0.000000
# 2020-11-01 19:20:00                     0.000283
# 2020-11-01 19:30:00                     0.000172
# 2020-11-01 19:40:00                     0.000060
# 2020-11-01 19:50:00                    -0.000026
#
#                      EURUSD BGNE Curncy Bid Close  \
# Dates
# 2020-11-01 19:10:00                      0.000000
# 2020-11-01 19:20:00                      0.000275
# 2020-11-01 19:30:00                     -0.000069
# 2020-11-01 19:40:00                      0.000034
# 2020-11-01 19:50:00                      0.000026
#
#                      EURUSD BGNE Curncy Bid High  EURUSD BGNE Curncy Bid Low  \
# Dates
# 2020-11-01 19:10:00                     0.000000                    0.000000
# 2020-11-01 19:20:00                     0.000197                   -0.000507
# 2020-11-01 19:30:00                     0.000017                   -0.000215
# 2020-11-01 19:40:00                    -0.000172                    0.000636
# 2020-11-01 19:50:00                    -0.000026                    0.000584
#
#                      EURUSD BGNE Curncy Bid Number Ticks  \
# Dates
# 2020-11-01 19:10:00                             0.000000
# 2020-11-01 19:20:00                            -0.978125
# 2020-11-01 19:30:00                             0.380952
# 2020-11-01 19:40:00                             3.310345
# 2020-11-01 19:50:00                            -0.984000
#
#                      EURUSD BGNE Curncy Ask Open  \
# Dates
# 2020-11-01 19:10:00                     0.000000
# 2020-11-01 19:20:00                     0.002121
# 2020-11-01 19:30:00                     0.000043
# 2020-11-01 19:40:00                    -0.000274
# 2020-11-01 19:50:00                    -0.000909
#
#                      EURUSD BGNE Curncy Ask Close  \
# Dates
# 2020-11-01 19:10:00                      0.000000
# 2020-11-01 19:20:00                      0.001597
# 2020-11-01 19:30:00                      0.000017
# 2020-11-01 19:40:00                     -0.001157
# 2020-11-01 19:50:00                     -0.000009
#
#                      EURUSD BGNE Curncy Ask High  EURUSD BGNE Curncy Ask Low  \
# Dates
# 2020-11-01 19:10:00                     0.000000                    0.000000
# 2020-11-01 19:20:00                     0.001631                    0.001761
# 2020-11-01 19:30:00                     0.000086                    0.000137
# 2020-11-01 19:40:00                    -0.000009                   -0.000926
# 2020-11-01 19:50:00                    -0.001268                    0.000017
#
#                      EURUSD BGNE Curncy Ask Number Ticks  ...  usdjpy___TAS_D  \
# Dates                                                     ...
# 2020-11-01 19:10:00                             0.000000  ...            56.0
# 2020-11-01 19:20:00                            -0.978125  ...            56.0
# 2020-11-01 19:30:00                             0.380952  ...            56.0
# 2020-11-01 19:40:00                             3.310345  ...            56.0
# 2020-11-01 19:50:00                            -0.984000  ...            56.0
#
#                      usdjpy___TAS_DS  usdjpy___TAS_DSS  usdjpy___TRENDER_UP  \
# Dates
# 2020-11-01 19:10:00        62.133335         67.244446           104.536598
# 2020-11-01 19:20:00        62.133335         67.244446           104.536598
# 2020-11-01 19:30:00        62.133335         67.244446           104.536598
# 2020-11-01 19:40:00        62.133335         67.244446           104.536598
# 2020-11-01 19:50:00        62.133335         67.244446           104.536598
#
#                      usdjpy___TRENDER_DN  usdjpy___TMAVG  usdjpy___VMAVG  \
# Dates
# 2020-11-01 19:10:00           104.576935      104.551109      104.620003
# 2020-11-01 19:20:00           104.576935      104.551109      104.620003
# 2020-11-01 19:30:00           104.576935      104.551109      104.620003
# 2020-11-01 19:40:00           104.576935      104.551109      104.620003
# 2020-11-01 19:50:00           104.576935      104.552223      104.620003
#
#                      usdjpy___WMAVG  usdjpy___WLPR  strategy
# Dates
# 2020-11-01 19:10:00      104.553337     -66.666664         1
# 2020-11-01 19:20:00      104.553337     -66.666664         2
# 2020-11-01 19:30:00      104.553337     -66.666664         0
# 2020-11-01 19:40:00      104.553337     -66.666664         2
# 2020-11-01 19:50:00      104.552666     -66.666664         2
#
# [5 rows x 1232 columns]

# %% [markdown]
# ## Plot daily changes of close prices and volatility

# %%
fig = plt.figure(figsize=(15,12))
st = fig.suptitle("Data Separation", fontsize=20)
st.set_y(0.95)

###############################################################################

ax1 = fig.add_subplot(211)
ax1.plot(train_data_dates, df_train[target], label='Training data')
ax1.plot(val_data_dates, df_val[target], label='Validation data')
ax1.plot(test_data_dates, df_test[target], label='Test data')
ax1.set_xlabel('Dates')
ax1.set_ylabel('Normalized Closing Returns')
ax1.set_title("Close Price", fontsize=18)
ax1.legend(loc="best", fontsize=12)

###############################################################################

ax2 = fig.add_subplot(212)
ax2.plot(train_data_dates, df_train['EURUSDV1Y Curncy Trade Open'], label='Training data') 
ax2.plot(val_data_dates, df_val['EURUSDV1Y Curncy Trade Open'], label='Validation data') 
ax2.plot(test_data_dates, df_test['EURUSDV1Y Curncy Trade Open'], label='Test data') 
ax2.set_xlabel('Dates')
ax2.set_ylabel('Normalized Volatility Changes')
ax2.set_title("Volatility", fontsize=18)
ax2.legend(loc="best", fontsize=12)

# %% [markdown]
# ## Create chunks of training, validation and test data

# %%
target_id = list(df_train.columns).index(target)
# Training data
X_train, y_train = [], []
for i in range(seq_len, len(train_data)):
    X_train.append(train_data[i-seq_len:i])
    y_train.append(train_data[:, target_id][i])
X_train, y_train = np.array(X_train, dtype=np.float32), np.array(y_train, dtype=np.float32)

###############################################################################

# Validation data
X_val, y_val = [], []
for i in range(seq_len, len(val_data)):
    X_val.append(val_data[i-seq_len:i])
    y_val.append(val_data[:, target_id][i])
X_val, y_val = np.array(X_val, dtype=np.float32), np.array(y_val, dtype=np.float32)

###############################################################################

# Test data
X_test, y_test = [], []
for i in range(seq_len, len(test_data)):
    X_test.append(test_data[i-seq_len:i])
    y_test.append(test_data[:, target_id][i])    
X_test, y_test = np.array(X_test, dtype=np.float32), np.array(y_test, dtype=np.float32)

print('Training set shape', X_train.shape, y_train.shape)
print('Validation set shape', X_val.shape, y_val.shape)
print('Testing set shape' ,X_test.shape, y_test.shape)
# Out:
# Training set shape (22954, 256, 1232) (22954,)
# Validation set shape (2645, 256, 1232) (2645,)
# Testing set shape (2645, 256, 1232) (2645,)

# %% [markdown]
# ## TimeVector

# %%
class Time2Vector(Layer):
    def __init__(self, seq_len, **kwargs):
        super(Time2Vector, self).__init__()
        self.seq_len = seq_len

    def build(self, input_shape):
        '''Initialize weights and biases with shape (batch, seq_len)'''
        self.weights_linear = self.add_weight(name='weight_linear',
                                    shape=(int(self.seq_len),),
                                    initializer='uniform',
                                    trainable=True)

        self.bias_linear = self.add_weight(name='bias_linear',
                                    shape=(int(self.seq_len),),
                                    initializer='uniform',
                                    trainable=True)

        self.weights_periodic = self.add_weight(name='weight_periodic',
                                    shape=(int(self.seq_len),),
                                    initializer='uniform',
                                    trainable=True)

        self.bias_periodic = self.add_weight(name='bias_periodic',
                                    shape=(int(self.seq_len),),
                                    initializer='uniform',
                                    trainable=True)

    def call(self, x):
        '''Calculate linear and periodic time features'''
        x = tf.math.reduce_mean(x[:,:,:4], axis=-1) 
        time_linear = self.weights_linear * x + self.bias_linear # Linear time feature
        time_linear = tf.expand_dims(time_linear, axis=-1) # Add dimension (batch, seq_len, 1)

        time_periodic = tf.math.sin(tf.multiply(x, self.weights_periodic) + self.bias_periodic)
        time_periodic = tf.expand_dims(time_periodic, axis=-1) # Add dimension (batch, seq_len, 1)
        return tf.concat([time_linear, time_periodic], axis=-1) # shape = (batch, seq_len, 2)
   
    def get_config(self): # Needed for saving and loading model with custom layer
        config = super().get_config().copy()
        config.update({'seq_len': self.seq_len})
        return config

# %% [markdown]
# ## Transformer

# %%
class SingleAttention(Layer):
    def __init__(self, d_k, d_v):
        super(SingleAttention, self).__init__()
        self.d_k = d_k
        self.d_v = d_v

    def build(self, input_shape):
        self.query = Dense(self.d_k, 
                           input_shape=input_shape, 
                           kernel_initializer='glorot_uniform', 
                           bias_initializer='glorot_uniform')

        self.key = Dense(self.d_k, 
                         input_shape=input_shape, 
                         kernel_initializer='glorot_uniform', 
                         bias_initializer='glorot_uniform')

        self.value = Dense(self.d_v, 
                           input_shape=input_shape, 
                           kernel_initializer='glorot_uniform', 
                           bias_initializer='glorot_uniform')

    def call(self, inputs): # inputs = (in_seq, in_seq, in_seq)
        q = self.query(inputs[0])
        k = self.key(inputs[1])

        attn_weights = tf.matmul(q, k, transpose_b=True)
        attn_weights = tf.map_fn(lambda x: x/np.sqrt(self.d_k), attn_weights)
        attn_weights = tf.nn.softmax(attn_weights, axis=-1)

        v = self.value(inputs[2])
        attn_out = tf.matmul(attn_weights, v)
        return attn_out    

#############################################################################

class MultiAttention(Layer):
    def __init__(self, d_k, d_v, n_heads):
        super(MultiAttention, self).__init__()
        self.d_k = d_k
        self.d_v = d_v
        self.n_heads = n_heads
        self.attn_heads = list()

    def build(self, input_shape):
        for n in range(self.n_heads):
            self.attn_heads.append(SingleAttention(self.d_k, self.d_v))  

        # input_shape[0]=(batch, seq_len, 7), input_shape[0][-1]=7 
        self.linear = Dense(input_shape[0][-1], 
                            input_shape=input_shape, 
                            kernel_initializer='glorot_uniform', 
                            bias_initializer='glorot_uniform')

    def call(self, inputs):
        attn = [self.attn_heads[i](inputs) for i in range(self.n_heads)]
        concat_attn = tf.concat(attn, axis=-1)
        multi_linear = self.linear(concat_attn)
        return multi_linear   

#############################################################################

class TransformerEncoder(Layer):
    def __init__(self, d_k, d_v, n_heads, ff_dim, dropout=0.1, **kwargs):
        super(TransformerEncoder, self).__init__()
        self.d_k = d_k
        self.d_v = d_v
        self.n_heads = n_heads
        self.ff_dim = ff_dim
        self.attn_heads = list()
        self.dropout_rate = dropout

    def build(self, input_shape):
        self.attn_multi = MultiAttention(self.d_k, self.d_v, self.n_heads)
        self.attn_dropout = Dropout(self.dropout_rate)
        self.attn_normalize = LayerNormalization(input_shape=input_shape, epsilon=1e-6)

        self.ff_conv1D_1 = Conv1D(filters=self.ff_dim, kernel_size=1, activation='relu')
        # input_shape[0]=(batch, seq_len, 7), input_shape[0][-1] = 7 
        self.ff_conv1D_2 = Conv1D(filters=input_shape[0][-1], kernel_size=1) 
        self.ff_dropout = Dropout(self.dropout_rate)
        self.ff_normalize = LayerNormalization(input_shape=input_shape, epsilon=1e-6)    
  
    def call(self, inputs): # inputs = (in_seq, in_seq, in_seq)
        attn_layer = self.attn_multi(inputs)
        attn_layer = self.attn_dropout(attn_layer)
        attn_layer = self.attn_normalize(inputs[0] + attn_layer)

        ff_layer = self.ff_conv1D_1(attn_layer)
        ff_layer = self.ff_conv1D_2(ff_layer)
        ff_layer = self.ff_dropout(ff_layer)
        ff_layer = self.ff_normalize(inputs[0] + ff_layer)
        return ff_layer 

    def get_config(self): # Needed for saving and loading model with custom layer
        config = super().get_config().copy()
        config.update({'d_k': self.d_k,
                       'd_v': self.d_v,
                       'n_heads': self.n_heads,
                       'ff_dim': self.ff_dim,
                       'attn_heads': self.attn_heads,
                       'dropout_rate': self.dropout_rate})
        return config

# %% [markdown]
# ## Model

# %%
def create_model(input_shape):
    '''Initialize time and transformer layers'''
    time_embedding = Time2Vector(seq_len)
    attn_layer1 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)
    attn_layer2 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)
    attn_layer3 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)

    '''Construct model'''
    in_seq = Input(shape=(seq_len, input_shape))
    x = time_embedding(in_seq)
    x = Concatenate(axis=-1)([in_seq, x])
    #   x = Concatenate(axis=-1)([Dense(128)(in_seq), x])
    x = attn_layer1((x, x, x))
    x = attn_layer2((x, x, x))
    x = attn_layer3((x, x, x))
    # x = GlobalAveragePooling1D(data_format='channels_first')(x)
    # x = Dense(256, activation='relu')(x)
    x = Flatten()(x)    
    x = Dropout(0.01)(x)
    x = Dense(64, activation='linear')(x)
    out = Dense(3, activation='linear')(x)

    model = Model(inputs=in_seq, outputs=out)
    opt = keras.optimizers.Adam(learning_rate=0.0001)
    
    model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
#!!!     model.compile(loss='mse', optimizer=opt, metrics=['mae', 'mape                                               
    return model


model = create_model(df.shape[1])
model.summary()

callback = tf.keras.callbacks.ModelCheckpoint('../content/Transformer+TimeEmbeddingClassification2{epoch:04}.hdf5', 
                                               monitor='val_loss', 
                                               save_best_only=True, verbose=1
                                             )

es = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=8,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)


if True: 
    history = model.fit(X_train, y_train,
                        batch_size=batch_size, 
                        epochs=70,
                        callbacks=[callback],
                        validation_data=(X_val, y_val))  
    with open('../content/historyClassification2.pkl', 'wb') as f:
        pickle.dump(history.history, f)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 1232)]  0
# __________________________________________________________________________________________________
# time2_vector (Time2Vector)      (None, 256, 2)       1024        input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 256, 1234)    0           input_1[0][0]
#                                                                  time2_vector[0][0]
# __________________________________________________________________________________________________
# transformer_encoder (Transforme (None, 256, 1234)    15812076    concatenate[0][0]
#                                                                  concatenate[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# transformer_encoder_1 (Transfor (None, 256, 1234)    15812076    transformer_encoder[0][0]
#                                                                  transformer_encoder[0][0]
#                                                                  transformer_encoder[0][0]
# __________________________________________________________________________________________________
# transformer_encoder_2 (Transfor (None, 256, 1234)    15812076    transformer_encoder_1[0][0]
#                                                                  transformer_encoder_1[0][0]
#                                                                  transformer_encoder_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 315904)       0           transformer_encoder_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 315904)       0           flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           20217920    dropout[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 3)            195         dense[0][0]
# ==================================================================================================
# Total params: 67,655,367
# Trainable params: 67,655,367
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/70
# 718/718 [==============================] - 1981s 3s/step - loss: 159.0956 - accuracy: 0.4563 - val_loss: 5.2111 - val_accuracy: 0.4949
#
# Epoch 00001: val_loss improved from inf to 5.21112, saving model to ../content/Transformer+TimeEmbeddingClassification20001.hdf5
# Epoch 2/70
# 718/718 [==============================] - 1921s 3s/step - loss: 8.5246 - accuracy: 0.4699 - val_loss: 0.8505 - val_accuracy: 0.4752
#
# Epoch 00002: val_loss improved from 5.21112 to 0.85050, saving model to ../content/Transformer+TimeEmbeddingClassification20002.hdf5
# Epoch 3/70
# 718/718 [==============================] - 1941s 3s/step - loss: 1.5894 - accuracy: 0.4764 - val_loss: 2.0932 - val_accuracy: 0.4752
#
# Epoch 00003: val_loss did not improve from 0.85050
# Epoch 4/70
# 718/718 [==============================] - 1899s 3s/step - loss: 1.3135 - accuracy: 0.4781 - val_loss: 0.9156 - val_accuracy: 0.4949
#
# Epoch 00004: val_loss did not improve from 0.85050
# Epoch 5/70
# 718/718 [==============================] - 1934s 3s/step - loss: 1.1080 - accuracy: 0.4814 - val_loss: 0.8447 - val_accuracy: 0.4752
#
# Epoch 00005: val_loss improved from 0.85050 to 0.84471, saving model to ../content/Transformer+TimeEmbeddingClassification20005.hdf5
# Epoch 6/70
# 718/718 [==============================] - 1919s 3s/step - loss: 1.0379 - accuracy: 0.4762 - val_loss: 0.8644 - val_accuracy: 0.4752
#
# Epoch 00006: val_loss did not improve from 0.84471
# Epoch 7/70
# 718/718 [==============================] - 1924s 3s/step - loss: 0.9764 - accuracy: 0.4797 - val_loss: 0.8259 - val_accuracy: 0.4949
#
# Epoch 00007: val_loss improved from 0.84471 to 0.82592, saving model to ../content/Transformer+TimeEmbeddingClassification20007.hdf5
# Epoch 8/70
# 718/718 [==============================] - 1927s 3s/step - loss: 0.9674 - accuracy: 0.4784 - val_loss: 1.1222 - val_accuracy: 0.4752
#
# Epoch 00008: val_loss did not improve from 0.82592
# Epoch 9/70
# 718/718 [==============================] - 1905s 3s/step - loss: 0.9310 - accuracy: 0.4793 - val_loss: 0.8921 - val_accuracy: 0.4949
#
# Epoch 00009: val_loss did not improve from 0.82592
# Epoch 10/70
# 718/718 [==============================] - 1908s 3s/step - loss: 0.9114 - accuracy: 0.4849 - val_loss: 0.8253 - val_accuracy: 0.4949
#
# Epoch 00010: val_loss improved from 0.82592 to 0.82534, saving model to ../content/Transformer+TimeEmbeddingClassification20010.hdf5
# Epoch 11/70
# 718/718 [==============================] - 1916s 3s/step - loss: 0.8849 - accuracy: 0.4866 - val_loss: 0.8206 - val_accuracy: 0.4949
#
# Epoch 00011: val_loss improved from 0.82534 to 0.82056, saving model to ../content/Transformer+TimeEmbeddingClassification20011.hdf5
# Epoch 12/70
# 718/718 [==============================] - 1922s 3s/step - loss: 0.8615 - accuracy: 0.4849 - val_loss: 0.8120 - val_accuracy: 0.4752
#
# Epoch 00012: val_loss improved from 0.82056 to 0.81198, saving model to ../content/Transformer+TimeEmbeddingClassification20012.hdf5
# Epoch 13/70
# 718/718 [==============================] - 1909s 3s/step - loss: 0.8408 - accuracy: 0.4814 - val_loss: 0.8110 - val_accuracy: 0.4752
#
# Epoch 00013: val_loss improved from 0.81198 to 0.81100, saving model to ../content/Transformer+TimeEmbeddingClassification20013.hdf5
# Epoch 14/70
# 718/718 [==============================] - 2004s 3s/step - loss: 0.8354 - accuracy: 0.4871 - val_loss: 0.8214 - val_accuracy: 0.4752
#
# Epoch 00014: val_loss did not improve from 0.81100
# Epoch 15/70
# 718/718 [==============================] - 1906s 3s/step - loss: 0.8373 - accuracy: 0.4808 - val_loss: 0.8116 - val_accuracy: 0.4752
#
# Epoch 00015: val_loss did not improve from 0.81100
# Epoch 16/70
# 718/718 [==============================] - 1952s 3s/step - loss: 0.8406 - accuracy: 0.4783 - val_loss: 0.8098 - val_accuracy: 0.4949
#
# Epoch 00016: val_loss improved from 0.81100 to 0.80979, saving model to ../content/Transformer+TimeEmbeddingClassification20016.hdf5
# Epoch 17/70
# 718/718 [==============================] - 1921s 3s/step - loss: 0.8401 - accuracy: 0.4852 - val_loss: 0.8309 - val_accuracy: 0.4752
#
# Epoch 00017: val_loss did not improve from 0.80979
# Epoch 18/70
# 718/718 [==============================] - 1974s 3s/step - loss: 0.8361 - accuracy: 0.4834 - val_loss: 0.8074 - val_accuracy: 0.4752
#
# Epoch 00018: val_loss improved from 0.80979 to 0.80744, saving model to ../content/Transformer+TimeEmbeddingClassification20018.hdf5
# Epoch 19/70
# 718/718 [==============================] - 1945s 3s/step - loss: 0.8757 - accuracy: 0.4852 - val_loss: 0.8072 - val_accuracy: 0.4949
#
# Epoch 00019: val_loss improved from 0.80744 to 0.80723, saving model to ../content/Transformer+TimeEmbeddingClassification20019.hdf5
# Epoch 20/70
# 718/718 [==============================] - 2000s 3s/step - loss: 0.8389 - accuracy: 0.4801 - val_loss: 0.8131 - val_accuracy: 0.4949
#
# Epoch 00020: val_loss did not improve from 0.80723
# Epoch 21/70
# 718/718 [==============================] - 2158s 3s/step - loss: 0.8413 - accuracy: 0.4726 - val_loss: 0.8135 - val_accuracy: 0.4752
#
# Epoch 00021: val_loss did not improve from 0.80723
# Epoch 22/70
# 718/718 [==============================] - 2211s 3s/step - loss: 0.8237 - accuracy: 0.4921 - val_loss: 0.8167 - val_accuracy: 0.5013
#
# Epoch 00022: val_loss did not improve from 0.80723
# Epoch 23/70
# 718/718 [==============================] - 2267s 3s/step - loss: 0.8181 - accuracy: 0.4894 - val_loss: 0.8245 - val_accuracy: 0.4650
#
# Epoch 00023: val_loss did not improve from 0.80723
# Epoch 24/70
# 718/718 [==============================] - 2330s 3s/step - loss: 0.8228 - accuracy: 0.4904 - val_loss: 0.8139 - val_accuracy: 0.4892
#
# Epoch 00024: val_loss did not improve from 0.80723
# Epoch 25/70
# 718/718 [==============================] - 2384s 3s/step - loss: 0.8201 - accuracy: 0.4925 - val_loss: 0.8249 - val_accuracy: 0.4752
#
# Epoch 00025: val_loss did not improve from 0.80723
# Epoch 26/70
# 718/718 [==============================] - 2339s 3s/step - loss: 0.8120 - accuracy: 0.4891 - val_loss: 0.8143 - val_accuracy: 0.4888
#
# Epoch 00026: val_loss did not improve from 0.80723
# Epoch 27/70
# 718/718 [==============================] - 2438s 3s/step - loss: 0.8035 - accuracy: 0.5017 - val_loss: 0.8172 - val_accuracy: 0.4862
#
# Epoch 00027: val_loss did not improve from 0.80723
# Epoch 28/70
# 718/718 [==============================] - 2459s 3s/step - loss: 0.8032 - accuracy: 0.5032 - val_loss: 0.8183 - val_accuracy: 0.4756
#
# Epoch 00028: val_loss did not improve from 0.80723
# Epoch 29/70
# 718/718 [==============================] - 2365s 3s/step - loss: 0.7981 - accuracy: 0.5010 - val_loss: 0.8372 - val_accuracy: 0.4790
#
# Epoch 00029: val_loss did not improve from 0.80723
# Epoch 30/70
# 718/718 [==============================] - 2365s 3s/step - loss: 0.7993 - accuracy: 0.5054 - val_loss: 0.8214 - val_accuracy: 0.4839
#
# Epoch 00030: val_loss did not improve from 0.80723
# Epoch 31/70
# 718/718 [==============================] - 2366s 3s/step - loss: 0.7910 - accuracy: 0.5083 - val_loss: 0.8231 - val_accuracy: 0.4979
#
# Epoch 00031: val_loss did not improve from 0.80723
# Epoch 32/70
# 718/718 [==============================] - 2247s 3s/step - loss: 0.7928 - accuracy: 0.5199 - val_loss: 0.8478 - val_accuracy: 0.4726
#
# Epoch 00032: val_loss did not improve from 0.80723
# Epoch 33/70
# 718/718 [==============================] - 2361s 3s/step - loss: 0.7867 - accuracy: 0.5245 - val_loss: 0.8401 - val_accuracy: 0.4790
#
# Epoch 00033: val_loss did not improve from 0.80723
# Epoch 34/70
# 718/718 [==============================] - 2313s 3s/step - loss: 0.7862 - accuracy: 0.5295 - val_loss: 0.8326 - val_accuracy: 0.4972
#
# Epoch 00034: val_loss did not improve from 0.80723
# Epoch 35/70
# 718/718 [==============================] - 2297s 3s/step - loss: 0.7795 - accuracy: 0.5425 - val_loss: 0.8382 - val_accuracy: 0.4752
#
# Epoch 00035: val_loss did not improve from 0.80723
# Epoch 36/70
# 718/718 [==============================] - 2245s 3s/step - loss: 0.7697 - accuracy: 0.5416 - val_loss: 0.8425 - val_accuracy: 0.4975
#
# Epoch 00036: val_loss did not improve from 0.80723
# Epoch 37/70
# 718/718 [==============================] - 2224s 3s/step - loss: 0.7730 - accuracy: 0.5436 - val_loss: 0.8530 - val_accuracy: 0.4911
#
# Epoch 00037: val_loss did not improve from 0.80723
# Epoch 38/70
# 718/718 [==============================] - 2282s 3s/step - loss: 0.7687 - accuracy: 0.5585 - val_loss: 0.8533 - val_accuracy: 0.4873
#
# Epoch 00038: val_loss did not improve from 0.80723
# Epoch 39/70
# 718/718 [==============================] - 2254s 3s/step - loss: 0.7629 - accuracy: 0.5542 - val_loss: 0.8636 - val_accuracy: 0.4639
#
# Epoch 00039: val_loss did not improve from 0.80723
# Epoch 40/70
# 718/718 [==============================] - 2289s 3s/step - loss: 0.7526 - accuracy: 0.5654 - val_loss: 0.8673 - val_accuracy: 0.4960
#
# Epoch 00040: val_loss did not improve from 0.80723
# Epoch 41/70
# 718/718 [==============================] - 2277s 3s/step - loss: 0.7540 - accuracy: 0.5665 - val_loss: 0.8487 - val_accuracy: 0.4760
#
# Epoch 00041: val_loss did not improve from 0.80723
# Epoch 42/70
# 718/718 [==============================] - 2290s 3s/step - loss: 0.7513 - accuracy: 0.5626 - val_loss: 0.9130 - val_accuracy: 0.4802
#
# Epoch 00042: val_loss did not improve from 0.80723
# Epoch 43/70
# 718/718 [==============================] - 2374s 3s/step - loss: 0.7414 - accuracy: 0.5839 - val_loss: 0.9030 - val_accuracy: 0.4711
#
# Epoch 00043: val_loss did not improve from 0.80723
# Epoch 44/70
# 718/718 [==============================] - 2315s 3s/step - loss: 0.7407 - accuracy: 0.5786 - val_loss: 0.8621 - val_accuracy: 0.4817
#
# Epoch 00044: val_loss did not improve from 0.80723
# Epoch 45/70
# 718/718 [==============================] - 2282s 3s/step - loss: 0.7337 - accuracy: 0.5889 - val_loss: 0.9130 - val_accuracy: 0.4809
#
# Epoch 00045: val_loss did not improve from 0.80723
# Epoch 46/70
# 718/718 [==============================] - 2292s 3s/step - loss: 0.7314 - accuracy: 0.5877 - val_loss: 0.8675 - val_accuracy: 0.4979
#
# Epoch 00046: val_loss did not improve from 0.80723
# Epoch 47/70
# 718/718 [==============================] - 2314s 3s/step - loss: 0.7282 - accuracy: 0.5931 - val_loss: 0.8661 - val_accuracy: 0.4915
#
# Epoch 00047: val_loss did not improve from 0.80723
# Epoch 48/70
# 718/718 [==============================] - 2283s 3s/step - loss: 0.7174 - accuracy: 0.5976 - val_loss: 0.8831 - val_accuracy: 0.4767
#
# Epoch 00048: val_loss did not improve from 0.80723
# Epoch 49/70
# 718/718 [==============================] - 2259s 3s/step - loss: 0.7191 - accuracy: 0.5918 - val_loss: 0.9038 - val_accuracy: 0.4881
#
# Epoch 00049: val_loss did not improve from 0.80723
# Epoch 50/70
# 718/718 [==============================] - 2299s 3s/step - loss: 0.7148 - accuracy: 0.6057 - val_loss: 0.8802 - val_accuracy: 0.4919
#
# Epoch 00050: val_loss did not improve from 0.80723
# Epoch 51/70
# 718/718 [==============================] - 2308s 3s/step - loss: 0.7113 - accuracy: 0.6006 - val_loss: 0.8751 - val_accuracy: 0.4949
#
# Epoch 00051: val_loss did not improve from 0.80723
# Epoch 52/70
# 718/718 [==============================] - 2284s 3s/step - loss: 0.7073 - accuracy: 0.6082 - val_loss: 0.8810 - val_accuracy: 0.4926
#
# Epoch 00052: val_loss did not improve from 0.80723
# Epoch 53/70
# 718/718 [==============================] - 2320s 3s/step - loss: 0.7079 - accuracy: 0.6073 - val_loss: 0.8827 - val_accuracy: 0.5017
#
# Epoch 00053: val_loss did not improve from 0.80723
# Epoch 54/70
# 718/718 [==============================] - 2261s 3s/step - loss: 0.7060 - accuracy: 0.6063 - val_loss: 0.9148 - val_accuracy: 0.4839
#
# Epoch 00054: val_loss did not improve from 0.80723
# Epoch 55/70
# 718/718 [==============================] - 2276s 3s/step - loss: 0.7126 - accuracy: 0.6082 - val_loss: 0.9107 - val_accuracy: 0.4813
#
# Epoch 00055: val_loss did not improve from 0.80723
# Epoch 56/70
# 718/718 [==============================] - 2240s 3s/step - loss: 0.6967 - accuracy: 0.6099 - val_loss: 0.9585 - val_accuracy: 0.4677
#
# Epoch 00056: val_loss did not improve from 0.80723
# Epoch 57/70
# 718/718 [==============================] - 2300s 3s/step - loss: 0.6943 - accuracy: 0.6117 - val_loss: 0.8952 - val_accuracy: 0.4843
#
# Epoch 00057: val_loss did not improve from 0.80723
# Epoch 58/70
# 718/718 [==============================] - 2290s 3s/step - loss: 0.6969 - accuracy: 0.6140 - val_loss: 0.9538 - val_accuracy: 0.4726
#
# Epoch 00058: val_loss did not improve from 0.80723
# Epoch 59/70
# 718/718 [==============================] - 2247s 3s/step - loss: 0.6933 - accuracy: 0.6185 - val_loss: 0.9502 - val_accuracy: 0.4658
#
# Epoch 00059: val_loss did not improve from 0.80723
# Epoch 60/70
# 718/718 [==============================] - 2245s 3s/step - loss: 0.6895 - accuracy: 0.6161 - val_loss: 0.9290 - val_accuracy: 0.4767
#
# Epoch 00060: val_loss did not improve from 0.80723
# Epoch 61/70
# 718/718 [==============================] - 2270s 3s/step - loss: 0.6946 - accuracy: 0.6145 - val_loss: 0.9332 - val_accuracy: 0.4786
#
# Epoch 00061: val_loss did not improve from 0.80723
# Epoch 62/70
# 718/718 [==============================] - 2244s 3s/step - loss: 0.6862 - accuracy: 0.6212 - val_loss: 0.9948 - val_accuracy: 0.4775
#
# Epoch 00062: val_loss did not improve from 0.80723
# Epoch 63/70
# 718/718 [==============================] - 2215s 3s/step - loss: 0.6855 - accuracy: 0.6225 - val_loss: 0.9666 - val_accuracy: 0.4802
# Epoch 00063: val_loss did not improve from 0.80723
# Epoch 64/70
# 718/718 [==============================] - 2109s 3s/step - loss: 0.6871 - accuracy: 0.6240 - val_loss: 0.9597 - val_accuracy: 0.4847
#
# Epoch 00064: val_loss did not improve from 0.80723
# Epoch 65/70
# 718/718 [==============================] - 2201s 3s/step - loss: 0.6855 - accuracy: 0.6201 - val_loss: 0.9400 - val_accuracy: 0.4991
#
# Epoch 00065: val_loss did not improve from 0.80723
# Epoch 66/70
# 718/718 [==============================] - 2181s 3s/step - loss: 0.6806 - accuracy: 0.6203 - val_loss: 0.9672 - val_accuracy: 0.4752
#
# Epoch 00066: val_loss did not improve from 0.80723
# Epoch 67/70
# 718/718 [==============================] - 2282s 3s/step - loss: 0.6776 - accuracy: 0.6296 - val_loss: 0.9487 - val_accuracy: 0.4832
#
# Epoch 00067: val_loss did not improve from 0.80723
# Epoch 68/70
# 718/718 [==============================] - 2305s 3s/step - loss: 0.6775 - accuracy: 0.6223 - val_loss: 0.9559 - val_accuracy: 0.4741
#
# Epoch 00068: val_loss did not improve from 0.80723
# Epoch 69/70
# 718/718 [==============================] - 2296s 3s/step - loss: 0.6761 - accuracy: 0.6279 - val_loss: 0.9755 - val_accuracy: 0.4873
#
# Epoch 00069: val_loss did not improve from 0.80723
# Epoch 70/70
# 718/718 [==============================] - 2322s 3s/step - loss: 0.6676 - accuracy: 0.6304 - val_loss: 0.9951 - val_accuracy: 0.4949
#
# Epoch 00070: val_loss did not improve from 0.80723

# %%
model_last = sorted([i for i in os.listdir('../content') if 'hdf5' in i and 'Transformer+TimeEmbeddingClassification2' in i])[-1]

# %%
model = tf.keras.models.load_model(
    os.path.join('../content', model_last),
    custom_objects={
        'Time2Vector': Time2Vector,
        'SingleAttention': SingleAttention,
        'MultiAttention': MultiAttention,
        'TransformerEncoder': TransformerEncoder
    }
)
with open('../content/historyClassification2.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
###############################################################################
'''Calculate predictions and metrics'''

#Calculate predication for training, validation and test data
train_pred = model.predict(X_train)
val_pred = model.predict(X_val)
test_pred = model.predict(X_test)

#Print evaluation metrics for all datasets
train_eval = model.evaluate(X_train, y_train, verbose=0)
val_eval = model.evaluate(X_val, y_val, verbose=0)
test_eval = model.evaluate(X_test, y_test, verbose=0)
print(' ')
print('Evaluation metrics')
print('Training Data - accuracy: {:.4f}'.format(train_eval[0]))
print('Validation Data - accuracy: {:.4f}'.format(val_eval[0]))
print('Test Data - accuracy: {:.4f}'.format(test_eval[0]))
# Out:
#
# Evaluation metrics
# Training Data - accuracy: 0.8384
# Validation Data - accuracy: 0.8072
# Test Data - accuracy: 0.8045

# %% [markdown]
# ### Training error

# %%
#!!! def mde(y_true, y_pred):
#!!!     return 1 - np.equal(y_true[1:] - y_true[:-1] >= 0, y_pred[1:] - y_true[:-1] >= 0).mean()

# %%
#!!! y = sc_target.inverse_transform(y_train.reshape(-1, 1))
#!!! y_pred = sc_target.inverse_transform(train_pred)
#!!! print(f'mse: {MSE(y.flatten(), y_pred.flatten()).numpy()}')
#!!! print(f'mae: {MAE(y.flatten(), y_pred.flatten()).numpy()}')
#!!! print(f'mape: {MAPE(y.flatten(), y_pred.flatten()).numpy()}')
#!!! print(f'mde: {mde(y.flatten(), y_pred.flatten())}')

# %% [markdown]
# ### Validation Error

# %%
#!!! y = sc_target.inverse_transform(y_val.reshape(-1, 1))
#!!! y_pred = sc_target.inverse_transform(val_pred)
#!!! print(f'mse: {MSE(y.flatten(), y_pred.flatten()).numpy()}')
#!!! print(f'mae: {MAE(y.flatten(), y_pred.flatten()).numpy()}')
#!!! print(f'mape: {MAPE(y.flatten(), y_pred.flatten()).numpy()}')
#!!! print(f'mde: {mde(y.flatten(), y_pred.flatten())}')

# %% [markdown]
# ### Test Error

# %%
#!!! y = sc_target.inverse_transform(y_test.reshape(-1, 1))
#!!! y_pred = sc_target.inverse_transform(test_pred)
#!!! print(f'mse: {MSE(y.flatten(), y_pred.flatten()).numpy()}')
#!!! print(f'mae: {MAE(y.flatten(), y_pred.flatten()).numpy()}')
#!!! print(f'mape: {MAPE(y.flatten(), y_pred.flatten()).numpy()}')
#!!! print(f'mde: {mde(y.flatten(), y_pred.flatten())}')

# %% [markdown]
# ## Display Results

# %%
###############################################################################
'''Display results'''

fig = plt.figure(figsize=(15,20))
st = fig.suptitle("Transformer + TimeEmbedding Model", fontsize=22)
st.set_y(0.92)

#Plot training data results
ax11 = fig.add_subplot(311)
ax11.plot(train_data_dates, train_data[:, 1], label='EURUSD Closing Returns')
ax11.plot(train_data_dates[seq_len:], train_pred, linewidth=3, label='Predicted EURUSD Closing Returns')
ax11.set_title("Training Data", fontsize=18)
ax11.set_xlabel('Dates')
ax11.set_ylabel('EURUSD Closing Returns')
ax11.legend(loc="best", fontsize=12)

#Plot validation data results
ax21 = fig.add_subplot(312)
ax21.plot(val_data_dates, val_data[:, 1], label='EURUSD Closing Returns')
ax21.plot(val_data_dates[seq_len:], val_pred, linewidth=3, label='Predicted EURUSD Closing Returns')
ax21.set_title("Validation Data", fontsize=18)
ax21.set_xlabel('Dates')
ax21.set_ylabel('EURUSD Closing Returns')
ax21.legend(loc="best", fontsize=12)

#Plot test data results
ax31 = fig.add_subplot(313)
ax31.plot(test_data_dates, test_data[:, 1], label='EURUSD Closing Returns')
ax31.plot(test_data_dates[seq_len:], test_pred, linewidth=3, label='Predicted EURUSD Closing Returns')
ax31.set_title("Test Data", fontsize=18)
ax31.set_xlabel('Dates')
ax31.set_ylabel('EURUSD Closing Returns')
ax31.legend(loc="best", fontsize=12)

# %% [markdown]
# ## Model metrics

# %%
'''Display model metrics'''

fig = plt.figure(figsize=(15,20))
st = fig.suptitle("Transformer + TimeEmbedding Model Metrics", fontsize=22)
st.set_y(0.92)

#Plot model loss
ax1 = fig.add_subplot(311)
ax1.plot(history['accuracy'], label='Training loss (accuracy)')
ax1.plot(history['val_accuracy'], label='Test loss (accuracy)')
ax1.set_title("Model accuracy", fontsize=18)
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss (accuracy)')
ax1.legend(loc="best", fontsize=12)

# %% [markdown]
# ## Model architecture overview

# %%
tf.keras.utils.plot_model(
    model,
    to_file="EURUSD_Transformer+TimeEmbedding1.png",
    show_shapes=True,
    show_layer_names=True,
    expand_nested=True,
    dpi=96,)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
#Berechnung Return, Standardabweichung & Sharpe Ratio: Code/Skript von Marius für ARIMA übernehmen
