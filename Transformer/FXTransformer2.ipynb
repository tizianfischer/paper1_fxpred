# %%
import pickle
import numpy as np
from tensorflow import keras
import pandas as pd
import os, datetime
from utils import get_fx_and_metric_data_wo_weekend
import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.losses import MSE, MAE, MAPE
print('Tensorflow version: {}'.format(tf.__version__))

from sklearn.preprocessing import StandardScaler
import scipy
    
import matplotlib.pyplot as plt
plt.style.use('seaborn')

import warnings
warnings.filterwarnings('ignore')
# Out:
# Tensorflow version: 2.4.1

# %% [markdown]
# ## Hyperparameter

# %%
batch_size = 32
seq_len = 128
d_k = 256
d_v = 256
n_heads = 12
ff_dim = 256

# %% [markdown]
# ## Data

# %%
from utils import get_fx_and_metric_data
df = get_fx_and_metric_data_wo_weekend(dtype=np.float32, directory='../data')
df
# Out:
#                      EURUSD BGNE Curncy Bid Open  \
# Dates
# 2020-11-01 19:10:00                     0.000000
# 2020-11-01 19:20:00                     0.000283
# 2020-11-01 19:30:00                     0.000172
# 2020-11-01 19:40:00                     0.000060
# 2020-11-01 19:50:00                    -0.000026
# ...                                          ...
# 2021-07-30 23:10:00                     0.000000
# 2021-07-30 23:20:00                     0.000000
# 2021-07-30 23:30:00                     0.000000
# 2021-07-30 23:40:00                     0.000000
# 2021-07-30 23:50:00                     0.000000
#
#                      EURUSD BGNE Curncy Bid Close  \
# Dates
# 2020-11-01 19:10:00                      0.000000
# 2020-11-01 19:20:00                      0.000275
# 2020-11-01 19:30:00                     -0.000069
# 2020-11-01 19:40:00                      0.000034
# 2020-11-01 19:50:00                      0.000026
# ...                                           ...
# 2021-07-30 23:10:00                      0.000000
# 2021-07-30 23:20:00                      0.000000
# 2021-07-30 23:30:00                      0.000000
# 2021-07-30 23:40:00                      0.000000
# 2021-07-30 23:50:00                      0.000000
#
#                      EURUSD BGNE Curncy Bid High  EURUSD BGNE Curncy Bid Low  \
# Dates
# 2020-11-01 19:10:00                     0.000000                    0.000000
# 2020-11-01 19:20:00                     0.000197                   -0.000507
# 2020-11-01 19:30:00                     0.000017                   -0.000215
# 2020-11-01 19:40:00                    -0.000172                    0.000636
# 2020-11-01 19:50:00                    -0.000026                    0.000584
# ...                                          ...                         ...
# 2021-07-30 23:10:00                     0.000000                    0.000000
# 2021-07-30 23:20:00                     0.000000                    0.000000
# 2021-07-30 23:30:00                     0.000000                    0.000000
# 2021-07-30 23:40:00                     0.000000                    0.000000
# 2021-07-30 23:50:00                     0.000000                    0.000000
#
#                      EURUSD BGNE Curncy Bid Number Ticks  \
# Dates
# 2020-11-01 19:10:00                             0.000000
# 2020-11-01 19:20:00                            -0.978125
# 2020-11-01 19:30:00                             0.380952
# 2020-11-01 19:40:00                             3.310345
# 2020-11-01 19:50:00                            -0.984000
# ...                                                  ...
# 2021-07-30 23:10:00                             0.000000
# 2021-07-30 23:20:00                             0.000000
# 2021-07-30 23:30:00                             0.000000
# 2021-07-30 23:40:00                             0.000000
# 2021-07-30 23:50:00                             0.000000
#
#                      EURUSD BGNE Curncy Ask Open  \
# Dates
# 2020-11-01 19:10:00                     0.000000
# 2020-11-01 19:20:00                     0.002121
# 2020-11-01 19:30:00                     0.000043
# 2020-11-01 19:40:00                    -0.000274
# 2020-11-01 19:50:00                    -0.000909
# ...                                          ...
# 2021-07-30 23:10:00                     0.000000
# 2021-07-30 23:20:00                     0.000000
# 2021-07-30 23:30:00                     0.000000
# 2021-07-30 23:40:00                     0.000000
# 2021-07-30 23:50:00                     0.000000
#
#                      EURUSD BGNE Curncy Ask Close  \
# Dates
# 2020-11-01 19:10:00                      0.000000
# 2020-11-01 19:20:00                      0.001597
# 2020-11-01 19:30:00                      0.000017
# 2020-11-01 19:40:00                     -0.001157
# 2020-11-01 19:50:00                     -0.000009
# ...                                           ...
# 2021-07-30 23:10:00                      0.000000
# 2021-07-30 23:20:00                      0.000000
# 2021-07-30 23:30:00                      0.000000
# 2021-07-30 23:40:00                      0.000000
# 2021-07-30 23:50:00                      0.000000
#
#                      EURUSD BGNE Curncy Ask High  EURUSD BGNE Curncy Ask Low  \
# Dates
# 2020-11-01 19:10:00                     0.000000                    0.000000
# 2020-11-01 19:20:00                     0.001631                    0.001761
# 2020-11-01 19:30:00                     0.000086                    0.000137
# 2020-11-01 19:40:00                    -0.000009                   -0.000926
# 2020-11-01 19:50:00                    -0.001268                    0.000017
# ...                                          ...                         ...
# 2021-07-30 23:10:00                     0.000000                    0.000000
# 2021-07-30 23:20:00                     0.000000                    0.000000
# 2021-07-30 23:30:00                     0.000000                    0.000000
# 2021-07-30 23:40:00                     0.000000                    0.000000
# 2021-07-30 23:50:00                     0.000000                    0.000000
#
#                      EURUSD BGNE Curncy Ask Number Ticks  ...  usdjpy___TAS_K  \
# Dates                                                     ...
# 2020-11-01 19:10:00                             0.000000  ...           40.00
# 2020-11-01 19:20:00                            -0.978125  ...           40.00
# 2020-11-01 19:30:00                             0.380952  ...           40.00
# 2020-11-01 19:40:00                             3.310345  ...           40.00
# 2020-11-01 19:50:00                            -0.984000  ...           40.00
# ...                                                  ...  ...             ...
# 2021-07-30 23:10:00                             0.000000  ...           43.75
# 2021-07-30 23:20:00                             0.000000  ...           43.75
# 2021-07-30 23:30:00                             0.000000  ...           43.75
# 2021-07-30 23:40:00                             0.000000  ...           43.75
# 2021-07-30 23:50:00                             0.000000  ...           43.75
#
#                      usdjpy___TAS_D  usdjpy___TAS_DS  usdjpy___TAS_DSS  \
# Dates
# 2020-11-01 19:10:00       56.000000        62.133335         67.244446
# 2020-11-01 19:20:00       56.000000        62.133335         67.244446
# 2020-11-01 19:30:00       56.000000        62.133335         67.244446
# 2020-11-01 19:40:00       56.000000        62.133335         67.244446
# 2020-11-01 19:50:00       56.000000        62.133335         67.244446
# ...                             ...              ...               ...
# 2021-07-30 23:10:00       20.178572        17.983767         17.992258
# 2021-07-30 23:20:00       20.178572        17.983767         17.992258
# 2021-07-30 23:30:00       20.178572        17.983767         17.992258
# 2021-07-30 23:40:00       20.178572        17.983767         17.992258
# 2021-07-30 23:50:00       20.178572        17.983767         17.992258
#
#                      usdjpy___TRENDER_UP  usdjpy___TRENDER_DN  usdjpy___TMAVG  \
# Dates
# 2020-11-01 19:10:00           104.536598           104.576935      104.551109
# 2020-11-01 19:20:00           104.536598           104.576935      104.551109
# 2020-11-01 19:30:00           104.536598           104.576935      104.551109
# 2020-11-01 19:40:00           104.536598           104.576935      104.551109
# 2020-11-01 19:50:00           104.536598           104.576935      104.552223
# ...                                  ...                  ...             ...
# 2021-07-30 23:10:00           109.763481           109.747704      109.705559
# 2021-07-30 23:20:00           109.763481           109.747704      109.705559
# 2021-07-30 23:30:00           109.763481           109.747704      109.705559
# 2021-07-30 23:40:00           109.763481           109.747704      109.705559
# 2021-07-30 23:50:00           109.763481           109.747704      109.705559
#
#                      usdjpy___VMAVG  usdjpy___WMAVG  usdjpy___WLPR
# Dates
# 2020-11-01 19:10:00      104.620003      104.553337     -66.666664
# 2020-11-01 19:20:00      104.620003      104.553337     -66.666664
# 2020-11-01 19:30:00      104.620003      104.553337     -66.666664
# 2020-11-01 19:40:00      104.620003      104.553337     -66.666664
# 2020-11-01 19:50:00      104.620003      104.552666     -66.666664
# ...                             ...             ...            ...
# 2021-07-30 23:10:00      109.735947      109.706001     -46.153847
# 2021-07-30 23:20:00      109.735947      109.706001     -46.153847
# 2021-07-30 23:30:00      109.735947      109.706001     -46.153847
# 2021-07-30 23:40:00      109.735947      109.706001     -46.153847
# 2021-07-30 23:50:00      109.735947      109.706001     -46.153847
#
# [29012 rows x 1231 columns]

# %%
target = 'EURUSD BGNE Curncy Bid Close'

# %% [markdown]
# ## Create training, validation and test split

# %%
times = sorted(df.index.values)
last_10pct = sorted(df.index.values)[-int(0.1*len(times))] # Last 10% of series
last_20pct = sorted(df.index.values)[-int(0.2*len(times))] # Last 20% of series

df_train = df[(df.index < last_20pct)]  # Training data are 80% of total data
df_val = df[(df.index >= last_20pct) & (df.index < last_10pct)]
df_test = df[(df.index >= last_10pct)]

# Convert pandas columns into arrays
train_data = df_train.values
sc = StandardScaler().fit(train_data)
sc_target = StandardScaler().fit(df_train.loc[:, target].values.reshape(-1, 1))
train_data = sc.transform(train_data)
train_data_dates = df_train.index.values  

val_data = sc.transform(df_val.values)
val_data_dates = df_val.index.values  

test_data = sc.transform(df_test.values)
test_data_dates = df_test.index.values 

print('Training data shape: {}'.format(train_data.shape))
print('Validation data shape: {}'.format(val_data.shape))
print('Test data shape: {}'.format(test_data.shape))

df_train.head()
# Out:
# Training data shape: (23210, 1231)
# Validation data shape: (2901, 1231)
# Test data shape: (2901, 1231)
#                      EURUSD BGNE Curncy Bid Open  \
# Dates
# 2020-11-01 19:10:00                     0.000000
# 2020-11-01 19:20:00                     0.000283
# 2020-11-01 19:30:00                     0.000172
# 2020-11-01 19:40:00                     0.000060
# 2020-11-01 19:50:00                    -0.000026
#
#                      EURUSD BGNE Curncy Bid Close  \
# Dates
# 2020-11-01 19:10:00                      0.000000
# 2020-11-01 19:20:00                      0.000275
# 2020-11-01 19:30:00                     -0.000069
# 2020-11-01 19:40:00                      0.000034
# 2020-11-01 19:50:00                      0.000026
#
#                      EURUSD BGNE Curncy Bid High  EURUSD BGNE Curncy Bid Low  \
# Dates
# 2020-11-01 19:10:00                     0.000000                    0.000000
# 2020-11-01 19:20:00                     0.000197                   -0.000507
# 2020-11-01 19:30:00                     0.000017                   -0.000215
# 2020-11-01 19:40:00                    -0.000172                    0.000636
# 2020-11-01 19:50:00                    -0.000026                    0.000584
#
#                      EURUSD BGNE Curncy Bid Number Ticks  \
# Dates
# 2020-11-01 19:10:00                             0.000000
# 2020-11-01 19:20:00                            -0.978125
# 2020-11-01 19:30:00                             0.380952
# 2020-11-01 19:40:00                             3.310345
# 2020-11-01 19:50:00                            -0.984000
#
#                      EURUSD BGNE Curncy Ask Open  \
# Dates
# 2020-11-01 19:10:00                     0.000000
# 2020-11-01 19:20:00                     0.002121
# 2020-11-01 19:30:00                     0.000043
# 2020-11-01 19:40:00                    -0.000274
# 2020-11-01 19:50:00                    -0.000909
#
#                      EURUSD BGNE Curncy Ask Close  \
# Dates
# 2020-11-01 19:10:00                      0.000000
# 2020-11-01 19:20:00                      0.001597
# 2020-11-01 19:30:00                      0.000017
# 2020-11-01 19:40:00                     -0.001157
# 2020-11-01 19:50:00                     -0.000009
#
#                      EURUSD BGNE Curncy Ask High  EURUSD BGNE Curncy Ask Low  \
# Dates
# 2020-11-01 19:10:00                     0.000000                    0.000000
# 2020-11-01 19:20:00                     0.001631                    0.001761
# 2020-11-01 19:30:00                     0.000086                    0.000137
# 2020-11-01 19:40:00                    -0.000009                   -0.000926
# 2020-11-01 19:50:00                    -0.001268                    0.000017
#
#                      EURUSD BGNE Curncy Ask Number Ticks  ...  usdjpy___TAS_K  \
# Dates                                                     ...
# 2020-11-01 19:10:00                             0.000000  ...            40.0
# 2020-11-01 19:20:00                            -0.978125  ...            40.0
# 2020-11-01 19:30:00                             0.380952  ...            40.0
# 2020-11-01 19:40:00                             3.310345  ...            40.0
# 2020-11-01 19:50:00                            -0.984000  ...            40.0
#
#                      usdjpy___TAS_D  usdjpy___TAS_DS  usdjpy___TAS_DSS  \
# Dates
# 2020-11-01 19:10:00            56.0        62.133335         67.244446
# 2020-11-01 19:20:00            56.0        62.133335         67.244446
# 2020-11-01 19:30:00            56.0        62.133335         67.244446
# 2020-11-01 19:40:00            56.0        62.133335         67.244446
# 2020-11-01 19:50:00            56.0        62.133335         67.244446
#
#                      usdjpy___TRENDER_UP  usdjpy___TRENDER_DN  usdjpy___TMAVG  \
# Dates
# 2020-11-01 19:10:00           104.536598           104.576935      104.551109
# 2020-11-01 19:20:00           104.536598           104.576935      104.551109
# 2020-11-01 19:30:00           104.536598           104.576935      104.551109
# 2020-11-01 19:40:00           104.536598           104.576935      104.551109
# 2020-11-01 19:50:00           104.536598           104.576935      104.552223
#
#                      usdjpy___VMAVG  usdjpy___WMAVG  usdjpy___WLPR
# Dates
# 2020-11-01 19:10:00      104.620003      104.553337     -66.666664
# 2020-11-01 19:20:00      104.620003      104.553337     -66.666664
# 2020-11-01 19:30:00      104.620003      104.553337     -66.666664
# 2020-11-01 19:40:00      104.620003      104.553337     -66.666664
# 2020-11-01 19:50:00      104.620003      104.552666     -66.666664
#
# [5 rows x 1231 columns]

# %% [markdown]
# ## Plot daily changes of close prices and volatility

# %%
fig = plt.figure(figsize=(15,12))
st = fig.suptitle("Data Separation", fontsize=20)
st.set_y(0.95)

###############################################################################

ax1 = fig.add_subplot(211)
ax1.plot(train_data_dates, df_train[target], label='Training data')
ax1.plot(val_data_dates, df_val[target], label='Validation data')
ax1.plot(test_data_dates, df_test[target], label='Test data')
ax1.set_xlabel('Dates')
ax1.set_ylabel('Normalized Closing Returns')
ax1.set_title("Close Price", fontsize=18)
ax1.legend(loc="best", fontsize=12)

###############################################################################

ax2 = fig.add_subplot(212)
ax2.plot(train_data_dates, df_train['EURUSDV1Y Curncy Trade Open'], label='Training data') 
ax2.plot(val_data_dates, df_val['EURUSDV1Y Curncy Trade Open'], label='Validation data') 
ax2.plot(test_data_dates, df_test['EURUSDV1Y Curncy Trade Open'], label='Test data') 
ax2.set_xlabel('Dates')
ax2.set_ylabel('Normalized Volatility Changes')
ax2.set_title("Volatility", fontsize=18)
ax2.legend(loc="best", fontsize=12)

# %% [markdown]
# ## Create chunks of training, validation and test data

# %%
target_id = list(df_train.columns).index(target)
# Training data
X_train, y_train = [], []
for i in range(seq_len, len(train_data)):
    X_train.append(train_data[i-seq_len:i])
    y_train.append(train_data[:, target_id][i])
X_train, y_train = np.array(X_train), np.array(y_train)

###############################################################################

# Validation data
X_val, y_val = [], []
for i in range(seq_len, len(val_data)):
    X_val.append(val_data[i-seq_len:i])
    y_val.append(val_data[:, target_id][i])
X_val, y_val = np.array(X_val), np.array(y_val)

###############################################################################

# Test data
X_test, y_test = [], []
for i in range(seq_len, len(test_data)):
    X_test.append(test_data[i-seq_len:i])
    y_test.append(test_data[:, target_id][i])    
X_test, y_test = np.array(X_test), np.array(y_test)

print('Training set shape', X_train.shape, y_train.shape)
print('Validation set shape', X_val.shape, y_val.shape)
print('Testing set shape' ,X_test.shape, y_test.shape)
# Out:
# Training set shape (23082, 128, 1231) (23082,)
# Validation set shape (2773, 128, 1231) (2773,)
# Testing set shape (2773, 128, 1231) (2773,)

# %% [markdown]
# ## TimeVector

# %%
class Time2Vector(Layer):
    def __init__(self, seq_len, **kwargs):
        super(Time2Vector, self).__init__()
        self.seq_len = seq_len

    def build(self, input_shape):
        '''Initialize weights and biases with shape (batch, seq_len)'''
        self.weights_linear = self.add_weight(name='weight_linear',
                                    shape=(int(self.seq_len),),
                                    initializer='uniform',
                                    trainable=True)

        self.bias_linear = self.add_weight(name='bias_linear',
                                    shape=(int(self.seq_len),),
                                    initializer='uniform',
                                    trainable=True)

        self.weights_periodic = self.add_weight(name='weight_periodic',
                                    shape=(int(self.seq_len),),
                                    initializer='uniform',
                                    trainable=True)

        self.bias_periodic = self.add_weight(name='bias_periodic',
                                    shape=(int(self.seq_len),),
                                    initializer='uniform',
                                    trainable=True)

    def call(self, x):
        '''Calculate linear and periodic time features'''
        x = tf.math.reduce_mean(x[:,:,:4], axis=-1) 
        time_linear = self.weights_linear * x + self.bias_linear # Linear time feature
        time_linear = tf.expand_dims(time_linear, axis=-1) # Add dimension (batch, seq_len, 1)

        time_periodic = tf.math.sin(tf.multiply(x, self.weights_periodic) + self.bias_periodic)
        time_periodic = tf.expand_dims(time_periodic, axis=-1) # Add dimension (batch, seq_len, 1)
        return tf.concat([time_linear, time_periodic], axis=-1) # shape = (batch, seq_len, 2)
   
    def get_config(self): # Needed for saving and loading model with custom layer
        config = super().get_config().copy()
        config.update({'seq_len': self.seq_len})
        return config

# %% [markdown]
# ## Transformer

# %%
class SingleAttention(Layer):
    def __init__(self, d_k, d_v):
        super(SingleAttention, self).__init__()
        self.d_k = d_k
        self.d_v = d_v

    def build(self, input_shape):
        self.query = Dense(self.d_k, 
                           input_shape=input_shape, 
                           kernel_initializer='glorot_uniform', 
                           bias_initializer='glorot_uniform')

        self.key = Dense(self.d_k, 
                         input_shape=input_shape, 
                         kernel_initializer='glorot_uniform', 
                         bias_initializer='glorot_uniform')

        self.value = Dense(self.d_v, 
                           input_shape=input_shape, 
                           kernel_initializer='glorot_uniform', 
                           bias_initializer='glorot_uniform')

    def call(self, inputs): # inputs = (in_seq, in_seq, in_seq)
        q = self.query(inputs[0])
        k = self.key(inputs[1])

        attn_weights = tf.matmul(q, k, transpose_b=True)
        attn_weights = tf.map_fn(lambda x: x/np.sqrt(self.d_k), attn_weights)
        attn_weights = tf.nn.softmax(attn_weights, axis=-1)

        v = self.value(inputs[2])
        attn_out = tf.matmul(attn_weights, v)
        return attn_out    

#############################################################################

class MultiAttention(Layer):
    def __init__(self, d_k, d_v, n_heads):
        super(MultiAttention, self).__init__()
        self.d_k = d_k
        self.d_v = d_v
        self.n_heads = n_heads
        self.attn_heads = list()

    def build(self, input_shape):
        for n in range(self.n_heads):
            self.attn_heads.append(SingleAttention(self.d_k, self.d_v))  

        # input_shape[0]=(batch, seq_len, 7), input_shape[0][-1]=7 
        self.linear = Dense(input_shape[0][-1], 
                            input_shape=input_shape, 
                            kernel_initializer='glorot_uniform', 
                            bias_initializer='glorot_uniform')

    def call(self, inputs):
        attn = [self.attn_heads[i](inputs) for i in range(self.n_heads)]
        concat_attn = tf.concat(attn, axis=-1)
        multi_linear = self.linear(concat_attn)
        return multi_linear   

#############################################################################

class TransformerEncoder(Layer):
    def __init__(self, d_k, d_v, n_heads, ff_dim, dropout=0.1, **kwargs):
        super(TransformerEncoder, self).__init__()
        self.d_k = d_k
        self.d_v = d_v
        self.n_heads = n_heads
        self.ff_dim = ff_dim
        self.attn_heads = list()
        self.dropout_rate = dropout

    def build(self, input_shape):
        self.attn_multi = MultiAttention(self.d_k, self.d_v, self.n_heads)
        self.attn_dropout = Dropout(self.dropout_rate)
        self.attn_normalize = LayerNormalization(input_shape=input_shape, epsilon=1e-6)

        self.ff_conv1D_1 = Conv1D(filters=self.ff_dim, kernel_size=1, activation='relu')
        # input_shape[0]=(batch, seq_len, 7), input_shape[0][-1] = 7 
        self.ff_conv1D_2 = Conv1D(filters=input_shape[0][-1], kernel_size=1) 
        self.ff_dropout = Dropout(self.dropout_rate)
        self.ff_normalize = LayerNormalization(input_shape=input_shape, epsilon=1e-6)    
  
    def call(self, inputs): # inputs = (in_seq, in_seq, in_seq)
        attn_layer = self.attn_multi(inputs)
        attn_layer = self.attn_dropout(attn_layer)
        attn_layer = self.attn_normalize(inputs[0] + attn_layer)

        ff_layer = self.ff_conv1D_1(attn_layer)
        ff_layer = self.ff_conv1D_2(ff_layer)
        ff_layer = self.ff_dropout(ff_layer)
        ff_layer = self.ff_normalize(inputs[0] + ff_layer)
        return ff_layer 

    def get_config(self): # Needed for saving and loading model with custom layer
        config = super().get_config().copy()
        config.update({'d_k': self.d_k,
                       'd_v': self.d_v,
                       'n_heads': self.n_heads,
                       'ff_dim': self.ff_dim,
                       'attn_heads': self.attn_heads,
                       'dropout_rate': self.dropout_rate})
        return config

# %% [markdown]
# ## Model

# %%
def create_model(input_shape):
    '''Initialize time and transformer layers'''
    time_embedding = Time2Vector(seq_len)
    attn_layer1 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)
    attn_layer2 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)
    attn_layer3 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)

    '''Construct model'''
    in_seq = Input(shape=(seq_len, input_shape))
    x = time_embedding(in_seq)
    x = Concatenate(axis=-1)([in_seq, x])
    #   x = Concatenate(axis=-1)([Dense(128)(in_seq), x])
    x = attn_layer1((x, x, x))
    x = attn_layer2((x, x, x))
    x = attn_layer3((x, x, x))
    # x = GlobalAveragePooling1D(data_format='channels_first')(x)
    # x = Dense(256, activation='relu')(x)
    x = Flatten()(x)    
    x = Dropout(0.01)(x)
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.01)(x)
    out = Dense(1, activation='linear')(x)

    model = Model(inputs=in_seq, outputs=out)
    opt = keras.optimizers.Adam(learning_rate=0.00001)
    model.compile(loss='mse', optimizer=opt, metrics=['mae', 'mape'])
    return model


model = create_model(df.shape[1])
model.summary()

callback = tf.keras.callbacks.ModelCheckpoint('../content/Transformer+TimeEmbedding2{epoch:04}.hdf5', 
                                               monitor='val_loss', 
                                               save_best_only=True, verbose=1
                                             )

es = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=8,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)


if True: 
    history = model.fit(X_train, y_train,
                        batch_size=batch_size, 
                        epochs=300,
                        callbacks=[callback],
                        validation_data=(X_val, y_val))  
    with open('../content/history2.pkl', 'wb') as f:
        pickle.dump(history.history, f)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 1231)]  0
# __________________________________________________________________________________________________
# time2_vector (Time2Vector)      (None, 128, 2)       512         input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 128, 1233)    0           input_1[0][0]
#                                                                  time2_vector[0][0]
# __________________________________________________________________________________________________
# transformer_encoder (Transforme (None, 128, 1233)    15799270    concatenate[0][0]
#                                                                  concatenate[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# transformer_encoder_1 (Transfor (None, 128, 1233)    15799270    transformer_encoder[0][0]
#                                                                  transformer_encoder[0][0]
#                                                                  transformer_encoder[0][0]
# __________________________________________________________________________________________________
# transformer_encoder_2 (Transfor (None, 128, 1233)    15799270    transformer_encoder_1[0][0]
#                                                                  transformer_encoder_1[0][0]
#                                                                  transformer_encoder_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 157824)       0           transformer_encoder_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 157824)       0           flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           10100800    dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            65          dropout_1[0][0]
# ==================================================================================================
# Total params: 57,499,187
# Trainable params: 57,499,187
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/300
# 722/722 [==============================] - 827s 1s/step - loss: 1.1976 - mae: 0.7333 - mape: 293.9966 - val_loss: 0.8363 - val_mae: 0.5972 - val_mape: 105.0780
#
# Epoch 00001: val_loss improved from inf to 0.83626, saving model to ../content/Transformer+TimeEmbedding20001.hdf5
# Epoch 2/300
# 722/722 [==============================] - 759s 1s/step - loss: 0.9787 - mae: 0.6522 - mape: 103.2475 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 99.9841
#
# Epoch 00002: val_loss improved from 0.83626 to 0.83438, saving model to ../content/Transformer+TimeEmbedding20002.hdf5
# Epoch 3/300
# 722/722 [==============================] - 769s 1s/step - loss: 0.9952 - mae: 0.6566 - mape: 101.6772 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0014
#
# Epoch 00003: val_loss did not improve from 0.83438
# Epoch 4/300
# 722/722 [==============================] - 783s 1s/step - loss: 0.9865 - mae: 0.6505 - mape: 100.7799 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 99.9737
#
# Epoch 00004: val_loss improved from 0.83438 to 0.83438, saving model to ../content/Transformer+TimeEmbedding20004.hdf5
# Epoch 5/300
# 722/722 [==============================] - 769s 1s/step - loss: 0.9744 - mae: 0.6445 - mape: 99.9925 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 99.9707
#
# Epoch 00005: val_loss improved from 0.83438 to 0.83438, saving model to ../content/Transformer+TimeEmbedding20005.hdf5
# Epoch 6/300
# 722/722 [==============================] - 774s 1s/step - loss: 0.9964 - mae: 0.6512 - mape: 100.2035 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 99.9801
#
# Epoch 00006: val_loss did not improve from 0.83438
# Epoch 7/300
# 722/722 [==============================] - 786s 1s/step - loss: 1.0185 - mae: 0.6512 - mape: 100.3838 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 99.9949
#
# Epoch 00007: val_loss did not improve from 0.83438
# Epoch 8/300
# 722/722 [==============================] - 786s 1s/step - loss: 0.9884 - mae: 0.6505 - mape: 99.9927 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 99.9914
#
# Epoch 00008: val_loss did not improve from 0.83438
# Epoch 9/300
# 722/722 [==============================] - 781s 1s/step - loss: 0.9645 - mae: 0.6435 - mape: 99.9964 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 99.9924
#
# Epoch 00009: val_loss did not improve from 0.83438
# Epoch 10/300
# 722/722 [==============================] - 787s 1s/step - loss: 0.9431 - mae: 0.6461 - mape: 100.0655 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0275
#
# Epoch 00010: val_loss did not improve from 0.83438
# Epoch 11/300
# 722/722 [==============================] - 787s 1s/step - loss: 1.0057 - mae: 0.6521 - mape: 100.0050 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0086
#
# Epoch 00011: val_loss did not improve from 0.83438
# Epoch 12/300
# 722/722 [==============================] - 782s 1s/step - loss: 1.0134 - mae: 0.6558 - mape: 99.9117 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0089
#
# Epoch 00012: val_loss did not improve from 0.83438
# Epoch 13/300
# 722/722 [==============================] - 779s 1s/step - loss: 1.0031 - mae: 0.6486 - mape: 99.9990 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 99.9994
#
# Epoch 00013: val_loss did not improve from 0.83438
# Epoch 14/300
# 722/722 [==============================] - 773s 1s/step - loss: 1.0244 - mae: 0.6503 - mape: 100.0024 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0097
#
# Epoch 00014: val_loss did not improve from 0.83438
# Epoch 15/300
# 722/722 [==============================] - 771s 1s/step - loss: 1.0279 - mae: 0.6585 - mape: 100.0786 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0080
#
# Epoch 00015: val_loss did not improve from 0.83438
# Epoch 16/300
# 722/722 [==============================] - 778s 1s/step - loss: 1.0219 - mae: 0.6515 - mape: 100.0441 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0066
#
# Epoch 00016: val_loss did not improve from 0.83438
# Epoch 17/300
# 722/722 [==============================] - 761s 1s/step - loss: 0.9880 - mae: 0.6478 - mape: 100.0371 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0048
#
# Epoch 00017: val_loss did not improve from 0.83438
# Epoch 18/300
# 722/722 [==============================] - 775s 1s/step - loss: 1.0053 - mae: 0.6570 - mape: 100.0138 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 99.9989
#
# Epoch 00018: val_loss did not improve from 0.83438
# Epoch 19/300
# 722/722 [==============================] - 778s 1s/step - loss: 1.0664 - mae: 0.6618 - mape: 100.0144 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0124
#
# Epoch 00019: val_loss did not improve from 0.83438
# Epoch 20/300
# 722/722 [==============================] - 780s 1s/step - loss: 1.0291 - mae: 0.6586 - mape: 100.0156 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0141
#
# Epoch 00020: val_loss did not improve from 0.83438
# Epoch 21/300
# 722/722 [==============================] - 787s 1s/step - loss: 1.0227 - mae: 0.6571 - mape: 100.0273 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0168
#
# Epoch 00021: val_loss did not improve from 0.83438
# Epoch 22/300
# 722/722 [==============================] - 784s 1s/step - loss: 1.0649 - mae: 0.6583 - mape: 100.0486 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0061
#
# Epoch 00022: val_loss did not improve from 0.83438
# Epoch 23/300
# 722/722 [==============================] - 759s 1s/step - loss: 1.0258 - mae: 0.6540 - mape: 99.9931 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0118
#
# Epoch 00023: val_loss did not improve from 0.83438
# Epoch 24/300
# 722/722 [==============================] - 763s 1s/step - loss: 0.9916 - mae: 0.6544 - mape: 99.9771 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0142
#
# Epoch 00024: val_loss did not improve from 0.83438
# Epoch 25/300
# 722/722 [==============================] - 786s 1s/step - loss: 0.9703 - mae: 0.6495 - mape: 99.9817 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0216
#
# Epoch 00025: val_loss did not improve from 0.83438
# Epoch 26/300
# 722/722 [==============================] - 766s 1s/step - loss: 0.9885 - mae: 0.6485 - mape: 100.0266 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0082
#
# Epoch 00026: val_loss did not improve from 0.83438
# Epoch 27/300
# 722/722 [==============================] - 785s 1s/step - loss: 1.0282 - mae: 0.6581 - mape: 99.9121 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 99.9963
#
# Epoch 00027: val_loss did not improve from 0.83438
# Epoch 28/300
# 722/722 [==============================] - 793s 1s/step - loss: 0.9456 - mae: 0.6455 - mape: 100.0383 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 99.9949
#
# Epoch 00028: val_loss did not improve from 0.83438
# Epoch 29/300
# 722/722 [==============================] - 786s 1s/step - loss: 1.0023 - mae: 0.6470 - mape: 100.0541 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0250
#
# Epoch 00029: val_loss did not improve from 0.83438
# Epoch 30/300
# 722/722 [==============================] - 786s 1s/step - loss: 1.0005 - mae: 0.6565 - mape: 100.0288 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0204
#
# Epoch 00030: val_loss did not improve from 0.83438
# Epoch 31/300
# 722/722 [==============================] - 772s 1s/step - loss: 1.0205 - mae: 0.6561 - mape: 99.9911 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0443
#
# Epoch 00031: val_loss did not improve from 0.83438
# Epoch 32/300
# 722/722 [==============================] - 784s 1s/step - loss: 0.9685 - mae: 0.6485 - mape: 100.0093 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0439
#
# Epoch 00032: val_loss did not improve from 0.83438
# Epoch 33/300
# 722/722 [==============================] - 793s 1s/step - loss: 1.0175 - mae: 0.6563 - mape: 100.0324 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0395
#
# Epoch 00033: val_loss did not improve from 0.83438
# Epoch 34/300
# 722/722 [==============================] - 770s 1s/step - loss: 0.9487 - mae: 0.6493 - mape: 100.0848 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0387
#
# Epoch 00034: val_loss did not improve from 0.83438
# Epoch 35/300
# 722/722 [==============================] - 790s 1s/step - loss: 0.9949 - mae: 0.6523 - mape: 100.0469 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0488
#
# Epoch 00035: val_loss did not improve from 0.83438
# Epoch 36/300
# 722/722 [==============================] - 794s 1s/step - loss: 1.0069 - mae: 0.6533 - mape: 100.0103 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0423
#
# Epoch 00036: val_loss did not improve from 0.83438
# Epoch 37/300
# 722/722 [==============================] - 794s 1s/step - loss: 1.0079 - mae: 0.6510 - mape: 100.1055 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0382
#
# Epoch 00037: val_loss did not improve from 0.83438
# Epoch 38/300
# 722/722 [==============================] - 788s 1s/step - loss: 1.0036 - mae: 0.6560 - mape: 100.0619 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0326
#
# Epoch 00038: val_loss did not improve from 0.83438
# Epoch 39/300
# 722/722 [==============================] - 792s 1s/step - loss: 1.0412 - mae: 0.6547 - mape: 99.9863 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0445
#
# Epoch 00039: val_loss did not improve from 0.83438
# Epoch 40/300
# 722/722 [==============================] - 814s 1s/step - loss: 1.0078 - mae: 0.6505 - mape: 100.0917 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0398
#
# Epoch 00040: val_loss did not improve from 0.83438
# Epoch 41/300
# 722/722 [==============================] - 803s 1s/step - loss: 0.9956 - mae: 0.6503 - mape: 100.0696 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0409
#
# Epoch 00041: val_loss did not improve from 0.83438
# Epoch 42/300
# 722/722 [==============================] - 809s 1s/step - loss: 1.0027 - mae: 0.6543 - mape: 100.0606 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0499
#
# Epoch 00042: val_loss did not improve from 0.83438
# Epoch 43/300
# 722/722 [==============================] - 809s 1s/step - loss: 1.0104 - mae: 0.6506 - mape: 100.0412 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0232
#
# Epoch 00043: val_loss did not improve from 0.83438
# Epoch 44/300
# 722/722 [==============================] - 800s 1s/step - loss: 1.0265 - mae: 0.6554 - mape: 100.1303 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0432
#
# Epoch 00044: val_loss did not improve from 0.83438
# Epoch 45/300
# 722/722 [==============================] - 808s 1s/step - loss: 1.0256 - mae: 0.6522 - mape: 100.0227 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0152
#
# Epoch 00045: val_loss did not improve from 0.83438
# Epoch 46/300
# 722/722 [==============================] - 802s 1s/step - loss: 0.9949 - mae: 0.6529 - mape: 100.0661 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0478
#
# Epoch 00046: val_loss did not improve from 0.83438
# Epoch 47/300
# 722/722 [==============================] - 817s 1s/step - loss: 1.0224 - mae: 0.6538 - mape: 100.1052 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0376
#
# Epoch 00047: val_loss did not improve from 0.83438
# Epoch 48/300
# 722/722 [==============================] - 815s 1s/step - loss: 1.0545 - mae: 0.6583 - mape: 100.0275 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0214
#
# Epoch 00048: val_loss did not improve from 0.83438
# Epoch 49/300
# 722/722 [==============================] - 812s 1s/step - loss: 1.0051 - mae: 0.6522 - mape: 100.0194 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0463
#
# Epoch 00049: val_loss did not improve from 0.83438
# Epoch 50/300
# 722/722 [==============================] - 808s 1s/step - loss: 0.9897 - mae: 0.6532 - mape: 100.0808 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0443
#
# Epoch 00050: val_loss did not improve from 0.83438
# Epoch 51/300
# 722/722 [==============================] - 776s 1s/step - loss: 0.9841 - mae: 0.6470 - mape: 100.1280 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0560
#
# Epoch 00051: val_loss did not improve from 0.83438
# Epoch 52/300
# 722/722 [==============================] - 776s 1s/step - loss: 1.0242 - mae: 0.6530 - mape: 100.0688 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0683
#
# Epoch 00052: val_loss did not improve from 0.83438
# Epoch 53/300
# 722/722 [==============================] - 797s 1s/step - loss: 1.0180 - mae: 0.6543 - mape: 100.0676 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0719
#
# Epoch 00053: val_loss did not improve from 0.83438
# Epoch 54/300
# 722/722 [==============================] - 808s 1s/step - loss: 0.9751 - mae: 0.6528 - mape: 100.0690 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0691
#
# Epoch 00054: val_loss did not improve from 0.83438
# Epoch 55/300
# 722/722 [==============================] - 810s 1s/step - loss: 1.0114 - mae: 0.6553 - mape: 100.0251 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0565
#
# Epoch 00055: val_loss did not improve from 0.83438
# Epoch 56/300
# 722/722 [==============================] - 821s 1s/step - loss: 1.0658 - mae: 0.6615 - mape: 100.1095 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0723
#
# Epoch 00056: val_loss did not improve from 0.83438
# Epoch 57/300
# 722/722 [==============================] - 817s 1s/step - loss: 1.0144 - mae: 0.6527 - mape: 100.0375 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0666
# Epoch 00057: val_loss did not improve from 0.83438
# Epoch 58/300
# 722/722 [==============================] - 811s 1s/step - loss: 1.0443 - mae: 0.6607 - mape: 100.0980 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0563
#
# Epoch 00058: val_loss did not improve from 0.83438
# Epoch 59/300
# 722/722 [==============================] - 801s 1s/step - loss: 1.0217 - mae: 0.6508 - mape: 100.1302 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0653
#
# Epoch 00059: val_loss did not improve from 0.83438
# Epoch 60/300
# 722/722 [==============================] - 795s 1s/step - loss: 1.0333 - mae: 0.6568 - mape: 100.0081 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0638
#
# Epoch 00060: val_loss did not improve from 0.83438
# Epoch 61/300
# 722/722 [==============================] - 799s 1s/step - loss: 0.9893 - mae: 0.6529 - mape: 100.0855 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0629
#
# Epoch 00061: val_loss did not improve from 0.83438
# Epoch 62/300
# 722/722 [==============================] - 821s 1s/step - loss: 1.0220 - mae: 0.6588 - mape: 100.0786 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0692
#
# Epoch 00062: val_loss did not improve from 0.83438
# Epoch 63/300
# 722/722 [==============================] - 815s 1s/step - loss: 0.9859 - mae: 0.6521 - mape: 100.1469 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0585
#
# Epoch 00063: val_loss did not improve from 0.83438
# Epoch 64/300
# 722/722 [==============================] - 812s 1s/step - loss: 0.9616 - mae: 0.6447 - mape: 100.0727 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0686
#
# Epoch 00064: val_loss did not improve from 0.83438
# Epoch 65/300
# 722/722 [==============================] - 801s 1s/step - loss: 0.9885 - mae: 0.6534 - mape: 100.0614 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0757
#
# Epoch 00065: val_loss did not improve from 0.83438
# Epoch 66/300
# 722/722 [==============================] - 757s 1s/step - loss: 1.0301 - mae: 0.6543 - mape: 100.0779 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0728
#
# Epoch 00066: val_loss did not improve from 0.83438
# Epoch 67/300
# 722/722 [==============================] - 804s 1s/step - loss: 1.0311 - mae: 0.6567 - mape: 100.0700 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0602
#
# Epoch 00067: val_loss did not improve from 0.83438
# Epoch 68/300
# 722/722 [==============================] - 803s 1s/step - loss: 0.9655 - mae: 0.6513 - mape: 100.0353 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0721
#
# Epoch 00068: val_loss did not improve from 0.83438
# Epoch 69/300
# 722/722 [==============================] - 813s 1s/step - loss: 0.9589 - mae: 0.6455 - mape: 100.0733 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0918
#
# Epoch 00069: val_loss did not improve from 0.83438
# Epoch 70/300
# 722/722 [==============================] - 805s 1s/step - loss: 1.0166 - mae: 0.6512 - mape: 100.0900 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0849
#
# Epoch 00070: val_loss did not improve from 0.83438
# Epoch 71/300
# 722/722 [==============================] - 795s 1s/step - loss: 0.9859 - mae: 0.6506 - mape: 100.1304 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0736
#
# Epoch 00071: val_loss did not improve from 0.83438
# Epoch 72/300
# 722/722 [==============================] - 814s 1s/step - loss: 0.9707 - mae: 0.6555 - mape: 100.0334 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0639
#
# Epoch 00072: val_loss did not improve from 0.83438
# Epoch 73/300
# 722/722 [==============================] - 799s 1s/step - loss: 0.9806 - mae: 0.6477 - mape: 100.0986 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0743
#
# Epoch 00073: val_loss did not improve from 0.83438
# Epoch 74/300
# 722/722 [==============================] - 797s 1s/step - loss: 1.0418 - mae: 0.6558 - mape: 100.1674 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0821
#
# Epoch 00074: val_loss did not improve from 0.83438
# Epoch 75/300
# 722/722 [==============================] - 808s 1s/step - loss: 0.9626 - mae: 0.6473 - mape: 100.0600 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0934
#
# Epoch 00075: val_loss did not improve from 0.83438
# Epoch 76/300
# 722/722 [==============================] - 810s 1s/step - loss: 1.0064 - mae: 0.6549 - mape: 100.1784 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0918
#
# Epoch 00076: val_loss did not improve from 0.83438
# Epoch 77/300
# 722/722 [==============================] - 816s 1s/step - loss: 1.0139 - mae: 0.6525 - mape: 100.1089 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0775
#
# Epoch 00077: val_loss did not improve from 0.83438
# Epoch 78/300
# 722/722 [==============================] - 816s 1s/step - loss: 0.9616 - mae: 0.6488 - mape: 100.1628 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0795
#
# Epoch 00078: val_loss did not improve from 0.83438
# Epoch 79/300
# 722/722 [==============================] - 806s 1s/step - loss: 0.9628 - mae: 0.6445 - mape: 100.1004 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0811
#
# Epoch 00079: val_loss did not improve from 0.83438
# Epoch 80/300
# 722/722 [==============================] - 808s 1s/step - loss: 1.0325 - mae: 0.6557 - mape: 100.1710 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0812
#
# Epoch 00080: val_loss did not improve from 0.83438
# Epoch 81/300
# 722/722 [==============================] - 818s 1s/step - loss: 1.0352 - mae: 0.6514 - mape: 100.1245 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0887
#
# Epoch 00081: val_loss did not improve from 0.83438
# Epoch 82/300
# 722/722 [==============================] - 814s 1s/step - loss: 0.9551 - mae: 0.6459 - mape: 100.0886 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0731
#
# Epoch 00082: val_loss did not improve from 0.83438
# Epoch 83/300
# 722/722 [==============================] - 814s 1s/step - loss: 0.9783 - mae: 0.6451 - mape: 100.1023 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0894
#
# Epoch 00083: val_loss did not improve from 0.83438
# Epoch 84/300
# 722/722 [==============================] - 809s 1s/step - loss: 1.0242 - mae: 0.6514 - mape: 100.0593 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0738
#
# Epoch 00084: val_loss did not improve from 0.83438
# Epoch 85/300
# 722/722 [==============================] - 807s 1s/step - loss: 0.9493 - mae: 0.6483 - mape: 100.1296 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0932
#
# Epoch 00085: val_loss did not improve from 0.83438
# Epoch 86/300
# 722/722 [==============================] - 805s 1s/step - loss: 0.9930 - mae: 0.6518 - mape: 100.1542 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0969
#
# Epoch 00086: val_loss did not improve from 0.83438
# Epoch 87/300
# 722/722 [==============================] - 809s 1s/step - loss: 0.9863 - mae: 0.6526 - mape: 100.1214 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0992
#
# Epoch 00087: val_loss did not improve from 0.83438
# Epoch 88/300
# 722/722 [==============================] - 804s 1s/step - loss: 1.0190 - mae: 0.6549 - mape: 100.1362 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0853
#
# Epoch 00088: val_loss did not improve from 0.83438
# Epoch 89/300
# 722/722 [==============================] - 815s 1s/step - loss: 0.9484 - mae: 0.6461 - mape: 100.1440 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0779
#
# Epoch 00089: val_loss did not improve from 0.83438
# Epoch 90/300
# 722/722 [==============================] - 816s 1s/step - loss: 0.9515 - mae: 0.6480 - mape: 100.1782 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0739
#
# Epoch 00090: val_loss did not improve from 0.83438
# Epoch 91/300
# 722/722 [==============================] - 762s 1s/step - loss: 1.0009 - mae: 0.6522 - mape: 100.0812 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0875
#
# Epoch 00091: val_loss did not improve from 0.83438
# Epoch 92/300
# 722/722 [==============================] - 813s 1s/step - loss: 1.0333 - mae: 0.6580 - mape: 100.0648 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0800
#
# Epoch 00092: val_loss did not improve from 0.83438
# Epoch 93/300
# 722/722 [==============================] - 805s 1s/step - loss: 1.0163 - mae: 0.6553 - mape: 100.1188 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0799
#
# Epoch 00093: val_loss did not improve from 0.83438
# Epoch 94/300
# 722/722 [==============================] - 817s 1s/step - loss: 0.9676 - mae: 0.6523 - mape: 100.1667 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0685
#
# Epoch 00094: val_loss did not improve from 0.83438
# Epoch 95/300
# 722/722 [==============================] - 783s 1s/step - loss: 0.9134 - mae: 0.6442 - mape: 100.1695 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0634
#
# Epoch 00095: val_loss did not improve from 0.83438
# Epoch 96/300
# 722/722 [==============================] - 778s 1s/step - loss: 1.0575 - mae: 0.6600 - mape: 100.0570 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0704
#
# Epoch 00096: val_loss did not improve from 0.83438
# Epoch 97/300
# 722/722 [==============================] - 783s 1s/step - loss: 0.9826 - mae: 0.6535 - mape: 100.0573 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0712
#
# Epoch 00097: val_loss did not improve from 0.83438
# Epoch 98/300
# 722/722 [==============================] - 792s 1s/step - loss: 1.0657 - mae: 0.6626 - mape: 100.0760 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0785
#
# Epoch 00098: val_loss did not improve from 0.83438
# Epoch 99/300
# 722/722 [==============================] - 785s 1s/step - loss: 1.0214 - mae: 0.6537 - mape: 100.0246 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0850
#
# Epoch 00099: val_loss did not improve from 0.83438
# Epoch 100/300
# 722/722 [==============================] - 788s 1s/step - loss: 0.9761 - mae: 0.6502 - mape: 100.1928 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0796
#
# Epoch 00100: val_loss did not improve from 0.83438
# Epoch 101/300
# 722/722 [==============================] - 780s 1s/step - loss: 0.9825 - mae: 0.6494 - mape: 100.0539 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0734
#
# Epoch 00101: val_loss did not improve from 0.83438
# Epoch 102/300
# 722/722 [==============================] - 784s 1s/step - loss: 1.0122 - mae: 0.6570 - mape: 100.1265 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0889
#
# Epoch 00102: val_loss did not improve from 0.83438
# Epoch 103/300
# 722/722 [==============================] - 764s 1s/step - loss: 1.0249 - mae: 0.6507 - mape: 100.0860 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0771
#
# Epoch 00103: val_loss did not improve from 0.83438
# Epoch 104/300
# 722/722 [==============================] - 786s 1s/step - loss: 1.0568 - mae: 0.6600 - mape: 100.0826 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0868
#
# Epoch 00104: val_loss did not improve from 0.83438
# Epoch 105/300
# 722/722 [==============================] - 784s 1s/step - loss: 0.9815 - mae: 0.6501 - mape: 100.1041 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0930
#
# Epoch 00105: val_loss did not improve from 0.83438
# Epoch 106/300
# 722/722 [==============================] - 786s 1s/step - loss: 1.0239 - mae: 0.6583 - mape: 100.1569 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0967
#
# Epoch 00106: val_loss did not improve from 0.83438
# Epoch 107/300
# 722/722 [==============================] - 791s 1s/step - loss: 1.0296 - mae: 0.6541 - mape: 100.1815 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0970
#
# Epoch 00107: val_loss did not improve from 0.83438
# Epoch 108/300
# 722/722 [==============================] - 784s 1s/step - loss: 1.0165 - mae: 0.6550 - mape: 100.0800 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0953
#
# Epoch 00108: val_loss did not improve from 0.83438
# Epoch 109/300
# 722/722 [==============================] - 781s 1s/step - loss: 1.0250 - mae: 0.6575 - mape: 100.1224 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1151
#
# Epoch 00109: val_loss did not improve from 0.83438
# Epoch 110/300
# 722/722 [==============================] - 786s 1s/step - loss: 1.0083 - mae: 0.6522 - mape: 100.0647 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1046
#
# Epoch 00110: val_loss did not improve from 0.83438
# Epoch 111/300
# 722/722 [==============================] - 783s 1s/step - loss: 1.0183 - mae: 0.6533 - mape: 100.1695 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1012
#
# Epoch 00111: val_loss did not improve from 0.83438
# Epoch 112/300
# 722/722 [==============================] - 785s 1s/step - loss: 0.9733 - mae: 0.6467 - mape: 100.1615 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0969
#
# Epoch 00112: val_loss did not improve from 0.83438
# Epoch 113/300
# 722/722 [==============================] - 799s 1s/step - loss: 0.9837 - mae: 0.6537 - mape: 100.0850 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0856
#
# Epoch 00113: val_loss did not improve from 0.83438
# Epoch 114/300
# 722/722 [==============================] - 779s 1s/step - loss: 1.0438 - mae: 0.6544 - mape: 100.1537 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1020
#
# Epoch 00114: val_loss did not improve from 0.83438
# Epoch 115/300
# 722/722 [==============================] - 763s 1s/step - loss: 0.9754 - mae: 0.6476 - mape: 100.1920 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0928
#
# Epoch 00115: val_loss did not improve from 0.83438
# Epoch 116/300
# 722/722 [==============================] - 748s 1s/step - loss: 1.0228 - mae: 0.6576 - mape: 100.0635 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0914
#
# Epoch 00116: val_loss did not improve from 0.83438
# Epoch 117/300
# 722/722 [==============================] - 761s 1s/step - loss: 1.0463 - mae: 0.6574 - mape: 100.0703 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1088
#
# Epoch 00117: val_loss did not improve from 0.83438
# Epoch 118/300
# 722/722 [==============================] - 761s 1s/step - loss: 0.9969 - mae: 0.6555 - mape: 100.1921 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1070
#
# Epoch 00118: val_loss did not improve from 0.83438
# Epoch 119/300
# 722/722 [==============================] - 763s 1s/step - loss: 0.9911 - mae: 0.6551 - mape: 100.1089 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0831
#
# Epoch 00119: val_loss did not improve from 0.83438
# Epoch 120/300
# 722/722 [==============================] - 748s 1s/step - loss: 1.0477 - mae: 0.6520 - mape: 100.1181 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1009
#
# Epoch 00120: val_loss did not improve from 0.83438
# Epoch 121/300
# 722/722 [==============================] - 761s 1s/step - loss: 1.0449 - mae: 0.6568 - mape: 100.1719 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0897
#
# Epoch 00121: val_loss did not improve from 0.83438
# Epoch 122/300
# 722/722 [==============================] - 763s 1s/step - loss: 0.9997 - mae: 0.6568 - mape: 100.1592 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1049
#
# Epoch 00122: val_loss did not improve from 0.83438
# Epoch 123/300
# 722/722 [==============================] - 754s 1s/step - loss: 1.0027 - mae: 0.6496 - mape: 100.1686 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0884
#
# Epoch 00123: val_loss did not improve from 0.83438
# Epoch 124/300
# 722/722 [==============================] - 753s 1s/step - loss: 0.9324 - mae: 0.6436 - mape: 100.1138 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0952
#
# Epoch 00124: val_loss did not improve from 0.83438
# Epoch 125/300
# 722/722 [==============================] - 767s 1s/step - loss: 1.0027 - mae: 0.6591 - mape: 100.1531 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0794
#
# Epoch 00125: val_loss did not improve from 0.83438
# Epoch 126/300
# 722/722 [==============================] - 765s 1s/step - loss: 1.0349 - mae: 0.6497 - mape: 100.1198 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0895
#
# Epoch 00126: val_loss did not improve from 0.83438
# Epoch 127/300
# 722/722 [==============================] - 758s 1s/step - loss: 1.0208 - mae: 0.6602 - mape: 100.1214 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0921
#
# Epoch 00127: val_loss did not improve from 0.83438
# Epoch 128/300
# 722/722 [==============================] - 761s 1s/step - loss: 0.9767 - mae: 0.6516 - mape: 100.1450 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0832
#
# Epoch 00128: val_loss did not improve from 0.83438
# Epoch 129/300
# 722/722 [==============================] - 761s 1s/step - loss: 1.0082 - mae: 0.6567 - mape: 100.1644 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0869
#
# Epoch 00129: val_loss did not improve from 0.83438
# Epoch 130/300
# 722/722 [==============================] - 760s 1s/step - loss: 1.0008 - mae: 0.6509 - mape: 100.1299 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0849
#
# Epoch 00130: val_loss did not improve from 0.83438
# Epoch 131/300
# 722/722 [==============================] - 737s 1s/step - loss: 0.9883 - mae: 0.6476 - mape: 100.1238 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0819
#
# Epoch 00131: val_loss did not improve from 0.83438
# Epoch 132/300
# 722/722 [==============================] - 764s 1s/step - loss: 0.9779 - mae: 0.6466 - mape: 100.1555 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0976
#
# Epoch 00132: val_loss did not improve from 0.83438
# Epoch 133/300
# 722/722 [==============================] - 765s 1s/step - loss: 1.0172 - mae: 0.6531 - mape: 100.0914 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0861
#
# Epoch 00133: val_loss did not improve from 0.83438
# Epoch 134/300
# 722/722 [==============================] - 767s 1s/step - loss: 1.0228 - mae: 0.6569 - mape: 100.0603 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1043
#
# Epoch 00134: val_loss did not improve from 0.83438
# Epoch 135/300
# 722/722 [==============================] - 769s 1s/step - loss: 0.9898 - mae: 0.6545 - mape: 100.1735 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1049
#
# Epoch 00135: val_loss did not improve from 0.83438
# Epoch 136/300
# 722/722 [==============================] - 756s 1s/step - loss: 1.0451 - mae: 0.6606 - mape: 100.1377 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0983
#
# Epoch 00136: val_loss did not improve from 0.83438
# Epoch 137/300
# 722/722 [==============================] - 762s 1s/step - loss: 0.9823 - mae: 0.6488 - mape: 100.1160 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1096
#
# Epoch 00137: val_loss did not improve from 0.83438
# Epoch 138/300
# 722/722 [==============================] - 759s 1s/step - loss: 0.9850 - mae: 0.6519 - mape: 100.0739 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0924
#
# Epoch 00138: val_loss did not improve from 0.83438
# Epoch 139/300
# 722/722 [==============================] - 758s 1s/step - loss: 0.9411 - mae: 0.6428 - mape: 100.1393 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0784
#
# Epoch 00139: val_loss did not improve from 0.83438
# Epoch 140/300
# 722/722 [==============================] - 761s 1s/step - loss: 1.0908 - mae: 0.6683 - mape: 100.0875 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0914
#
# Epoch 00140: val_loss did not improve from 0.83438
# Epoch 141/300
# 722/722 [==============================] - 765s 1s/step - loss: 0.9868 - mae: 0.6451 - mape: 100.0972 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0848
#
# Epoch 00141: val_loss did not improve from 0.83438
# Epoch 142/300
# 722/722 [==============================] - 770s 1s/step - loss: 0.9797 - mae: 0.6514 - mape: 100.1013 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0711
#
# Epoch 00142: val_loss did not improve from 0.83438
# Epoch 143/300
# 722/722 [==============================] - 765s 1s/step - loss: 1.0102 - mae: 0.6459 - mape: 100.1312 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1014
#
# Epoch 00143: val_loss did not improve from 0.83438
# Epoch 144/300
# 722/722 [==============================] - 730s 1s/step - loss: 0.9983 - mae: 0.6491 - mape: 100.1880 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1175
#
# Epoch 00144: val_loss did not improve from 0.83438
# Epoch 145/300
# 722/722 [==============================] - 760s 1s/step - loss: 0.9765 - mae: 0.6505 - mape: 100.1362 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1012
#
# Epoch 00145: val_loss did not improve from 0.83438
# Epoch 146/300
# 722/722 [==============================] - 769s 1s/step - loss: 1.0348 - mae: 0.6566 - mape: 100.1530 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1022
#
# Epoch 00146: val_loss did not improve from 0.83438
# Epoch 147/300
# 722/722 [==============================] - 757s 1s/step - loss: 1.0224 - mae: 0.6586 - mape: 100.0986 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0841
#
# Epoch 00147: val_loss did not improve from 0.83438
# Epoch 148/300
# 722/722 [==============================] - 758s 1s/step - loss: 0.9762 - mae: 0.6501 - mape: 100.0956 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0833
#
# Epoch 00148: val_loss did not improve from 0.83438
# Epoch 149/300
# 722/722 [==============================] - 768s 1s/step - loss: 1.0334 - mae: 0.6533 - mape: 100.1199 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0822
#
# Epoch 00149: val_loss did not improve from 0.83438
# Epoch 150/300
# 722/722 [==============================] - 757s 1s/step - loss: 1.0165 - mae: 0.6496 - mape: 100.0749 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0899
#
# Epoch 00150: val_loss did not improve from 0.83438
# Epoch 151/300
# 722/722 [==============================] - 712s 986ms/step - loss: 0.9918 - mae: 0.6418 - mape: 100.1888 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0781
#
# Epoch 00151: val_loss did not improve from 0.83438
# Epoch 152/300
# 722/722 [==============================] - 761s 1s/step - loss: 0.9771 - mae: 0.6515 - mape: 100.1531 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0814
#
# Epoch 00152: val_loss did not improve from 0.83438
# Epoch 153/300
# 722/722 [==============================] - 754s 1s/step - loss: 1.0235 - mae: 0.6539 - mape: 100.1057 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0889
#
# Epoch 00153: val_loss did not improve from 0.83438
# Epoch 154/300
# 722/722 [==============================] - 752s 1s/step - loss: 1.0019 - mae: 0.6556 - mape: 100.1510 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0893
#
# Epoch 00154: val_loss did not improve from 0.83438
# Epoch 155/300
# 722/722 [==============================] - 756s 1s/step - loss: 0.9981 - mae: 0.6501 - mape: 100.0900 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0859
#
# Epoch 00155: val_loss did not improve from 0.83438
# Epoch 156/300
# 722/722 [==============================] - 765s 1s/step - loss: 1.0212 - mae: 0.6525 - mape: 100.1107 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0975
#
# Epoch 00156: val_loss did not improve from 0.83438
# Epoch 157/300
# 722/722 [==============================] - 768s 1s/step - loss: 0.9724 - mae: 0.6472 - mape: 100.1153 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0754
#
# Epoch 00157: val_loss did not improve from 0.83438
# Epoch 158/300
# 722/722 [==============================] - 763s 1s/step - loss: 1.0171 - mae: 0.6499 - mape: 100.1468 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0806
#
# Epoch 00158: val_loss did not improve from 0.83438
# Epoch 159/300
# 722/722 [==============================] - 759s 1s/step - loss: 0.9595 - mae: 0.6484 - mape: 100.0870 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0795
#
# Epoch 00159: val_loss did not improve from 0.83438
# Epoch 160/300
# 722/722 [==============================] - 745s 1s/step - loss: 1.0155 - mae: 0.6526 - mape: 100.1771 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1054
#
# Epoch 00160: val_loss did not improve from 0.83438
# Epoch 161/300
# 722/722 [==============================] - 751s 1s/step - loss: 0.9928 - mae: 0.6537 - mape: 100.1080 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0910
#
# Epoch 00161: val_loss did not improve from 0.83438
# Epoch 162/300
# 722/722 [==============================] - 755s 1s/step - loss: 1.0040 - mae: 0.6561 - mape: 100.1565 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1105
#
# Epoch 00162: val_loss did not improve from 0.83438
# Epoch 163/300
# 722/722 [==============================] - 760s 1s/step - loss: 1.0108 - mae: 0.6552 - mape: 100.0869 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1067
#
# Epoch 00163: val_loss did not improve from 0.83438
# Epoch 164/300
# 722/722 [==============================] - 762s 1s/step - loss: 0.9821 - mae: 0.6482 - mape: 100.1046 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0893
#
# Epoch 00164: val_loss did not improve from 0.83438
# Epoch 165/300
# 722/722 [==============================] - 758s 1s/step - loss: 1.0125 - mae: 0.6459 - mape: 100.0838 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0913
#
# Epoch 00165: val_loss did not improve from 0.83438
# Epoch 166/300
# 722/722 [==============================] - 764s 1s/step - loss: 0.9829 - mae: 0.6498 - mape: 100.1810 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0957
#
# Epoch 00166: val_loss did not improve from 0.83438
# Epoch 167/300
# 722/722 [==============================] - 767s 1s/step - loss: 0.9757 - mae: 0.6485 - mape: 100.2194 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0933
#
# Epoch 00167: val_loss did not improve from 0.83438
# Epoch 168/300
# 722/722 [==============================] - 760s 1s/step - loss: 1.0379 - mae: 0.6580 - mape: 100.0881 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0983
#
# Epoch 00168: val_loss did not improve from 0.83438
# Epoch 169/300
# 722/722 [==============================] - 757s 1s/step - loss: 1.0960 - mae: 0.6602 - mape: 100.1099 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0684
#
# Epoch 00169: val_loss did not improve from 0.83438
# Epoch 170/300
# 722/722 [==============================] - 744s 1s/step - loss: 1.0248 - mae: 0.6558 - mape: 100.1408 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0883
#
# Epoch 00170: val_loss did not improve from 0.83438
# Epoch 171/300
# 722/722 [==============================] - 772s 1s/step - loss: 1.0449 - mae: 0.6585 - mape: 100.0859 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0957
#
# Epoch 00171: val_loss did not improve from 0.83438
# Epoch 172/300
# 722/722 [==============================] - 722s 999ms/step - loss: 0.9621 - mae: 0.6519 - mape: 100.1363 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0597
#
# Epoch 00172: val_loss did not improve from 0.83438
# Epoch 173/300
# 722/722 [==============================] - 790s 1s/step - loss: 1.0065 - mae: 0.6562 - mape: 100.0596 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0828
#
# Epoch 00173: val_loss did not improve from 0.83438
# Epoch 174/300
# 722/722 [==============================] - 834s 1s/step - loss: 0.9589 - mae: 0.6522 - mape: 100.1335 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0796
#
# Epoch 00174: val_loss did not improve from 0.83438
# Epoch 175/300
# 722/722 [==============================] - 746s 1s/step - loss: 0.9772 - mae: 0.6528 - mape: 100.1010 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0939
#
# Epoch 00175: val_loss did not improve from 0.83438
# Epoch 176/300
# 722/722 [==============================] - 760s 1s/step - loss: 1.0129 - mae: 0.6548 - mape: 100.0402 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0716
#
# Epoch 00176: val_loss did not improve from 0.83438
# Epoch 177/300
# 722/722 [==============================] - 770s 1s/step - loss: 1.0097 - mae: 0.6587 - mape: 100.1132 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0694
#
# Epoch 00177: val_loss did not improve from 0.83438
# Epoch 178/300
# 722/722 [==============================] - 768s 1s/step - loss: 0.9667 - mae: 0.6471 - mape: 100.1606 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0748
#
# Epoch 00178: val_loss did not improve from 0.83438
# Epoch 179/300
# 722/722 [==============================] - 764s 1s/step - loss: 0.9618 - mae: 0.6475 - mape: 100.1154 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0616
#
# Epoch 00179: val_loss did not improve from 0.83438
# Epoch 180/300
# 722/722 [==============================] - 766s 1s/step - loss: 0.9958 - mae: 0.6548 - mape: 100.0978 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0783
#
# Epoch 00180: val_loss did not improve from 0.83438
# Epoch 181/300
# 722/722 [==============================] - 757s 1s/step - loss: 0.9785 - mae: 0.6570 - mape: 100.1180 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0812
#
# Epoch 00181: val_loss did not improve from 0.83438
# Epoch 182/300
# 722/722 [==============================] - 760s 1s/step - loss: 1.0856 - mae: 0.6592 - mape: 100.1361 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0733
#
# Epoch 00182: val_loss did not improve from 0.83438
# Epoch 183/300
# 722/722 [==============================] - 762s 1s/step - loss: 0.9688 - mae: 0.6488 - mape: 100.1120 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0772
#
# Epoch 00183: val_loss did not improve from 0.83438
# Epoch 184/300
# 722/722 [==============================] - 766s 1s/step - loss: 1.0320 - mae: 0.6586 - mape: 100.1042 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0588
#
# Epoch 00184: val_loss did not improve from 0.83438
# Epoch 185/300
# 722/722 [==============================] - 764s 1s/step - loss: 0.9538 - mae: 0.6528 - mape: 100.0960 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0637
#
# Epoch 00185: val_loss did not improve from 0.83438
# Epoch 186/300
# 722/722 [==============================] - 768s 1s/step - loss: 0.9709 - mae: 0.6520 - mape: 99.9919 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0616
#
# Epoch 00186: val_loss did not improve from 0.83438
# Epoch 187/300
# 722/722 [==============================] - 764s 1s/step - loss: 0.9517 - mae: 0.6438 - mape: 100.0856 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0601
#
# Epoch 00187: val_loss did not improve from 0.83438
# Epoch 188/300
# 722/722 [==============================] - 766s 1s/step - loss: 0.9843 - mae: 0.6578 - mape: 100.1519 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0619
#
# Epoch 00188: val_loss did not improve from 0.83438
# Epoch 189/300
# 722/722 [==============================] - 754s 1s/step - loss: 1.0011 - mae: 0.6569 - mape: 100.0883 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0771
#
# Epoch 00189: val_loss did not improve from 0.83438
# Epoch 190/300
# 722/722 [==============================] - 762s 1s/step - loss: 1.0048 - mae: 0.6551 - mape: 100.0940 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0486
#
# Epoch 00190: val_loss did not improve from 0.83438
# Epoch 191/300
# 722/722 [==============================] - 720s 997ms/step - loss: 1.0456 - mae: 0.6574 - mape: 100.0494 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0534
#
# Epoch 00191: val_loss did not improve from 0.83438
# Epoch 192/300
# 722/722 [==============================] - 760s 1s/step - loss: 0.9710 - mae: 0.6478 - mape: 100.0461 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0631
#
# Epoch 00192: val_loss did not improve from 0.83438
# Epoch 193/300
# 722/722 [==============================] - 761s 1s/step - loss: 0.9381 - mae: 0.6432 - mape: 100.1255 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0723
#
# Epoch 00193: val_loss did not improve from 0.83438
# Epoch 194/300
# 722/722 [==============================] - 765s 1s/step - loss: 1.0047 - mae: 0.6528 - mape: 100.0662 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0570
#
# Epoch 00194: val_loss did not improve from 0.83438
# Epoch 195/300
# 722/722 [==============================] - 762s 1s/step - loss: 0.9558 - mae: 0.6453 - mape: 100.0265 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0590
#
# Epoch 00195: val_loss did not improve from 0.83438
# Epoch 196/300
# 722/722 [==============================] - 754s 1s/step - loss: 1.0093 - mae: 0.6487 - mape: 100.0899 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0599
#
# Epoch 00196: val_loss did not improve from 0.83438
# Epoch 197/300
# 722/722 [==============================] - 759s 1s/step - loss: 1.0239 - mae: 0.6600 - mape: 100.0899 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0542
#
# ...
#
# Epoch 00230: val_loss did not improve from 0.83438
# Epoch 231/300
# 722/722 [==============================] - 761s 1s/step - loss: 1.0451 - mae: 0.6609 - mape: 100.1312 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0759
#
# Epoch 00231: val_loss did not improve from 0.83438
# Epoch 232/300
# 722/722 [==============================] - 759s 1s/step - loss: 1.0130 - mae: 0.6491 - mape: 100.0891 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0759
#
# Epoch 00232: val_loss did not improve from 0.83438
# Epoch 233/300
# 722/722 [==============================] - 752s 1s/step - loss: 0.9904 - mae: 0.6549 - mape: 100.0359 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0596
#
# Epoch 00233: val_loss did not improve from 0.83438
# Epoch 234/300
# 722/722 [==============================] - 757s 1s/step - loss: 1.0237 - mae: 0.6535 - mape: 100.0964 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0814
#
# Epoch 00234: val_loss did not improve from 0.83438
# Epoch 235/300
# 722/722 [==============================] - 751s 1s/step - loss: 1.0398 - mae: 0.6585 - mape: 100.0031 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0760
#
# Epoch 00235: val_loss did not improve from 0.83438
# Epoch 236/300
# 722/722 [==============================] - 755s 1s/step - loss: 1.0204 - mae: 0.6556 - mape: 100.1135 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1013
#
# Epoch 00236: val_loss did not improve from 0.83438
# Epoch 237/300
# 722/722 [==============================] - 757s 1s/step - loss: 0.9479 - mae: 0.6408 - mape: 100.0393 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0696
#
# Epoch 00237: val_loss did not improve from 0.83438
# Epoch 238/300
# 722/722 [==============================] - 764s 1s/step - loss: 0.9812 - mae: 0.6434 - mape: 100.0428 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0775
#
# Epoch 00238: val_loss did not improve from 0.83438
# Epoch 239/300
# 722/722 [==============================] - 760s 1s/step - loss: 1.0265 - mae: 0.6614 - mape: 100.0650 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0560
#
# Epoch 00239: val_loss did not improve from 0.83438
# Epoch 240/300
# 722/722 [==============================] - 751s 1s/step - loss: 0.9868 - mae: 0.6419 - mape: 100.0744 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0594
#
# Epoch 00240: val_loss did not improve from 0.83438
# Epoch 241/300
# 722/722 [==============================] - 744s 1s/step - loss: 1.0454 - mae: 0.6521 - mape: 100.0767 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0633
#
# Epoch 00241: val_loss did not improve from 0.83438
# Epoch 242/300
# 722/722 [==============================] - 744s 1s/step - loss: 0.9842 - mae: 0.6537 - mape: 100.0446 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0634
#
# Epoch 00242: val_loss did not improve from 0.83438
# Epoch 243/300
# 722/722 [==============================] - 762s 1s/step - loss: 0.9765 - mae: 0.6475 - mape: 100.0636 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0879
#
# Epoch 00243: val_loss did not improve from 0.83438
# Epoch 244/300
# 722/722 [==============================] - 760s 1s/step - loss: 0.9846 - mae: 0.6510 - mape: 100.2140 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0824
#
# Epoch 00244: val_loss did not improve from 0.83438
# Epoch 245/300
# 722/722 [==============================] - 763s 1s/step - loss: 1.0155 - mae: 0.6515 - mape: 100.1649 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0948
#
# Epoch 00245: val_loss did not improve from 0.83438
# Epoch 246/300
# 722/722 [==============================] - 758s 1s/step - loss: 1.0544 - mae: 0.6547 - mape: 100.1928 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0963
#
# Epoch 00246: val_loss did not improve from 0.83438
# Epoch 247/300
# 722/722 [==============================] - 755s 1s/step - loss: 1.0107 - mae: 0.6516 - mape: 100.1349 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0975
#
# Epoch 00247: val_loss did not improve from 0.83438
# Epoch 248/300
# 722/722 [==============================] - 765s 1s/step - loss: 0.9791 - mae: 0.6452 - mape: 100.1369 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1005
#
# Epoch 00248: val_loss did not improve from 0.83438
# Epoch 249/300
# 722/722 [==============================] - 764s 1s/step - loss: 1.0020 - mae: 0.6476 - mape: 100.1455 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0818
#
# Epoch 00249: val_loss did not improve from 0.83438
# Epoch 250/300
# 722/722 [==============================] - 768s 1s/step - loss: 1.0077 - mae: 0.6524 - mape: 100.1186 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0698
#
# Epoch 00250: val_loss did not improve from 0.83438
# Epoch 251/300
# 722/722 [==============================] - 763s 1s/step - loss: 0.9767 - mae: 0.6518 - mape: 100.0975 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0809
#
# Epoch 00251: val_loss did not improve from 0.83438
# Epoch 252/300
# 722/722 [==============================] - 760s 1s/step - loss: 0.9671 - mae: 0.6497 - mape: 100.1452 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0791
#
# Epoch 00252: val_loss did not improve from 0.83438
# Epoch 253/300
# 722/722 [==============================] - 760s 1s/step - loss: 1.0531 - mae: 0.6632 - mape: 100.1346 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0972
#
# Epoch 00253: val_loss did not improve from 0.83438
# Epoch 254/300
# 722/722 [==============================] - 757s 1s/step - loss: 0.9944 - mae: 0.6554 - mape: 100.1653 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0869
#
# Epoch 00254: val_loss did not improve from 0.83438
# Epoch 255/300
# 722/722 [==============================] - 737s 1s/step - loss: 0.9728 - mae: 0.6513 - mape: 100.1327 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1046
#
# Epoch 00255: val_loss did not improve from 0.83438
# Epoch 256/300
# 722/722 [==============================] - 760s 1s/step - loss: 0.9957 - mae: 0.6530 - mape: 100.1905 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1030
#
# Epoch 00256: val_loss did not improve from 0.83438
# Epoch 257/300
# 722/722 [==============================] - 768s 1s/step - loss: 1.0682 - mae: 0.6587 - mape: 100.0972 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0902
#
# Epoch 00257: val_loss did not improve from 0.83438
# Epoch 258/300
# 722/722 [==============================] - 762s 1s/step - loss: 1.0134 - mae: 0.6526 - mape: 100.1701 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0986
#
# Epoch 00258: val_loss did not improve from 0.83438
# Epoch 259/300
# 722/722 [==============================] - 767s 1s/step - loss: 0.9705 - mae: 0.6473 - mape: 100.1007 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0947
#
# Epoch 00259: val_loss did not improve from 0.83438
# Epoch 260/300
# 722/722 [==============================] - 766s 1s/step - loss: 0.9883 - mae: 0.6529 - mape: 100.1576 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1250
#
# Epoch 00260: val_loss did not improve from 0.83438
# Epoch 261/300
# 722/722 [==============================] - 745s 1s/step - loss: 0.9667 - mae: 0.6486 - mape: 100.1762 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1200
#
# Epoch 00261: val_loss did not improve from 0.83438
# Epoch 262/300
# 722/722 [==============================] - 765s 1s/step - loss: 0.9979 - mae: 0.6497 - mape: 100.0965 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1075
#
# Epoch 00262: val_loss did not improve from 0.83438
# Epoch 263/300
# 722/722 [==============================] - 766s 1s/step - loss: 1.0449 - mae: 0.6555 - mape: 100.0962 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1015
#
# Epoch 00263: val_loss did not improve from 0.83438
# Epoch 264/300
# 722/722 [==============================] - 765s 1s/step - loss: 1.0221 - mae: 0.6541 - mape: 100.1610 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1039
#
# Epoch 00264: val_loss did not improve from 0.83438
# Epoch 265/300
# 722/722 [==============================] - 736s 1s/step - loss: 1.0017 - mae: 0.6512 - mape: 100.1164 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1203
#
# Epoch 00265: val_loss did not improve from 0.83438
# Epoch 266/300
# 722/722 [==============================] - 755s 1s/step - loss: 1.0416 - mae: 0.6575 - mape: 100.1704 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1136
#
# Epoch 00266: val_loss did not improve from 0.83438
# Epoch 267/300
# 722/722 [==============================] - 744s 1s/step - loss: 0.9679 - mae: 0.6511 - mape: 100.1350 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1034
#
# Epoch 00267: val_loss did not improve from 0.83438
# Epoch 268/300
# 722/722 [==============================] - 756s 1s/step - loss: 0.9134 - mae: 0.6371 - mape: 100.1921 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1054
#
# Epoch 00268: val_loss did not improve from 0.83438
# Epoch 269/300
# 722/722 [==============================] - 766s 1s/step - loss: 1.0574 - mae: 0.6598 - mape: 100.0957 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0881
#
# Epoch 00269: val_loss did not improve from 0.83438
# Epoch 270/300
# 722/722 [==============================] - 754s 1s/step - loss: 0.9827 - mae: 0.6493 - mape: 100.1184 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0773
#
# Epoch 00270: val_loss did not improve from 0.83438
# Epoch 271/300
# 722/722 [==============================] - 746s 1s/step - loss: 0.9756 - mae: 0.6489 - mape: 100.1526 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0980
#
# Epoch 00271: val_loss did not improve from 0.83438
# Epoch 272/300
# 722/722 [==============================] - 761s 1s/step - loss: 1.0000 - mae: 0.6528 - mape: 100.1288 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1066
#
# Epoch 00272: val_loss did not improve from 0.83438
# Epoch 273/300
# 722/722 [==============================] - 763s 1s/step - loss: 0.9798 - mae: 0.6532 - mape: 100.1475 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1046
#
# Epoch 00273: val_loss did not improve from 0.83438
# Epoch 274/300
# 722/722 [==============================] - 762s 1s/step - loss: 0.9525 - mae: 0.6466 - mape: 100.1390 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0960
#
# Epoch 00274: val_loss did not improve from 0.83438
# Epoch 275/300
# 722/722 [==============================] - 763s 1s/step - loss: 1.0116 - mae: 0.6535 - mape: 100.1297 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0745
#
# Epoch 00275: val_loss did not improve from 0.83438
# Epoch 276/300
# 722/722 [==============================] - 759s 1s/step - loss: 1.0015 - mae: 0.6508 - mape: 100.0393 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0812
#
# Epoch 00276: val_loss did not improve from 0.83438
# Epoch 277/300
# 722/722 [==============================] - 751s 1s/step - loss: 1.0139 - mae: 0.6578 - mape: 100.1278 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1129
#
# Epoch 00277: val_loss did not improve from 0.83438
# Epoch 278/300
# 722/722 [==============================] - 764s 1s/step - loss: 1.0070 - mae: 0.6560 - mape: 100.1718 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0895
#
# Epoch 00278: val_loss did not improve from 0.83438
# Epoch 279/300
# 722/722 [==============================] - 751s 1s/step - loss: 1.0200 - mae: 0.6550 - mape: 100.0799 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1015
#
# Epoch 00279: val_loss did not improve from 0.83438
# Epoch 280/300
# 722/722 [==============================] - 749s 1s/step - loss: 1.0812 - mae: 0.6559 - mape: 100.1963 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1014
#
# Epoch 00280: val_loss did not improve from 0.83438
# Epoch 281/300
# 722/722 [==============================] - 725s 1s/step - loss: 0.9861 - mae: 0.6516 - mape: 100.1729 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1188
#
# Epoch 00281: val_loss did not improve from 0.83438
# Epoch 282/300
# 722/722 [==============================] - 755s 1s/step - loss: 0.9654 - mae: 0.6420 - mape: 100.1569 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1253
#
# Epoch 00282: val_loss did not improve from 0.83438
# Epoch 283/300
# 722/722 [==============================] - 770s 1s/step - loss: 1.0111 - mae: 0.6540 - mape: 100.1571 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1037
#
# Epoch 00283: val_loss did not improve from 0.83438
# Epoch 284/300
# 722/722 [==============================] - 755s 1s/step - loss: 0.9703 - mae: 0.6548 - mape: 100.1208 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1016
#
# Epoch 00284: val_loss did not improve from 0.83438
# Epoch 285/300
# 722/722 [==============================] - 783s 1s/step - loss: 1.0097 - mae: 0.6507 - mape: 100.2344 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1104
#
# Epoch 00285: val_loss did not improve from 0.83438
# Epoch 286/300
# 722/722 [==============================] - 773s 1s/step - loss: 0.9557 - mae: 0.6500 - mape: 100.0828 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0884
#
# Epoch 00286: val_loss did not improve from 0.83438
# Epoch 287/300
# 722/722 [==============================] - 739s 1s/step - loss: 0.9623 - mae: 0.6465 - mape: 100.0364 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0970
#
# Epoch 00287: val_loss did not improve from 0.83438
# Epoch 288/300
# 722/722 [==============================] - 796s 1s/step - loss: 1.0564 - mae: 0.6578 - mape: 100.0556 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1058
#
# Epoch 00288: val_loss did not improve from 0.83438
# Epoch 289/300
# 722/722 [==============================] - 768s 1s/step - loss: 0.9934 - mae: 0.6562 - mape: 100.1647 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1147
#
# Epoch 00289: val_loss did not improve from 0.83438
# Epoch 290/300
# 722/722 [==============================] - 741s 1s/step - loss: 0.9851 - mae: 0.6514 - mape: 100.0706 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0923
#
# Epoch 00290: val_loss did not improve from 0.83438
# Epoch 291/300
# 722/722 [==============================] - 763s 1s/step - loss: 1.0014 - mae: 0.6523 - mape: 100.1670 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0917
#
# Epoch 00291: val_loss did not improve from 0.83438
# Epoch 292/300
# 722/722 [==============================] - 805s 1s/step - loss: 1.1188 - mae: 0.6629 - mape: 100.1828 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0971
#
# Epoch 00292: val_loss did not improve from 0.83438
# Epoch 293/300
# 722/722 [==============================] - 799s 1s/step - loss: 1.0721 - mae: 0.6584 - mape: 100.1186 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0921
#
# Epoch 00293: val_loss did not improve from 0.83438
# Epoch 294/300
# 722/722 [==============================] - 814s 1s/step - loss: 1.0650 - mae: 0.6591 - mape: 100.1436 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1035
#
# Epoch 00294: val_loss did not improve from 0.83438
# Epoch 295/300
# 722/722 [==============================] - 817s 1s/step - loss: 0.9365 - mae: 0.6411 - mape: 100.2181 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0996
#
# Epoch 00295: val_loss did not improve from 0.83438
# Epoch 296/300
# 722/722 [==============================] - 816s 1s/step - loss: 1.0018 - mae: 0.6503 - mape: 100.1642 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1040
#
# Epoch 00296: val_loss did not improve from 0.83438
# Epoch 297/300
# 722/722 [==============================] - 814s 1s/step - loss: 1.0189 - mae: 0.6541 - mape: 100.1216 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1209
#
# Epoch 00297: val_loss did not improve from 0.83438
# Epoch 298/300
# 722/722 [==============================] - 785s 1s/step - loss: 1.0288 - mae: 0.6631 - mape: 100.0803 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1112
#
# Epoch 00298: val_loss did not improve from 0.83438
# Epoch 299/300
# 722/722 [==============================] - 815s 1s/step - loss: 1.0105 - mae: 0.6573 - mape: 100.2275 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1416
#
# Epoch 00299: val_loss did not improve from 0.83438
# Epoch 300/300
# 722/722 [==============================] - 814s 1s/step - loss: 0.9397 - mae: 0.6497 - mape: 100.1249 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.1210
#
# Epoch 00300: val_loss did not improve from 0.83438

# %%
model_last = sorted([i for i in os.listdir('../content') if 'hdf5' in i and 'Transformer+TimeEmbedding2' in i])[-1]

# %%
model = tf.keras.models.load_model(
    os.path.join('../content', model_last),
    custom_objects={
        'Time2Vector': Time2Vector,
        'SingleAttention': SingleAttention,
        'MultiAttention': MultiAttention,
        'TransformerEncoder': TransformerEncoder
    }
)
with open('../content/history2.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
###############################################################################
'''Calculate predictions and metrics'''

#Calculate predication for training, validation and test data
train_pred = model.predict(X_train)
val_pred = model.predict(X_val)
test_pred = model.predict(X_test)

#Print evaluation metrics for all datasets
train_eval = model.evaluate(X_train, y_train, verbose=0)
val_eval = model.evaluate(X_val, y_val, verbose=0)
test_eval = model.evaluate(X_test, y_test, verbose=0)
print(' ')
print('Evaluation metrics')
print('Training Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(train_eval[0], train_eval[1], train_eval[2]))
print('Validation Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(val_eval[0], val_eval[1], val_eval[2]))
print('Test Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(test_eval[0], test_eval[1], test_eval[2]))
# Out:
#
# Evaluation metrics
# Training Data - Loss: 1.0019, MAE: 0.6524, MAPE: 100.0228
# Validation Data - Loss: 0.8344, MAE: 0.5964, MAPE: 99.9707
# Test Data - Loss: 0.6875, MAE: 0.5652, MAPE: 99.9738

# %% [markdown]
# ### Training error

# %%
def mde(y_true, y_pred):
    return 1 - np.equal(y_true[1:] - y_true[:-1] >= 0, y_pred[1:] - y_true[:-1] >= 0).mean()

# %%
y = sc_target.inverse_transform(y_train.reshape(-1, 1))
y_pred = sc_target.inverse_transform(train_pred)
print(f'mse: {MSE(y.flatten(), y_pred.flatten()).numpy()}')
print(f'mae: {MAE(y.flatten(), y_pred.flatten()).numpy()}')
print(f'mape: {MAPE(y.flatten(), y_pred.flatten()).numpy()}')
print(f'mde: {mde(y.flatten(), y_pred.flatten())}')
# Out:
# mse: 1.1354895690374178e-07
# mae: 0.0002196430432377383
# mape: 173.29763793945312
# mde: 0.23603829990035097

# %% [markdown]
# ### Validation Error

# %%
y = sc_target.inverse_transform(y_val.reshape(-1, 1))
y_pred = sc_target.inverse_transform(val_pred)
print(f'mse: {MSE(y.flatten(), y_pred.flatten()).numpy()}')
print(f'mae: {MAE(y.flatten(), y_pred.flatten()).numpy()}')
print(f'mape: {MAPE(y.flatten(), y_pred.flatten()).numpy()}')
print(f'mde: {mde(y.flatten(), y_pred.flatten())}')
# Out:
# mse: 9.456659455508998e-08
# mae: 0.00020079087698832154
# mape: 154.02816772460938
# mde: 0.237012987012987

# %% [markdown]
# ### Test Error

# %%
y = sc_target.inverse_transform(y_test.reshape(-1, 1))
y_pred = sc_target.inverse_transform(test_pred)
print(f'mse: {MSE(y.flatten(), y_pred.flatten()).numpy()}')
print(f'mae: {MAE(y.flatten(), y_pred.flatten()).numpy()}')
print(f'mape: {MAPE(y.flatten(), y_pred.flatten()).numpy()}')
print(f'mde: {mde(y.flatten(), y_pred.flatten())}')
# Out:
# mse: 7.791741296614418e-08
# mae: 0.00019026790687348694
# mape: 150.03890991210938
# mde: 0.24422799422799424

# %% [markdown]
# ## Display Results

# %%
###############################################################################
'''Display results'''

fig = plt.figure(figsize=(15,20))
st = fig.suptitle("Transformer + TimeEmbedding Model", fontsize=22)
st.set_y(0.92)

#Plot training data results
ax11 = fig.add_subplot(311)
ax11.plot(train_data_dates, train_data[:, 1], label='EURUSD Closing Returns')
ax11.plot(train_data_dates[seq_len:], train_pred, linewidth=3, label='Predicted EURUSD Closing Returns')
ax11.set_title("Training Data", fontsize=18)
ax11.set_xlabel('Dates')
ax11.set_ylabel('EURUSD Closing Returns')
ax11.legend(loc="best", fontsize=12)

#Plot validation data results
ax21 = fig.add_subplot(312)
ax21.plot(val_data_dates, val_data[:, 1], label='EURUSD Closing Returns')
ax21.plot(val_data_dates[seq_len:], val_pred, linewidth=3, label='Predicted EURUSD Closing Returns')
ax21.set_title("Validation Data", fontsize=18)
ax21.set_xlabel('Dates')
ax21.set_ylabel('EURUSD Closing Returns')
ax21.legend(loc="best", fontsize=12)

#Plot test data results
ax31 = fig.add_subplot(313)
ax31.plot(test_data_dates, test_data[:, 1], label='EURUSD Closing Returns')
ax31.plot(test_data_dates[seq_len:], test_pred, linewidth=3, label='Predicted EURUSD Closing Returns')
ax31.set_title("Test Data", fontsize=18)
ax31.set_xlabel('Dates')
ax31.set_ylabel('EURUSD Closing Returns')
ax31.legend(loc="best", fontsize=12)

# %% [markdown]
# ## Model metrics

# %%
'''Display model metrics'''

fig = plt.figure(figsize=(15,20))
st = fig.suptitle("Transformer + TimeEmbedding Model Metrics", fontsize=22)
st.set_y(0.92)

#Plot model loss
ax1 = fig.add_subplot(311)
ax1.plot(history['loss'], label='Training loss (MSE)')
ax1.plot(history['val_loss'], label='Test loss (MSE)')
ax1.set_title("Model loss", fontsize=18)
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss (MSE)')
ax1.legend(loc="best", fontsize=12)

#Plot MAE
ax2 = fig.add_subplot(312)
ax2.plot(history['mae'], label='Training MAE')
ax2.plot(history['val_mae'], label='Test MAE')
ax2.set_title("Model metric - Mean average error (MAE)", fontsize=18)
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Mean average error (MAE)')
ax2.legend(loc="best", fontsize=12)

#Plot MAPE
ax3 = fig.add_subplot(313)
ax3.plot(history['mape'], label='Training MAPE')
ax3.plot(history['val_mape'], label='Test MAPE')
ax3.set_title("Model metric - Mean average percentage error (MAPE)", fontsize=18)
ax3.set_xlabel('Epoch')
ax3.set_ylabel('Mean average percentage error (MAPE)')
ax3.legend(loc="best", fontsize=12)

# %% [markdown]
# ## Model architecture overview

# %%
tf.keras.utils.plot_model(
    model,
    to_file="EURUSD_Transformer+TimeEmbedding1.png",
    show_shapes=True,
    show_layer_names=True,
    expand_nested=True,
    dpi=96,)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
