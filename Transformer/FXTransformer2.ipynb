# %%
import pickle
import numpy as np
from tensorflow import keras
import pandas as pd
import os, datetime
from utils import get_fx_and_metric_data_wo_weekend
import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.losses import MSE, MAE, MAPE
print('Tensorflow version: {}'.format(tf.__version__))

from sklearn.preprocessing import StandardScaler
import scipy
    
import matplotlib.pyplot as plt
plt.style.use('seaborn')

import warnings
warnings.filterwarnings('ignore')
# Out:
# Tensorflow version: 2.4.1

# %% [markdown]
# ## Hyperparameter

# %%
batch_size = 32
seq_len = 128
d_k = 256
d_v = 256
n_heads = 12
ff_dim = 256

# %% [markdown]
# ## Data

# %%
from utils import get_fx_and_metric_data
df = get_fx_and_metric_data_wo_weekend(dtype=np.float32, directory='../data')
df
# Out:
#                      EURUSD BGNE Curncy Bid Open  \
# Dates
# 2020-11-01 19:10:00                     0.000000
# 2020-11-01 19:20:00                     0.000283
# 2020-11-01 19:30:00                     0.000172
# 2020-11-01 19:40:00                     0.000060
# 2020-11-01 19:50:00                    -0.000026
# ...                                          ...
# 2021-07-30 23:10:00                     0.000000
# 2021-07-30 23:20:00                     0.000000
# 2021-07-30 23:30:00                     0.000000
# 2021-07-30 23:40:00                     0.000000
# 2021-07-30 23:50:00                     0.000000
#
#                      EURUSD BGNE Curncy Bid Close  \
# Dates
# 2020-11-01 19:10:00                      0.000000
# 2020-11-01 19:20:00                      0.000275
# 2020-11-01 19:30:00                     -0.000069
# 2020-11-01 19:40:00                      0.000034
# 2020-11-01 19:50:00                      0.000026
# ...                                           ...
# 2021-07-30 23:10:00                      0.000000
# 2021-07-30 23:20:00                      0.000000
# 2021-07-30 23:30:00                      0.000000
# 2021-07-30 23:40:00                      0.000000
# 2021-07-30 23:50:00                      0.000000
#
#                      EURUSD BGNE Curncy Bid High  EURUSD BGNE Curncy Bid Low  \
# Dates
# 2020-11-01 19:10:00                     0.000000                    0.000000
# 2020-11-01 19:20:00                     0.000197                   -0.000507
# 2020-11-01 19:30:00                     0.000017                   -0.000215
# 2020-11-01 19:40:00                    -0.000172                    0.000636
# 2020-11-01 19:50:00                    -0.000026                    0.000584
# ...                                          ...                         ...
# 2021-07-30 23:10:00                     0.000000                    0.000000
# 2021-07-30 23:20:00                     0.000000                    0.000000
# 2021-07-30 23:30:00                     0.000000                    0.000000
# 2021-07-30 23:40:00                     0.000000                    0.000000
# 2021-07-30 23:50:00                     0.000000                    0.000000
#
#                      EURUSD BGNE Curncy Bid Number Ticks  \
# Dates
# 2020-11-01 19:10:00                             0.000000
# 2020-11-01 19:20:00                            -0.978125
# 2020-11-01 19:30:00                             0.380952
# 2020-11-01 19:40:00                             3.310345
# 2020-11-01 19:50:00                            -0.984000
# ...                                                  ...
# 2021-07-30 23:10:00                             0.000000
# 2021-07-30 23:20:00                             0.000000
# 2021-07-30 23:30:00                             0.000000
# 2021-07-30 23:40:00                             0.000000
# 2021-07-30 23:50:00                             0.000000
#
#                      EURUSD BGNE Curncy Ask Open  \
# Dates
# 2020-11-01 19:10:00                     0.000000
# 2020-11-01 19:20:00                     0.002121
# 2020-11-01 19:30:00                     0.000043
# 2020-11-01 19:40:00                    -0.000274
# 2020-11-01 19:50:00                    -0.000909
# ...                                          ...
# 2021-07-30 23:10:00                     0.000000
# 2021-07-30 23:20:00                     0.000000
# 2021-07-30 23:30:00                     0.000000
# 2021-07-30 23:40:00                     0.000000
# 2021-07-30 23:50:00                     0.000000
#
#                      EURUSD BGNE Curncy Ask Close  \
# Dates
# 2020-11-01 19:10:00                      0.000000
# 2020-11-01 19:20:00                      0.001597
# 2020-11-01 19:30:00                      0.000017
# 2020-11-01 19:40:00                     -0.001157
# 2020-11-01 19:50:00                     -0.000009
# ...                                           ...
# 2021-07-30 23:10:00                      0.000000
# 2021-07-30 23:20:00                      0.000000
# 2021-07-30 23:30:00                      0.000000
# 2021-07-30 23:40:00                      0.000000
# 2021-07-30 23:50:00                      0.000000
#
#                      EURUSD BGNE Curncy Ask High  EURUSD BGNE Curncy Ask Low  \
# Dates
# 2020-11-01 19:10:00                     0.000000                    0.000000
# 2020-11-01 19:20:00                     0.001631                    0.001761
# 2020-11-01 19:30:00                     0.000086                    0.000137
# 2020-11-01 19:40:00                    -0.000009                   -0.000926
# 2020-11-01 19:50:00                    -0.001268                    0.000017
# ...                                          ...                         ...
# 2021-07-30 23:10:00                     0.000000                    0.000000
# 2021-07-30 23:20:00                     0.000000                    0.000000
# 2021-07-30 23:30:00                     0.000000                    0.000000
# 2021-07-30 23:40:00                     0.000000                    0.000000
# 2021-07-30 23:50:00                     0.000000                    0.000000
#
#                      EURUSD BGNE Curncy Ask Number Ticks  ...  usdjpy___TAS_K  \
# Dates                                                     ...
# 2020-11-01 19:10:00                             0.000000  ...           40.00
# 2020-11-01 19:20:00                            -0.978125  ...           40.00
# 2020-11-01 19:30:00                             0.380952  ...           40.00
# 2020-11-01 19:40:00                             3.310345  ...           40.00
# 2020-11-01 19:50:00                            -0.984000  ...           40.00
# ...                                                  ...  ...             ...
# 2021-07-30 23:10:00                             0.000000  ...           43.75
# 2021-07-30 23:20:00                             0.000000  ...           43.75
# 2021-07-30 23:30:00                             0.000000  ...           43.75
# 2021-07-30 23:40:00                             0.000000  ...           43.75
# 2021-07-30 23:50:00                             0.000000  ...           43.75
#
#                      usdjpy___TAS_D  usdjpy___TAS_DS  usdjpy___TAS_DSS  \
# Dates
# 2020-11-01 19:10:00       56.000000        62.133335         67.244446
# 2020-11-01 19:20:00       56.000000        62.133335         67.244446
# 2020-11-01 19:30:00       56.000000        62.133335         67.244446
# 2020-11-01 19:40:00       56.000000        62.133335         67.244446
# 2020-11-01 19:50:00       56.000000        62.133335         67.244446
# ...                             ...              ...               ...
# 2021-07-30 23:10:00       20.178572        17.983767         17.992258
# 2021-07-30 23:20:00       20.178572        17.983767         17.992258
# 2021-07-30 23:30:00       20.178572        17.983767         17.992258
# 2021-07-30 23:40:00       20.178572        17.983767         17.992258
# 2021-07-30 23:50:00       20.178572        17.983767         17.992258
#
#                      usdjpy___TRENDER_UP  usdjpy___TRENDER_DN  usdjpy___TMAVG  \
# Dates
# 2020-11-01 19:10:00           104.536598           104.576935      104.551109
# 2020-11-01 19:20:00           104.536598           104.576935      104.551109
# 2020-11-01 19:30:00           104.536598           104.576935      104.551109
# 2020-11-01 19:40:00           104.536598           104.576935      104.551109
# 2020-11-01 19:50:00           104.536598           104.576935      104.552223
# ...                                  ...                  ...             ...
# 2021-07-30 23:10:00           109.763481           109.747704      109.705559
# 2021-07-30 23:20:00           109.763481           109.747704      109.705559
# 2021-07-30 23:30:00           109.763481           109.747704      109.705559
# 2021-07-30 23:40:00           109.763481           109.747704      109.705559
# 2021-07-30 23:50:00           109.763481           109.747704      109.705559
#
#                      usdjpy___VMAVG  usdjpy___WMAVG  usdjpy___WLPR
# Dates
# 2020-11-01 19:10:00      104.620003      104.553337     -66.666664
# 2020-11-01 19:20:00      104.620003      104.553337     -66.666664
# 2020-11-01 19:30:00      104.620003      104.553337     -66.666664
# 2020-11-01 19:40:00      104.620003      104.553337     -66.666664
# 2020-11-01 19:50:00      104.620003      104.552666     -66.666664
# ...                             ...             ...            ...
# 2021-07-30 23:10:00      109.735947      109.706001     -46.153847
# 2021-07-30 23:20:00      109.735947      109.706001     -46.153847
# 2021-07-30 23:30:00      109.735947      109.706001     -46.153847
# 2021-07-30 23:40:00      109.735947      109.706001     -46.153847
# 2021-07-30 23:50:00      109.735947      109.706001     -46.153847
#
# [29012 rows x 1231 columns]

# %%
target = 'EURUSD BGNE Curncy Bid Close'

# %% [markdown]
# ## Create training, validation and test split

# %%
times = sorted(df.index.values)
last_10pct = sorted(df.index.values)[-int(0.1*len(times))] # Last 10% of series
last_20pct = sorted(df.index.values)[-int(0.2*len(times))] # Last 20% of series

df_train = df[(df.index < last_20pct)]  # Training data are 80% of total data
df_val = df[(df.index >= last_20pct) & (df.index < last_10pct)]
df_test = df[(df.index >= last_10pct)]

# Convert pandas columns into arrays
train_data = df_train.values
sc = StandardScaler().fit(train_data)
sc_target = StandardScaler().fit(df_train.loc[:, target].values.reshape(-1, 1))
train_data = sc.transform(train_data)
train_data_dates = df_train.index.values  

val_data = sc.transform(df_val.values)
val_data_dates = df_val.index.values  

test_data = sc.transform(df_test.values)
test_data_dates = df_test.index.values 

print('Training data shape: {}'.format(train_data.shape))
print('Validation data shape: {}'.format(val_data.shape))
print('Test data shape: {}'.format(test_data.shape))

df_train.head()
# Out:
# Training data shape: (23210, 1231)
# Validation data shape: (2901, 1231)
# Test data shape: (2901, 1231)
#                      EURUSD BGNE Curncy Bid Open  \
# Dates
# 2020-11-01 19:10:00                     0.000000
# 2020-11-01 19:20:00                     0.000283
# 2020-11-01 19:30:00                     0.000172
# 2020-11-01 19:40:00                     0.000060
# 2020-11-01 19:50:00                    -0.000026
#
#                      EURUSD BGNE Curncy Bid Close  \
# Dates
# 2020-11-01 19:10:00                      0.000000
# 2020-11-01 19:20:00                      0.000275
# 2020-11-01 19:30:00                     -0.000069
# 2020-11-01 19:40:00                      0.000034
# 2020-11-01 19:50:00                      0.000026
#
#                      EURUSD BGNE Curncy Bid High  EURUSD BGNE Curncy Bid Low  \
# Dates
# 2020-11-01 19:10:00                     0.000000                    0.000000
# 2020-11-01 19:20:00                     0.000197                   -0.000507
# 2020-11-01 19:30:00                     0.000017                   -0.000215
# 2020-11-01 19:40:00                    -0.000172                    0.000636
# 2020-11-01 19:50:00                    -0.000026                    0.000584
#
#                      EURUSD BGNE Curncy Bid Number Ticks  \
# Dates
# 2020-11-01 19:10:00                             0.000000
# 2020-11-01 19:20:00                            -0.978125
# 2020-11-01 19:30:00                             0.380952
# 2020-11-01 19:40:00                             3.310345
# 2020-11-01 19:50:00                            -0.984000
#
#                      EURUSD BGNE Curncy Ask Open  \
# Dates
# 2020-11-01 19:10:00                     0.000000
# 2020-11-01 19:20:00                     0.002121
# 2020-11-01 19:30:00                     0.000043
# 2020-11-01 19:40:00                    -0.000274
# 2020-11-01 19:50:00                    -0.000909
#
#                      EURUSD BGNE Curncy Ask Close  \
# Dates
# 2020-11-01 19:10:00                      0.000000
# 2020-11-01 19:20:00                      0.001597
# 2020-11-01 19:30:00                      0.000017
# 2020-11-01 19:40:00                     -0.001157
# 2020-11-01 19:50:00                     -0.000009
#
#                      EURUSD BGNE Curncy Ask High  EURUSD BGNE Curncy Ask Low  \
# Dates
# 2020-11-01 19:10:00                     0.000000                    0.000000
# 2020-11-01 19:20:00                     0.001631                    0.001761
# 2020-11-01 19:30:00                     0.000086                    0.000137
# 2020-11-01 19:40:00                    -0.000009                   -0.000926
# 2020-11-01 19:50:00                    -0.001268                    0.000017
#
#                      EURUSD BGNE Curncy Ask Number Ticks  ...  usdjpy___TAS_K  \
# Dates                                                     ...
# 2020-11-01 19:10:00                             0.000000  ...            40.0
# 2020-11-01 19:20:00                            -0.978125  ...            40.0
# 2020-11-01 19:30:00                             0.380952  ...            40.0
# 2020-11-01 19:40:00                             3.310345  ...            40.0
# 2020-11-01 19:50:00                            -0.984000  ...            40.0
#
#                      usdjpy___TAS_D  usdjpy___TAS_DS  usdjpy___TAS_DSS  \
# Dates
# 2020-11-01 19:10:00            56.0        62.133335         67.244446
# 2020-11-01 19:20:00            56.0        62.133335         67.244446
# 2020-11-01 19:30:00            56.0        62.133335         67.244446
# 2020-11-01 19:40:00            56.0        62.133335         67.244446
# 2020-11-01 19:50:00            56.0        62.133335         67.244446
#
#                      usdjpy___TRENDER_UP  usdjpy___TRENDER_DN  usdjpy___TMAVG  \
# Dates
# 2020-11-01 19:10:00           104.536598           104.576935      104.551109
# 2020-11-01 19:20:00           104.536598           104.576935      104.551109
# 2020-11-01 19:30:00           104.536598           104.576935      104.551109
# 2020-11-01 19:40:00           104.536598           104.576935      104.551109
# 2020-11-01 19:50:00           104.536598           104.576935      104.552223
#
#                      usdjpy___VMAVG  usdjpy___WMAVG  usdjpy___WLPR
# Dates
# 2020-11-01 19:10:00      104.620003      104.553337     -66.666664
# 2020-11-01 19:20:00      104.620003      104.553337     -66.666664
# 2020-11-01 19:30:00      104.620003      104.553337     -66.666664
# 2020-11-01 19:40:00      104.620003      104.553337     -66.666664
# 2020-11-01 19:50:00      104.620003      104.552666     -66.666664
#
# [5 rows x 1231 columns]

# %% [markdown]
# ## Plot daily changes of close prices and volatility

# %%
fig = plt.figure(figsize=(15,12))
st = fig.suptitle("Data Separation", fontsize=20)
st.set_y(0.95)

###############################################################################

ax1 = fig.add_subplot(211)
ax1.plot(train_data_dates, df_train[target], label='Training data')
ax1.plot(val_data_dates, df_val[target], label='Validation data')
ax1.plot(test_data_dates, df_test[target], label='Test data')
ax1.set_xlabel('Dates')
ax1.set_ylabel('Normalized Closing Returns')
ax1.set_title("Close Price", fontsize=18)
ax1.legend(loc="best", fontsize=12)

###############################################################################

ax2 = fig.add_subplot(212)
ax2.plot(train_data_dates, df_train['EURUSDV1Y Curncy Trade Open'], label='Training data') 
ax2.plot(val_data_dates, df_val['EURUSDV1Y Curncy Trade Open'], label='Validation data') 
ax2.plot(test_data_dates, df_test['EURUSDV1Y Curncy Trade Open'], label='Test data') 
ax2.set_xlabel('Dates')
ax2.set_ylabel('Normalized Volatility Changes')
ax2.set_title("Volatility", fontsize=18)
ax2.legend(loc="best", fontsize=12)

# %% [markdown]
# ## Create chunks of training, validation and test data

# %%
target_id = list(df_train.columns).index(target)
# Training data
X_train, y_train = [], []
for i in range(seq_len, len(train_data)):
    X_train.append(train_data[i-seq_len:i])
    y_train.append(train_data[:, target_id][i])
X_train, y_train = np.array(X_train), np.array(y_train)

###############################################################################

# Validation data
X_val, y_val = [], []
for i in range(seq_len, len(val_data)):
    X_val.append(val_data[i-seq_len:i])
    y_val.append(val_data[:, target_id][i])
X_val, y_val = np.array(X_val), np.array(y_val)

###############################################################################

# Test data
X_test, y_test = [], []
for i in range(seq_len, len(test_data)):
    X_test.append(test_data[i-seq_len:i])
    y_test.append(test_data[:, target_id][i])    
X_test, y_test = np.array(X_test), np.array(y_test)

print('Training set shape', X_train.shape, y_train.shape)
print('Validation set shape', X_val.shape, y_val.shape)
print('Testing set shape' ,X_test.shape, y_test.shape)
# Out:
# Training set shape (23082, 128, 1231) (23082,)
# Validation set shape (2773, 128, 1231) (2773,)
# Testing set shape (2773, 128, 1231) (2773,)

# %% [markdown]
# ## TimeVector

# %%
class Time2Vector(Layer):
    def __init__(self, seq_len, **kwargs):
        super(Time2Vector, self).__init__()
        self.seq_len = seq_len

    def build(self, input_shape):
        '''Initialize weights and biases with shape (batch, seq_len)'''
        self.weights_linear = self.add_weight(name='weight_linear',
                                    shape=(int(self.seq_len),),
                                    initializer='uniform',
                                    trainable=True)

        self.bias_linear = self.add_weight(name='bias_linear',
                                    shape=(int(self.seq_len),),
                                    initializer='uniform',
                                    trainable=True)

        self.weights_periodic = self.add_weight(name='weight_periodic',
                                    shape=(int(self.seq_len),),
                                    initializer='uniform',
                                    trainable=True)

        self.bias_periodic = self.add_weight(name='bias_periodic',
                                    shape=(int(self.seq_len),),
                                    initializer='uniform',
                                    trainable=True)

    def call(self, x):
        '''Calculate linear and periodic time features'''
        x = tf.math.reduce_mean(x[:,:,:4], axis=-1) 
        time_linear = self.weights_linear * x + self.bias_linear # Linear time feature
        time_linear = tf.expand_dims(time_linear, axis=-1) # Add dimension (batch, seq_len, 1)

        time_periodic = tf.math.sin(tf.multiply(x, self.weights_periodic) + self.bias_periodic)
        time_periodic = tf.expand_dims(time_periodic, axis=-1) # Add dimension (batch, seq_len, 1)
        return tf.concat([time_linear, time_periodic], axis=-1) # shape = (batch, seq_len, 2)
   
    def get_config(self): # Needed for saving and loading model with custom layer
        config = super().get_config().copy()
        config.update({'seq_len': self.seq_len})
        return config

# %% [markdown]
# ## Transformer

# %%
class SingleAttention(Layer):
    def __init__(self, d_k, d_v):
        super(SingleAttention, self).__init__()
        self.d_k = d_k
        self.d_v = d_v

    def build(self, input_shape):
        self.query = Dense(self.d_k, 
                           input_shape=input_shape, 
                           kernel_initializer='glorot_uniform', 
                           bias_initializer='glorot_uniform')

        self.key = Dense(self.d_k, 
                         input_shape=input_shape, 
                         kernel_initializer='glorot_uniform', 
                         bias_initializer='glorot_uniform')

        self.value = Dense(self.d_v, 
                           input_shape=input_shape, 
                           kernel_initializer='glorot_uniform', 
                           bias_initializer='glorot_uniform')

    def call(self, inputs): # inputs = (in_seq, in_seq, in_seq)
        q = self.query(inputs[0])
        k = self.key(inputs[1])

        attn_weights = tf.matmul(q, k, transpose_b=True)
        attn_weights = tf.map_fn(lambda x: x/np.sqrt(self.d_k), attn_weights)
        attn_weights = tf.nn.softmax(attn_weights, axis=-1)

        v = self.value(inputs[2])
        attn_out = tf.matmul(attn_weights, v)
        return attn_out    

#############################################################################

class MultiAttention(Layer):
    def __init__(self, d_k, d_v, n_heads):
        super(MultiAttention, self).__init__()
        self.d_k = d_k
        self.d_v = d_v
        self.n_heads = n_heads
        self.attn_heads = list()

    def build(self, input_shape):
        for n in range(self.n_heads):
            self.attn_heads.append(SingleAttention(self.d_k, self.d_v))  

        # input_shape[0]=(batch, seq_len, 7), input_shape[0][-1]=7 
        self.linear = Dense(input_shape[0][-1], 
                            input_shape=input_shape, 
                            kernel_initializer='glorot_uniform', 
                            bias_initializer='glorot_uniform')

    def call(self, inputs):
        attn = [self.attn_heads[i](inputs) for i in range(self.n_heads)]
        concat_attn = tf.concat(attn, axis=-1)
        multi_linear = self.linear(concat_attn)
        return multi_linear   

#############################################################################

class TransformerEncoder(Layer):
    def __init__(self, d_k, d_v, n_heads, ff_dim, dropout=0.1, **kwargs):
        super(TransformerEncoder, self).__init__()
        self.d_k = d_k
        self.d_v = d_v
        self.n_heads = n_heads
        self.ff_dim = ff_dim
        self.attn_heads = list()
        self.dropout_rate = dropout

    def build(self, input_shape):
        self.attn_multi = MultiAttention(self.d_k, self.d_v, self.n_heads)
        self.attn_dropout = Dropout(self.dropout_rate)
        self.attn_normalize = LayerNormalization(input_shape=input_shape, epsilon=1e-6)

        self.ff_conv1D_1 = Conv1D(filters=self.ff_dim, kernel_size=1, activation='relu')
        # input_shape[0]=(batch, seq_len, 7), input_shape[0][-1] = 7 
        self.ff_conv1D_2 = Conv1D(filters=input_shape[0][-1], kernel_size=1) 
        self.ff_dropout = Dropout(self.dropout_rate)
        self.ff_normalize = LayerNormalization(input_shape=input_shape, epsilon=1e-6)    
  
    def call(self, inputs): # inputs = (in_seq, in_seq, in_seq)
        attn_layer = self.attn_multi(inputs)
        attn_layer = self.attn_dropout(attn_layer)
        attn_layer = self.attn_normalize(inputs[0] + attn_layer)

        ff_layer = self.ff_conv1D_1(attn_layer)
        ff_layer = self.ff_conv1D_2(ff_layer)
        ff_layer = self.ff_dropout(ff_layer)
        ff_layer = self.ff_normalize(inputs[0] + ff_layer)
        return ff_layer 

    def get_config(self): # Needed for saving and loading model with custom layer
        config = super().get_config().copy()
        config.update({'d_k': self.d_k,
                       'd_v': self.d_v,
                       'n_heads': self.n_heads,
                       'ff_dim': self.ff_dim,
                       'attn_heads': self.attn_heads,
                       'dropout_rate': self.dropout_rate})
        return config

# %% [markdown]
# ## Model

# %%
def create_model(input_shape):
    '''Initialize time and transformer layers'''
    time_embedding = Time2Vector(seq_len)
    attn_layer1 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)
    attn_layer2 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)
    attn_layer3 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)

    '''Construct model'''
    in_seq = Input(shape=(seq_len, input_shape))
    x = time_embedding(in_seq)
    x = Concatenate(axis=-1)([in_seq, x])
    #   x = Concatenate(axis=-1)([Dense(128)(in_seq), x])
    x = attn_layer1((x, x, x))
    x = attn_layer2((x, x, x))
    x = attn_layer3((x, x, x))
    x = GlobalAveragePooling1D(data_format='channels_first')(x)
    x = Dropout(0.01)(x)
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.01)(x)
    out = Dense(1, activation='linear')(x)

    model = Model(inputs=in_seq, outputs=out)
    opt = keras.optimizers.Adam(learning_rate=0.00001)
    model.compile(loss='mse', optimizer=opt, metrics=['mae', 'mape'])
    return model


model = create_model(df.shape[1])
model.summary()

callback = tf.keras.callbacks.ModelCheckpoint('../content/Transformer+TimeEmbedding2{epoch}.hdf5', 
                                               monitor='val_loss', 
                                               save_best_only=True, verbose=1
                                             )

es = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=8,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)


if True: 
    history = model.fit(X_train, y_train,
                        batch_size=batch_size, 
                        epochs=300,
                        callbacks=[callback],
                        validation_data=(X_val, y_val))  
    with open('../content/history2.pkl', 'wb') as f:
        pickle.dump(history.history, f)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 1231)]  0
# __________________________________________________________________________________________________
# time2_vector (Time2Vector)      (None, 128, 2)       512         input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 128, 1233)    0           input_1[0][0]
#                                                                  time2_vector[0][0]
# __________________________________________________________________________________________________
# transformer_encoder (Transforme (None, 128, 1233)    15799270    concatenate[0][0]
#                                                                  concatenate[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# transformer_encoder_1 (Transfor (None, 128, 1233)    15799270    transformer_encoder[0][0]
#                                                                  transformer_encoder[0][0]
#                                                                  transformer_encoder[0][0]
# __________________________________________________________________________________________________
# transformer_encoder_2 (Transfor (None, 128, 1233)    15799270    transformer_encoder_1[0][0]
#                                                                  transformer_encoder_1[0][0]
#                                                                  transformer_encoder_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 128)          0           transformer_encoder_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128)          0           global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           8256        dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            65          dropout_1[0][0]
# ==================================================================================================
# Total params: 47,406,643
# Trainable params: 47,406,643
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/300
# 722/722 [==============================] - 1017s 1s/step - loss: 1.0370 - mae: 0.6584 - mape: 100.0318 - val_loss: 0.8344 - val_mae: 0.5965 - val_mape: 100.3495
#
# Epoch 00001: val_loss improved from inf to 0.83444, saving model to ../content/Transformer+TimeEmbedding21.hdf5
# Epoch 2/300
# 722/722 [==============================] - 884s 1s/step - loss: 1.0089 - mae: 0.6571 - mape: 101.1233 - val_loss: 0.8344 - val_mae: 0.5964 - val_mape: 100.0550
#
# Epoch 00002: val_loss improved from 0.83444 to 0.83439, saving model to ../content/Transformer+TimeEmbedding22.hdf5
# Epoch 3/300
# 722/722 [==============================] - 876s 1s/step - loss: 1.0161 - mae: 0.6577 - mape: 100.1654 - val_loss: 0.8345 - val_mae: 0.5965 - val_mape: 100.5306
#
# Epoch 00003: val_loss did not improve from 0.83439
# Epoch 4/300
# 722/722 [==============================] - 882s 1s/step - loss: 0.9731 - mae: 0.6521 - mape: 100.4505 - val_loss: 0.8346 - val_mae: 0.5966 - val_mape: 101.2524
#
# Epoch 00004: val_loss did not improve from 0.83439
# Epoch 5/300
# 722/722 [==============================] - 896s 1s/step - loss: 1.0438 - mae: 0.6568 - mape: 101.1683 - val_loss: 0.8348 - val_mae: 0.5967 - val_mape: 102.5900
#
# Epoch 00005: val_loss did not improve from 0.83439
# Epoch 6/300
# 722/722 [==============================] - 900s 1s/step - loss: 1.0489 - mae: 0.6502 - mape: 102.2918 - val_loss: 0.8348 - val_mae: 0.5967 - val_mape: 102.6327
#
# Epoch 00006: val_loss did not improve from 0.83439
# Epoch 7/300
# 722/722 [==============================] - 905s 1s/step - loss: 1.0982 - mae: 0.6625 - mape: 99.8078 - val_loss: 0.8351 - val_mae: 0.5969 - val_mape: 104.5407
#
# Epoch 00007: val_loss did not improve from 0.83439
# Epoch 8/300
# 722/722 [==============================] - 912s 1s/step - loss: 1.0051 - mae: 0.6543 - mape: 101.2762 - val_loss: 0.8347 - val_mae: 0.5968 - val_mape: 104.1309
#
# Epoch 00008: val_loss did not improve from 0.83439
# Epoch 9/300
# 722/722 [==============================] - 921s 1s/step - loss: 1.0021 - mae: 0.6469 - mape: 102.1691 - val_loss: 0.8356 - val_mae: 0.5971 - val_mape: 107.0282
#
# Epoch 00009: val_loss did not improve from 0.83439
# Epoch 10/300
# 722/722 [==============================] - 826s 1s/step - loss: 0.9686 - mae: 0.6535 - mape: 103.4312 - val_loss: 0.8366 - val_mae: 0.5977 - val_mape: 111.8547
#
# Epoch 00010: val_loss did not improve from 0.83439
# Epoch 11/300
# 722/722 [==============================] - 823s 1s/step - loss: 0.9737 - mae: 0.6482 - mape: 105.8581 - val_loss: 0.8361 - val_mae: 0.5976 - val_mape: 111.4125
#
# Epoch 00011: val_loss did not improve from 0.83439
# Epoch 12/300
# 722/722 [==============================] - 826s 1s/step - loss: 0.9959 - mae: 0.6538 - mape: 107.1024 - val_loss: 0.8371 - val_mae: 0.5981 - val_mape: 116.9256
#
# Epoch 00012: val_loss did not improve from 0.83439
# Epoch 13/300
# 722/722 [==============================] - 843s 1s/step - loss: 0.9565 - mae: 0.6459 - mape: 112.1533 - val_loss: 0.8386 - val_mae: 0.5989 - val_mape: 124.2427
#
# Epoch 00013: val_loss did not improve from 0.83439
# Epoch 14/300
# 722/722 [==============================] - 829s 1s/step - loss: 1.0368 - mae: 0.6585 - mape: 118.7992 - val_loss: 0.8385 - val_mae: 0.5990 - val_mape: 124.4590
#
# Epoch 00014: val_loss did not improve from 0.83439
# Epoch 15/300
# 722/722 [==============================] - 830s 1s/step - loss: 1.0096 - mae: 0.6554 - mape: 122.5850 - val_loss: 0.8378 - val_mae: 0.5987 - val_mape: 122.0856
#
# Epoch 00015: val_loss did not improve from 0.83439
# Epoch 16/300
# 722/722 [==============================] - 835s 1s/step - loss: 1.0017 - mae: 0.6550 - mape: 122.8193 - val_loss: 0.8402 - val_mae: 0.5999 - val_mape: 128.0345
#
# Epoch 00016: val_loss did not improve from 0.83439
# Epoch 17/300
# 722/722 [==============================] - 849s 1s/step - loss: 0.9982 - mae: 0.6497 - mape: 125.4025 - val_loss: 0.8379 - val_mae: 0.5987 - val_mape: 124.6252
#
# Epoch 00017: val_loss did not improve from 0.83439
# Epoch 18/300
# 722/722 [==============================] - 849s 1s/step - loss: 1.0221 - mae: 0.6568 - mape: 127.7929 - val_loss: 0.8378 - val_mae: 0.5989 - val_mape: 128.7109
#
# Epoch 00018: val_loss did not improve from 0.83439
# Epoch 19/300
# 722/722 [==============================] - 836s 1s/step - loss: 1.0331 - mae: 0.6605 - mape: 133.0315 - val_loss: 0.8397 - val_mae: 0.6000 - val_mape: 134.7614
#
# Epoch 00019: val_loss did not improve from 0.83439
# Epoch 20/300
# 722/722 [==============================] - 864s 1s/step - loss: 0.9824 - mae: 0.6494 - mape: 137.3403 - val_loss: 0.8407 - val_mae: 0.6005 - val_mape: 138.6266
#
# Epoch 00020: val_loss did not improve from 0.83439
# Epoch 21/300
# 722/722 [==============================] - 860s 1s/step - loss: 1.0013 - mae: 0.6503 - mape: 141.9449 - val_loss: 0.8416 - val_mae: 0.6010 - val_mape: 140.6333
#
# Epoch 00021: val_loss did not improve from 0.83439
# Epoch 22/300
# 722/722 [==============================] - 862s 1s/step - loss: 0.9896 - mae: 0.6533 - mape: 143.8277 - val_loss: 0.8420 - val_mae: 0.6014 - val_mape: 144.8764
#
# Epoch 00022: val_loss did not improve from 0.83439
# Epoch 23/300
# 722/722 [==============================] - 862s 1s/step - loss: 0.9491 - mae: 0.6489 - mape: 147.7983 - val_loss: 0.8418 - val_mae: 0.6022 - val_mape: 149.1501
#
# Epoch 00023: val_loss did not improve from 0.83439
# Epoch 24/300
# 722/722 [==============================] - 862s 1s/step - loss: 0.9876 - mae: 0.6515 - mape: 150.1608 - val_loss: 0.8446 - val_mae: 0.6030 - val_mape: 152.7848
#
# Epoch 00024: val_loss did not improve from 0.83439
# Epoch 25/300
# 722/722 [==============================] - 877s 1s/step - loss: 0.9653 - mae: 0.6500 - mape: 154.8601 - val_loss: 0.8462 - val_mae: 0.6042 - val_mape: 157.7078
#
# Epoch 00025: val_loss did not improve from 0.83439
# Epoch 26/300
# 722/722 [==============================] - 873s 1s/step - loss: 1.0125 - mae: 0.6483 - mape: 157.1484 - val_loss: 0.8422 - val_mae: 0.6027 - val_mape: 152.7168
#
# Epoch 00026: val_loss did not improve from 0.83439
# Epoch 27/300
# 722/722 [==============================] - 875s 1s/step - loss: 0.9782 - mae: 0.6567 - mape: 155.0748 - val_loss: 0.8443 - val_mae: 0.6039 - val_mape: 158.6769
#
# Epoch 00027: val_loss did not improve from 0.83439
# Epoch 28/300
# 722/722 [==============================] - 878s 1s/step - loss: 0.9801 - mae: 0.6532 - mape: 161.4642 - val_loss: 0.8494 - val_mae: 0.6068 - val_mape: 171.4319
#
# Epoch 00028: val_loss did not improve from 0.83439
# Epoch 29/300
# 722/722 [==============================] - 871s 1s/step - loss: 0.9941 - mae: 0.6560 - mape: 164.0597 - val_loss: 0.8518 - val_mae: 0.6078 - val_mape: 171.3894
#
# Epoch 00029: val_loss did not improve from 0.83439
# Epoch 30/300
# 722/722 [==============================] - 874s 1s/step - loss: 0.9922 - mae: 0.6521 - mape: 161.5238 - val_loss: 0.8465 - val_mae: 0.6042 - val_mape: 159.2874
#
# Epoch 00030: val_loss did not improve from 0.83439
# Epoch 31/300
# 722/722 [==============================] - 875s 1s/step - loss: 0.9955 - mae: 0.6565 - mape: 158.9061 - val_loss: 0.8520 - val_mae: 0.6085 - val_mape: 178.2599
#
# Epoch 00031: val_loss did not improve from 0.83439
# Epoch 32/300
# 722/722 [==============================] - 889s 1s/step - loss: 1.0206 - mae: 0.6548 - mape: 165.8257 - val_loss: 0.8486 - val_mae: 0.6066 - val_mape: 166.1680
#
# Epoch 00032: val_loss did not improve from 0.83439
# Epoch 33/300
# 722/722 [==============================] - 877s 1s/step - loss: 1.0163 - mae: 0.6551 - mape: 163.4527 - val_loss: 0.8559 - val_mae: 0.6115 - val_mape: 190.0172
#
# Epoch 00033: val_loss did not improve from 0.83439
# Epoch 34/300
# 722/722 [==============================] - 884s 1s/step - loss: 0.9558 - mae: 0.6496 - mape: 170.5892 - val_loss: 0.8524 - val_mae: 0.6093 - val_mape: 181.4817
#
# Epoch 00034: val_loss did not improve from 0.83439
# Epoch 35/300
# 722/722 [==============================] - 880s 1s/step - loss: 1.0245 - mae: 0.6571 - mape: 173.3917 - val_loss: 0.8485 - val_mae: 0.6059 - val_mape: 166.6502
#
# Epoch 00035: val_loss did not improve from 0.83439
# Epoch 36/300
# 722/722 [==============================] - 880s 1s/step - loss: 1.0025 - mae: 0.6488 - mape: 170.2702 - val_loss: 0.8547 - val_mae: 0.6109 - val_mape: 185.5437
#
# Epoch 00036: val_loss did not improve from 0.83439
# Epoch 37/300
# 722/722 [==============================] - 878s 1s/step - loss: 1.0176 - mae: 0.6580 - mape: 174.0633 - val_loss: 0.8551 - val_mae: 0.6112 - val_mape: 187.4985
#
# Epoch 00037: val_loss did not improve from 0.83439
# Epoch 38/300
# 722/722 [==============================] - 875s 1s/step - loss: 0.9702 - mae: 0.6532 - mape: 177.8684 - val_loss: 0.8551 - val_mae: 0.6107 - val_mape: 186.7118
#
# Epoch 00038: val_loss did not improve from 0.83439
# Epoch 39/300
# 722/722 [==============================] - 882s 1s/step - loss: 0.9775 - mae: 0.6504 - mape: 179.9339 - val_loss: 0.8472 - val_mae: 0.6059 - val_mape: 165.6393
#
# Epoch 00039: val_loss did not improve from 0.83439
# Epoch 40/300
# 722/722 [==============================] - 880s 1s/step - loss: 1.0234 - mae: 0.6563 - mape: 176.5155 - val_loss: 0.8545 - val_mae: 0.6095 - val_mape: 180.5895
#
# Epoch 00040: val_loss did not improve from 0.83439
# Epoch 41/300
# 722/722 [==============================] - 858s 1s/step - loss: 1.0141 - mae: 0.6613 - mape: 176.3520 - val_loss: 0.8569 - val_mae: 0.6113 - val_mape: 188.2428
#
# Epoch 00041: val_loss did not improve from 0.83439
# Epoch 42/300
# 722/722 [==============================] - 723s 1s/step - loss: 0.9503 - mae: 0.6438 - mape: 178.6491 - val_loss: 0.8659 - val_mae: 0.6180 - val_mape: 212.3417
#
# Epoch 00042: val_loss did not improve from 0.83439
# Epoch 43/300
# 722/722 [==============================] - 708s 980ms/step - loss: 0.9842 - mae: 0.6566 - mape: 178.3686 - val_loss: 0.8589 - val_mae: 0.6137 - val_mape: 196.5067
#
# Epoch 00043: val_loss did not improve from 0.83439
# Epoch 44/300
# 722/722 [==============================] - 708s 980ms/step - loss: 0.9615 - mae: 0.6507 - mape: 177.3462 - val_loss: 0.8718 - val_mae: 0.6218 - val_mape: 221.1297
#
# Epoch 00044: val_loss did not improve from 0.83439
# Epoch 45/300
# 722/722 [==============================] - 713s 987ms/step - loss: 1.0225 - mae: 0.6613 - mape: 182.2909 - val_loss: 0.8778 - val_mae: 0.6246 - val_mape: 230.2207
#
# Epoch 00045: val_loss did not improve from 0.83439
# Epoch 46/300
# 722/722 [==============================] - 710s 984ms/step - loss: 0.9670 - mae: 0.6426 - mape: 183.0572 - val_loss: 0.8622 - val_mae: 0.6150 - val_mape: 200.9370
#
# Epoch 00046: val_loss did not improve from 0.83439
# Epoch 47/300
# 722/722 [==============================] - 711s 985ms/step - loss: 0.9886 - mae: 0.6513 - mape: 180.5338 - val_loss: 0.8702 - val_mae: 0.6223 - val_mape: 220.4929
#
# Epoch 00047: val_loss did not improve from 0.83439
# Epoch 48/300
# 722/722 [==============================] - 717s 993ms/step - loss: 0.9898 - mae: 0.6503 - mape: 182.6698 - val_loss: 0.8867 - val_mae: 0.6315 - val_mape: 250.5820
#
# Epoch 00048: val_loss did not improve from 0.83439
# Epoch 49/300
# 722/722 [==============================] - 720s 997ms/step - loss: 0.9733 - mae: 0.6465 - mape: 175.7547 - val_loss: 0.8862 - val_mae: 0.6304 - val_mape: 247.9143
#
# Epoch 00049: val_loss did not improve from 0.83439
# Epoch 50/300
# 722/722 [==============================] - 766s 1s/step - loss: 0.9775 - mae: 0.6511 - mape: 184.1755 - val_loss: 0.9015 - val_mae: 0.6413 - val_mape: 279.8118
#
# Epoch 00050: val_loss did not improve from 0.83439
# Epoch 51/300
# 722/722 [==============================] - 767s 1s/step - loss: 0.9368 - mae: 0.6435 - mape: 186.5504 - val_loss: 0.8845 - val_mae: 0.6303 - val_mape: 248.4286
#
# Epoch 00051: val_loss did not improve from 0.83439
# Epoch 52/300
# 722/722 [==============================] - 771s 1s/step - loss: 0.9614 - mae: 0.6496 - mape: 188.4663 - val_loss: 0.8775 - val_mae: 0.6259 - val_mape: 237.1849
#
# Epoch 00052: val_loss did not improve from 0.83439
# Epoch 53/300
# 722/722 [==============================] - 770s 1s/step - loss: 0.9487 - mae: 0.6417 - mape: 188.6000 - val_loss: 0.9018 - val_mae: 0.6411 - val_mape: 277.3648
#
# Epoch 00053: val_loss did not improve from 0.83439
# Epoch 54/300
# 722/722 [==============================] - 757s 1s/step - loss: 0.9296 - mae: 0.6425 - mape: 189.1642 - val_loss: 0.8881 - val_mae: 0.6328 - val_mape: 249.2218
#
# Epoch 00054: val_loss did not improve from 0.83439
# Epoch 55/300
# 722/722 [==============================] - 758s 1s/step - loss: 1.0560 - mae: 0.6569 - mape: 187.2270 - val_loss: 0.9068 - val_mae: 0.6434 - val_mape: 284.4987
#
# Epoch 00055: val_loss did not improve from 0.83439
# Epoch 56/300
# 722/722 [==============================] - 760s 1s/step - loss: 0.9374 - mae: 0.6413 - mape: 188.3282 - val_loss: 0.9030 - val_mae: 0.6423 - val_mape: 282.3849
#
# Epoch 00056: val_loss did not improve from 0.83439
# Epoch 57/300
# 722/722 [==============================] - 770s 1s/step - loss: 0.9563 - mae: 0.6497 - mape: 195.0297 - val_loss: 0.8855 - val_mae: 0.6306 - val_mape: 248.9589
#
# Epoch 00057: val_loss did not improve from 0.83439
# Epoch 58/300
# 722/722 [==============================] - 772s 1s/step - loss: 0.9740 - mae: 0.6469 - mape: 204.3073 - val_loss: 0.8795 - val_mae: 0.6290 - val_mape: 241.8098
#
# Epoch 00058: val_loss did not improve from 0.83439
# Epoch 59/300
# 722/722 [==============================] - 779s 1s/step - loss: 0.9790 - mae: 0.6478 - mape: 197.0856 - val_loss: 0.9003 - val_mae: 0.6424 - val_mape: 277.3417
#
# Epoch 00059: val_loss did not improve from 0.83439
# Epoch 60/300
# 722/722 [==============================] - 759s 1s/step - loss: 0.9068 - mae: 0.6329 - mape: 205.4766 - val_loss: 0.9202 - val_mae: 0.6532 - val_mape: 301.6445
#
# Epoch 00060: val_loss did not improve from 0.83439
# Epoch 61/300
# 722/722 [==============================] - 772s 1s/step - loss: 0.9197 - mae: 0.6398 - mape: 204.2219 - val_loss: 0.9425 - val_mae: 0.6676 - val_mape: 343.1571
#
# Epoch 00061: val_loss did not improve from 0.83439
# Epoch 62/300
# 722/722 [==============================] - 777s 1s/step - loss: 0.8795 - mae: 0.6327 - mape: 222.5686 - val_loss: 0.9113 - val_mae: 0.6492 - val_mape: 292.5869
#
# Epoch 00062: val_loss did not improve from 0.83439
# Epoch 63/300
# 722/722 [==============================] - 779s 1s/step - loss: 0.9060 - mae: 0.6440 - mape: 198.4609 - val_loss: 0.9317 - val_mae: 0.6614 - val_mape: 312.8271
#
# Epoch 00063: val_loss did not improve from 0.83439
# Epoch 64/300
# 722/722 [==============================] - 795s 1s/step - loss: 0.9080 - mae: 0.6385 - mape: 204.3982 - val_loss: 0.9033 - val_mae: 0.6437 - val_mape: 281.7751
#
# Epoch 00064: val_loss did not improve from 0.83439
# Epoch 65/300
# 722/722 [==============================] - 804s 1s/step - loss: 0.9371 - mae: 0.6443 - mape: 213.2951 - val_loss: 0.9438 - val_mae: 0.6668 - val_mape: 326.0157
#
# Epoch 00065: val_loss did not improve from 0.83439
# Epoch 66/300
# 722/722 [==============================] - 785s 1s/step - loss: 0.9562 - mae: 0.6406 - mape: 208.6960 - val_loss: 0.9308 - val_mae: 0.6599 - val_mape: 316.9975
#
# Epoch 00066: val_loss did not improve from 0.83439
# Epoch 67/300
# 722/722 [==============================] - 760s 1s/step - loss: 0.9504 - mae: 0.6409 - mape: 218.5160 - val_loss: 0.9585 - val_mae: 0.6771 - val_mape: 346.7777
#
# Epoch 00067: val_loss did not improve from 0.83439
# Epoch 68/300
# 722/722 [==============================] - 761s 1s/step - loss: 0.9417 - mae: 0.6393 - mape: 207.2375 - val_loss: 0.9336 - val_mae: 0.6637 - val_mape: 320.4108
#
# Epoch 00068: val_loss did not improve from 0.83439
# Epoch 69/300
# 722/722 [==============================] - 762s 1s/step - loss: 0.9919 - mae: 0.6461 - mape: 214.3530 - val_loss: 0.9767 - val_mae: 0.6875 - val_mape: 380.0021
#
# Epoch 00069: val_loss did not improve from 0.83439
# Epoch 70/300
# 722/722 [==============================] - 767s 1s/step - loss: 0.9401 - mae: 0.6376 - mape: 219.1580 - val_loss: 0.9561 - val_mae: 0.6786 - val_mape: 362.4117
#
# Epoch 00070: val_loss did not improve from 0.83439
# Epoch 71/300
# 722/722 [==============================] - 758s 1s/step - loss: 0.8986 - mae: 0.6286 - mape: 222.6815 - val_loss: 0.9334 - val_mae: 0.6659 - val_mape: 329.7825
#
# Epoch 00071: val_loss did not improve from 0.83439
# Epoch 72/300
# 722/722 [==============================] - 758s 1s/step - loss: 0.9269 - mae: 0.6355 - mape: 211.9354 - val_loss: 0.9716 - val_mae: 0.6888 - val_mape: 378.5457
#
# Epoch 00072: val_loss did not improve from 0.83439
# Epoch 73/300
# 722/722 [==============================] - 759s 1s/step - loss: 0.8921 - mae: 0.6322 - mape: 207.1855 - val_loss: 0.9659 - val_mae: 0.6838 - val_mape: 359.5687
#
# Epoch 00073: val_loss did not improve from 0.83439
# Epoch 74/300
# 722/722 [==============================] - 768s 1s/step - loss: 0.8993 - mae: 0.6315 - mape: 226.1973 - val_loss: 0.9817 - val_mae: 0.6915 - val_mape: 372.1117
#
# Epoch 00074: val_loss did not improve from 0.83439
# Epoch 75/300
# 722/722 [==============================] - 758s 1s/step - loss: 0.8819 - mae: 0.6310 - mape: 229.9159 - val_loss: 1.0364 - val_mae: 0.7184 - val_mape: 423.8898
#
# Epoch 00075: val_loss did not improve from 0.83439
# Epoch 76/300
# 722/722 [==============================] - 772s 1s/step - loss: 0.9081 - mae: 0.6297 - mape: 219.2341 - val_loss: 1.0771 - val_mae: 0.7435 - val_mape: 457.7031
#
# Epoch 00076: val_loss did not improve from 0.83439
# Epoch 77/300
# 722/722 [==============================] - 776s 1s/step - loss: 0.9101 - mae: 0.6281 - mape: 234.6582 - val_loss: 1.0124 - val_mae: 0.7065 - val_mape: 402.7572
#
# Epoch 00077: val_loss did not improve from 0.83439
# Epoch 78/300
# 722/722 [==============================] - 763s 1s/step - loss: 0.8836 - mae: 0.6263 - mape: 234.5780 - val_loss: 1.0818 - val_mae: 0.7427 - val_mape: 444.7084
#
# Epoch 00078: val_loss did not improve from 0.83439
# Epoch 79/300
# 722/722 [==============================] - 779s 1s/step - loss: 0.8927 - mae: 0.6251 - mape: 245.8141 - val_loss: 1.0765 - val_mae: 0.7432 - val_mape: 448.7821
#
# Epoch 00079: val_loss did not improve from 0.83439
# Epoch 80/300
# 722/722 [==============================] - 769s 1s/step - loss: 0.9296 - mae: 0.6347 - mape: 243.7348 - val_loss: 1.0609 - val_mae: 0.7338 - val_mape: 432.8128
#
# Epoch 00080: val_loss did not improve from 0.83439
# Epoch 81/300
# 722/722 [==============================] - 763s 1s/step - loss: 0.8591 - mae: 0.6216 - mape: 235.2321 - val_loss: 1.0471 - val_mae: 0.7292 - val_mape: 427.7107
#
# Epoch 00081: val_loss did not improve from 0.83439
# Epoch 82/300
# 722/722 [==============================] - 760s 1s/step - loss: 0.8872 - mae: 0.6274 - mape: 223.7736 - val_loss: 1.0773 - val_mae: 0.7435 - val_mape: 439.5974
#
# Epoch 00082: val_loss did not improve from 0.83439
# Epoch 83/300
# 722/722 [==============================] - 767s 1s/step - loss: 0.9128 - mae: 0.6245 - mape: 241.4417 - val_loss: 1.0613 - val_mae: 0.7343 - val_mape: 422.5421
#
# Epoch 00083: val_loss did not improve from 0.83439
# Epoch 84/300
# 722/722 [==============================] - 758s 1s/step - loss: 0.9283 - mae: 0.6257 - mape: 240.7243 - val_loss: 1.1106 - val_mae: 0.7649 - val_mape: 480.1293
#
# Epoch 00084: val_loss did not improve from 0.83439
# Epoch 85/300
# 722/722 [==============================] - 757s 1s/step - loss: 0.7993 - mae: 0.6115 - mape: 245.6780 - val_loss: 1.0737 - val_mae: 0.7435 - val_mape: 454.4549
#
# Epoch 00085: val_loss did not improve from 0.83439
# Epoch 86/300
# 722/722 [==============================] - 754s 1s/step - loss: 0.9029 - mae: 0.6233 - mape: 253.1188 - val_loss: 1.0899 - val_mae: 0.7514 - val_mape: 442.1308
#
# Epoch 00086: val_loss did not improve from 0.83439
# Epoch 87/300
# 722/722 [==============================] - 761s 1s/step - loss: 0.8464 - mae: 0.6258 - mape: 248.0206 - val_loss: 1.1028 - val_mae: 0.7604 - val_mape: 464.4598
#
# Epoch 00087: val_loss did not improve from 0.83439
# Epoch 88/300
# 722/722 [==============================] - 770s 1s/step - loss: 0.8612 - mae: 0.6132 - mape: 245.6864 - val_loss: 1.1012 - val_mae: 0.7625 - val_mape: 455.4107
#
# Epoch 00088: val_loss did not improve from 0.83439
# Epoch 89/300
# 722/722 [==============================] - 749s 1s/step - loss: 0.8415 - mae: 0.6113 - mape: 252.7530 - val_loss: 1.1687 - val_mae: 0.7950 - val_mape: 518.3978
#
# Epoch 00089: val_loss did not improve from 0.83439
# Epoch 90/300
# 722/722 [==============================] - 764s 1s/step - loss: 0.7945 - mae: 0.6088 - mape: 244.6652 - val_loss: 1.0931 - val_mae: 0.7551 - val_mape: 448.0991
#
# Epoch 00090: val_loss did not improve from 0.83439
# Epoch 91/300
# 722/722 [==============================] - 756s 1s/step - loss: 0.8596 - mae: 0.6122 - mape: 250.8309 - val_loss: 1.1206 - val_mae: 0.7699 - val_mape: 478.3453
#
# Epoch 00091: val_loss did not improve from 0.83439
# Epoch 92/300
# 722/722 [==============================] - 763s 1s/step - loss: 0.8257 - mae: 0.6149 - mape: 246.2747 - val_loss: 1.2513 - val_mae: 0.8334 - val_mape: 569.2823
#
# Epoch 00092: val_loss did not improve from 0.83439
# Epoch 93/300
# 722/722 [==============================] - 765s 1s/step - loss: 0.8721 - mae: 0.6116 - mape: 247.9524 - val_loss: 1.2006 - val_mae: 0.8152 - val_mape: 537.3620
#
# Epoch 00093: val_loss did not improve from 0.83439
# Epoch 94/300
# 722/722 [==============================] - 765s 1s/step - loss: 0.8397 - mae: 0.6032 - mape: 259.1172 - val_loss: 1.1915 - val_mae: 0.8033 - val_mape: 515.1130
#
# Epoch 00094: val_loss did not improve from 0.83439
# Epoch 95/300
# 722/722 [==============================] - 755s 1s/step - loss: 0.7941 - mae: 0.6067 - mape: 245.6012 - val_loss: 1.2328 - val_mae: 0.8218 - val_mape: 533.3530
#
# Epoch 00095: val_loss did not improve from 0.83439
# Epoch 96/300
# 722/722 [==============================] - 752s 1s/step - loss: 0.7981 - mae: 0.5996 - mape: 245.8793 - val_loss: 1.3486 - val_mae: 0.8802 - val_mape: 645.3166
#
# Epoch 00096: val_loss did not improve from 0.83439
# Epoch 97/300
# 722/722 [==============================] - 762s 1s/step - loss: 0.8486 - mae: 0.6082 - mape: 248.8856 - val_loss: 1.2954 - val_mae: 0.8571 - val_mape: 586.0742
#
# Epoch 00097: val_loss did not improve from 0.83439
# Epoch 98/300
# 722/722 [==============================] - 767s 1s/step - loss: 0.8055 - mae: 0.6036 - mape: 251.7124 - val_loss: 1.2524 - val_mae: 0.8351 - val_mape: 545.0398
#
# Epoch 00098: val_loss did not improve from 0.83439
# Epoch 99/300
# 722/722 [==============================] - 753s 1s/step - loss: 0.7969 - mae: 0.5970 - mape: 254.1004 - val_loss: 1.3459 - val_mae: 0.8712 - val_mape: 618.4768
#
# Epoch 00099: val_loss did not improve from 0.83439
# Epoch 100/300
# 722/722 [==============================] - 835s 1s/step - loss: 0.8434 - mae: 0.6047 - mape: 258.4864 - val_loss: 1.2733 - val_mae: 0.8342 - val_mape: 539.6156
#
# Epoch 00100: val_loss did not improve from 0.83439
# Epoch 101/300
# 722/722 [==============================] - 837s 1s/step - loss: 0.7870 - mae: 0.5989 - mape: 243.0926 - val_loss: 1.4783 - val_mae: 0.9311 - val_mape: 684.2831
#
# Epoch 00101: val_loss did not improve from 0.83439
# Epoch 102/300
# 722/722 [==============================] - 839s 1s/step - loss: 0.7677 - mae: 0.5896 - mape: 249.0067 - val_loss: 1.3522 - val_mae: 0.8776 - val_mape: 606.6871
#
# Epoch 00102: val_loss did not improve from 0.83439
# Epoch 103/300
# 722/722 [==============================] - 836s 1s/step - loss: 0.7326 - mae: 0.5853 - mape: 262.1156 - val_loss: 1.3872 - val_mae: 0.8959 - val_mape: 652.7664
#
# Epoch 00103: val_loss did not improve from 0.83439
# Epoch 104/300
# 722/722 [==============================] - 867s 1s/step - loss: 0.7788 - mae: 0.5893 - mape: 256.7125 - val_loss: 1.4069 - val_mae: 0.8927 - val_mape: 619.6786
#
# Epoch 00104: val_loss did not improve from 0.83439
# Epoch 105/300
# 722/722 [==============================] - 848s 1s/step - loss: 0.7624 - mae: 0.5925 - mape: 265.0977 - val_loss: 1.3597 - val_mae: 0.8805 - val_mape: 603.0161
#
# Epoch 00105: val_loss did not improve from 0.83439
# Epoch 106/300
# 722/722 [==============================] - 860s 1s/step - loss: 0.8414 - mae: 0.5976 - mape: 252.4844 - val_loss: 1.4562 - val_mae: 0.9167 - val_mape: 658.3375
#
# Epoch 00106: val_loss did not improve from 0.83439
# Epoch 107/300
# 722/722 [==============================] - 869s 1s/step - loss: 0.7447 - mae: 0.5835 - mape: 255.0207 - val_loss: 1.4551 - val_mae: 0.9113 - val_mape: 639.8937
#
# Epoch 00107: val_loss did not improve from 0.83439
# Epoch 108/300
# 722/722 [==============================] - 892s 1s/step - loss: 0.8040 - mae: 0.5946 - mape: 262.9631 - val_loss: 1.4669 - val_mae: 0.9137 - val_mape: 660.7910
#
# Epoch 00108: val_loss did not improve from 0.83439
# Epoch 109/300
# 722/722 [==============================] - 859s 1s/step - loss: 0.7634 - mae: 0.5863 - mape: 253.3804 - val_loss: 1.4480 - val_mae: 0.9071 - val_mape: 613.3863
#
# Epoch 00109: val_loss did not improve from 0.83439
# Epoch 110/300
# 722/722 [==============================] - 869s 1s/step - loss: 0.7491 - mae: 0.5811 - mape: 256.7184 - val_loss: 1.4979 - val_mae: 0.9321 - val_mape: 667.3445
#
# Epoch 00110: val_loss did not improve from 0.83439
# Epoch 111/300
# 722/722 [==============================] - 890s 1s/step - loss: 0.7372 - mae: 0.5798 - mape: 260.4430 - val_loss: 1.6050 - val_mae: 0.9781 - val_mape: 705.9495
#
# Epoch 00111: val_loss did not improve from 0.83439
# Epoch 112/300
# 722/722 [==============================] - 922s 1s/step - loss: 0.7298 - mae: 0.5853 - mape: 267.6913 - val_loss: 1.5906 - val_mae: 0.9642 - val_mape: 698.6630
#
# Epoch 00112: val_loss did not improve from 0.83439
# Epoch 113/300
# 722/722 [==============================] - 899s 1s/step - loss: 0.7098 - mae: 0.5753 - mape: 253.6434 - val_loss: 1.6846 - val_mae: 1.0042 - val_mape: 735.6757
#
# Epoch 00113: val_loss did not improve from 0.83439
# Epoch 114/300
# 722/722 [==============================] - 900s 1s/step - loss: 0.7020 - mae: 0.5751 - mape: 271.2449 - val_loss: 1.5700 - val_mae: 0.9523 - val_mape: 681.9650
#
# Epoch 00114: val_loss did not improve from 0.83439
# Epoch 115/300
# 722/722 [==============================] - 896s 1s/step - loss: 0.7381 - mae: 0.5788 - mape: 259.5000 - val_loss: 1.5417 - val_mae: 0.9397 - val_mape: 654.4196
#
# Epoch 00115: val_loss did not improve from 0.83439
# Epoch 116/300
# 722/722 [==============================] - 926s 1s/step - loss: 0.7451 - mae: 0.5756 - mape: 252.9677 - val_loss: 1.6546 - val_mae: 0.9874 - val_mape: 731.4517
#
# Epoch 00116: val_loss did not improve from 0.83439
# Epoch 117/300
# 722/722 [==============================] - 890s 1s/step - loss: 0.7413 - mae: 0.5756 - mape: 262.9682 - val_loss: 1.7200 - val_mae: 1.0147 - val_mape: 760.9781
#
# Epoch 00117: val_loss did not improve from 0.83439
# Epoch 118/300
# 722/722 [==============================] - 892s 1s/step - loss: 0.7553 - mae: 0.5737 - mape: 262.4938 - val_loss: 1.7619 - val_mae: 1.0239 - val_mape: 760.2090
#
# Epoch 00118: val_loss did not improve from 0.83439
# Epoch 119/300
# 722/722 [==============================] - 908s 1s/step - loss: 0.7109 - mae: 0.5733 - mape: 262.8225 - val_loss: 1.6688 - val_mae: 0.9769 - val_mape: 690.5981
#
# Epoch 00119: val_loss did not improve from 0.83439
# Epoch 120/300
# 722/722 [==============================] - 928s 1s/step - loss: 0.7221 - mae: 0.5717 - mape: 262.8354 - val_loss: 1.7084 - val_mae: 0.9982 - val_mape: 727.9796
#
# Epoch 00120: val_loss did not improve from 0.83439
# Epoch 121/300
# 722/722 [==============================] - 900s 1s/step - loss: 0.7182 - mae: 0.5708 - mape: 274.2455 - val_loss: 1.6700 - val_mae: 0.9806 - val_mape: 715.3542
#
# Epoch 00121: val_loss did not improve from 0.83439
# Epoch 122/300
# 722/722 [==============================] - 904s 1s/step - loss: 0.6698 - mae: 0.5622 - mape: 257.3573 - val_loss: 1.7719 - val_mae: 1.0224 - val_mape: 769.6965
#
# Epoch 00122: val_loss did not improve from 0.83439
# Epoch 123/300
# 722/722 [==============================] - 901s 1s/step - loss: 0.6938 - mae: 0.5590 - mape: 262.8632 - val_loss: 1.9809 - val_mae: 1.1052 - val_mape: 858.7897
#
# Epoch 00123: val_loss did not improve from 0.83439
# Epoch 124/300
# 722/722 [==============================] - 923s 1s/step - loss: 0.7116 - mae: 0.5604 - mape: 262.5673 - val_loss: 1.7448 - val_mae: 1.0096 - val_mape: 730.1490
#
# Epoch 00124: val_loss did not improve from 0.83439
# Epoch 125/300
# 722/722 [==============================] - 891s 1s/step - loss: 0.6826 - mae: 0.5563 - mape: 259.0890 - val_loss: 1.6863 - val_mae: 0.9791 - val_mape: 707.6810
#
# Epoch 00125: val_loss did not improve from 0.83439
# Epoch 126/300
# 722/722 [==============================] - 900s 1s/step - loss: 0.6587 - mae: 0.5555 - mape: 268.4687 - val_loss: 1.8122 - val_mae: 1.0291 - val_mape: 760.7413
#
# Epoch 00126: val_loss did not improve from 0.83439
# Epoch 127/300
# 722/722 [==============================] - 898s 1s/step - loss: 0.6689 - mae: 0.5551 - mape: 276.4658 - val_loss: 1.7701 - val_mae: 1.0044 - val_mape: 725.6151
#
# Epoch 00127: val_loss did not improve from 0.83439
# Epoch 128/300
# 722/722 [==============================] - 919s 1s/step - loss: 0.7021 - mae: 0.5617 - mape: 266.6346 - val_loss: 1.8607 - val_mae: 1.0510 - val_mape: 807.8504
#
# Epoch 00128: val_loss did not improve from 0.83439
# Epoch 129/300
# 722/722 [==============================] - 903s 1s/step - loss: 0.6860 - mae: 0.5597 - mape: 275.1733 - val_loss: 2.0006 - val_mae: 1.1049 - val_mape: 845.7636
#
# Epoch 00129: val_loss did not improve from 0.83439
# Epoch 130/300
# 722/722 [==============================] - 898s 1s/step - loss: 0.6917 - mae: 0.5605 - mape: 271.1491 - val_loss: 1.9252 - val_mae: 1.0696 - val_mape: 802.2853
#
# Epoch 00130: val_loss did not improve from 0.83439
# Epoch 131/300
# 722/722 [==============================] - 899s 1s/step - loss: 0.6292 - mae: 0.5493 - mape: 267.9368 - val_loss: 1.9129 - val_mae: 1.0624 - val_mape: 798.0228
#
# Epoch 00131: val_loss did not improve from 0.83439
# Epoch 132/300
# 722/722 [==============================] - 927s 1s/step - loss: 0.6531 - mae: 0.5501 - mape: 262.2043 - val_loss: 1.8012 - val_mae: 1.0217 - val_mape: 760.0436
#
# Epoch 00132: val_loss did not improve from 0.83439
# Epoch 133/300
# 722/722 [==============================] - 888s 1s/step - loss: 0.7136 - mae: 0.5561 - mape: 273.4956 - val_loss: 2.0320 - val_mae: 1.1043 - val_mape: 856.4530
#
# Epoch 00133: val_loss did not improve from 0.83439
# Epoch 134/300
# 722/722 [==============================] - 899s 1s/step - loss: 0.6759 - mae: 0.5476 - mape: 279.0480 - val_loss: 2.1605 - val_mae: 1.1591 - val_mape: 920.0383
#
# Epoch 00134: val_loss did not improve from 0.83439
# Epoch 135/300
# 722/722 [==============================] - 899s 1s/step - loss: 0.6781 - mae: 0.5478 - mape: 274.1548 - val_loss: 1.9820 - val_mae: 1.0910 - val_mape: 823.2618
#
# Epoch 00135: val_loss did not improve from 0.83439
# Epoch 136/300
# 722/722 [==============================] - 932s 1s/step - loss: 0.6692 - mae: 0.5480 - mape: 266.7970 - val_loss: 2.1903 - val_mae: 1.1574 - val_mape: 886.1760
#
# Epoch 00136: val_loss did not improve from 0.83439
# Epoch 137/300
# 722/722 [==============================] - 890s 1s/step - loss: 0.6999 - mae: 0.5520 - mape: 258.2982 - val_loss: 2.1890 - val_mae: 1.1548 - val_mape: 904.7458
#
# Epoch 00137: val_loss did not improve from 0.83439
# Epoch 138/300
# 722/722 [==============================] - 897s 1s/step - loss: 0.6257 - mae: 0.5428 - mape: 270.2682 - val_loss: 2.1328 - val_mae: 1.1293 - val_mape: 881.3251
#
# Epoch 00138: val_loss did not improve from 0.83439
# Epoch 139/300
# 722/722 [==============================] - 893s 1s/step - loss: 0.6389 - mae: 0.5413 - mape: 281.0141 - val_loss: 1.9578 - val_mae: 1.0647 - val_mape: 797.7574
#
# Epoch 00139: val_loss did not improve from 0.83439
# Epoch 140/300
# 722/722 [==============================] - 908s 1s/step - loss: 0.6500 - mae: 0.5390 - mape: 267.2768 - val_loss: 1.8668 - val_mae: 1.0312 - val_mape: 755.8659
#
# Epoch 00140: val_loss did not improve from 0.83439
# Epoch 141/300
# 722/722 [==============================] - 797s 1s/step - loss: 0.6298 - mae: 0.5410 - mape: 286.5689 - val_loss: 2.2801 - val_mae: 1.1794 - val_mape: 916.7891
#
# Epoch 00141: val_loss did not improve from 0.83439
# Epoch 142/300
# 722/722 [==============================] - 792s 1s/step - loss: 0.6526 - mae: 0.5437 - mape: 255.5541 - val_loss: 2.0409 - val_mae: 1.0981 - val_mape: 839.9518
#
# Epoch 00142: val_loss did not improve from 0.83439
# Epoch 143/300
# 722/722 [==============================] - 758s 1s/step - loss: 0.6129 - mae: 0.5326 - mape: 271.6710 - val_loss: 2.1324 - val_mae: 1.1263 - val_mape: 861.7184
#
# Epoch 00143: val_loss did not improve from 0.83439
# Epoch 144/300
# 722/722 [==============================] - 714s 989ms/step - loss: 0.6232 - mae: 0.5334 - mape: 270.2857 - val_loss: 2.1223 - val_mae: 1.1325 - val_mape: 875.8798
#
# Epoch 00144: val_loss did not improve from 0.83439
# Epoch 145/300
# 722/722 [==============================] - 718s 994ms/step - loss: 0.6125 - mae: 0.5393 - mape: 276.0545 - val_loss: 2.2692 - val_mae: 1.1777 - val_mape: 905.4760
#
# Epoch 00145: val_loss did not improve from 0.83439
# Epoch 146/300
# 722/722 [==============================] - 712s 986ms/step - loss: 0.6209 - mae: 0.5273 - mape: 266.2598 - val_loss: 2.0761 - val_mae: 1.1072 - val_mape: 824.8704
#
# Epoch 00146: val_loss did not improve from 0.83439
# Epoch 147/300
# 722/722 [==============================] - 714s 989ms/step - loss: 0.6196 - mae: 0.5317 - mape: 268.9576 - val_loss: 2.3221 - val_mae: 1.2006 - val_mape: 931.1146
#
# Epoch 00147: val_loss did not improve from 0.83439
# Epoch 148/300
# 722/722 [==============================] - 715s 991ms/step - loss: 0.6277 - mae: 0.5293 - mape: 273.1463 - val_loss: 2.0551 - val_mae: 1.0995 - val_mape: 827.2458
#
# Epoch 00148: val_loss did not improve from 0.83439
# Epoch 149/300
# 722/722 [==============================] - 699s 968ms/step - loss: 0.5970 - mae: 0.5272 - mape: 272.1111 - val_loss: 2.3489 - val_mae: 1.1965 - val_mape: 917.4622
#
# Epoch 00149: val_loss did not improve from 0.83439
# Epoch 150/300
# 722/722 [==============================] - 719s 995ms/step - loss: 0.5687 - mae: 0.5199 - mape: 256.9768 - val_loss: 2.4827 - val_mae: 1.2431 - val_mape: 959.2692
#
# Epoch 00150: val_loss did not improve from 0.83439
# Epoch 151/300
# 722/722 [==============================] - 720s 997ms/step - loss: 0.6055 - mae: 0.5290 - mape: 290.1447 - val_loss: 2.4285 - val_mae: 1.2276 - val_mape: 961.4040
#
# Epoch 00151: val_loss did not improve from 0.83439
# Epoch 152/300
# 722/722 [==============================] - 726s 1s/step - loss: 0.5622 - mae: 0.5171 - mape: 272.0975 - val_loss: 2.5971 - val_mae: 1.2807 - val_mape: 1028.0812
#
# Epoch 00152: val_loss did not improve from 0.83439
# Epoch 153/300
# 722/722 [==============================] - 724s 1s/step - loss: 0.6346 - mae: 0.5219 - mape: 266.6533 - val_loss: 2.4916 - val_mae: 1.2397 - val_mape: 982.8670
#
# Epoch 00153: val_loss did not improve from 0.83439
# Epoch 154/300
# 722/722 [==============================] - 714s 989ms/step - loss: 0.6083 - mae: 0.5236 - mape: 275.3246 - val_loss: 2.6576 - val_mae: 1.2792 - val_mape: 1039.9419
#
# Epoch 00154: val_loss did not improve from 0.83439
# Epoch 155/300
# 722/722 [==============================] - 767s 1s/step - loss: 0.5949 - mae: 0.5259 - mape: 272.4616 - val_loss: 2.4577 - val_mae: 1.2242 - val_mape: 1000.6409
#
# Epoch 00155: val_loss did not improve from 0.83439
# Epoch 156/300
# 722/722 [==============================] - 752s 1s/step - loss: 0.5636 - mae: 0.5167 - mape: 261.6659 - val_loss: 2.5469 - val_mae: 1.2487 - val_mape: 1013.5878
#
# Epoch 00156: val_loss did not improve from 0.83439
# Epoch 157/300
# 722/722 [==============================] - 741s 1s/step - loss: 0.5766 - mae: 0.5167 - mape: 266.8477 - val_loss: 3.0744 - val_mae: 1.4176 - val_mape: 1158.0316
#
# Epoch 00157: val_loss did not improve from 0.83439
# Epoch 158/300
# 722/722 [==============================] - 739s 1s/step - loss: 0.5944 - mae: 0.5211 - mape: 264.5154 - val_loss: 2.4916 - val_mae: 1.2309 - val_mape: 980.5045
#
# Epoch 00158: val_loss did not improve from 0.83439
# Epoch 159/300
# 722/722 [==============================] - 767s 1s/step - loss: 0.5561 - mae: 0.5100 - mape: 276.1304 - val_loss: 2.7108 - val_mae: 1.2798 - val_mape: 1050.5643
#
# Epoch 00159: val_loss did not improve from 0.83439
# Epoch 160/300
# 722/722 [==============================] - 727s 1s/step - loss: 0.5851 - mae: 0.5149 - mape: 263.5220 - val_loss: 2.7116 - val_mae: 1.2921 - val_mape: 1040.6697
#
# Epoch 00160: val_loss did not improve from 0.83439
# Epoch 161/300
# 722/722 [==============================] - 732s 1s/step - loss: 0.6011 - mae: 0.5130 - mape: 262.2140 - val_loss: 3.1192 - val_mae: 1.4272 - val_mape: 1205.4888
#
# Epoch 00161: val_loss did not improve from 0.83439
# Epoch 162/300
# 722/722 [==============================] - 740s 1s/step - loss: 0.5563 - mae: 0.5066 - mape: 285.3809 - val_loss: 2.8420 - val_mae: 1.3233 - val_mape: 1071.7650
#
# Epoch 00162: val_loss did not improve from 0.83439
# Epoch 163/300
# 722/722 [==============================] - 746s 1s/step - loss: 0.5754 - mae: 0.5098 - mape: 274.5821 - val_loss: 3.0974 - val_mae: 1.4182 - val_mape: 1182.1158
#
# Epoch 00163: val_loss did not improve from 0.83439
# Epoch 164/300
# 722/722 [==============================] - 758s 1s/step - loss: 0.5386 - mae: 0.5026 - mape: 257.2193 - val_loss: 3.1666 - val_mae: 1.4368 - val_mape: 1176.5641
#
# Epoch 00164: val_loss did not improve from 0.83439
# Epoch 165/300
# 722/722 [==============================] - 743s 1s/step - loss: 0.5274 - mae: 0.5034 - mape: 273.0912 - val_loss: 2.9728 - val_mae: 1.3715 - val_mape: 1124.7915
#
# Epoch 00165: val_loss did not improve from 0.83439
# Epoch 166/300
# 722/722 [==============================] - 769s 1s/step - loss: 0.5817 - mae: 0.5119 - mape: 272.4259 - val_loss: 3.1119 - val_mae: 1.3972 - val_mape: 1171.1606
#
# Epoch 00166: val_loss did not improve from 0.83439
# Epoch 167/300
# 722/722 [==============================] - 758s 1s/step - loss: 0.5335 - mae: 0.4999 - mape: 266.7124 - val_loss: 2.8789 - val_mae: 1.3396 - val_mape: 1095.9855
#
# Epoch 00167: val_loss did not improve from 0.83439
# Epoch 168/300
# 722/722 [==============================] - 765s 1s/step - loss: 0.5428 - mae: 0.5002 - mape: 266.1921 - val_loss: 3.1018 - val_mae: 1.3997 - val_mape: 1141.3904
#
# Epoch 00168: val_loss did not improve from 0.83439
# Epoch 169/300
# 722/722 [==============================] - 781s 1s/step - loss: 0.5452 - mae: 0.4999 - mape: 267.0422 - val_loss: 3.3651 - val_mae: 1.4849 - val_mape: 1233.5344
#
# Epoch 00169: val_loss did not improve from 0.83439
# Epoch 170/300
# 722/722 [==============================] - 763s 1s/step - loss: 0.5123 - mae: 0.4908 - mape: 260.7053 - val_loss: 2.8839 - val_mae: 1.3360 - val_mape: 1065.8153
#
# Epoch 00170: val_loss did not improve from 0.83439
# Epoch 171/300
# 722/722 [==============================] - 769s 1s/step - loss: 0.5160 - mae: 0.4925 - mape: 259.1209 - val_loss: 3.2265 - val_mae: 1.4241 - val_mape: 1146.7795
#
# Epoch 00171: val_loss did not improve from 0.83439
# Epoch 172/300
# 722/722 [==============================] - 761s 1s/step - loss: 0.5552 - mae: 0.4980 - mape: 263.0064 - val_loss: 2.9082 - val_mae: 1.3434 - val_mape: 1052.0986
#
# Epoch 00172: val_loss did not improve from 0.83439
# Epoch 173/300
# 722/722 [==============================] - 777s 1s/step - loss: 0.5248 - mae: 0.4919 - mape: 285.7836 - val_loss: 2.9029 - val_mae: 1.3427 - val_mape: 1054.3464
#
# Epoch 00173: val_loss did not improve from 0.83439
# Epoch 174/300
# 722/722 [==============================] - 762s 1s/step - loss: 0.4895 - mae: 0.4882 - mape: 271.3898 - val_loss: 3.3822 - val_mae: 1.4745 - val_mape: 1180.2542
#
# Epoch 00174: val_loss did not improve from 0.83439
# Epoch 175/300
# 722/722 [==============================] - 763s 1s/step - loss: 0.5080 - mae: 0.4896 - mape: 282.6690 - val_loss: 3.3334 - val_mae: 1.4418 - val_mape: 1196.1046
#
# Epoch 00175: val_loss did not improve from 0.83439
# Epoch 176/300
# 722/722 [==============================] - 757s 1s/step - loss: 0.5146 - mae: 0.4860 - mape: 258.4323 - val_loss: 3.1072 - val_mae: 1.3904 - val_mape: 1071.1548
#
# Epoch 00176: val_loss did not improve from 0.83439
# Epoch 177/300
# 722/722 [==============================] - 759s 1s/step - loss: 0.4963 - mae: 0.4812 - mape: 266.6000 - val_loss: 3.5449 - val_mae: 1.5229 - val_mape: 1258.2219
#
# Epoch 00177: val_loss did not improve from 0.83439
# Epoch 178/300
# 722/722 [==============================] - 791s 1s/step - loss: 0.5438 - mae: 0.4850 - mape: 300.1291 - val_loss: 3.6143 - val_mae: 1.5364 - val_mape: 1245.6770
#
# Epoch 00178: val_loss did not improve from 0.83439
# Epoch 179/300
# 722/722 [==============================] - 773s 1s/step - loss: 0.5170 - mae: 0.4844 - mape: 270.4806 - val_loss: 3.2220 - val_mae: 1.4035 - val_mape: 1090.8843
#
# Epoch 00179: val_loss did not improve from 0.83439
# Epoch 180/300
# 722/722 [==============================] - 788s 1s/step - loss: 0.4713 - mae: 0.4803 - mape: 261.9902 - val_loss: 3.1114 - val_mae: 1.3649 - val_mape: 1106.0096
#
# Epoch 00180: val_loss did not improve from 0.83439
# Epoch 181/300
# 722/722 [==============================] - 797s 1s/step - loss: 0.4957 - mae: 0.4762 - mape: 256.9229 - val_loss: 3.9572 - val_mae: 1.6085 - val_mape: 1293.7129
#
# Epoch 00181: val_loss did not improve from 0.83439
# Epoch 182/300
# 722/722 [==============================] - 795s 1s/step - loss: 0.4774 - mae: 0.4762 - mape: 261.0569 - val_loss: 3.7584 - val_mae: 1.5558 - val_mape: 1256.4901
#
# Epoch 00182: val_loss did not improve from 0.83439
# Epoch 183/300
# 722/722 [==============================] - 811s 1s/step - loss: 0.4720 - mae: 0.4770 - mape: 269.5031 - val_loss: 3.4382 - val_mae: 1.4713 - val_mape: 1167.9042
#
# Epoch 00183: val_loss did not improve from 0.83439
# Epoch 184/300
# 722/722 [==============================] - 779s 1s/step - loss: 0.4810 - mae: 0.4759 - mape: 271.1254 - val_loss: 3.6137 - val_mae: 1.5184 - val_mape: 1213.7847
#
# Epoch 00184: val_loss did not improve from 0.83439
# Epoch 185/300
# 722/722 [==============================] - 780s 1s/step - loss: 0.4645 - mae: 0.4711 - mape: 260.3038 - val_loss: 3.5178 - val_mae: 1.4841 - val_mape: 1201.8834
#
# Epoch 00185: val_loss did not improve from 0.83439
# Epoch 186/300
# 722/722 [==============================] - 783s 1s/step - loss: 0.5043 - mae: 0.4775 - mape: 267.9494 - val_loss: 3.8749 - val_mae: 1.6043 - val_mape: 1355.4285
#
# Epoch 00186: val_loss did not improve from 0.83439
# Epoch 187/300
# 722/722 [==============================] - 800s 1s/step - loss: 0.4422 - mae: 0.4687 - mape: 272.5741 - val_loss: 3.4631 - val_mae: 1.4663 - val_mape: 1214.4614
#
# Epoch 00187: val_loss did not improve from 0.83439
# Epoch 188/300
# 722/722 [==============================] - 773s 1s/step - loss: 0.4513 - mae: 0.4660 - mape: 276.4757 - val_loss: 3.4832 - val_mae: 1.4852 - val_mape: 1213.0072
#
# Epoch 00188: val_loss did not improve from 0.83439
# Epoch 189/300
# 722/722 [==============================] - 767s 1s/step - loss: 0.4591 - mae: 0.4630 - mape: 258.2312 - val_loss: 3.4221 - val_mae: 1.4571 - val_mape: 1195.4198
#
# Epoch 00189: val_loss did not improve from 0.83439
# Epoch 190/300
# 722/722 [==============================] - 781s 1s/step - loss: 0.4774 - mae: 0.4674 - mape: 257.6256 - val_loss: 3.8285 - val_mae: 1.5620 - val_mape: 1327.7050
#
# Epoch 00190: val_loss did not improve from 0.83439
# Epoch 191/300
# 722/722 [==============================] - 808s 1s/step - loss: 0.4492 - mae: 0.4615 - mape: 269.4302 - val_loss: 3.9731 - val_mae: 1.5793 - val_mape: 1312.9561
#
# Epoch 00191: val_loss did not improve from 0.83439
# Epoch 192/300
# 722/722 [==============================] - 807s 1s/step - loss: 0.4609 - mae: 0.4647 - mape: 259.4055 - val_loss: 3.7366 - val_mae: 1.5454 - val_mape: 1228.5243
#
# Epoch 00192: val_loss did not improve from 0.83439
# Epoch 193/300
# 722/722 [==============================] - 781s 1s/step - loss: 0.4892 - mae: 0.4662 - mape: 261.6985 - val_loss: 3.1522 - val_mae: 1.3902 - val_mape: 1061.9812
#
# Epoch 00193: val_loss did not improve from 0.83439
# Epoch 194/300
# 722/722 [==============================] - 774s 1s/step - loss: 0.4500 - mae: 0.4570 - mape: 255.6556 - val_loss: 4.1374 - val_mae: 1.6510 - val_mape: 1340.9705
#
# Epoch 00194: val_loss did not improve from 0.83439
# Epoch 195/300
# 722/722 [==============================] - 785s 1s/step - loss: 0.4565 - mae: 0.4578 - mape: 278.3165 - val_loss: 3.4138 - val_mae: 1.4630 - val_mape: 1184.1337
#
# Epoch 00195: val_loss did not improve from 0.83439
# Epoch 196/300
# 722/722 [==============================] - 814s 1s/step - loss: 0.4398 - mae: 0.4542 - mape: 252.5361 - val_loss: 4.0081 - val_mae: 1.6149 - val_mape: 1321.2198
#
# Epoch 00196: val_loss did not improve from 0.83439
# Epoch 197/300
# 722/722 [==============================] - 780s 1s/step - loss: 0.4273 - mae: 0.4531 - mape: 254.7638 - val_loss: 3.7515 - val_mae: 1.5351 - val_mape: 1228.6742
#
# Epoch 00197: val_loss did not improve from 0.83439
# ...
#
# Epoch 00230: val_loss did not improve from 0.83439
# Epoch 231/300
# 722/722 [==============================] - 748s 1s/step - loss: 0.3453 - mae: 0.4034 - mape: 265.4859 - val_loss: 4.7485 - val_mae: 1.7026 - val_mape: 1396.7600
#
# Epoch 00231: val_loss did not improve from 0.83439
# Epoch 232/300
# 722/722 [==============================] - 738s 1s/step - loss: 0.3270 - mae: 0.3930 - mape: 256.6350 - val_loss: 4.4771 - val_mae: 1.6397 - val_mape: 1287.6798
#
# Epoch 00232: val_loss did not improve from 0.83439
# Epoch 233/300
# 722/722 [==============================] - 734s 1s/step - loss: 0.3462 - mae: 0.4048 - mape: 265.6555 - val_loss: 4.9420 - val_mae: 1.7729 - val_mape: 1425.7461
#
# Epoch 00233: val_loss did not improve from 0.83439
# Epoch 234/300
# 722/722 [==============================] - 742s 1s/step - loss: 0.3509 - mae: 0.3990 - mape: 254.2192 - val_loss: 5.1179 - val_mae: 1.8076 - val_mape: 1441.7681
#
# Epoch 00234: val_loss did not improve from 0.83439
# Epoch 235/300
# 722/722 [==============================] - 743s 1s/step - loss: 0.3177 - mae: 0.3898 - mape: 254.2436 - val_loss: 5.1903 - val_mae: 1.8084 - val_mape: 1423.4468
#
# Epoch 00235: val_loss did not improve from 0.83439
# Epoch 236/300
# 722/722 [==============================] - 737s 1s/step - loss: 0.3063 - mae: 0.3858 - mape: 259.5703 - val_loss: 4.7334 - val_mae: 1.7211 - val_mape: 1417.7205
#
# Epoch 00236: val_loss did not improve from 0.83439
# Epoch 237/300
# 722/722 [==============================] - 732s 1s/step - loss: 0.3369 - mae: 0.3923 - mape: 253.9914 - val_loss: 4.8571 - val_mae: 1.7364 - val_mape: 1369.3257
#
# Epoch 00237: val_loss did not improve from 0.83439
# Epoch 238/300
# 722/722 [==============================] - 740s 1s/step - loss: 0.3199 - mae: 0.3814 - mape: 255.8748 - val_loss: 5.0274 - val_mae: 1.7629 - val_mape: 1341.3302
#
# Epoch 00238: val_loss did not improve from 0.83439
# Epoch 239/300
# 722/722 [==============================] - 736s 1s/step - loss: 0.3154 - mae: 0.3850 - mape: 254.0140 - val_loss: 4.5038 - val_mae: 1.6606 - val_mape: 1276.3416
#
# Epoch 00239: val_loss did not improve from 0.83439
# Epoch 240/300
# 722/722 [==============================] - 738s 1s/step - loss: 0.3059 - mae: 0.3821 - mape: 245.5515 - val_loss: 5.0030 - val_mae: 1.7624 - val_mape: 1392.3719
#
# Epoch 00240: val_loss did not improve from 0.83439
# Epoch 241/300
# 722/722 [==============================] - 737s 1s/step - loss: 0.3061 - mae: 0.3813 - mape: 258.0149 - val_loss: 5.0269 - val_mae: 1.7548 - val_mape: 1318.4181
#
# Epoch 00241: val_loss did not improve from 0.83439
# Epoch 242/300
# 722/722 [==============================] - 746s 1s/step - loss: 0.3256 - mae: 0.3807 - mape: 261.4590 - val_loss: 4.5439 - val_mae: 1.6692 - val_mape: 1259.0297
#
# Epoch 00242: val_loss did not improve from 0.83439
# Epoch 243/300
# 722/722 [==============================] - 737s 1s/step - loss: 0.2878 - mae: 0.3767 - mape: 250.6662 - val_loss: 5.2897 - val_mae: 1.8173 - val_mape: 1389.4608
#
# Epoch 00243: val_loss did not improve from 0.83439
# Epoch 244/300
# 722/722 [==============================] - 740s 1s/step - loss: 0.3211 - mae: 0.3822 - mape: 253.7059 - val_loss: 5.8881 - val_mae: 1.9423 - val_mape: 1570.7649
#
# Epoch 00244: val_loss did not improve from 0.83439
# Epoch 245/300
# 722/722 [==============================] - 748s 1s/step - loss: 0.2890 - mae: 0.3697 - mape: 271.0474 - val_loss: 5.3780 - val_mae: 1.8381 - val_mape: 1396.4928
#
# Epoch 00245: val_loss did not improve from 0.83439
# Epoch 246/300
# 722/722 [==============================] - 744s 1s/step - loss: 0.2776 - mae: 0.3669 - mape: 256.9062 - val_loss: 4.6483 - val_mae: 1.6753 - val_mape: 1304.6605
#
# Epoch 00246: val_loss did not improve from 0.83439
# Epoch 247/300
# 722/722 [==============================] - 749s 1s/step - loss: 0.2872 - mae: 0.3679 - mape: 250.2069 - val_loss: 4.8303 - val_mae: 1.7097 - val_mape: 1357.9989
#
# Epoch 00247: val_loss did not improve from 0.83439
# Epoch 248/300
# 722/722 [==============================] - 752s 1s/step - loss: 0.2908 - mae: 0.3670 - mape: 243.4249 - val_loss: 4.8907 - val_mae: 1.7355 - val_mape: 1363.3147
#
# Epoch 00248: val_loss did not improve from 0.83439
# Epoch 249/300
# 722/722 [==============================] - 771s 1s/step - loss: 0.2710 - mae: 0.3640 - mape: 243.3570 - val_loss: 5.2270 - val_mae: 1.8121 - val_mape: 1442.4197
#
# Epoch 00249: val_loss did not improve from 0.83439
# Epoch 250/300
# 722/722 [==============================] - 774s 1s/step - loss: 0.3022 - mae: 0.3662 - mape: 257.1927 - val_loss: 5.1821 - val_mae: 1.7994 - val_mape: 1414.0948
#
# Epoch 00250: val_loss did not improve from 0.83439
# Epoch 251/300
# 722/722 [==============================] - 775s 1s/step - loss: 0.2832 - mae: 0.3627 - mape: 249.4807 - val_loss: 5.7463 - val_mae: 1.9252 - val_mape: 1524.5626
#
# Epoch 00251: val_loss did not improve from 0.83439
# Epoch 252/300
# 722/722 [==============================] - 777s 1s/step - loss: 0.2889 - mae: 0.3571 - mape: 245.8021 - val_loss: 4.9822 - val_mae: 1.7562 - val_mape: 1384.7367
#
# Epoch 00252: val_loss did not improve from 0.83439
# Epoch 253/300
# 722/722 [==============================] - 771s 1s/step - loss: 0.2718 - mae: 0.3581 - mape: 238.6489 - val_loss: 5.2111 - val_mae: 1.7896 - val_mape: 1397.3115
#
# Epoch 00253: val_loss did not improve from 0.83439
# Epoch 254/300
# 722/722 [==============================] - 786s 1s/step - loss: 0.2736 - mae: 0.3585 - mape: 251.0861 - val_loss: 5.4145 - val_mae: 1.8389 - val_mape: 1464.6288
#
# Epoch 00254: val_loss did not improve from 0.83439
# Epoch 255/300
# 722/722 [==============================] - 781s 1s/step - loss: 0.2809 - mae: 0.3598 - mape: 252.1453 - val_loss: 5.0857 - val_mae: 1.7798 - val_mape: 1408.0288
#
# Epoch 00255: val_loss did not improve from 0.83439
# Epoch 256/300
# 722/722 [==============================] - 793s 1s/step - loss: 0.2633 - mae: 0.3555 - mape: 253.7581 - val_loss: 5.0539 - val_mae: 1.7724 - val_mape: 1373.8732
#
# Epoch 00256: val_loss did not improve from 0.83439
# Epoch 257/300
# 722/722 [==============================] - 790s 1s/step - loss: 0.2753 - mae: 0.3574 - mape: 240.0089 - val_loss: 5.3418 - val_mae: 1.8370 - val_mape: 1406.2633
#
# Epoch 00257: val_loss did not improve from 0.83439
# Epoch 258/300
# 722/722 [==============================] - 781s 1s/step - loss: 0.2716 - mae: 0.3531 - mape: 245.6352 - val_loss: 5.0814 - val_mae: 1.7706 - val_mape: 1393.5920
#
# Epoch 00258: val_loss did not improve from 0.83439
# Epoch 259/300
# 722/722 [==============================] - 792s 1s/step - loss: 0.2636 - mae: 0.3508 - mape: 251.3956 - val_loss: 5.6583 - val_mae: 1.8715 - val_mape: 1451.7037
#
# Epoch 00259: val_loss did not improve from 0.83439
# Epoch 260/300
# 722/722 [==============================] - 790s 1s/step - loss: 0.2744 - mae: 0.3521 - mape: 244.6611 - val_loss: 4.2872 - val_mae: 1.6027 - val_mape: 1258.4745
#
# Epoch 00260: val_loss did not improve from 0.83439
# Epoch 261/300
# 722/722 [==============================] - 798s 1s/step - loss: 0.2469 - mae: 0.3478 - mape: 245.1610 - val_loss: 5.6953 - val_mae: 1.8956 - val_mape: 1502.5254
#
# Epoch 00261: val_loss did not improve from 0.83439
# Epoch 262/300
# 722/722 [==============================] - 788s 1s/step - loss: 0.2693 - mae: 0.3465 - mape: 240.1818 - val_loss: 5.5537 - val_mae: 1.8612 - val_mape: 1459.1254
#
# Epoch 00262: val_loss did not improve from 0.83439
# Epoch 263/300
# 722/722 [==============================] - 782s 1s/step - loss: 0.2640 - mae: 0.3462 - mape: 244.9271 - val_loss: 4.6340 - val_mae: 1.6796 - val_mape: 1274.9473
#
# Epoch 00263: val_loss did not improve from 0.83439
# Epoch 264/300
# 722/722 [==============================] - 788s 1s/step - loss: 0.2489 - mae: 0.3439 - mape: 247.8332 - val_loss: 4.8351 - val_mae: 1.7160 - val_mape: 1319.9581
#
# Epoch 00264: val_loss did not improve from 0.83439
# Epoch 265/300
# 722/722 [==============================] - 790s 1s/step - loss: 0.2514 - mae: 0.3412 - mape: 239.6865 - val_loss: 5.2200 - val_mae: 1.7803 - val_mape: 1344.4536
#
# Epoch 00265: val_loss did not improve from 0.83439
# Epoch 266/300
# 722/722 [==============================] - 800s 1s/step - loss: 0.2353 - mae: 0.3386 - mape: 254.2928 - val_loss: 4.9665 - val_mae: 1.7468 - val_mape: 1351.2771
#
# Epoch 00266: val_loss did not improve from 0.83439
# Epoch 267/300
# 722/722 [==============================] - 785s 1s/step - loss: 0.2228 - mae: 0.3328 - mape: 238.1654 - val_loss: 5.9373 - val_mae: 1.9233 - val_mape: 1479.1066
#
# Epoch 00267: val_loss did not improve from 0.83439
# Epoch 268/300
# 722/722 [==============================] - 795s 1s/step - loss: 0.2447 - mae: 0.3356 - mape: 232.2780 - val_loss: 6.1236 - val_mae: 1.9833 - val_mape: 1610.3287
#
# Epoch 00268: val_loss did not improve from 0.83439
# Epoch 269/300
# 722/722 [==============================] - 784s 1s/step - loss: 0.2587 - mae: 0.3337 - mape: 229.8579 - val_loss: 5.4530 - val_mae: 1.8376 - val_mape: 1418.6730
#
# Epoch 00269: val_loss did not improve from 0.83439
# Epoch 270/300
# 722/722 [==============================] - 788s 1s/step - loss: 0.2297 - mae: 0.3292 - mape: 231.3348 - val_loss: 5.1858 - val_mae: 1.8150 - val_mape: 1435.4551
#
# Epoch 00270: val_loss did not improve from 0.83439
# Epoch 271/300
# 722/722 [==============================] - 790s 1s/step - loss: 0.2371 - mae: 0.3355 - mape: 231.3382 - val_loss: 5.0134 - val_mae: 1.7740 - val_mape: 1382.1897
#
# Epoch 00271: val_loss did not improve from 0.83439
# Epoch 272/300
# 722/722 [==============================] - 778s 1s/step - loss: 0.2406 - mae: 0.3300 - mape: 225.1755 - val_loss: 5.7083 - val_mae: 1.9088 - val_mape: 1544.4951
#
# Epoch 00272: val_loss did not improve from 0.83439
# Epoch 273/300
# 722/722 [==============================] - 770s 1s/step - loss: 0.2340 - mae: 0.3253 - mape: 235.8672 - val_loss: 5.6451 - val_mae: 1.8878 - val_mape: 1516.0950
#
# Epoch 00273: val_loss did not improve from 0.83439
# Epoch 274/300
# 722/722 [==============================] - 782s 1s/step - loss: 0.2214 - mae: 0.3238 - mape: 237.1164 - val_loss: 5.1409 - val_mae: 1.7667 - val_mape: 1340.2870
#
# Epoch 00274: val_loss did not improve from 0.83439
# Epoch 275/300
# 722/722 [==============================] - 789s 1s/step - loss: 0.2162 - mae: 0.3188 - mape: 238.8526 - val_loss: 5.4622 - val_mae: 1.8189 - val_mape: 1400.1005
#
# Epoch 00275: val_loss did not improve from 0.83439
# Epoch 276/300
# 722/722 [==============================] - 805s 1s/step - loss: 0.2309 - mae: 0.3244 - mape: 230.3110 - val_loss: 5.7299 - val_mae: 1.8663 - val_mape: 1438.9598
#
# Epoch 00276: val_loss did not improve from 0.83439
# Epoch 277/300
# 722/722 [==============================] - 763s 1s/step - loss: 0.2250 - mae: 0.3167 - mape: 239.8957 - val_loss: 5.7419 - val_mae: 1.8567 - val_mape: 1392.0002
#
# Epoch 00277: val_loss did not improve from 0.83439
# Epoch 278/300
# 722/722 [==============================] - 756s 1s/step - loss: 0.2413 - mae: 0.3257 - mape: 228.2001 - val_loss: 5.4542 - val_mae: 1.8335 - val_mape: 1423.7614
#
# Epoch 00278: val_loss did not improve from 0.83439
# Epoch 279/300
# 722/722 [==============================] - 762s 1s/step - loss: 0.2336 - mae: 0.3159 - mape: 227.5418 - val_loss: 5.7030 - val_mae: 1.8651 - val_mape: 1427.8583
#
# Epoch 00279: val_loss did not improve from 0.83439
# Epoch 280/300
# 722/722 [==============================] - 752s 1s/step - loss: 0.2020 - mae: 0.3119 - mape: 236.6264 - val_loss: 5.4671 - val_mae: 1.8311 - val_mape: 1416.1853
#
# Epoch 00280: val_loss did not improve from 0.83439
# Epoch 281/300
# 722/722 [==============================] - 751s 1s/step - loss: 0.1939 - mae: 0.3102 - mape: 241.0036 - val_loss: 4.9397 - val_mae: 1.7121 - val_mape: 1284.2244
#
# Epoch 00281: val_loss did not improve from 0.83439
# Epoch 282/300
# 722/722 [==============================] - 746s 1s/step - loss: 0.2100 - mae: 0.3105 - mape: 234.5448 - val_loss: 5.4184 - val_mae: 1.8175 - val_mape: 1399.6553
#
# Epoch 00282: val_loss did not improve from 0.83439
# Epoch 283/300
# 722/722 [==============================] - 748s 1s/step - loss: 0.2005 - mae: 0.3076 - mape: 235.7838 - val_loss: 5.9275 - val_mae: 1.9179 - val_mape: 1546.2461
#
# Epoch 00283: val_loss did not improve from 0.83439
# Epoch 284/300
# 722/722 [==============================] - 744s 1s/step - loss: 0.2019 - mae: 0.3128 - mape: 231.6824 - val_loss: 4.7852 - val_mae: 1.7085 - val_mape: 1304.7292
#
# Epoch 00284: val_loss did not improve from 0.83439
# Epoch 285/300
# 722/722 [==============================] - 743s 1s/step - loss: 0.1854 - mae: 0.3075 - mape: 222.9029 - val_loss: 5.2897 - val_mae: 1.8015 - val_mape: 1392.1462
#
# Epoch 00285: val_loss did not improve from 0.83439
# Epoch 286/300
# 722/722 [==============================] - 753s 1s/step - loss: 0.1898 - mae: 0.3013 - mape: 224.2725 - val_loss: 5.3846 - val_mae: 1.8430 - val_mape: 1482.3333
#
# Epoch 00286: val_loss did not improve from 0.83439
# Epoch 287/300
# 722/722 [==============================] - 739s 1s/step - loss: 0.1995 - mae: 0.3046 - mape: 218.9311 - val_loss: 5.8651 - val_mae: 1.9165 - val_mape: 1508.0205
#
# Epoch 00287: val_loss did not improve from 0.83439
# Epoch 288/300
# 722/722 [==============================] - 741s 1s/step - loss: 0.1940 - mae: 0.3016 - mape: 234.4742 - val_loss: 5.0479 - val_mae: 1.7588 - val_mape: 1379.8326
#
# Epoch 00288: val_loss did not improve from 0.83439
# Epoch 289/300
# 722/722 [==============================] - 745s 1s/step - loss: 0.1856 - mae: 0.2971 - mape: 211.0901 - val_loss: 5.1637 - val_mae: 1.7789 - val_mape: 1360.4468
#
# Epoch 00289: val_loss did not improve from 0.83439
# Epoch 290/300
# 722/722 [==============================] - 743s 1s/step - loss: 0.1721 - mae: 0.2920 - mape: 231.5388 - val_loss: 5.0718 - val_mae: 1.7559 - val_mape: 1343.1790
#
# Epoch 00290: val_loss did not improve from 0.83439
# Epoch 291/300
# 722/722 [==============================] - 747s 1s/step - loss: 0.1876 - mae: 0.2974 - mape: 225.6399 - val_loss: 5.9322 - val_mae: 1.9152 - val_mape: 1493.2480
#
# Epoch 00291: val_loss did not improve from 0.83439
# Epoch 292/300
# 722/722 [==============================] - 731s 1s/step - loss: 0.1766 - mae: 0.2930 - mape: 214.1829 - val_loss: 5.2828 - val_mae: 1.7890 - val_mape: 1375.5658
#
# Epoch 00292: val_loss did not improve from 0.83439
# Epoch 293/300
# 722/722 [==============================] - 735s 1s/step - loss: 0.1742 - mae: 0.2936 - mape: 225.7763 - val_loss: 6.3333 - val_mae: 1.9880 - val_mape: 1551.0016
#
# Epoch 00293: val_loss did not improve from 0.83439
# Epoch 294/300
# 722/722 [==============================] - 750s 1s/step - loss: 0.1714 - mae: 0.2927 - mape: 218.0649 - val_loss: 5.1538 - val_mae: 1.7739 - val_mape: 1422.2637
#
# Epoch 00294: val_loss did not improve from 0.83439
# Epoch 295/300
# 722/722 [==============================] - 747s 1s/step - loss: 0.1925 - mae: 0.2950 - mape: 227.3256 - val_loss: 5.3731 - val_mae: 1.8120 - val_mape: 1403.2897
#
# Epoch 00295: val_loss did not improve from 0.83439
# Epoch 296/300
# 722/722 [==============================] - 758s 1s/step - loss: 0.1791 - mae: 0.2901 - mape: 212.3865 - val_loss: 5.3354 - val_mae: 1.8141 - val_mape: 1425.1532
#
# Epoch 00296: val_loss did not improve from 0.83439
# Epoch 297/300
# 722/722 [==============================] - 748s 1s/step - loss: 0.1793 - mae: 0.2925 - mape: 215.0724 - val_loss: 5.2557 - val_mae: 1.7931 - val_mape: 1391.4067
#
# Epoch 00297: val_loss did not improve from 0.83439
# Epoch 298/300
# 722/722 [==============================] - 755s 1s/step - loss: 0.1899 - mae: 0.2893 - mape: 216.1373 - val_loss: 5.3094 - val_mae: 1.8087 - val_mape: 1424.1046
#
# Epoch 00298: val_loss did not improve from 0.83439
# Epoch 299/300
# 722/722 [==============================] - 747s 1s/step - loss: 0.1755 - mae: 0.2847 - mape: 217.2465 - val_loss: 5.4579 - val_mae: 1.8266 - val_mape: 1421.7638
#
# Epoch 00299: val_loss did not improve from 0.83439
# Epoch 300/300
# 722/722 [==============================] - 739s 1s/step - loss: 0.1655 - mae: 0.2818 - mape: 222.3911 - val_loss: 5.7034 - val_mae: 1.8645 - val_mape: 1440.5836
#
# Epoch 00300: val_loss did not improve from 0.83439

# %%
model_last = sorted([i for i in os.listdir('../content') if 'hdf5' in i and 'Transformer+TimeEmbedding2' in i])[-1]

# %%
model = tf.keras.models.load_model(
    os.path.join('../content', model_last),
    custom_objects={
        'Time2Vector': Time2Vector,
        'SingleAttention': SingleAttention,
        'MultiAttention': MultiAttention,
        'TransformerEncoder': TransformerEncoder
    }
)
with open('../content/history2.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
###############################################################################
'''Calculate predictions and metrics'''

#Calculate predication for training, validation and test data
train_pred = model.predict(X_train)
val_pred = model.predict(X_val)
test_pred = model.predict(X_test)

#Print evaluation metrics for all datasets
train_eval = model.evaluate(X_train, y_train, verbose=0)
val_eval = model.evaluate(X_val, y_val, verbose=0)
test_eval = model.evaluate(X_test, y_test, verbose=0)
print(' ')
print('Evaluation metrics')
print('Training Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(train_eval[0], train_eval[1], train_eval[2]))
print('Validation Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(val_eval[0], val_eval[1], val_eval[2]))
print('Test Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(test_eval[0], test_eval[1], test_eval[2]))
# Out:
#
# Evaluation metrics
# Training Data - Loss: 1.0022, MAE: 0.6525, MAPE: 100.0686
# Validation Data - Loss: 0.8344, MAE: 0.5964, MAPE: 100.0550
# Test Data - Loss: 0.6875, MAE: 0.5652, MAPE: 100.1230

# %% [markdown]
# ### Training error

# %%
def mde(y_true, y_pred):
    return 1 - np.equal(y_true[1:] - y_true[:-1] >= 0, y_pred[1:] - y_true[:-1] >= 0).mean()

# %%
y = sc_target.inverse_transform(y_train.reshape(-1, 1))
y_pred = sc_target.inverse_transform(train_pred)
print(f'mse: {MSE(y.flatten(), y_pred.flatten()).numpy()}')
print(f'mae: {MAE(y.flatten(), y_pred.flatten()).numpy()}')
print(f'mape: {MAPE(y.flatten(), y_pred.flatten()).numpy()}')
print(f'mde: {mde(y.flatten(), y_pred.flatten())}')
# Out:
# mse: 1.135844982513845e-07
# mae: 0.00021967632346786559
# mape: 175.486328125
# mde: 0.236168276937741

# %% [markdown]
# ### Validation Error

# %%
y = sc_target.inverse_transform(y_val.reshape(-1, 1))
y_pred = sc_target.inverse_transform(val_pred)
print(f'mse: {MSE(y.flatten(), y_pred.flatten()).numpy()}')
print(f'mae: {MAE(y.flatten(), y_pred.flatten()).numpy()}')
print(f'mape: {MAPE(y.flatten(), y_pred.flatten()).numpy()}')
print(f'mde: {mde(y.flatten(), y_pred.flatten())}')
# Out:
# mse: 9.45675466823559e-08
# mae: 0.00020079353998880833
# mape: 155.7835235595703
# mde: 0.237012987012987

# %% [markdown]
# ### Test Error

# %%
y = sc_target.inverse_transform(y_test.reshape(-1, 1))
y_pred = sc_target.inverse_transform(test_pred)
print(f'mse: {MSE(y.flatten(), y_pred.flatten()).numpy()}')
print(f'mae: {MAE(y.flatten(), y_pred.flatten()).numpy()}')
print(f'mape: {MAPE(y.flatten(), y_pred.flatten()).numpy()}')
print(f'mde: {mde(y.flatten(), y_pred.flatten())}')
# Out:
# mse: 7.791769007781113e-08
# mae: 0.00019026795052923262
# mape: 153.3639373779297
# mde: 0.24422799422799424

# %% [markdown]
# ## Display Results

# %%
###############################################################################
'''Display results'''

fig = plt.figure(figsize=(15,20))
st = fig.suptitle("Transformer + TimeEmbedding Model", fontsize=22)
st.set_y(0.92)

#Plot training data results
ax11 = fig.add_subplot(311)
ax11.plot(train_data_dates, train_data[:, 3], label='EURUSD Closing Returns')
ax11.plot(train_data_dates[seq_len:], train_pred, linewidth=3, label='Predicted EURUSD Closing Returns')
ax11.set_title("Training Data", fontsize=18)
ax11.set_xlabel('Dates')
ax11.set_ylabel('EURUSD Closing Returns')
ax11.legend(loc="best", fontsize=12)

#Plot validation data results
ax21 = fig.add_subplot(312)
ax21.plot(val_data_dates, val_data[:, 3], label='EURUSD Closing Returns')
ax21.plot(val_data_dates[seq_len:], val_pred, linewidth=3, label='Predicted EURUSD Closing Returns')
ax21.set_title("Validation Data", fontsize=18)
ax21.set_xlabel('Dates')
ax21.set_ylabel('EURUSD Closing Returns')
ax21.legend(loc="best", fontsize=12)

#Plot test data results
ax31 = fig.add_subplot(313)
ax31.plot(test_data_dates, test_data[:, 3], label='EURUSD Closing Returns')
ax31.plot(test_data_dates[seq_len:], test_pred, linewidth=3, label='Predicted EURUSD Closing Returns')
ax31.set_title("Test Data", fontsize=18)
ax31.set_xlabel('Dates')
ax31.set_ylabel('EURUSD Closing Returns')
ax31.legend(loc="best", fontsize=12)

# %% [markdown]
# ## Model metrics

# %%
'''Display model metrics'''

fig = plt.figure(figsize=(15,20))
st = fig.suptitle("Transformer + TimeEmbedding Model Metrics", fontsize=22)
st.set_y(0.92)

#Plot model loss
ax1 = fig.add_subplot(311)
ax1.plot(history['loss'], label='Training loss (MSE)')
ax1.plot(history['val_loss'], label='Test loss (MSE)')
ax1.set_title("Model loss", fontsize=18)
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss (MSE)')
ax1.legend(loc="best", fontsize=12)

#Plot MAE
ax2 = fig.add_subplot(312)
ax2.plot(history['mae'], label='Training MAE')
ax2.plot(history['val_mae'], label='Test MAE')
ax2.set_title("Model metric - Mean average error (MAE)", fontsize=18)
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Mean average error (MAE)')
ax2.legend(loc="best", fontsize=12)

#Plot MAPE
ax3 = fig.add_subplot(313)
ax3.plot(history['mape'], label='Training MAPE')
ax3.plot(history['val_mape'], label='Test MAPE')
ax3.set_title("Model metric - Mean average percentage error (MAPE)", fontsize=18)
ax3.set_xlabel('Epoch')
ax3.set_ylabel('Mean average percentage error (MAPE)')
ax3.legend(loc="best", fontsize=12)

# %% [markdown]
# ## Model architecture overview

# %%
tf.keras.utils.plot_model(
    model,
    to_file="EURUSD_Transformer+TimeEmbedding1.png",
    show_shapes=True,
    show_layer_names=True,
    expand_nested=True,
    dpi=96,)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
