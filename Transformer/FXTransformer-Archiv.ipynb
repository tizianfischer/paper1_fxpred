# %%
import pickle
import numpy as np
from tensorflow import keras
import pandas as pd
import os, datetime
from utils import data_read_dict, data_read_concat, data_merge
import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
print('Tensorflow version: {}'.format(tf.__version__))

import matplotlib.pyplot as plt
plt.style.use('seaborn')

import warnings
warnings.filterwarnings('ignore')
# Out:
# Tensorflow version: 2.4.1

# %%
import platform
if platform.node() == "msbq":
    from tensorflow.python.client import device_lib
    print(device_lib.list_local_devices())
    print(tf.__version__)
    print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
    tf.config.list_physical_devices('GPU')
    # !python --version

#     tf.config.list_physical_devices('GPU')
#     gpus = tf.config.experimental.list_physical_devices('GPU')
#     if gpus:
#       # Restrict TensorFlow to only allocate 4GB of memory on the first GPU
#       try:
#         tf.config.experimental.set_virtual_device_configuration(
#             gpus[0],
#             [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4096)])
#         logical_gpus = tf.config.experimental.list_logical_devices('GPU')
#         print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#       except RuntimeError as e:
#         # Virtual devices must be set before GPUs have been initialized
#         print(e)
#         print('asdf')

# %% [markdown]
# ## Hyperparameters

# %%
batch_size = 32
seq_len = 128

d_k = 256
d_v = 256
n_heads = 12
ff_dim = 256

# %% [markdown]
# ## Load data

# %%
IBM_path = '../content/10min Dataset.csv'

# df = pd.read_csv(IBM_path, delimiter=';', usecols=['Dates', 'EURUSD BGNE Curncy Bid Open', 'EURUSD BGNE Curncy Bid Close', 'EURUSD BGNE Curncy Bid High', 'EURUSD BGNE Curncy Bid Low', 'EURUSD BGNE Curncy Bid Number Ticks', 'EURUSD BGNE Curncy Ask Open', 'EURUSD BGNE Curncy Ask Close', 'EURUSD BGNE Curncy Ask High', 'EURUSD BGNE Curncy Ask Low', 'EURUSD BGNE Curncy Ask Number Ticks', 'USDJPY BGNE Curncy Bid Open', 'USDJPY BGNE Curncy Bid Close', 'USDJPY BGNE Curncy Bid High', 'USDJPY BGNE Curncy Bid Low', 'USDJPY BGNE Curncy Bid Number Ticks', 'USDJPY BGNE Curncy Ask Open', 'USDJPY BGNE Curncy Ask Close', 'USDJPY BGNE Curncy Ask High', 'USDJPY BGNE Curncy Ask Low', 'USDJPY BGNE Curncy Ask Number Ticks', 'GBPUSD BGNE Curncy Bid Open', 'GBPUSD BGNE Curncy Bid Close', 'GBPUSD BGNE Curncy Bid High', 'GBPUSD BGNE Curncy Bid Low', 'GBPUSD BGNE Curncy Bid Number Ticks', 'GBPUSD BGNE Curncy Ask Open', 'GBPUSD BGNE Curncy Ask Close', 'GBPUSD BGNE Curncy Ask High', 'GBPUSD BGNE Curncy Ask Low', 'GBPUSD BGNE Curncy Ask Number Ticks', 'AUDUSD BGNE Curncy Bid Open', 'AUDUSD BGNE Curncy Bid Close', 'AUDUSD BGNE Curncy Bid High', 'AUDUSD BGNE Curncy Bid Low', 'AUDUSD BGNE Curncy Bid Number Ticks', 'AUDUSD BGNE Curncy Ask Open', 'AUDUSD BGNE Curncy Ask Close', 'AUDUSD BGNE Curncy Ask High', 'AUDUSD BGNE Curncy Ask Low', 'AUDUSD BGNE Curncy Ask Number Ticks', 'USDCAD BGNE Curncy Bid Open', 'USDCAD BGNE Curncy Bid Close', 'USDCAD BGNE Curncy Bid High', 'USDCAD BGNE Curncy Bid Low', 'USDCAD BGNE Curncy B
ade Open', 'TY1 Comdty Trade Open', 'RX1 Comdty Trade Open', 'JB1 Comdty Trade Open', 'US1 Comdty Trade Open', 'IK1 Comdty Trade Open', 'ED1 Comdty Trade Open', 'WN1 Comdty Trade Open', 'YM1 Comdty Trade Open', 'FV1 Comdty Trade Open', 'G 1 Comdty Trade Open', 'UB1 Comdty Trade Open', 'FF1 Comdty Trade Open', 'OE1 Comdty Trade Open', 'TU1 Comdty Trade Open', 'KE1 Comdty Trade Open', 'DU1 Comdty Trade Open', 'UXY1 Comdty Trade Open', 'CN1 Comdty Trade Open', 'KAA1 Comdty Trade Open'])
df = pd.read_csv(IBM_path, delimiter=';')

# Replace 0 to avoid dividing by 0 later on
df.replace(to_replace=0, method='ffill', inplace=True) 
df.drop('UXA1 Comdty Trade Open', axis=1, inplace=True)
df['Dates'] = pd.to_datetime(df['Dates'], format='%d.%m.%y %H:%M')
df.sort_values('Dates', inplace=True)
df.sort_values('Dates')
df.index = df['Dates']
df.tail()
# Out:
#                                   Dates  EURUSD BGNE Curncy Bid Open  \
# Dates
# 2021-03-22 23:10:00 2021-03-22 23:10:00                      1.19315
# 2021-03-22 23:20:00 2021-03-22 23:20:00                      1.19338
# 2021-03-22 23:30:00 2021-03-22 23:30:00                      1.19327
# 2021-03-22 23:40:00 2021-03-22 23:40:00                      1.19327
# 2021-03-22 23:50:00 2021-03-22 23:50:00                      1.19335
#
#                      EURUSD BGNE Curncy Bid Close  \
# Dates
# 2021-03-22 23:10:00                       1.19339
# 2021-03-22 23:20:00                       1.19327
# 2021-03-22 23:30:00                       1.19330
# 2021-03-22 23:40:00                       1.19335
# 2021-03-22 23:50:00                       1.19335
#
#                      EURUSD BGNE Curncy Bid High  EURUSD BGNE Curncy Bid Low  \
# Dates
# 2021-03-22 23:10:00                      1.19348                     1.19313
# 2021-03-22 23:20:00                      1.19343                     1.19326
# 2021-03-22 23:30:00                      1.19344                     1.19320
# 2021-03-22 23:40:00                      1.19345                     1.19324
# 2021-03-22 23:50:00                      1.19341                     1.19330
#
#                      EURUSD BGNE Curncy Bid Number Ticks  \
# Dates
# 2021-03-22 23:10:00                                  952
# 2021-03-22 23:20:00                                  958
# 2021-03-22 23:30:00                                 1002
# 2021-03-22 23:40:00                                 1039
# 2021-03-22 23:50:00                                 1083
#
#                      EURUSD BGNE Curncy Ask Open  \
# Dates
# 2021-03-22 23:10:00                      1.19326
# 2021-03-22 23:20:00                      1.19349
# 2021-03-22 23:30:00                      1.19336
# 2021-03-22 23:40:00                      1.19334
# 2021-03-22 23:50:00                      1.19343
#
#                      EURUSD BGNE Curncy Ask Close  \
# Dates
# 2021-03-22 23:10:00                       1.19348
# 2021-03-22 23:20:00                       1.19337
# 2021-03-22 23:30:00                       1.19333
# 2021-03-22 23:40:00                       1.19341
# 2021-03-22 23:50:00                       1.19340
#
#                      EURUSD BGNE Curncy Ask High  EURUSD BGNE Curncy Ask Low  \
# Dates
# 2021-03-22 23:10:00                      1.19355                     1.19320
# 2021-03-22 23:20:00                      1.19351                     1.19332
# 2021-03-22 23:30:00                      1.19350                     1.19325
# 2021-03-22 23:40:00                      1.19351                     1.19330
# 2021-03-22 23:50:00                      1.19348                     1.19336
#
#                      ...  G 1 Comdty Trade Open  UB1 Comdty Trade Open  \
# Dates                ...
# 2021-03-22 23:10:00  ...                 128.55                 205.64
# 2021-03-22 23:20:00  ...                 128.55                 205.64
# 2021-03-22 23:30:00  ...                 128.55                 205.64
# 2021-03-22 23:40:00  ...                 128.55                 205.64
# 2021-03-22 23:50:00  ...                 128.55                 205.64
#
#                      FF1 Comdty Trade Open  OE1 Comdty Trade Open  \
# Dates
# 2021-03-22 23:10:00                  99.93                 135.19
# 2021-03-22 23:20:00                  99.93                 135.19
# 2021-03-22 23:30:00                  99.93                 135.19
# 2021-03-22 23:40:00                  99.93                 135.19
# 2021-03-22 23:50:00                  99.93                 135.19
#
#                      TU1 Comdty Trade Open  KE1 Comdty Trade Open  \
# Dates
# 2021-03-22 23:10:00               110.4375                 110.81
# 2021-03-22 23:20:00               110.4375                 110.81
# 2021-03-22 23:30:00               110.4375                 110.81
# 2021-03-22 23:40:00               110.4375                 110.81
# 2021-03-22 23:50:00               110.4375                 110.81
#
#                      DU1 Comdty Trade Open  UXY1 Comdty Trade Open  \
# Dates
# 2021-03-22 23:10:00                112.125              144.468750
# 2021-03-22 23:20:00                112.125              144.531250
# 2021-03-22 23:30:00                112.125              144.531250
# 2021-03-22 23:40:00                112.125              144.562500
# 2021-03-22 23:50:00                112.125              144.640625
#
#                      CN1 Comdty Trade Open  KAA1 Comdty Trade Open
# Dates
# 2021-03-22 23:10:00                 140.89                  126.25
# 2021-03-22 23:20:00                 140.89                  126.25
# 2021-03-22 23:30:00                 140.89                  126.25
# 2021-03-22 23:40:00                 140.89                  126.25
# 2021-03-22 23:50:00                 140.89                  126.25
#
# [5 rows x 434 columns]

# %%
df_metrics = data_merge(data_read_dict('../data/bbg/'))
df_metrics = df_metrics.iloc[::-1, :].bfill().iloc[::-1, :]
df_metrics.shape
# Out:
# (15926, 840)

# %%
df_merged = pd.merge(df, df_metrics, left_index=True, right_index=True, how='outer')
df_merged = df_merged.loc[df_merged.index <= max(df.Dates),:]
d = pd.isna(df_metrics).any(axis=1)
df_merged = df_merged.loc[df_merged.index >= df_metrics.loc[~d].index.min()]
df_merged.loc[~pd.isna(df_merged).any(axis=1)]
# Out:
#                                   Dates  EURUSD BGNE Curncy Bid Open  \
# Dates
# 2020-11-02 08:20:00 2020-11-02 08:20:00                      1.16400
# 2020-11-02 08:30:00 2020-11-02 08:30:00                      1.16389
# 2020-11-02 08:40:00 2020-11-02 08:40:00                      1.16320
# 2020-11-02 08:50:00 2020-11-02 08:50:00                      1.16380
# 2020-11-02 09:00:00 2020-11-02 09:00:00                      1.16298
# ...                                 ...                          ...
# 2021-03-22 23:10:00 2021-03-22 23:10:00                      1.19315
# 2021-03-22 23:20:00 2021-03-22 23:20:00                      1.19338
# 2021-03-22 23:30:00 2021-03-22 23:30:00                      1.19327
# 2021-03-22 23:40:00 2021-03-22 23:40:00                      1.19327
# 2021-03-22 23:50:00 2021-03-22 23:50:00                      1.19335
#
#                      EURUSD BGNE Curncy Bid Close  \
# Dates
# 2020-11-02 08:20:00                       1.16389
# 2020-11-02 08:30:00                       1.16320
# 2020-11-02 08:40:00                       1.16386
# 2020-11-02 08:50:00                       1.16301
# 2020-11-02 09:00:00                       1.16312
# ...                                           ...
# 2021-03-22 23:10:00                       1.19339
# 2021-03-22 23:20:00                       1.19327
# 2021-03-22 23:30:00                       1.19330
# 2021-03-22 23:40:00                       1.19335
# 2021-03-22 23:50:00                       1.19335
#
#                      EURUSD BGNE Curncy Bid High  EURUSD BGNE Curncy Bid Low  \
# Dates
# 2020
# 2021-03-22 23:20:00  ...       42.857143       65.714286        83.318903
# 2021-03-22 23:30:00  ...       28.571429       54.285714        75.555556
# 2021-03-22 23:40:00  ...       28.571429       42.857143        65.714286
# 2021-03-22 23:50:00  ...       33.333333       35.238095        55.047619
#
#                      usdjpy___TAS_DSS  usdjpy___TRENDER_UP  \
# Dates
# 2020-11-02 08:20:00         69.892308           104.710617
# 2020-11-02 08:30:00         71.776068           104.721683
# 2020-11-02 08:40:00         75.010256           104.732429
# 2020-11-02 08:50:00         79.157466           104.742358
# 2020-11-02 09:00:00         83.964706           104.763179
# ...                               ...                  ...
# 2021-03-22 23:10:00         91.595516           108.802835
# 2021-03-22 23:20:00         88.484848           108.802835
# 2021-03-22 23:30:00         82.747475           108.802835
# 2021-03-22 23:40:00         74.862915           108.802835
# 2021-03-22 23:50:00         65.439153           108.802835
#
#                      usdjpy___TRENDER_DN  usdjpy___TMAVG  usdjpy___VMAVG  \
# Dates
# 2020-11-02 08:20:00           104.576931      104.754444      104.730164
# 2020-11-02 08:30:00           104.576931      104.764444      104.733712
# 2020-11-02 08:40:00           104.576931      104.777778      104.738813
# 2020-11-02 08:50:00           104.576931      104.795556      104.746303
# 2020-11-02 09:00:00           104.576931      104.816667      104.756070
# ...                                  ...             ...             ...
# 2021-03-22 23:10:00           108.751982      108.835556      108.811932
# 2021-03-22 23:20:00           108.751982      108.826667      108.811868
# 2021-03-22 23:30:00           108.860237      108.816667      108.811405
# 2021-03-22 23:40:00           108.852871      108.808889      108.810871
# 2021-03-22 23:50:00           108.846162      108.804444      108.810824
#
#                      usdjpy___WMAVG  usdjpy___WLPR
# Dates
# 2020-11-02 08:20:00      104.762000       0.000000
# 2020-11-02 08:30:00      104.773333       0.000000
# 2020-11-02 08:40:00      104.788000      -7.692308
# 2020-11-02 08:50:00      104.812000      -5.882353
# 2020-11-02 09:00:00      104.832667       0.000000
# ...                             ...            ...
# 2021-03-22 23:10:00      108.828000     -80.000000
# 2021-03-22 23:20:00      108.820000     -80.000000
# 2021-03-22 23:30:00      108.811333    -100.000000
# 2021-03-22 23:40:00      108.805333     -83.333333
# 2021-03-22 23:50:00      108.805333     -66.666667
#
# [14701 rows x 1274 columns]

# %%
df = df_merged[:]
df.shape
# Out:
# (20254, 1274)

# %% [markdown]
# ## Plot 10min EURUSD closing prices and volatility

# %%
fig = plt.figure(figsize=(15,10))
st = fig.suptitle("EURUSD Spot Rate", fontsize=20)
st.set_y(0.92)

ax1 = fig.add_subplot(211)
# ax1.plot(df['EURUSD BGNE Curncy Bid Close'], label='EURUSD BGNE Curncy Bid Close')
ax1.plot(df['Dates'], df['EURUSD BGNE Curncy Bid Close'], label='EURUSD BGNE Curncy Bid Close')
#ax1.set_xticks(range(0, df.shape[0], 1464))
#ax1.set_xticklabels(df['Dates'].loc[::1464])
ax1.set_ylabel('Close Price', fontsize=18)
ax1.legend(loc="upper left", fontsize=12)

ax2 = fig.add_subplot(212)
# ax2.plot(df['EURUSDV1Y Curncy Trade Open'], label='EURUSDV1Y Curncy Trade Open')
ax2.plot(df['Dates'], df['EURUSDV1Y Curncy Trade Open'], label='EURUSDV1Y Curncy Trade Open')
#ax2.set_xticks(range(0, df.shape[0], 1464))
#ax2.set_xticklabels(df['Dates'].loc[::1464])
ax2.set_ylabel('EURUSDV1Y Curncy Trade Open', fontsize=18)
ax2.legend(loc="upper left", fontsize=12)

# %% [markdown]
# ## Calculate normalized percentage change of all columns

# %%
'''Calculate percentage change'''
df = df.set_index('Dates')
df.pct_change()

df.dropna(how='any', axis=0, inplace=True) # Drop all rows with NaN values

# %%
'''Normalize price columns'''
df = (df - df.mean()) / (df.max() - df.min())
df.columns[np.isnan(df).any(axis=0)]
# Out:
# Index([], dtype='object')

# %%
#df.dropna(how='any', axis=0, inplace=True) # Drop all rows with NaN values
#np.isinf(df)
#df

# %% [markdown]
# ## Create training, validation and test split

# %%
times = sorted(df.index.values)
last_10pct = sorted(df.index.values)[-int(0.1*len(times))] # Last 10% of series
last_20pct = sorted(df.index.values)[-int(0.2*len(times))] # Last 20% of series

df_train = df[(df.index < last_20pct)]  # Training data are 80% of total data
df_val = df[(df.index >= last_20pct) & (df.index < last_10pct)]
df_test = df[(df.index >= last_10pct)]

# Convert pandas columns into arrays
train_data = df_train.values
val_data = df_val.values
test_data = df_test.values
print('Training data shape: {}'.format(train_data.shape))
print('Validation data shape: {}'.format(val_data.shape))
print('Test data shape: {}'.format(test_data.shape))

df_train.head()
# Out:
# Training data shape: (11761, 1273)
# Validation data shape: (1470, 1273)
# Test data shape: (1470, 1273)
#                      EURUSD BGNE Curncy Bid Open  \
# Dates
# 2020-11-02 08:20:00                    -0.559804
# 2020-11-02 08:30:00                    -0.561302
# 2020-11-02 08:40:00                    -0.570696
# 2020-11-02 08:50:00                    -0.562527
# 2020-11-02 09:00:00                    -0.573691
#
#                      EURUSD BGNE Curncy Bid Close  \
# Dates
# 2020-11-02 08:20:00                     -0.561330
# 2020-11-02 08:30:00                     -0.570724
# 2020-11-02 08:40:00                     -0.561738
# 2020-11-02 08:50:00                     -0.573311
# 2020-11-02 09:00:00                     -0.571813
#
#                      EURUSD BGNE Curncy Bid High  EURUSD BGNE Curncy Bid Low  \
# Dates
# 2020-11-02 08:20:00                    -0.568648                   -0.554952
# 2020-11-02 08:30:00                    -0.572929                   -0.564271
# 2020-11-02 08:40:00                    -0.573205                   -0.563461
# 2020-11-02 08:50:00                    -0.571962                   -0.568728
# 2020-11-02 09:00:00                    -0.582456                   -0.571160
#
#                      EURUSD BGNE Curncy Bid Number Ticks  \
# Dates
# 2020-11-02 08:20:00                             0.069035
# 2020-11-02 08:30:00                             0.080522
# 2020-11-02 08:40:00                             0.109816
# 2020-11-02 08:50:00                             0.079948
# 2020-11-02 09:00:00                             0.101200
#
#                      EURUSD BGNE Curncy Ask Open  \
# Dates
# 2020-11-02 08:20:00                    -0.560642
# 2020-11-02 08:30:00                    -0.562140
# 2020-11-02 08:40:00                    -0.571537
# 2020-11-02 08:50:00                    -0.563093
# 2020-11-02 09:00:00                    -0.574397
#
#                      EURUSD BGNE Curncy Ask Close  \
# Dates
# 2020-11-02 08:20:00                     -0.562526
# 2020-11-02 08:30:00                     -0.571930
# 2020-11-02 08:40:00                     -0.563208
# 2020-11-02 08:50:00                     -0.574655
# 2020-11-02 09:00:00                     -0.573429
#
#                      EURUSD BGNE Curncy Ask High  EURUSD BGNE Curncy Ask Low  \
# Dates
# 2020-11-02 08:20:00                    -0.570526                   -0.556325
# 2020-11-02 08:30:00                    -0.574533                   -0.565645
# 2020-11-02 08:40:00                    -0.574810                   -0.564700
# 2020-11-02 08:50:00                    -0.573566                   -0.569968
# 2020-11-02 09:00:00                    -0.584068                   -0.572264
#
#                      EURUSD BGNE Curncy Ask Number Ticks  ...  usdjpy___TAS_K  \
# Dates                                                     ...
# 2020-11-02 08:20:00                             0.069035  ...        0.492777
# 2020-11-02 08:30:00                             0.080522  ...        0.492777
# 2020-11-02 08:40:00                             0.109816  ...        0.415854
# 2020-11-02 08:50:00                             0.079948  ...        0.433953
# 2020-11-02 09:00:00                             0.101200  ...        0.492777
#
#                      usdjpy___TAS_D  usdjpy___TAS_DS  usdjpy___TAS_DSS  \
# Dates
# 2020-11-02 08:20:00        0.286028         0.210139          0.195253
# 2020-11-02 08:30:00        0.352695         0.242083          0.214519
# 2020-11-02 08:40:00        0.387310         0.284951          0.247597
# 2020-11-02 08:50:00        0.425546         0.336358          0.290013
# 2020-11-02 09:00:00        0.465546         0.388390          0.339179
#
#                      usdjpy___TRENDER_UP  usdjpy___TRENDER_DN  usdjpy___TMAVG  \
# Dates
# 2020-11-02 08:20:00            -0.035189            -0.050749       -0.026994
# 2020-11-02 08:30:00            -0.033524            -0.050749       -0.025499
# 2020-11-02 08:40:00            -0.031907            -0.050749       -0.023506
# 2020-11-02 08:50:00            -0.030413            -0.050749       -0.020849
# 2020-11-02 09:00:00            -0.027280            -0.050749       -0.017693
#
#                      usdjpy___VMAVG  usdjpy___WMAVG  usdjpy___WLPR
# Dates
# 2020-11-02 08:20:00       -0.030783       -0.025916       0.492415
# 2020-11-02 08:30:00       -0.030244       -0.024220       0.492415
# 2020-11-02 08:40:00       -0.029469       -0.022025       0.415492
# 2020-11-02 08:50:00       -0.028331       -0.018433       0.433592
# 2020-11-02 09:00:00       -0.026848       -0.015339       0.492415
#
# [5 rows x 1273 columns]

# %% [markdown]
# ## Plot daily changes of close prices and volatility

# %%
fig = plt.figure(figsize=(15,12))
st = fig.suptitle("Data Separation", fontsize=20)
st.set_y(0.95)

###############################################################################

ax1 = fig.add_subplot(211)
ax1.plot(np.arange(train_data.shape[0]), df_train['EURUSD BGNE Curncy Bid Close'], label='Training data')

ax1.plot(np.arange(train_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]), df_val['EURUSD BGNE Curncy Bid Close'], label='Validation data')

ax1.plot(np.arange(train_data.shape[0]+val_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]+test_data.shape[0]), df_test['EURUSD BGNE Curncy Bid Close'], label='Test data')
ax1.set_xlabel('Dates')
ax1.set_ylabel('Normalized Closing Returns')
ax1.set_title("Close Price", fontsize=18)
ax1.legend(loc="best", fontsize=12)

###############################################################################

ax2 = fig.add_subplot(212)
ax2.plot(np.arange(train_data.shape[0]), df_train['EURUSDV1Y Curncy Trade Open'], label='Training data')

ax2.plot(np.arange(train_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]), df_val['EURUSDV1Y Curncy Trade Open'], label='Validation data')

ax2.plot(np.arange(train_data.shape[0]+val_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]+test_data.shape[0]), df_test['EURUSDV1Y Curncy Trade Open'], label='Test data')
ax2.set_xlabel('Dates')
ax2.set_ylabel('Normalized Volatility Changes')
ax2.set_title("Volatility", fontsize=18)
ax2.legend(loc="best", fontsize=12)

# %% [markdown]
# ## Create chunks of training, validation and test data

# %%
# Training data
X_train, y_train = [], []
for i in range(seq_len, len(train_data)):
  X_train.append(train_data[i-seq_len:i]) # Chunks of training data with a length of 128 df-rows
  y_train.append(train_data[:, 3][i]) #Value of 4th column (Close Price) of df-row 128+1
X_train, y_train = np.array(X_train), np.array(y_train)

###############################################################################

# Validation data
X_val, y_val = [], []
for i in range(seq_len, len(val_data)):
    X_val.append(val_data[i-seq_len:i])
    y_val.append(val_data[:, 3][i])
X_val, y_val = np.array(X_val), np.array(y_val)

###############################################################################

# Test data
X_test, y_test = [], []
for i in range(seq_len, len(test_data)):
    X_test.append(test_data[i-seq_len:i])
    y_test.append(test_data[:, 3][i])    
X_test, y_test = np.array(X_test), np.array(y_test)

print('Training set shape', X_train.shape, y_train.shape)
print('Validation set shape', X_val.shape, y_val.shape)
print('Testing set shape' ,X_test.shape, y_test.shape)
# Out:
# Training set shape (11633, 128, 1273) (11633,)
# Validation set shape (1342, 128, 1273) (1342,)
# Testing set shape (1342, 128, 1273) (1342,)

# %% [markdown]
# ## TimeVector

# %%
class Time2Vector(Layer):
  def __init__(self, seq_len, **kwargs):
    super(Time2Vector, self).__init__()
    self.seq_len = seq_len

  def build(self, input_shape):
    '''Initialize weights and biases with shape (batch, seq_len)'''
    self.weights_linear = self.add_weight(name='weight_linear',
                                shape=(int(self.seq_len),),
                                initializer='uniform',
                                trainable=True)
    
    self.bias_linear = self.add_weight(name='bias_linear',
                                shape=(int(self.seq_len),),
                                initializer='uniform',
                                trainable=True)
    
    self.weights_periodic = self.add_weight(name='weight_periodic',
                                shape=(int(self.seq_len),),
                                initializer='uniform',
                                trainable=True)

    self.bias_periodic = self.add_weight(name='bias_periodic',
                                shape=(int(self.seq_len),),
                                initializer='uniform',
                                trainable=True)

  def call(self, x):
    '''Calculate linear and periodic time features'''
    x = tf.math.reduce_mean(x[:,:,:4], axis=-1) 
    time_linear = self.weights_linear * x + self.bias_linear # Linear time feature
    time_linear = tf.expand_dims(time_linear, axis=-1) # Add dimension (batch, seq_len, 1)
    
    time_periodic = tf.math.sin(tf.multiply(x, self.weights_periodic) + self.bias_periodic)
    time_periodic = tf.expand_dims(time_periodic, axis=-1) # Add dimension (batch, seq_len, 1)
    return tf.concat([time_linear, time_periodic], axis=-1) # shape = (batch, seq_len, 2)
   
  def get_config(self): # Needed for saving and loading model with custom layer
    config = super().get_config().copy()
    config.update({'seq_len': self.seq_len})
    return config

# %% [markdown]
# ## Transformer

# %%
class SingleAttention(Layer):
  def __init__(self, d_k, d_v):
    super(SingleAttention, self).__init__()
    self.d_k = d_k
    self.d_v = d_v

  def build(self, input_shape):
    self.query = Dense(self.d_k, 
                       input_shape=input_shape, 
                       kernel_initializer='glorot_uniform', 
                       bias_initializer='glorot_uniform')
    
    self.key = Dense(self.d_k, 
                     input_shape=input_shape, 
                     kernel_initializer='glorot_uniform', 
                     bias_initializer='glorot_uniform')
    
    self.value = Dense(self.d_v, 
                       input_shape=input_shape, 
                       kernel_initializer='glorot_uniform', 
                       bias_initializer='glorot_uniform')

  def call(self, inputs): # inputs = (in_seq, in_seq, in_seq)
    q = self.query(inputs[0])
    k = self.key(inputs[1])

    attn_weights = tf.matmul(q, k, transpose_b=True)
    attn_weights = tf.map_fn(lambda x: x/np.sqrt(self.d_k), attn_weights)
    attn_weights = tf.nn.softmax(attn_weights, axis=-1)
    
    v = self.value(inputs[2])
    attn_out = tf.matmul(attn_weights, v)
    return attn_out    

#############################################################################

class MultiAttention(Layer):
  def __init__(self, d_k, d_v, n_heads):
    super(MultiAttention, self).__init__()
    self.d_k = d_k
    self.d_v = d_v
    self.n_heads = n_heads
    self.attn_heads = list()

  def build(self, input_shape):
    for n in range(self.n_heads):
      self.attn_heads.append(SingleAttention(self.d_k, self.d_v))  
    
    # input_shape[0]=(batch, seq_len, 7), input_shape[0][-1]=7 
    self.linear = Dense(input_shape[0][-1], 
                        input_shape=input_shape, 
                        kernel_initializer='glorot_uniform', 
                        bias_initializer='glorot_uniform')

  def call(self, inputs):
    attn = [self.attn_heads[i](inputs) for i in range(self.n_heads)]
    concat_attn = tf.concat(attn, axis=-1)
    multi_linear = self.linear(concat_attn)
    return multi_linear   

#############################################################################

class TransformerEncoder(Layer):
  def __init__(self, d_k, d_v, n_heads, ff_dim, dropout=0.1, **kwargs):
    super(TransformerEncoder, self).__init__()
    self.d_k = d_k
    self.d_v = d_v
    self.n_heads = n_heads
    self.ff_dim = ff_dim
    self.attn_heads = list()
    self.dropout_rate = dropout

  def build(self, input_shape):
    self.attn_multi = MultiAttention(self.d_k, self.d_v, self.n_heads)
    self.attn_dropout = Dropout(self.dropout_rate)
    self.attn_normalize = LayerNormalization(input_shape=input_shape, epsilon=1e-6)

    self.ff_conv1D_1 = Conv1D(filters=self.ff_dim, kernel_size=1, activation='relu')
    # input_shape[0]=(batch, seq_len, 7), input_shape[0][-1] = 7 
    self.ff_conv1D_2 = Conv1D(filters=input_shape[0][-1], kernel_size=1) 
    self.ff_dropout = Dropout(self.dropout_rate)
    self.ff_normalize = LayerNormalization(input_shape=input_shape, epsilon=1e-6)    
  
  def call(self, inputs): # inputs = (in_seq, in_seq, in_seq)
    attn_layer = self.attn_multi(inputs)
    attn_layer = self.attn_dropout(attn_layer)
    attn_layer = self.attn_normalize(inputs[0] + attn_layer)

    ff_layer = self.ff_conv1D_1(attn_layer)
    ff_layer = self.ff_conv1D_2(ff_layer)
    ff_layer = self.ff_dropout(ff_layer)
    ff_layer = self.ff_normalize(inputs[0] + ff_layer)
    return ff_layer 

  def get_config(self): # Needed for saving and loading model with custom layer
    config = super().get_config().copy()
    config.update({'d_k': self.d_k,
                   'd_v': self.d_v,
                   'n_heads': self.n_heads,
                   'ff_dim': self.ff_dim,
                   'attn_heads': self.attn_heads,
                   'dropout_rate': self.dropout_rate})
    return config

# %% [markdown]
# ## Model

# %%
def create_model(input_shape):
  '''Initialize time and transformer layers'''
  time_embedding = Time2Vector(seq_len)
  attn_layer1 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)
  attn_layer2 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)
  attn_layer3 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)

  '''Construct model'''
  in_seq = Input(shape=(seq_len, input_shape))
  x = time_embedding(in_seq)
  x = Concatenate(axis=-1)([in_seq, x])
#   x = Concatenate(axis=-1)([Dense(64)(in_seq), x])
  x = attn_layer1((x, x, x))
  x = attn_layer2((x, x, x))
  x = attn_layer3((x, x, x))
  x = GlobalAveragePooling1D(data_format='channels_first')(x)
  x = Dropout(0.1)(x)
  x = Dense(64, activation='relu')(x)
  x = Dropout(0.1)(x)
  out = Dense(1, activation='linear')(x)

  model = Model(inputs=in_seq, outputs=out)
  opt = keras.optimizers.Adam(learning_rate=0.0001)
  model.compile(loss='mse', optimizer=opt, metrics=['mae', 'mape'])
  return model


model = create_model(df.shape[1])
model.summary()

callback = tf.keras.callbacks.ModelCheckpoint('../content/Transformer+TimeEmbedding{epoch}.hdf5', 
                                              monitor='val_loss', 
                                              save_best_only=True, verbose=1)

es = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=8,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)


if True: 
    history = model.fit(X_train, y_train,
                        batch_size=batch_size, 
                        epochs=1000, 
                        callbacks=[callback],
                        validation_data=(X_val, y_val))  
    with open('../content/history.pkl', 'wb') as f:
        pickle.dump(history.history, f)
# else    
#    model.save(.h5)
#    model.load
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 1273)]  0
# __________________________________________________________________________________________________
# time2_vector (Time2Vector)      (None, 128, 2)       512         input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 128, 1275)    0           input_1[0][0]
#                                                                  time2_vector[0][0]
# __________________________________________________________________________________________________
# transformer_encoder (Transforme (None, 128, 1275)    16337122    concatenate[0][0]
#                                                                  concatenate[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# transformer_encoder_1 (Transfor (None, 128, 1275)    16337122    transformer_encoder[0][0]
#                                                                  transformer_encoder[0][0]
#                                                                  transformer_encoder[0][0]
# __________________________________________________________________________________________________
# transformer_encoder_2 (Transfor (None, 128, 1275)    16337122    transformer_encoder_1[0][0]
#                                                                  transformer_encoder_1[0][0]
#                                                                  transformer_encoder_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 128)          0           transformer_encoder_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128)          0           global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           8256        dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            65          dropout_1[0][0]
# ==================================================================================================
# Total params: 49,020,199
# Trainable params: 49,020,199
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/1000
# 364/364 [==============================] - 439s 1s/step - loss: 0.0249 - mae: 0.1157 - mape: 86.9809 - val_loss: 0.0280 - val_mae: 0.1405 - val_mape: 1098.9417
#
# Epoch 00001: val_loss improved from inf to 0.02803, saving model to content/Transformer+TimeEmbedding1.hdf5
# Epoch 2/1000
# 364/364 [==============================] - 416s 1s/step - loss: 8.1360e-04 - mae: 0.0211 - mape: 42.9435 - val_loss: 0.0605 - val_mae: 0.2141 - val_mape: 1792.1487
#
# Epoch 00002: val_loss did not improve from 0.02803
# Epoch 3/1000
# 364/364 [==============================] - 420s 1s/step - loss: 6.1850e-04 - mae: 0.0187 - mape: 31.8803 - val_loss: 0.0580 - val_mae: 0.2072 - val_mape: 1660.8478
#
# Epoch 00003: val_loss did not improve from 0.02803
# Epoch 4/1000
# 364/364 [==============================] - 404s 1s/step - loss: 5.5120e-04 - mae: 0.0177 - mape: 22.6443 - val_loss: 0.0912 - val_mae: 0.2634 - val_mape: 2350.1458
#
# Epoch 00004: val_loss did not improve from 0.02803
# Epoch 5/1000
# 364/364 [==============================] - 416s 1s/step - loss: 5.0612e-04 - mae: 0.0168 - mape: 29.1925 - val_loss: 0.0789 - val_mae: 0.2402 - val_mape: 2301.1609
#
# Epoch 00005: val_loss did not improve from 0.02803
# Epoch 6/1000
# 364/364 [==============================] - 407s 1s/step - loss: 5.2240e-04 - mae: 0.0169 - mape: 25.0102 - val_loss: 0.1085 - val_mae: 0.2828 - val_mape: 2668.9846
#
# Epoch 00006: val_loss did not improve from 0.02803
# Epoch 7/1000
# 364/364 [==============================] - 413s 1s/step - loss: 4.7083e-04 - mae: 0.0161 - mape: 24.4260 - val_loss: 0.1052 - val_mae: 0.2716 - val_mape: 2371.4956
#
# Epoch 00007: val_loss did not improve from 0.02803
# Epoch 8/1000
# 364/364 [==============================] - 409s 1s/step - loss: 4.5630e-04 - mae: 0.0159 - mape: 23.4398 - val_loss: 0.1416 - val_mae: 0.3258 - val_mape: 3018.2534
#
# Epoch 00008: val_loss did not improve from 0.02803
# Epoch 9/1000
# 364/364 [==============================] - 414s 1s/step - loss: 4.4289e-04 - mae: 0.0156 - mape: 24.0643 - val_loss: 0.1381 - val_mae: 0.3220 - val_mape: 2993.7473
#
# Epoch 00009: val_loss did not improve from 0.02803
# Epoch 10/1000
# 364/364 [==============================] - 404s 1s/step - loss: 4.6103e-04 - mae: 0.0157 - mape: 24.8872 - val_loss: 0.1451 - val_mae: 0.3294 - val_mape: 3076.6899
#
# Epoch 00010: val_loss did not improve from 0.02803
# Epoch 11/1000
# 364/364 [==============================] - 407s 1s/step - loss: 4.0945e-04 - mae: 0.0150 - mape: 26.0650 - val_loss: 0.1533 - val_mae: 0.3435 - val_mape: 3072.6255
#
# Epoch 00011: val_loss did not improve from 0.02803
# Epoch 12/1000
# 364/364 [==============================] - 415s 1s/step - loss: 3.9245e-04 - mae: 0.0146 - mape: 19.4721 - val_loss: 0.1263 - val_mae: 0.3064 - val_mape: 2359.6833
#
# Epoch 00012: val_loss did not improve from 0.02803
# Epoch 13/1000
# 364/364 [==============================] - 408s 1s/step - loss: 3.8216e-04 - mae: 0.0145 - mape: 21.2329 - val_loss: 0.0550 - val_mae: 0.1989 - val_mape: 1660.9417
#
# Epoch 00013: val_loss did not improve from 0.02803
# Epoch 14/1000
# 364/364 [==============================] - 401s 1s/step - loss: 3.8029e-04 - mae: 0.0146 - mape: 25.7009 - val_loss: 0.0926 - val_mae: 0.2556 - val_mape: 2359.1072
#
# Epoch 00014: val_loss did not improve from 0.02803
# Epoch 15/1000
# 364/364 [==============================] - 409s 1s/step - loss: 3.6178e-04 - mae: 0.0141 - mape: 20.2285 - val_loss: 0.0416 - val_mae: 0.1635 - val_mape: 1256.0049
#
# Epoch 00015: val_loss did not improve from 0.02803
# Epoch 16/1000
# 364/364 [==============================] - 407s 1s/step - loss: 3.7323e-04 - mae: 0.0142 - mape: 20.3927 - val_loss: 0.0636 - val_mae: 0.2011 - val_mape: 1783.7440
#
# Epoch 00016: val_loss did not improve from 0.02803
# Epoch 17/1000
# 364/364 [==============================] - 400s 1s/step - loss: 3.6444e-04 - mae: 0.0142 - mape: 23.2580 - val_loss: 0.0264 - val_mae: 0.1181 - val_mape: 948.2719
#
# Epoch 00017: val_loss improved from 0.02803 to 0.02643, saving model to content/Transformer+TimeEmbedding17.hdf5
# Epoch 18/1000
# 364/364 [==============================] - 407s 1s/step - loss: 3.6783e-04 - mae: 0.0141 - mape: 22.6730 - val_loss: 0.0850 - val_mae: 0.2334 - val_mape: 2161.0059
#
# Epoch 00018: val_loss did not improve from 0.02643
# Epoch 19/1000
# 364/364 [==============================] - 407s 1s/step - loss: 3.4330e-04 - mae: 0.0136 - mape: 19.7450 - val_loss: 0.0761 - val_mae: 0.2174 - val_mape: 1892.6091
#
# Epoch 00019: val_loss did not improve from 0.02643
# Epoch 20/1000
# 364/364 [==============================] - 410s 1s/step - loss: 3.3115e-04 - mae: 0.0135 - mape: 22.2270 - val_loss: 0.0582 - val_mae: 0.1857 - val_mape: 1509.8215
#
# Epoch 00020: val_loss did not improve from 0.02643
# Epoch 21/1000
# 364/364 [==============================] - 411s 1s/step - loss: 3.3275e-04 - mae: 0.0133 - mape: 18.0375 - val_loss: 0.0644 - val_mae: 0.1999 - val_mape: 1681.7117
# Epoch 00021: val_loss did not improve from 0.02643
# Epoch 22/1000
# Epoch 00033: val_loss improved from 0.00217 to 0.00209, saving model to content/Transformer+TimeEmbedding33.hdf5
# Epoch 34/1000
# 364/364 [==============================] - 403s 1s/step - loss: 2.9455e-04 - mae: 0.0125 - mape: 17.0373 - val_loss: 0.0220 - val_mae: 0.1000 - val_mape: 501.4675
#
# Epoch 00034: val_loss did not improve from 0.00209
# Epoch 35/1000
# 364/364 [==============================] - 406s 1s/step - loss: 2.8120e-04 - mae: 0.0123 - mape: 16.5829 - val_loss: 0.0152 - val_mae: 0.0672 - val_mape: 303.3446
#
# Epoch 00035: val_loss did not improve from 0.00209
# Epoch 36/1000
# 364/364 [==============================] - 412s 1s/step - loss: 3.4445e-04 - mae: 0.0133 - mape: 20.5804 - val_loss: 0.0051 - val_mae: 0.0617 - val_mape: 477.5368
#
# Epoch 00036: val_loss did not improve from 0.00209
# Epoch 37/1000
# 364/364 [==============================] - 400s 1s/step - loss: 3.0439e-04 - mae: 0.0129 - mape: 18.4234 - val_loss: 0.0031 - val_mae: 0.0455 - val_mape: 402.0053
#
# Epoch 00037: val_loss did not improve from 0.00209
# Epoch 38/1000
# 364/364 [==============================] - 408s 1s/step - loss: 2.7633e-04 - mae: 0.0123 - mape: 19.1433 - val_loss: 0.0027 - val_mae: 0.0423 - val_mape: 371.9974
#
# Epoch 00038: val_loss did not improve from 0.00209
# Epoch 39/1000
# 364/364 [==============================] - 397s 1s/step - loss: 2.7003e-04 - mae: 0.0121 - mape: 16.4557 - val_loss: 0.0028 - val_mae: 0.0437 - val_mape: 385.2336
#
# Epoch 00039: val_loss did not improve from 0.00209
# Epoch 40/1000
# 364/364 [==============================] - 401s 1s/step - loss: 2.8144e-04 - mae: 0.0122 - mape: 14.7076 - val_loss: 0.0026 - val_mae: 0.0423 - val_mape: 359.2251
#
# Epoch 00040: val_loss did not improve from 0.00209
# Epoch 41/1000
# 364/364 [==============================] - 409s 1s/step - loss: 2.7429e-04 - mae: 0.0121 - mape: 16.2767 - val_loss: 0.0027 - val_mae: 0.0438 - val_mape: 365.8105
#
# Epoch 00041: val_loss did not improve from 0.00209
# Epoch 42/1000
# 364/364 [==============================] - 407s 1s/step - loss: 2.5562e-04 - mae: 0.0117 - mape: 16.4882 - val_loss: 0.0032 - val_mae: 0.0458 - val_mape: 419.1740
#
# Epoch 00042: val_loss did not improve from 0.00209
# Epoch 43/1000
# 364/364 [==============================] - 406s 1s/step - loss: 2.6070e-04 - mae: 0.0119 - mape: 16.6421 - val_loss: 0.0025 - val_mae: 0.0403 - val_mape: 367.7595
#
# Epoch 00043: val_loss did not improve from 0.00209
# Epoch 44/1000
# 364/364 [==============================] - 399s 1s/step - loss: 2.6404e-04 - mae: 0.0119 - mape: 16.7955 - val_loss: 0.0029 - val_mae: 0.0428 - val_mape: 417.5235
#
# Epoch 00044: val_loss did not improve from 0.00209
# Epoch 45/1000
# 364/364 [==============================] - 403s 1s/step - loss: 2.7530e-04 - mae: 0.0123 - mape: 19.3072 - val_loss: 0.0026 - val_mae: 0.0411 - val_mape: 368.3176
#
# Epoch 00057: val_loss improved from 0.00209 to 0.00205, saving model to content/Transformer+TimeEmbedding57.hdf5
# Epoch 58/1000
# 364/364 [==============================] - 398s 1s/step - loss: 2.4073e-04 - mae: 0.0111 - mape: 15.6661 - val_loss: 0.0022 - val_mae: 0.0362 - val_mape: 264.8434
#
# Epoch 00058: val_loss did not improve from 0.00205
# Epoch 59/1000
# 364/364 [==============================] - 403s 1s/step - loss: 2.4137e-04 - mae: 0.0113 - mape: 14.8463 - val_loss: 0.0023 - val_mae: 0.0371 - val_mape: 325.9860
#
# Epoch 00059: val_loss did not improve from 0.00205
# Epoch 60/1000
# 364/364 [==============================] - 409s 1s/step - loss: 2.4263e-04 - mae: 0.0113 - mape: 16.0310 - val_loss: 0.0027 - val_mae: 0.0389 - val_mape: 249.7535
#
# Epoch 00060: val_loss did not improve from 0.00205
# Epoch 61/1000
# 364/364 [==============================] - 415s 1s/step - loss: 2.3981e-04 - mae: 0.0112 - mape: 14.4319 - val_loss: 0.0021 - val_mae: 0.0363 - val_mape: 305.2189
#
# Epoch 00061: val_loss did not improve from 0.00205
# Epoch 62/1000
# 364/364 [==============================] - 404s 1s/step - loss: 2.3444e-04 - mae: 0.0110 - mape: 14.5619 - val_loss: 0.0024 - val_mae: 0.0379 - val_mape: 290.0323
#
# Epoch 00062: val_loss did not improve from 0.00205
# Epoch 63/1000
# 364/364 [==============================] - 416s 1s/step - loss: 2.4720e-04 - mae: 0.0114 - mape: 13.3416 - val_loss: 0.0025 - val_mae: 0.0385 - val_mape: 277.4950
#
# Epoch 00063: val_loss did not improve from 0.00205
# Epoch 64/1000
# 364/364 [==============================] - 415s 1s/step - loss: 2.4273e-04 - mae: 0.0112 - mape: 14.1879 - val_loss: 0.0026 - val_mae: 0.0400 - val_mape: 300.9420
#
# Epoch 00064: val_loss did not improve from 0.00205
# Epoch 65/1000
# 364/364 [==============================] - 414s 1s/step - loss: 2.4127e-04 - mae: 0.0112 - mape: 17.3497 - val_loss: 0.0027 - val_mae: 0.0397 - val_mape: 284.6193
#
# Epoch 00065: val_loss did not improve from 0.00205
# Epoch 66/1000
# 364/364 [==============================] - 411s 1s/step - loss: 2.3298e-04 - mae: 0.0108 - mape: 13.2031 - val_loss: 0.0030 - val_mae: 0.0416 - val_mape: 272.9112
#
# Epoch 00066: val_loss did not improve from 0.00205
# Epoch 67/1000
# 364/364 [==============================] - 417s 1s/step - loss: 2.3371e-04 - mae: 0.0110 - mape: 14.4683 - val_loss: 0.0028 - val_mae: 0.0412 - val_mape: 298.1057
#
# Epoch 00067: val_loss did not improve from 0.00205
# Epoch 68/1000
# 364/364 [==============================] - 412s 1s/step - loss: 2.2305e-04 - mae: 0.0108 - mape: 13.5773 - val_loss: 0.0028 - val_mae: 0.0408 - val_mape: 289.4144
#
# Epoch 00068: val_loss did not improve from 0.00205
# Epoch 69/1000
# 364/364 [==============================] - 407s 1s/step - loss: 2.2419e-04 - mae: 0.0107 - mape: 14.9383 - val_loss: 0.0028 - val_mae: 0.0401 - val_mape: 304.1231
#
# Epoch 00069: val_loss did not improve from 0.00205
# Epoch 70/1000
# 364/364 [==============================] - 407s 1s/step - loss: 2.3921e-04 - mae: 0.0112 - mape: 15.9140 - val_loss: 0.0029 - val_mae: 0.0402 - val_mape: 251.7569
#
# Epoch 00070: val_loss did not improve from 0.00205
# Epoch 71/1000
# 364/364 [==============================] - 411s 1s/step - loss: 2.2451e-04 - mae: 0.0106 - mape: 13.2150 - val_loss: 0.0028 - val_mae: 0.0394 - val_mape: 262.5574
#
# Epoch 00071: val_loss did not improve from 0.00205
# Epoch 72/1000
# 364/364 [==============================] - 409s 1s/step - loss: 2.2913e-04 - mae: 0.0108 - mape: 13.3252 - val_loss: 0.0028 - val_mae: 0.0406 - val_mape: 295.7470
#
# Epoch 00072: val_loss did not improve from 0.00205
# Epoch 73/1000
# 364/364 [==============================] - 409s 1s/step - loss: 2.3606e-04 - mae: 0.0111 - mape: 14.8651 - val_loss: 0.0029 - val_mae: 0.0411 - val_mape: 291.4342
#
# Epoch 00073: val_loss did not improve from 0.00205
# Epoch 74/1000
# 364/364 [==============================] - 414s 1s/step - loss: 2.2283e-04 - mae: 0.0107 - mape: 12.8895 - val_loss: 0.0038 - val_mae: 0.0475 - val_mape: 384.7776
#
# Epoch 00074: val_loss did not improve from 0.00205
# Epoch 75/1000
# 364/364 [==============================] - 407s 1s/step - loss: 2.2158e-04 - mae: 0.0106 - mape: 13.5453 - val_loss: 0.0027 - val_mae: 0.0395 - val_mape: 306.3618
#
# Epoch 00075: val_loss did not improve from 0.00205
# Epoch 76/1000
# 364/364 [==============================] - 413s 1s/step - loss: 2.2430e-04 - mae: 0.0108 - mape: 14.6240 - val_loss: 0.0030 - val_mae: 0.0414 - val_mape: 349.9688
#
# Epoch 00076: val_loss did not improve from 0.00205
# Epoch 77/1000
# 364/364 [==============================] - 409s 1s/step - loss: 2.4030e-04 - mae: 0.0111 - mape: 15.3947 - val_loss: 0.0044 - val_mae: 0.0497 - val_mape: 469.6617
#
# Epoch 00077: val_loss did not improve from 0.00205
# Epoch 78/1000
# 364/364 [==============================] - 405s 1s/step - loss: 2.2447e-04 - mae: 0.0108 - mape: 13.9635 - val_loss: 0.0034 - val_mae: 0.0450 - val_mape: 371.5609
#
# Epoch 00078: val_loss did not improve from 0.00205
# Epoch 79/1000
# 364/364 [==============================] - 404s 1s/step - loss: 2.1823e-04 - mae: 0.0107 - mape: 15.8098 - val_loss: 0.0026 - val_mae: 0.0389 - val_mape: 323.1369
#
# Epoch 00079: val_loss did not improve from 0.00205
# Epoch 80/1000
# 364/364 [==============================] - 406s 1s/step - loss: 2.3600e-04 - mae: 0.0111 - mape: 13.4104 - val_loss: 0.0031 - val_mae: 0.0413 - val_mape: 392.8407
#
# Epoch 00080: val_loss did not improve from 0.00205
# Epoch 81/1000
# 364/364 [==============================] - 417s 1s/step - loss: 2.3713e-04 - mae: 0.0109 - mape: 15.6000 - val_loss: 0.0048 - val_mae: 0.0518 - val_mape: 478.8877
#
# Epoch 00081: val_loss did not improve from 0.00205
# Epoch 82/1000
# 364/364 [==============================] - 416s 1s/step - loss: 2.1706e-04 - mae: 0.0105 - mape: 11.8686 - val_loss: 0.0042 - val_mae: 0.0485 - val_mape: 442.5862
#
# Epoch 00082: val_loss did not improve from 0.00205
# Epoch 83/1000
# 364/364 [==============================] - 411s 1s/step - loss: 2.2213e-04 - mae: 0.0106 - mape: 14.0627 - val_loss: 0.0056 - val_mae: 0.0558 - val_mape: 555.2177
#
# Epoch 00083: val_loss did not improve from 0.00205
# Epoch 84/1000
# 364/364 [==============================] - 413s 1s/step - loss: 2.2900e-04 - mae: 0.0108 - mape: 14.4915 - val_loss: 0.0038 - val_mae: 0.0452 - val_mape: 443.7638
#
# Epoch 00084: val_loss did not improve from 0.00205
# Epoch 85/1000
# 364/364 [==============================] - 411s 1s/step - loss: 2.2677e-04 - mae: 0.0107 - mape: 13.4609 - val_loss: 0.0030 - val_mae: 0.0415 - val_mape: 337.6741
#
# Epoch 00085: val_loss did not improve from 0.00205
# Epoch 86/1000
# 364/364 [==============================] - 414s 1s/step - loss: 2.3558e-04 - mae: 0.0109 - mape: 12.2559 - val_loss: 0.0048 - val_mae: 0.0520 - val_mape: 466.7463
#
# Epoch 00086: val_loss did not improve from 0.00205
# Epoch 87/1000
# 364/364 [==============================] - 421s 1s/step - loss: 2.2083e-04 - mae: 0.0106 - mape: 14.5360 - val_loss: 0.0158 - val_mae: 0.1024 - val_mape: 870.0412
#
# Epoch 00087: val_loss did not improve from 0.00205
# Epoch 88/1000
# 364/364 [==============================] - 421s 1s/step - loss: 2.3433e-04 - mae: 0.0108 - mape: 14.0477 - val_loss: 0.0105 - val_mae: 0.0820 - val_mape: 757.0090
#
# Epoch 00088: val_loss did not improve from 0.00205
# Epoch 89/1000
# 364/364 [==============================] - 417s 1s/step - loss: 2.2248e-04 - mae: 0.0106 - mape: 12.6637 - val_loss: 0.0147 - val_mae: 0.0987 - val_mape: 825.4459
#
# Epoch 00089: val_loss did not improve from 0.00205
# Epoch 90/1000
# 364/364 [==============================] - 419s 1s/step - loss: 2.3787e-04 - mae: 0.0109 - mape: 15.6302 - val_loss: 0.0135 - val_mae: 0.0948 - val_mape: 813.2869
#
# Epoch 00090: val_loss did not improve from 0.00205
# Epoch 91/1000
# 364/364 [==============================] - 414s 1s/step - loss: 2.1077e-04 - mae: 0.0103 - mape: 11.4389 - val_loss: 0.0181 - val_mae: 0.1118 - val_mape: 921.0984
#
# Epoch 00091: val_loss did not improve from 0.00205
# Epoch 92/1000
# 364/364 [==============================] - 416s 1s/step - loss: 2.2366e-04 - mae: 0.0106 - mape: 13.1925 - val_loss: 0.0184 - val_mae: 0.1138 - val_mape: 977.2261
#
# Epoch 00092: val_loss did not improve from 0.00205
# Epoch 93/1000
# 364/364 [==============================] - 416s 1s/step - loss: 2.1181e-04 - mae: 0.0105 - mape: 14.0048 - val_loss: 0.0106 - val_mae: 0.0805 - val_mape: 681.0366
#
# Epoch 00093: val_loss did not improve from 0.00205
# Epoch 94/1000
# 364/364 [==============================] - 412s 1s/step - loss: 2.2129e-04 - mae: 0.0104 - mape: 14.3135 - val_loss: 0.0077 - val_mae: 0.0684 - val_mape: 566.4965
#
# Epoch 00094: val_loss did not improve from 0.00205
# Epoch 95/1000
# 364/364 [==============================] - 405s 1s/step - loss: 2.2008e-04 - mae: 0.0105 - mape: 13.7881 - val_loss: 0.0131 - val_mae: 0.0913 - val_mape: 825.6923
#
# Epoch 00095: val_loss did not improve from 0.00205
# Epoch 96/1000
# 364/364 [==============================] - 400s 1s/step - loss: 2.2905e-04 - mae: 0.0108 - mape: 14.0586 - val_loss: 0.0076 - val_mae: 0.0652 - val_mape: 616.0399
#
# Epoch 00096: val_loss did not improve from 0.00205
# Epoch 97/1000
# 364/364 [==============================] - 398s 1s/step - loss: 2.2537e-04 - mae: 0.0106 - mape: 13.9434 - val_loss: 0.0822 - val_mae: 0.2354 - val_mape: 1736.2136
#
# Epoch 00097: val_loss did not improve from 0.00205
# Epoch 98/1000
# 364/364 [==============================] - 409s 1s/step - loss: 2.1642e-04 - mae: 0.0105 - mape: 12.7061 - val_loss: 0.0659 - val_mae: 0.2144 - val_mape: 1527.0530
#
# Epoch 00098: val_loss did not improve from 0.00205
# Epoch 99/1000
# 364/364 [==============================] - 407s 1s/step - loss: 2.1432e-04 - mae: 0.0103 - mape: 14.1183 - val_loss: 0.0661 - val_mae: 0.2152 - val_mape: 1595.6226
#
# Epoch 00099: val_loss did not improve from 0.00205
# Epoch 100/1000
# 364/364 [==============================] - 414s 1s/step - loss: 2.2100e-04 - mae: 0.0107 - mape: 12.9752 - val_loss: 0.0635 - val_mae: 0.2117 - val_mape: 1526.6385
#
# Epoch 00100: val_loss did not improve from 0.00205
# Epoch 101/1000
# 364/364 [==============================] - 403s 1s/step - loss: 2.3504e-04 - mae: 0.0109 - mape: 13.7774 - val_loss: 0.0751 - val_mae: 0.2345 - val_mape: 1846.2319
#
# Epoch 00101: val_loss did not improve from 0.00205
# Epoch 102/1000
# 364/364 [==============================] - 418s 1s/step - loss: 2.2333e-04 - mae: 0.0105 - mape: 13.3535 - val_loss: 0.0494 - val_mae: 0.1877 - val_mape: 1379.4377
#
# Epoch 00102: val_loss did not improve from 0.00205
# Epoch 103/1000
# 364/364 [==============================] - 411s 1s/step - loss: 2.1061e-04 - mae: 0.0104 - mape: 12.7337 - val_loss: 0.0448 - val_mae: 0.1787 - val_mape: 1289.3158
#
# Epoch 00103: val_loss did not improve from 0.00205
# Epoch 104/1000
# 364/364 [==============================] - 405s 1s/step - loss: 2.1148e-04 - mae: 0.0103 - mape: 14.3087 - val_loss: 0.0258 - val_mae: 0.1272 - val_mape: 802.7158
#
# Epoch 00104: val_loss did not improve from 0.00205
# Epoch 105/1000
# 364/364 [==============================] - 414s 1s/step - loss: 2.1164e-04 - mae: 0.0103 - mape: 12.3385 - val_loss: 0.0522 - val_mae: 0.1944 - val_mape: 1458.4459
#
# Epoch 00105: val_loss did not improve from 0.00205
# Epoch 106/1000
# 364/364 [==============================] - 395s 1s/step - loss: 2.1942e-04 - mae: 0.0105 - mape: 12.5055 - val_loss: 0.0365 - val_mae: 0.1633 - val_mape: 1310.1215
#
# Epoch 00106: val_loss did not improve from 0.00205
# Epoch 107/1000
# 364/364 [==============================] - 396s 1s/step - loss: 2.3736e-04 - mae: 0.0109 - mape: 12.7720 - val_loss: 0.0549 - val_mae: 0.2032 - val_mape: 1610.5922
#
# Epoch 00107: val_loss did not improve from 0.00205
# Epoch 108/1000
# 364/364 [==============================] - 397s 1s/step - loss: 2.2338e-04 - mae: 0.0106 - mape: 13.8490 - val_loss: 0.0525 - val_mae: 0.1991 - val_mape: 1627.9657
#
# Epoch 00108: val_loss did not improve from 0.00205
# Epoch 109/1000
# 364/364 [==============================] - 406s 1s/step - loss: 2.1774e-04 - mae: 0.0104 - mape: 13.4652 - val_loss: 0.0331 - val_mae: 0.1569 - val_mape: 1294.1754
#
# Epoch 00109: val_loss did not improve from 0.00205
# Epoch 110/1000
# 364/364 [==============================] - 401s 1s/step - loss: 2.2305e-04 - mae: 0.0106 - mape: 12.2014 - val_loss: 0.0247 - val_mae: 0.1351 - val_mape: 1109.8428
#
# Epoch 00110: val_loss did not improve from 0.00205
# Epoch 111/1000
# 364/364 [==============================] - 399s 1s/step - loss: 2.2494e-04 - mae: 0.0104 - mape: 13.0652 - val_loss: 0.0385 - val_mae: 0.1697 - val_mape: 1427.1931
#
# Epoch 00111: val_loss did not improve from 0.00205
# Epoch 112/1000
# 364/364 [==============================] - 405s 1s/step - loss: 2.0978e-04 - mae: 0.0103 - mape: 13.7909 - val_loss: 0.0466 - val_mae: 0.1875 - val_mape: 1534.8108
#
# Epoch 00112: val_loss did not improve from 0.00205
# Epoch 113/1000
# 364/364 [==============================] - 400s 1s/step - loss: 2.1870e-04 - mae: 0.0106 - mape: 15.3355 - val_loss: 0.0219 - val_mae: 0.1254 - val_mape: 1067.9102
#
# Epoch 00113: val_loss did not improve from 0.00205
# Epoch 114/1000
# 364/364 [==============================] - 407s 1s/step - loss: 2.1152e-04 - mae: 0.0104 - mape: 12.4822 - val_loss: 0.0311 - val_mae: 0.1519 - val_mape: 1328.0217
#
# Epoch 00114: val_loss did not improve from 0.00205
# Epoch 115/1000
# 364/364 [==============================] - 411s 1s/step - loss: 2.2055e-04 - mae: 0.0105 - mape: 13.5515 - val_loss: 0.0336 - val_mae: 0.1587 - val_mape: 1361.4678
#
# Epoch 00115: val_loss did not improve from 0.00205
# Epoch 116/1000
# 364/364 [==============================] - 404s 1s/step - loss: 2.1742e-04 - mae: 0.0104 - mape: 12.7898 - val_loss: 0.0277 - val_mae: 0.1403 - val_mape: 1115.5516
#
# Epoch 00116: val_loss did not improve from 0.00205
# Epoch 117/1000
# 364/364 [==============================] - 401s 1s/step - loss: 2.1843e-04 - mae: 0.0104 - mape: 12.0309 - val_loss: 0.0325 - val_mae: 0.1568 - val_mape: 1333.8975
#
# Epoch 00117: val_loss did not improve from 0.00205
# Epoch 118/1000
# 364/364 [==============================] - 399s 1s/step - loss: 2.2221e-04 - mae: 0.0107 - mape: 13.5097 - val_loss: 0.0307 - val_mae: 0.1471 - val_mape: 1179.8113
#
# Epoch 00118: val_loss did not improve from 0.00205
# Epoch 119/1000
# 364/364 [==============================] - 409s 1s/step - loss: 2.2334e-04 - mae: 0.0106 - mape: 13.4091 - val_loss: 0.0203 - val_mae: 0.1207 - val_mape: 945.9378
#
# Epoch 00119: val_loss did not improve from 0.00205
# Epoch 120/1000
# 364/364 [==============================] - 407s 1s/step - loss: 2.1957e-04 - mae: 0.0105 - mape: 13.8442 - val_loss: 0.0165 - val_mae: 0.1051 - val_mape: 822.7622
#
# Epoch 00120: val_loss did not improve from 0.00205
# Epoch 121/1000
# 364/364 [==============================] - 402s 1s/step - loss: 2.2128e-04 - mae: 0.0105 - mape: 12.3057 - val_loss: 0.0305 - val_mae: 0.1516 - val_mape: 1209.0966
#
# Epoch 00121: val_loss did not improve from 0.00205
# Epoch 122/1000
# 364/364 [==============================] - 391s 1s/step - loss: 2.1616e-04 - mae: 0.0104 - mape: 14.9597 - val_loss: 0.0175 - val_mae: 0.1106 - val_mape: 939.5276
#
# Epoch 00122: val_loss did not improve from 0.00205
# Epoch 123/1000
# 364/364 [==============================] - 402s 1s/step - loss: 2.0850e-04 - mae: 0.0102 - mape: 14.0574 - val_loss: 0.0259 - val_mae: 0.1410 - val_mape: 1147.5234
#
# Epoch 00123: val_loss did not improve from 0.00205
# Epoch 124/1000
# 364/364 [==============================] - 403s 1s/step - loss: 2.1212e-04 - mae: 0.0104 - mape: 13.3329 - val_loss: 0.0393 - val_mae: 0.1747 - val_mape: 1406.1238
#
# Epoch 00124: val_loss did not improve from 0.00205
# Epoch 125/1000
# 364/364 [==============================] - 400s 1s/step - loss: 2.1549e-04 - mae: 0.0103 - mape: 13.1395 - val_loss: 0.0354 - val_mae: 0.1657 - val_mape: 1344.3595
#
# Epoch 00125: val_loss did not improve from 0.00205
# Epoch 126/1000
# 364/364 [==============================] - 399s 1s/step - loss: 2.1036e-04 - mae: 0.0103 - mape: 12.5100 - val_loss: 0.0422 - val_mae: 0.1804 - val_mape: 1459.4633
#
# Epoch 00126: val_loss did not improve from 0.00205
# Epoch 127/1000
# 364/364 [==============================] - 391s 1s/step - loss: 2.2077e-04 - mae: 0.0105 - mape: 13.5868 - val_loss: 0.0357 - val_mae: 0.1656 - val_mape: 1346.9370
# Epoch 00127: val_loss did not improve from 0.00205
# Epoch 128/1000
# 364/364 [==============================] - 400s 1s/step - loss: 1.9586e-04 - mae: 0.0100 - mape: 14.8069 - val_loss: 0.0473 - val_mae: 0.1933 - val_mape: 1562.7167
#
# Epoch 00128: val_loss did not improve from 0.00205
# Epoch 129/1000
# 364/364 [==============================] - 406s 1s/step - loss: 2.1036e-04 - mae: 0.0103 - mape: 12.7263 - val_loss: 0.0491 - val_mae: 0.1934 - val_mape: 1564.3339
#
# Epoch 00129: val_loss did not improve from 0.00205
# Epoch 130/1000
# 364/364 [==============================] - 397s 1s/step - loss: 2.1228e-04 - mae: 0.0102 - mape: 12.1909 - val_loss: 0.0254 - val_mae: 0.1387 - val_mape: 1173.0332
#
# Epoch 00130: val_loss did not improve from 0.00205
# Epoch 131/1000
# 364/364 [==============================] - 407s 1s/step - loss: 2.1066e-04 - mae: 0.0102 - mape: 12.7918 - val_loss: 0.0285 - val_mae: 0.1475 - val_mape: 1220.7327
#
# Epoch 00131: val_loss did not improve from 0.00205
# Epoch 132/1000
# 364/364 [==============================] - 399s 1s/step - loss: 2.0845e-04 - mae: 0.0101 - mape: 11.8288 - val_loss: 0.0365 - val_mae: 0.1696 - val_mape: 1375.6267
#
# Epoch 00132: val_loss did not improve from 0.00205
# Epoch 133/1000
# 364/364 [==============================] - 387s 1s/step - loss: 2.1900e-04 - mae: 0.0105 - mape: 14.2408 - val_loss: 0.0289 - val_mae: 0.1481 - val_mape: 1231.7291
#
# Epoch 00133: val_loss did not improve from 0.00205
# Epoch 134/1000
# 364/364 [==============================] - 393s 1s/step - loss: 2.1577e-04 - mae: 0.0104 - mape: 13.0156 - val_loss: 0.0390 - val_mae: 0.1765 - val_mape: 1415.9294
#
# Epoch 00134: val_loss did not improve from 0.00205
# Epoch 135/1000
# 364/364 [==============================] - 393s 1s/step - loss: 2.1239e-04 - mae: 0.0104 - mape: 14.2837 - val_loss: 0.0226 - val_mae: 0.1301 - val_mape: 1109.7793
#
# Epoch 00135: val_loss did not improve from 0.00205
# Epoch 136/1000
# 364/364 [==============================] - 398s 1s/step - loss: 2.1052e-04 - mae: 0.0102 - mape: 12.6203 - val_loss: 0.0223 - val_mae: 0.1299 - val_mape: 1108.6494
#
# Epoch 00136: val_loss did not improve from 0.00205
# Epoch 137/1000
# 364/364 [==============================] - 396s 1s/step - loss: 2.0405e-04 - mae: 0.0102 - mape: 12.6864 - val_loss: 0.0273 - val_mae: 0.1443 - val_mape: 1226.2994
#
# Epoch 00137: val_loss did not improve from 0.00205
# Epoch 138/1000
# 364/364 [==============================] - 398s 1s/step - loss: 2.0074e-04 - mae: 0.0101 - mape: 11.5844 - val_loss: 0.0332 - val_mae: 0.1607 - val_mape: 1349.8510
#
# Epoch 00138: val_loss did not improve from 0.00205
# Epoch 139/1000
# 364/364 [==============================] - 395s 1s/step - loss: 2.1316e-04 - mae: 0.0103 - mape: 13.3865 - val_loss: 0.0273 - val_mae: 0.1447 - val_mape: 1208.1637
#
# Epoch 00139: val_loss did not improve from 0.00205
# Epoch 140/1000
# 364/364 [==============================] - 394s 1s/step - loss: 1.9822e-04 - mae: 0.0100 - mape: 13.0949 - val_loss: 0.0289 - val_mae: 0.1494 - val_mape: 1232.3634
#
# Epoch 00140: val_loss did not improve from 0.00205
# Epoch 141/1000
# 364/364 [==============================] - 390s 1s/step - loss: 2.0507e-04 - mae: 0.0102 - mape: 12.4757 - val_loss: 0.0352 - val_mae: 0.1672 - val_mape: 1375.6425
#
# Epoch 00141: val_loss did not improve from 0.00205
# Epoch 142/1000
# 364/364 [==============================] - 387s 1s/step - loss: 2.1409e-04 - mae: 0.0103 - mape: 13.2216 - val_loss: 0.0291 - val_mae: 0.1503 - val_mape: 1263.0955
#
# Epoch 00142: val_loss did not improve from 0.00205
# Epoch 143/1000
# 364/364 [==============================] - 389s 1s/step - loss: 2.1000e-04 - mae: 0.0103 - mape: 15.8554 - val_loss: 0.0642 - val_mae: 0.2266 - val_mape: 1825.2899
#
# Epoch 00143: val_loss did not improve from 0.00205
# Epoch 144/1000
# 364/364 [==============================] - 391s 1s/step - loss: 2.0222e-04 - mae: 0.0100 - mape: 11.8513 - val_loss: 0.1002 - val_mae: 0.2818 - val_mape: 2368.2268
#
# Epoch 00144: val_loss did not improve from 0.00205
# Epoch 145/1000
# 364/364 [==============================] - 387s 1s/step - loss: 2.1013e-04 - mae: 0.0102 - mape: 12.3526 - val_loss: 0.1230 - val_mae: 0.3069 - val_mape: 2695.6765
#
# Epoch 00145: val_loss did not improve from 0.00205
# Epoch 146/1000
# 364/364 [==============================] - 391s 1s/step - loss: 2.0867e-04 - mae: 0.0101 - mape: 12.8919 - val_loss: 0.1318 - val_mae: 0.3233 - val_mape: 2750.0317
#
# Epoch 00146: val_loss did not improve from 0.00205
# Epoch 147/1000
# 364/364 [==============================] - 392s 1s/step - loss: 2.0871e-04 - mae: 0.0101 - mape: 14.0420 - val_loss: 0.1535 - val_mae: 0.3494 - val_mape: 3044.2024
#
# Epoch 00147: val_loss did not improve from 0.00205
# Epoch 148/1000
# 364/364 [==============================] - 395s 1s/step - loss: 2.1303e-04 - mae: 0.0103 - mape: 13.1487 - val_loss: 0.1251 - val_mae: 0.3164 - val_mape: 2632.9646
#
# Epoch 00148: val_loss did not improve from 0.00205
# Epoch 149/1000
# 364/364 [==============================] - 391s 1s/step - loss: 2.0439e-04 - mae: 0.0101 - mape: 11.6326 - val_loss: 0.1109 - val_mae: 0.3023 - val_mape: 2417.5916
#
# Epoch 00149: val_loss did not improve from 0.00205
# Epoch 150/1000
# 364/364 [==============================] - 394s 1s/step - loss: 2.1724e-04 - mae: 0.0104 - mape: 13.2460 - val_loss: 0.1045 - val_mae: 0.2961 - val_mape: 2335.3926
#
# Epoch 00150: val_loss did not improve from 0.00205
# Epoch 151/1000
# 364/364 [==============================] - 394s 1s/step - loss: 2.0037e-04 - mae: 0.0099 - mape: 11.8726 - val_loss: 0.1108 - val_mae: 0.3060 - val_mape: 2402.4329
#
# Epoch 00151: val_loss did not improve from 0.00205
# Epoch 152/1000
# 364/364 [==============================] - 389s 1s/step - loss: 2.1808e-04 - mae: 0.0106 - mape: 13.8652 - val_loss: 0.0808 - val_mae: 0.2586 - val_mape: 2074.1926
#
# Epoch 00152: val_loss did not improve from 0.00205
# Epoch 153/1000
# 364/364 [==============================] - 387s 1s/step - loss: 2.0929e-04 - mae: 0.0102 - mape: 13.6907 - val_loss: 0.0718 - val_mae: 0.2429 - val_mape: 1958.4309
#
# Epoch 00153: val_loss did not improve from 0.00205
# Epoch 154/1000
# 364/364 [==============================] - 382s 1s/step - loss: 2.5746e-04 - mae: 0.0109 - mape: 13.4718 - val_loss: 0.2137 - val_mae: 0.4037 - val_mape: 3688.4937
#
# Epoch 00154: val_loss did not improve from 0.00205
# Epoch 155/1000
# 364/364 [==============================] - 388s 1s/step - loss: 2.1323e-04 - mae: 0.0104 - mape: 14.4104 - val_loss: 0.2245 - val_mae: 0.4124 - val_mape: 3804.4895
#
# Epoch 00155: val_loss did not improve from 0.00205
# Epoch 156/1000
# 364/364 [==============================] - 393s 1s/step - loss: 2.1362e-04 - mae: 0.0103 - mape: 11.8993 - val_loss: 0.2258 - val_mae: 0.4166 - val_mape: 3796.5278
#
# Epoch 00156: val_loss did not improve from 0.00205
# Epoch 157/1000
# 364/364 [==============================] - 392s 1s/step - loss: 2.1557e-04 - mae: 0.0104 - mape: 12.5470 - val_loss: 0.2309 - val_mae: 0.4207 - val_mape: 3862.5723
#
# Epoch 00157: val_loss did not improve from 0.00205
# Epoch 158/1000
# 364/364 [==============================] - 383s 1s/step - loss: 2.0964e-04 - mae: 0.0101 - mape: 12.8490 - val_loss: 0.2258 - val_mae: 0.4189 - val_mape: 3781.8811
#
# Epoch 00158: val_loss did not improve from 0.00205
# Epoch 159/1000
# 364/364 [==============================] - 389s 1s/step - loss: 2.0218e-04 - mae: 0.0101 - mape: 13.9170 - val_loss: 0.2206 - val_mae: 0.4124 - val_mape: 3785.7556
#
# Epoch 00159: val_loss did not improve from 0.00205
# Epoch 160/1000
# 364/364 [==============================] - 391s 1s/step - loss: 2.0512e-04 - mae: 0.0100 - mape: 14.5196 - val_loss: 0.2198 - val_mae: 0.4123 - val_mape: 3774.3196
#
# Epoch 00160: val_loss did not improve from 0.00205
# Epoch 161/1000
# 364/364 [==============================] - 386s 1s/step - loss: 2.2351e-04 - mae: 0.0106 - mape: 13.1782 - val_loss: 0.2255 - val_mae: 0.4275 - val_mape: 3770.1956
#
# Epoch 00161: val_loss did not improve from 0.00205
# Epoch 162/1000
# 364/364 [==============================] - 391s 1s/step - loss: 2.0634e-04 - mae: 0.0103 - mape: 14.3840 - val_loss: 0.2308 - val_mae: 0.4324 - val_mape: 3797.4519
#
# Epoch 00162: val_loss did not improve from 0.00205
# Epoch 163/1000
# 364/364 [==============================] - 384s 1s/step - loss: 2.0320e-04 - mae: 0.0100 - mape: 12.6856 - val_loss: 0.2351 - val_mae: 0.4431 - val_mape: 3798.3662
#
# Epoch 00163: val_loss did not improve from 0.00205
# Epoch 164/1000
# 364/364 [==============================] - 380s 1s/step - loss: 1.9734e-04 - mae: 0.0100 - mape: 11.7098 - val_loss: 0.2311 - val_mae: 0.4398 - val_mape: 3757.1577
#
# Epoch 00164: val_loss did not improve from 0.00205
# Epoch 165/1000
# 364/364 [==============================] - 386s 1s/step - loss: 2.1564e-04 - mae: 0.0102 - mape: 11.4562 - val_loss: 0.2401 - val_mae: 0.4485 - val_mape: 3836.6182
#
# Epoch 00165: val_loss did not improve from 0.00205
# Epoch 166/1000
# 364/364 [==============================] - 392s 1s/step - loss: 1.9477e-04 - mae: 0.0099 - mape: 12.7655 - val_loss: 0.2394 - val_mae: 0.4452 - val_mape: 3834.0815
#
# Epoch 00166: val_loss did not improve from 0.00205
# Epoch 167/1000
# 364/364 [==============================] - 390s 1s/step - loss: 2.1310e-04 - mae: 0.0103 - mape: 16.5121 - val_loss: 0.2232 - val_mae: 0.4278 - val_mape: 3723.5225
#
# Epoch 00167: val_loss did not improve from 0.00205
# Epoch 168/1000
# 364/364 [==============================] - 384s 1s/step - loss: 2.2276e-04 - mae: 0.0105 - mape: 13.7602 - val_loss: 0.2348 - val_mae: 0.4440 - val_mape: 3772.2534
#
# Epoch 00168: val_loss did not improve from 0.00205
# Epoch 169/1000
# 364/364 [==============================] - 391s 1s/step - loss: 2.0225e-04 - mae: 0.0100 - mape: 12.1088 - val_loss: 0.2177 - val_mae: 0.4208 - val_mape: 3676.9250
#
# Epoch 00169: val_loss did not improve from 0.00205
# Epoch 170/1000
# 364/364 [==============================] - 388s 1s/step - loss: 1.9485e-04 - mae: 0.0099 - mape: 12.1104 - val_loss: 0.2262 - val_mae: 0.4335 - val_mape: 3718.5916
#
# Epoch 00170: val_loss did not improve from 0.00205
# Epoch 171/1000
# 364/364 [==============================] - 395s 1s/step - loss: 2.1496e-04 - mae: 0.0103 - mape: 13.7823 - val_loss: 0.2282 - val_mae: 0.4383 - val_mape: 3705.6814
#
# Epoch 00171: val_loss did not improve from 0.00205
# Epoch 172/1000
# 364/364 [==============================] - 391s 1s/step - loss: 2.1396e-04 - mae: 0.0102 - mape: 13.5837 - val_loss: 0.2177 - val_mae: 0.4219 - val_mape: 3681.5334
#
# Epoch 00172: val_loss did not improve from 0.00205
# Epoch 173/1000
# 364/364 [==============================] - 390s 1s/step - loss: 2.1476e-04 - mae: 0.0103 - mape: 12.0733 - val_loss: 0.2224 - val_mae: 0.4299 - val_mape: 3690.4363
#
# Epoch 00173: val_loss did not improve from 0.00205
# Epoch 174/1000
# 364/364 [==============================] - 385s 1s/step - loss: 2.1521e-04 - mae: 0.0103 - mape: 14.4921 - val_loss: 0.2101 - val_mae: 0.4141 - val_mape: 3606.4612
#
# Epoch 00174: val_loss did not improve from 0.00205
# Epoch 175/1000
# 364/364 [==============================] - 389s 1s/step - loss: 2.0776e-04 - mae: 0.0101 - mape: 11.2284 - val_loss: 0.2262 - val_mae: 0.4368 - val_mape: 3667.0168
#
# Epoch 00175: val_loss did not improve from 0.00205
# Epoch 176/1000
# 364/364 [==============================] - 388s 1s/step - loss: 2.1672e-04 - mae: 0.0101 - mape: 11.7193 - val_loss: 0.2279 - val_mae: 0.4382 - val_mape: 3684.2939
#
# Epoch 00176: val_loss did not improve from 0.00205
# Epoch 177/1000
# 364/364 [==============================] - 384s 1s/step - loss: 2.0177e-04 - mae: 0.0101 - mape: 11.4052 - val_loss: 0.2311 - val_mae: 0.4410 - val_mape: 3708.9993
#
# Epoch 00177: val_loss did not improve from 0.00205
# Epoch 178/1000
# 364/364 [==============================] - 381s 1s/step - loss: 2.1251e-04 - mae: 0.0103 - mape: 15.5345 - val_loss: 0.2122 - val_mae: 0.4201 - val_mape: 3579.0000
#
# Epoch 00178: val_loss did not improve from 0.00205
# Epoch 179/1000
# 364/364 [==============================] - 380s 1s/step - loss: 2.0304e-04 - mae: 0.0102 - mape: 12.0282 - val_loss: 0.2193 - val_mae: 0.4270 - val_mape: 3651.6687
#
# Epoch 00179: val_loss did not improve from 0.00205
# Epoch 180/1000
# 364/364 [==============================] - 385s 1s/step - loss: 2.0498e-04 - mae: 0.0100 - mape: 13.2168 - val_loss: 0.2266 - val_mae: 0.4373 - val_mape: 3680.7522
#
# Epoch 00180: val_loss did not improve from 0.00205
# Epoch 181/1000
# 364/364 [==============================] - 386s 1s/step - loss: 2.1102e-04 - mae: 0.0101 - mape: 18.3560 - val_loss: 0.2131 - val_mae: 0.4203 - val_mape: 3609.2512
#
# Epoch 00181: val_loss did not improve from 0.00205
# Epoch 182/1000
# 364/364 [==============================] - 385s 1s/step - loss: 2.1019e-04 - mae: 0.0102 - mape: 12.1162 - val_loss: 0.2222 - val_mae: 0.4321 - val_mape: 3661.4597
#
# Epoch 00182: val_loss did not improve from 0.00205
# Epoch 183/1000
# 364/364 [==============================] - 387s 1s/step - loss: 2.1002e-04 - mae: 0.0101 - mape: 14.8296 - val_loss: 0.2192 - val_mae: 0.4294 - val_mape: 3641.9832
#
# Epoch 00183: val_loss did not improve from 0.00205
# Epoch 184/1000
# 364/364 [==============================] - 393s 1s/step - loss: 2.0074e-04 - mae: 0.0101 - mape: 11.8867 - val_loss: 0.2130 - val_mae: 0.4209 - val_mape: 3621.6741
#
# Epoch 00184: val_loss did not improve from 0.00205
# Epoch 185/1000
# 364/364 [==============================] - 384s 1s/step - loss: 1.9792e-04 - mae: 0.0100 - mape: 11.7782 - val_loss: 0.2154 - val_mae: 0.4245 - val_mape: 3625.2168
#
# Epoch 00185: val_loss did not improve from 0.00205
# Epoch 186/1000
# 364/364 [==============================] - 392s 1s/step - loss: 2.0776e-04 - mae: 0.0101 - mape: 12.2867 - val_loss: 0.2152 - val_mae: 0.4226 - val_mape: 3625.8486
#
# Epoch 00186: val_loss did not improve from 0.00205
# Epoch 187/1000
# 364/364 [==============================] - 387s 1s/step - loss: 1.9949e-04 - mae: 0.0100 - mape: 13.8712 - val_loss: 0.2150 - val_mae: 0.4209 - val_mape: 3645.7422
#
# Epoch 00187: val_loss did not improve from 0.00205
# Epoch 188/1000
# 364/364 [==============================] - 382s 1s/step - loss: 1.9700e-04 - mae: 0.0099 - mape: 12.3817 - val_loss: 0.2191 - val_mae: 0.4252 - val_mape: 3659.6182
#
# Epoch 00188: val_loss did not improve from 0.00205
# Epoch 189/1000
# 364/364 [==============================] - 387s 1s/step - loss: 2.0410e-04 - mae: 0.0102 - mape: 13.9618 - val_loss: 0.2057 - val_mae: 0.4085 - val_mape: 3583.1702
#
# Epoch 00189: val_loss did not improve from 0.00205
# Epoch 190/1000
# 364/364 [==============================] - 386s 1s/step - loss: 2.0240e-04 - mae: 0.0100 - mape: 12.1882 - val_loss: 0.2182 - val_mae: 0.4278 - val_mape: 3615.0359
#
# Epoch 00190: val_loss did not improve from 0.00205
# Epoch 191/1000
# 364/364 [==============================] - 395s 1s/step - loss: 2.0219e-04 - mae: 0.0099 - mape: 12.4568 - val_loss: 0.2110 - val_mae: 0.4153 - val_mape: 3622.1155
#
# Epoch 00191: val_loss did not improve from 0.00205
# Epoch 192/1000
# 364/364 [==============================] - 389s 1s/step - loss: 2.0808e-04 - mae: 0.0101 - mape: 11.3891 - val_loss: 0.1977 - val_mae: 0.3992 - val_mape: 3496.4067
#
# Epoch 00192: val_loss did not improve from 0.00205
# Epoch 193/1000
# ...
#
# Epoch 00931: val_loss did not improve from 0.00205
# Epoch 932/1000
# 364/364 [==============================] - 388s 1s/step - loss: 1.8074e-04 - mae: 0.0095 - mape: 13.3672 - val_loss: 0.0288 - val_mae: 0.1436 - val_mape: 1181.7502
#
# Epoch 00932: val_loss did not improve from 0.00205
# Epoch 933/1000
# 364/364 [==============================] - 387s 1s/step - loss: 1.8776e-04 - mae: 0.0095 - mape: 12.4573 - val_loss: 0.0251 - val_mae: 0.1333 - val_mape: 1167.8312
#
# Epoch 00933: val_loss did not improve from 0.00205
# Epoch 934/1000
# 364/364 [==============================] - 385s 1s/step - loss: 1.9087e-04 - mae: 0.0095 - mape: 12.9827 - val_loss: 0.0276 - val_mae: 0.1392 - val_mape: 1222.9677
#
# Epoch 00934: val_loss did not improve from 0.00205
# Epoch 935/1000
# 364/364 [==============================] - 384s 1s/step - loss: 1.7158e-04 - mae: 0.0091 - mape: 15.2553 - val_loss: 0.0290 - val_mae: 0.1438 - val_mape: 1211.7124
#
# Epoch 00935: val_loss did not improve from 0.00205
# Epoch 936/1000
# 364/364 [==============================] - 382s 1s/step - loss: 1.8300e-04 - mae: 0.0093 - mape: 12.7721 - val_loss: 0.0300 - val_mae: 0.1475 - val_mape: 1239.4524
#
# Epoch 00936: val_loss did not improve from 0.00205
# Epoch 937/1000
# 364/364 [==============================] - 384s 1s/step - loss: 1.8589e-04 - mae: 0.0094 - mape: 13.5810 - val_loss: 0.0310 - val_mae: 0.1499 - val_mape: 1257.9749
#
# Epoch 00937: val_loss did not improve from 0.00205
# Epoch 938/1000
# 364/364 [==============================] - 386s 1s/step - loss: 1.8014e-04 - mae: 0.0094 - mape: 13.8095 - val_loss: 0.0245 - val_mae: 0.1309 - val_mape: 1153.7255
#
# Epoch 00938: val_loss did not improve from 0.00205
# Epoch 939/1000
# 364/364 [==============================] - 380s 1s/step - loss: 1.8636e-04 - mae: 0.0094 - mape: 11.6036 - val_loss: 0.0230 - val_mae: 0.1237 - val_mape: 1115.8602
#
# Epoch 00939: val_loss did not improve from 0.00205
# Epoch 00951: val_loss did not improve from 0.00205
# Epoch 952/1000
# 364/364 [==============================] - 411s 1s/step - loss: 1.7678e-04 - mae: 0.0092 - mape: 12.9349 - val_loss: 0.0237 - val_mae: 0.1241 - val_mape: 1162.3721
#
# Epoch 00952: val_loss did not improve from 0.00205
# Epoch 953/1000
# 364/364 [==============================] - 417s 1s/step - loss: 1.8039e-04 - mae: 0.0093 - mape: 13.9178 - val_loss: 0.0185 - val_mae: 0.1078 - val_mape: 1034.2050
#
# Epoch 00953: val_loss did not improve from 0.00205
# Epoch 954/1000
# 364/364 [==============================] - 412s 1s/step - loss: 1.8252e-04 - mae: 0.0093 - mape: 13.5689 - val_loss: 0.0190 - val_mae: 0.1106 - val_mape: 1049.3531
#
# Epoch 00954: val_loss did not improve from 0.00205
# Epoch 955/1000
# 364/364 [==============================] - 412s 1s/step - loss: 1.7987e-04 - mae: 0.0092 - mape: 11.4813 - val_loss: 0.0190 - val_mae: 0.1099 - val_mape: 1052.9094
#
# Epoch 00955: val_loss did not improve from 0.00205
# Epoch 956/1000
# 364/364 [==============================] - 406s 1s/step - loss: 1.7314e-04 - mae: 0.0092 - mape: 15.3706 - val_loss: 0.0212 - val_mae: 0.1167 - val_mape: 1127.6534
#
# Epoch 00956: val_loss did not improve from 0.00205
# Epoch 957/1000
# 364/364 [==============================] - 417s 1s/step - loss: 1.8254e-04 - mae: 0.0094 - mape: 12.3500 - val_loss: 0.0179 - val_mae: 0.1065 - val_mape: 1033.4027
#
# Epoch 00957: val_loss did not improve from 0.00205
# Epoch 958/1000
# 364/364 [==============================] - 414s 1s/step - loss: 1.8406e-04 - mae: 0.0095 - mape: 10.8155 - val_loss: 0.0194 - val_mae: 0.1103 - val_mape: 1059.8724
#
# Epoch 00958: val_loss did not improve from 0.00205
# Epoch 959/1000
# 364/364 [==============================] - 415s 1s/step - loss: 1.7878e-04 - mae: 0.0092 - mape: 11.4737 - val_loss: 0.0152 - val_mae: 0.0970 - val_mape: 946.4501
#
# Epoch 00959: val_loss did not improve from 0.00205
# Epoch 960/1000
# 364/364 [==============================] - 415s 1s/step - loss: 1.8474e-04 - mae: 0.0094 - mape: 11.1475 - val_loss: 0.0187 - val_mae: 0.1092 - val_mape: 1034.1959
#
# Epoch 00960: val_loss did not improve from 0.00205
# Epoch 961/1000
# 364/364 [==============================] - 419s 1s/step - loss: 1.7614e-04 - mae: 0.0092 - mape: 12.9478 - val_loss: 0.0175 - val_mae: 0.1042 - val_mape: 1027.7693
#
# Epoch 00961: val_loss did not improve from 0.00205
# Epoch 962/1000
# 364/364 [==============================] - 404s 1s/step - loss: 1.8667e-04 - mae: 0.0094 - mape: 13.5963 - val_loss: 0.0204 - val_mae: 0.1135 - val_mape: 1107.6582
#
# Epoch 00962: val_loss did not improve from 0.00205
# Epoch 963/1000
# 364/364 [==============================] - 410s 1s/step - loss: 1.8656e-04 - mae: 0.0095 - mape: 11.5297 - val_loss: 0.0184 - val_mae: 0.1079 - val_mape: 1053.5022
#
# Epoch 00963: val_loss did not improve from 0.00205
# Epoch 964/1000
# 364/364 [==============================] - 426s 1s/step - loss: 1.8209e-04 - mae: 0.0093 - mape: 11.7886 - val_loss: 0.1110 - val_mae: 0.2848 - val_mape: 2651.4131
#
# Epoch 00964: val_loss did not improve from 0.00205
# Epoch 965/1000
# 364/364 [==============================] - 417s 1s/step - loss: 1.8256e-04 - mae: 0.0093 - mape: 12.6415 - val_loss: 0.1163 - val_mae: 0.2912 - val_mape: 2749.3613
#
# Epoch 00965: val_loss did not improve from 0.00205
# Epoch 966/1000
# 364/364 [==============================] - 415s 1s/step - loss: 1.9048e-04 - mae: 0.0095 - mape: 10.6987 - val_loss: 0.1037 - val_mae: 0.2760 - val_mape: 2557.4954
#
# Epoch 00966: val_loss did not improve from 0.00205
# Epoch 967/1000
# 364/364 [==============================] - 422s 1s/step - loss: 1.8123e-04 - mae: 0.0093 - mape: 11.7033 - val_loss: 0.1079 - val_mae: 0.2815 - val_mape: 2635.0876
#
# Epoch 00967: val_loss did not improve from 0.00205
# Epoch 968/1000
# 364/364 [==============================] - 415s 1s/step - loss: 1.7248e-04 - mae: 0.0091 - mape: 13.5008 - val_loss: 0.0959 - val_mae: 0.2645 - val_mape: 2443.1917
#
# Epoch 00968: val_loss did not improve from 0.00205
# Epoch 969/1000
# 364/364 [==============================] - 416s 1s/step - loss: 1.7529e-04 - mae: 0.0093 - mape: 12.3915 - val_loss: 0.0920 - val_mae: 0.2586 - val_mape: 2327.5225
#
# Epoch 00969: val_loss did not improve from 0.00205
# Epoch 970/1000
# 364/364 [==============================] - 421s 1s/step - loss: 1.8036e-04 - mae: 0.0093 - mape: 12.1690 - val_loss: 0.0948 - val_mae: 0.2628 - val_mape: 2393.4219
#
# Epoch 00970: val_loss did not improve from 0.00205
# Epoch 971/1000
# 364/364 [==============================] - 411s 1s/step - loss: 1.7594e-04 - mae: 0.0092 - mape: 10.6241 - val_loss: 0.0896 - val_mae: 0.2560 - val_mape: 2306.0845
#
# Epoch 00971: val_loss did not improve from 0.00205
# Epoch 972/1000
# 364/364 [==============================] - 415s 1s/step - loss: 1.8340e-04 - mae: 0.0095 - mape: 13.5876 - val_loss: 0.0901 - val_mae: 0.2575 - val_mape: 2309.4080
#
# Epoch 00972: val_loss did not improve from 0.00205
# Epoch 973/1000
# 364/364 [==============================] - 420s 1s/step - loss: 1.7790e-04 - mae: 0.0092 - mape: 11.7341 - val_loss: 0.0824 - val_mae: 0.2444 - val_mape: 2200.1038
#
# Epoch 00973: val_loss did not improve from 0.00205
# Epoch 974/1000
# 364/364 [==============================] - 413s 1s/step - loss: 1.9439e-04 - mae: 0.0095 - mape: 13.2812 - val_loss: 0.0913 - val_mae: 0.2585 - val_mape: 2342.0947
#
# Epoch 00974: val_loss did not improve from 0.00205
# Epoch 975/1000
# 364/364 [==============================] - 408s 1s/step - loss: 1.7588e-04 - mae: 0.0092 - mape: 11.5615 - val_loss: 0.0903 - val_mae: 0.2571 - val_mape: 2266.2898
#
# Epoch 00975: val_loss did not improve from 0.00205
# Epoch 976/1000
# 364/364 [==============================] - 406s 1s/step - loss: 1.7924e-04 - mae: 0.0093 - mape: 13.7501 - val_loss: 0.0887 - val_mae: 0.2544 - val_mape: 2169.1282
#
# Epoch 00976: val_loss did not improve from 0.00205
# Epoch 977/1000
# 364/364 [==============================] - 413s 1s/step - loss: 1.8145e-04 - mae: 0.0093 - mape: 15.1117 - val_loss: 0.0750 - val_mae: 0.2332 - val_mape: 1992.1625
#
# Epoch 00977: val_loss did not improve from 0.00205
# Epoch 978/1000
# 364/364 [==============================] - 417s 1s/step - loss: 1.7963e-04 - mae: 0.0094 - mape: 11.9395 - val_loss: 0.0889 - val_mae: 0.2523 - val_mape: 2260.2441
#
# Epoch 00978: val_loss did not improve from 0.00205
# Epoch 979/1000
# 364/364 [==============================] - 408s 1s/step - loss: 1.9337e-04 - mae: 0.0094 - mape: 12.5159 - val_loss: 0.0807 - val_mae: 0.2402 - val_mape: 2084.2744
# Epoch 00979: val_loss did not improve from 0.00205
# Epoch 980/1000
# 364/364 [==============================] - 419s 1s/step - loss: 1.8241e-04 - mae: 0.0092 - mape: 10.8121 - val_loss: 0.0802 - val_mae: 0.2358 - val_mape: 2196.7285
#
# Epoch 00980: val_loss did not improve from 0.00205
# Epoch 981/1000
# 364/364 [==============================] - 418s 1s/step - loss: 1.7808e-04 - mae: 0.0092 - mape: 13.0211 - val_loss: 0.0790 - val_mae: 0.2380 - val_mape: 2041.8383
#
# Epoch 00981: val_loss did not improve from 0.00205
# Epoch 982/1000
# 364/364 [==============================] - 415s 1s/step - loss: 1.7682e-04 - mae: 0.0092 - mape: 11.8091 - val_loss: 0.0818 - val_mae: 0.2440 - val_mape: 2147.4731
#
# Epoch 00982: val_loss did not improve from 0.00205
# Epoch 983/1000
# 364/364 [==============================] - 414s 1s/step - loss: 1.9415e-04 - mae: 0.0096 - mape: 13.0426 - val_loss: 0.0852 - val_mae: 0.2492 - val_mape: 2218.4028
#
# Epoch 00983: val_loss did not improve from 0.00205
# Epoch 984/1000
# 364/364 [==============================] - 419s 1s/step - loss: 1.7612e-04 - mae: 0.0092 - mape: 12.8812 - val_loss: 0.0832 - val_mae: 0.2459 - val_mape: 2144.5486
#
# Epoch 00984: val_loss did not improve from 0.00205
# Epoch 985/1000
# 364/364 [==============================] - 418s 1s/step - loss: 1.8018e-04 - mae: 0.0093 - mape: 12.3975 - val_loss: 0.0745 - val_mae: 0.2305 - val_mape: 2006.8502
#
# Epoch 00985: val_loss did not improve from 0.00205
# Epoch 986/1000
# 364/364 [==============================] - 412s 1s/step - loss: 1.8514e-04 - mae: 0.0093 - mape: 11.0090 - val_loss: 0.0718 - val_mae: 0.2271 - val_mape: 1931.8329
#
# Epoch 00986: val_loss did not improve from 0.00205
# Epoch 987/1000
# 364/364 [==============================] - 411s 1s/step - loss: 1.7980e-04 - mae: 0.0093 - mape: 11.5408 - val_loss: 0.0726 - val_mae: 0.2288 - val_mape: 1903.0233
#
# Epoch 00987: val_loss did not improve from 0.00205
# Epoch 988/1000
# 364/364 [==============================] - 414s 1s/step - loss: 1.7582e-04 - mae: 0.0092 - mape: 13.3356 - val_loss: 0.0711 - val_mae: 0.2245 - val_mape: 1830.8248
#
# Epoch 00988: val_loss did not improve from 0.00205
# Epoch 989/1000
# 364/364 [==============================] - 408s 1s/step - loss: 1.8319e-04 - mae: 0.0095 - mape: 12.1256 - val_loss: 0.0727 - val_mae: 0.2240 - val_mape: 1956.3573
#
# Epoch 00989: val_loss did not improve from 0.00205
# Epoch 990/1000
# 364/364 [==============================] - 396s 1s/step - loss: 1.8619e-04 - mae: 0.0095 - mape: 14.1100 - val_loss: 0.0657 - val_mae: 0.2139 - val_mape: 1737.7321
#
# Epoch 00990: val_loss did not improve from 0.00205
# Epoch 991/1000
# 364/364 [==============================] - 406s 1s/step - loss: 1.8761e-04 - mae: 0.0093 - mape: 12.8288 - val_loss: 0.0671 - val_mae: 0.2194 - val_mape: 1771.7710
#
# Epoch 00991: val_loss did not improve from 0.00205
# Epoch 992/1000
# 364/364 [==============================] - 419s 1s/step - loss: 1.8315e-04 - mae: 0.0094 - mape: 13.3741 - val_loss: 0.0718 - val_mae: 0.2265 - val_mape: 1841.1371
#
# Epoch 00992: val_loss did not improve from 0.00205
# Epoch 993/1000
# 364/364 [==============================] - 417s 1s/step - loss: 1.6503e-04 - mae: 0.0090 - mape: 11.2661 - val_loss: 0.0692 - val_mae: 0.2238 - val_mape: 1888.6562
#
# Epoch 00993: val_loss did not improve from 0.00205
# Epoch 994/1000
# 364/364 [==============================] - 397s 1s/step - loss: 1.8644e-04 - mae: 0.0095 - mape: 15.9559 - val_loss: 0.0715 - val_mae: 0.2276 - val_mape: 1852.1906
#
# Epoch 00994: val_loss did not improve from 0.00205
# Epoch 995/1000
# 364/364 [==============================] - 408s 1s/step - loss: 1.8168e-04 - mae: 0.0093 - mape: 11.4590 - val_loss: 0.0698 - val_mae: 0.2247 - val_mape: 1798.1459
#
# Epoch 00995: val_loss did not improve from 0.00205
# Epoch 996/1000
# 364/364 [==============================] - 408s 1s/step - loss: 1.8515e-04 - mae: 0.0094 - mape: 12.5968 - val_loss: 0.0676 - val_mae: 0.2207 - val_mape: 1749.6049
#
# Epoch 00996: val_loss did not improve from 0.00205
# Epoch 997/1000
# 364/364 [==============================] - 414s 1s/step - loss: 1.7350e-04 - mae: 0.0091 - mape: 11.8350 - val_loss: 0.0697 - val_mae: 0.2259 - val_mape: 1783.0669
#
# Epoch 00997: val_loss did not improve from 0.00205
# Epoch 998/1000
# 364/364 [==============================] - 404s 1s/step - loss: 1.8014e-04 - mae: 0.0093 - mape: 13.1531 - val_loss: 0.0639 - val_mae: 0.2152 - val_mape: 1704.3229
#
# Epoch 00998: val_loss did not improve from 0.00205
# Epoch 999/1000
# 364/364 [==============================] - 387s 1s/step - loss: 1.8057e-04 - mae: 0.0094 - mape: 13.0652 - val_loss: 0.0592 - val_mae: 0.2068 - val_mape: 1655.2003
#
# Epoch 00999: val_loss did not improve from 0.00205
# Epoch 1000/1000
# 364/364 [==============================] - 398s 1s/step - loss: 1.7967e-04 - mae: 0.0092 - mape: 11.2882 - val_loss: 0.0610 - val_mae: 0.2094 - val_mape: 1659.2942
#
# Epoch 01000: val_loss did not improve from 0.00205

# %%
model_last = sorted([i for i in os.listdir('content') if 'hdf5' in i and 'Transformer+TimeEmbedding' in i])[-1]

# %%
model = tf.keras.models.load_model(
    os.path.join('content', model_last),
    custom_objects={
        'Time2Vector': Time2Vector,
        'SingleAttention': SingleAttention,
        'MultiAttention': MultiAttention,
        'TransformerEncoder': TransformerEncoder
    }
)
with open('../content/history.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
###############################################################################
'''Calculate predictions and metrics'''

#Calculate predication for training, validation and test data
train_pred = model.predict(X_train)
val_pred = model.predict(X_val)
test_pred = model.predict(X_test)

#Print evaluation metrics for all datasets
train_eval = model.evaluate(X_train, y_train, verbose=0)
val_eval = model.evaluate(X_val, y_val, verbose=0)
test_eval = model.evaluate(X_test, y_test, verbose=0)
print(' ')
print('Evaluation metrics')
print('Training Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(train_eval[0], train_eval[1], train_eval[2]))
print('Validation Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(val_eval[0], val_eval[1], val_eval[2]))
print('Test Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(test_eval[0], test_eval[1], test_eval[2]))

###############################################################################
'''Display results'''

fig = plt.figure(figsize=(15,20))
st = fig.suptitle("Transformer + TimeEmbedding Model", fontsize=22)
st.set_y(0.92)

#Plot training data results
ax11 = fig.add_subplot(311)
ax11.plot(train_data[:, 3], label='EURUSD Closing Returns')
ax11.plot(np.arange(seq_len, train_pred.shape[0]+seq_len), train_pred, linewidth=3, label='Predicted EURUSD Closing Returns')
ax11.set_title("Training Data", fontsize=18)
ax11.set_xlabel('Dates')
ax11.set_ylabel('EURUSD Closing Returns')
ax11.legend(loc="best", fontsize=12)

#Plot validation data results
ax21 = fig.add_subplot(312)
ax21.plot(val_data[:, 3], label='EURUSD Closing Returns')
ax21.plot(np.arange(seq_len, val_pred.shape[0]+seq_len), val_pred, linewidth=3, label='Predicted EURUSD Closing Returns')
ax21.set_title("Validation Data", fontsize=18)
ax21.set_xlabel('Dates')
ax21.set_ylabel('EURUSD Closing Returns')
ax21.legend(loc="best", fontsize=12)

#Plot test data results
ax31 = fig.add_subplot(313)
ax31.plot(test_data[:, 3], label='EURUSD Closing Returns')
ax31.plot(np.arange(seq_len, test_pred.shape[0]+seq_len), test_pred, linewidth=3, label='Predicted EURUSD Closing Returns')
ax31.set_title("Test Data", fontsize=18)
ax31.set_xlabel('Dates')
ax31.set_ylabel('EURUSD Closing Returns')
ax31.legend(loc="best", fontsize=12)
# Out:
#
# Evaluation metrics
# Training Data - Loss: 0.0001, MAE: 0.0089, MAPE: 13.0869
# Validation Data - Loss: 0.0021, MAE: 0.0355, MAPE: 343.0058
# Test Data - Loss: 0.0023, MAE: 0.0392, MAPE: 22.2996

# %% [markdown]
# ## Model metrics

# %%
'''Display model metrics'''

fig = plt.figure(figsize=(15,20))
st = fig.suptitle("Transformer + TimeEmbedding Model Metrics", fontsize=22)
st.set_y(0.92)

#Plot model loss
ax1 = fig.add_subplot(311)
ax1.plot(history['loss'], label='Training loss (MSE)')
ax1.plot(history['val_loss'], label='Validation loss (MSE)')
ax1.set_title("Model loss", fontsize=18)
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss (MSE)')
ax1.legend(loc="best", fontsize=12)

#Plot MAE
ax2 = fig.add_subplot(312)
ax2.plot(history['mae'], label='Training MAE')
ax2.plot(history['val_mae'], label='Validation MAE')
ax2.set_title("Model metric - Mean average error (MAE)", fontsize=18)
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Mean average error (MAE)')
ax2.legend(loc="best", fontsize=12)

#Plot MAPE
ax3 = fig.add_subplot(313)
ax3.plot(history['mape'], label='Training MAPE')
ax3.plot(history['val_mape'], label='Validation MAPE')
ax3.set_title("Model metric - Mean average percentage error (MAPE)", fontsize=18)
ax3.set_xlabel('Epoch')
ax3.set_ylabel('Mean average percentage error (MAPE)')
ax3.legend(loc="best", fontsize=12)

# %% [markdown]
# ## Model architecture overview

# %%
tf.keras.utils.plot_model(
    model,
    to_file="EURUSD_Transformer+TimeEmbedding.png",
    show_shapes=True,
    show_layer_names=True,
    expand_nested=True,
    dpi=96,)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
