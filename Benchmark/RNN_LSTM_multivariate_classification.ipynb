# %% [markdown]
# # A

# %%
#!/usr/bin/env python

# coding: utf-8

# %% Loading Packages
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
# from sklearn.metrics import mean_squared_error, mean_absolute_erIPython.notebook.kernel.execute('nb_name = "' + IPython.notebook.notebook_name + '"')ror


import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import ReLU
from tensorflow.keras.layers import Dropout
from tensorflow.keras.activations import tanh
from tensorflow.keras.layers import PReLU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import MSE, MAE, MAPE
from tensorflow.keras.metrics import Accuracy, SparseCategoricalAccuracy
from tensorflow.keras.losses import kullback_leibler_divergence, SparseCategoricalCrossentropy, KLDivergence
from tensorflow.keras.callbacks import LearningRateScheduler

import sys

from tensorflow.python.ops.gen_batch_ops import batch

import sys
import os
import sys
import platform

from tensorflow.python.ops.gen_math_ops import Tanh
if platform.node() in ['msbq']:
    os.chdir('/home/ms/github/fxpred')
    # os.chdir('../.')
    sys.path.append(os.path.join(os.getcwd(), 'Transformer'))
# from utils import data_read_dict, data_read_concat, data_merge
from utils import get_fx_and_metric_data_wo_weekend, mde
from utils_NN_opt_learning_rate import opt_learn_rate_plot
from benchmark_utils import actual_pred_plot

from benchmark_utils import ts_train_test_normalize


name = 'LSTM_multivariate_classification'
# Out:
# /home/ms/github/venv/fxpred3/lib/python3.8/site-packages/pandas/core/frame.py:4305: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dtype = np.float32  # np.float64
tf.keras.backend.set_floatx('float32')
# %% read in data and adapt
df = get_fx_and_metric_data_wo_weekend(dtype=dtype)
target = 'EURUSD BGNE Curncy Bid Close'
# target_column = [i for i in df.columns.tolist() if 'Bid Close' in i]
# target_column_id = [list(df.columns).index(i) for i in target_column]
target_column_id = list(df.columns).index(target)

# %%
# create a list of our conditions #!!! 
conditions = [
    (df[target] <= -0.00000001),
    (df[target] > -0.00000001) & (df[target] <= 0.00000001),
    (df[target] > 0.00000001)
]

# create a list of the values we want to assign for each condition #!!! 
values = ['sell', 'hold', 'buy']
values = [0, 1, 2]

# create a new column and use np.select to assign values to it using our lists as arguments #!!! 
df['strategy'] = np.select(conditions, values)
df.strategy = df.strategy.astype(np.int32)

# display updated DataFrame #!!! 
df.head()
# Out:
#                      EURUSD BGNE Curncy Bid Open  \
# Dates
# 2020-11-01 19:10:00                     0.000000
# 2020-11-01 19:20:00                     0.000283
# 2020-11-01 19:30:00                     0.000172
# 2020-11-01 19:40:00                     0.000060
# 2020-11-01 19:50:00                    -0.000026
#
#                      EURUSD BGNE Curncy Bid Close  \
# Dates
# 2020-11-01 19:10:00                      0.000000
# 2020-11-01 19:20:00                      0.000275
# 2020-11-01 19:30:00                     -0.000069
# 2020-11-01 19:40:00                      0.000034
# 2020-11-01 19:50:00                      0.000026
#
#                      EURUSD BGNE Curncy Bid High  EURUSD BGNE Curncy Bid Low  \
# Dates
# 2020-11-01 19:10:00                     0.000000                    0.000000
# 2020-11-01 19:20:00                     0.000197                   -0.000507
# 2020-11-01 19:30:00                     0.000017                   -0.000215
# 2020-11-01 19:40:00                    -0.000172                    0.000636
# 2020-11-01 19:50:00                    -0.000026                    0.000584
#
#                      EURUSD BGNE Curncy Bid Number Ticks  \
# Dates
# 2020-11-01 19:10:00                             0.000000
# 2020-11-01 19:20:00                            -0.978125
# 2020-11-01 19:30:00                             0.380952
# 2020-11-01 19:40:00                             3.310345
# 2020-11-01 19:50:00                            -0.984000
#
#                      EURUSD BGNE Curncy Ask Open  \
# Dates
# 2020-11-01 19:10:00                     0.000000
# 2020-11-01 19:20:00                     0.002121
# 2020-11-01 19:30:00                     0.000043
# 2020-11-01 19:40:00                    -0.000274
# 2020-11-01 19:50:00                    -0.000909
#
#                      EURUSD BGNE Curncy Ask Close  \
# Dates
# 2020-11-01 19:10:00                      0.000000
# 2020-11-01 19:20:00                      0.001597
# 2020-11-01 19:30:00                      0.000017
# 2020-11-01 19:40:00                     -0.001157
# 2020-11-01 19:50:00                     -0.000009
#
#                      EURUSD BGNE Curncy Ask High  EURUSD BGNE Curncy Ask Low  \
# Dates
# 2020-11-01 19:10:00                     0.000000                    0.000000
# 2020-11-01 19:20:00                     0.001631                    0.001761
# 2020-11-01 19:30:00                     0.000086                    0.000137
# 2020-11-01 19:40:00                    -0.000009                   -0.000926
# 2020-11-01 19:50:00                    -0.001268                    0.000017
#
#                      EURUSD BGNE Curncy Ask Number Ticks  ...  usdjpy___TAS_D  \
# Dates                                                     ...
# 2020-11-01 19:10:00                             0.000000  ...            56.0
# 2020-11-01 19:20:00                            -0.978125  ...            56.0
# 2020-11-01 19:30:00                             0.380952  ...            56.0
# 2020-11-01 19:40:00                             3.310345  ...            56.0
# 2020-11-01 19:50:00                            -0.984000  ...            56.0
#
#                      usdjpy___TAS_DS  usdjpy___TAS_DSS  usdjpy___TRENDER_UP  \
# Dates
# 2020-11-01 19:10:00        62.133335         67.244446           104.536598
# 2020-11-01 19:20:00        62.133335         67.244446           104.536598
# 2020-11-01 19:30:00        62.133335         67.244446           104.536598
# 2020-11-01 19:40:00        62.133335         67.244446           104.536598
# 2020-11-01 19:50:00        62.133335         67.244446           104.536598
#
#                      usdjpy___TRENDER_DN  usdjpy___TMAVG  usdjpy___VMAVG  \
# Dates
# 2020-11-01 19:10:00           104.576935      104.551109      104.620003
# 2020-11-01 19:20:00           104.576935      104.551109      104.620003
# 2020-11-01 19:30:00           104.576935      104.551109      104.620003
# 2020-11-01 19:40:00           104.576935      104.551109      104.620003
# 2020-11-01 19:50:00           104.576935      104.552223      104.620003
#
#                      usdjpy___WMAVG  usdjpy___WLPR  strategy
# Dates
# 2020-11-01 19:10:00      104.553337     -66.666664         1
# 2020-11-01 19:20:00      104.553337     -66.666664         2
# 2020-11-01 19:30:00      104.553337     -66.666664         0
# 2020-11-01 19:40:00      104.553337     -66.666664         2
# 2020-11-01 19:50:00      104.552666     -66.666664         2
#
# [5 rows x 1239 columns]

# %%
df['EURUSD BGNE Curncy Bid Close'].plot()
plt.title('Return of closing price')
plt.show()

# %%
# X_train, y_train, X_val, y_val , X_test, y_test, sc, sc_target, index_train, index_val, index_test = \
#     ts_train_test_normalize(df, 64, 1, [i for i in target_columns_id])

lag = 128
h = 1
X_train, y_train, X_val, y_val , X_test, y_test, sc, sc_target, index_train, index_val, index_test, X_train_index, y_train_index = \
    ts_train_test_normalize(df, lag, h, df.columns.to_list().index('strategy'), dtype=dtype)

# %%
X_train = X_train#.astype(dtype)
X_val = X_val#.astype(dtype)
X_test = X_test#.astype(dtype)
y_train = sc_target.inverse_transform(y_train).round()
y_val = sc_target.inverse_transform(y_val).round()
y_test = sc_target.inverse_transform(y_test).round()

# %%
def LSTM_model():
    # The LSTM architecture
    loss_fct = 'tanh'
    dr = 0.5
    my_LSTM_model = Sequential()
    my_LSTM_model.add(LSTM(units=256, activation=loss_fct, return_sequences=True, dropout=dr))
    my_LSTM_model.add(BatchNormalization())
    my_LSTM_model.add(LSTM(units=256, activation=loss_fct, return_sequences=True, dropout=dr))
    my_LSTM_model.add(BatchNormalization())
    my_LSTM_model.add(LSTM(units=256, activation=loss_fct, return_sequences=True, dropout=dr))
    my_LSTM_model.add(BatchNormalization())
    my_LSTM_model.add(LSTM(units=256, activation=loss_fct, return_sequences=True, dropout=dr))
    my_LSTM_model.add(BatchNormalization())
    my_LSTM_model.add(LSTM(units=128, activation=loss_fct, return_sequences=True, dropout=dr))
    my_LSTM_model.add(BatchNormalization())
    my_LSTM_model.add(Flatten())
    my_LSTM_model.add(Dense(units=3, activation='softmax'))
    return my_LSTM_model

# %%
def predictions(my_model, X_test, sc=None):
    LSTM_prediction = my_model.predict(X_test)
    if sc is not None:
        LSTM_prediction = sc.inverse_transform(LSTM_prediction)
    return LSTM_prediction

# %%
def earlyStopping():
    return tf.keras.callbacks.EarlyStopping(
        monitor="val_loss",
        min_delta=0,
        patience=10,
        verbose=0,
        mode="auto",
        baseline=None,
        restore_best_weights=True,
    )
if not os.path.exists('Benchmark/trained_models'):
    os.mkdir('Benchmark/trained_models')
model_checkpoints = tf.keras.callbacks.ModelCheckpoint(
    'Benchmark/trained_models/%s____{epoch:04}.hdf5'%name,
    monitor='val_loss',
    save_best_only=False,
    verbose=1
)
def learning_rate_scheduler(epoch):
    if epoch < 10:
        return 0.001
    elif epoch < 20:
        return 0.0005
    elif epoch < 50:
        return 0.0001
    elif epoch < 100:
        return 0.00001
    else:
        return 0.000001

# %%
from tensorflow.keras.optimizers import Adam
my_LSTM_model = LSTM_model()
my_LSTM_model.compile(
    optimizer=Adam(
        learning_rate=0.05
    ),
    loss=SparseCategoricalCrossentropy(from_logits=False),
#     loss='accuracy',
    metrics=['kullback_leibler_divergence', 'accuracy'],
)

history = my_LSTM_model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_val, y_val),
    verbose=1,
    shuffle=True,
    callbacks=[
        # earlyStopping(),
        LearningRateScheduler(learning_rate_scheduler),
        model_checkpoints,
        tf.keras.callbacks.TerminateOnNaN()
    ]
)
# Out:
# Epoch 1/100
# 1045/1045 [==============================] - 54s 47ms/step - loss: 1.4872 - kullback_leibler_divergence: 4.6510 - accuracy: 0.4670 - val_loss: 2.2317 - val_kullback_leibler_divergence: 9.8793 - val_accuracy: 0.4801
#
# Epoch 00001: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0001.hdf5
# Epoch 2/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 1.1191 - kullback_leibler_divergence: 3.4666 - accuracy: 0.4836 - val_loss: 0.8423 - val_kullback_leibler_divergence: 3.0940 - val_accuracy: 0.4813
#
# Epoch 00002: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0002.hdf5
# Epoch 3/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.9363 - kullback_leibler_divergence: 2.8676 - accuracy: 0.4799 - val_loss: 0.8319 - val_kullback_leibler_divergence: 2.9225 - val_accuracy: 0.4840
#
# Epoch 00003: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0003.hdf5
# Epoch 4/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.8394 - kullback_leibler_divergence: 2.6812 - accuracy: 0.4828 - val_loss: 0.8228 - val_kullback_leibler_divergence: 2.5621 - val_accuracy: 0.4865
#
# Epoch 00004: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0004.hdf5
# Epoch 5/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.8114 - kullback_leibler_divergence: 2.6492 - accuracy: 0.4894 - val_loss: 0.8290 - val_kullback_leibler_divergence: 2.6648 - val_accuracy: 0.4811
#
# Epoch 00005: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0005.hdf5
# Epoch 6/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.8055 - kullback_leibler_divergence: 2.6577 - accuracy: 0.4866 - val_loss: 0.8204 - val_kullback_leibler_divergence: 2.5372 - val_accuracy: 0.4811
#
# Epoch 00006: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0006.hdf5
# Epoch 7/100
# 1045/1045 [==============================] - 46s 44ms/step - loss: 0.8036 - kullback_leibler_divergence: 2.6533 - accuracy: 0.4902 - val_loss: 0.8212 - val_kullback_leibler_divergence: 2.6570 - val_accuracy: 0.4843
#
# Epoch 00007: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0007.hdf5
# Epoch 8/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.8042 - kullback_leibler_divergence: 2.6631 - accuracy: 0.4880 - val_loss: 0.8215 - val_kullback_leibler_divergence: 2.6320 - val_accuracy: 0.4843
#
# Epoch 00008: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0008.hdf5
# Epoch 9/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.8028 - kullback_leibler_divergence: 2.6702 - accuracy: 0.4878 - val_loss: 0.8224 - val_kullback_leibler_divergence: 2.5444 - val_accuracy: 0.4843
#
# Epoch 00009: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0009.hdf5
# Epoch 10/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.8037 - kullback_leibler_divergence: 2.6749 - accuracy: 0.4898 - val_loss: 0.8223 - val_kullback_leibler_divergence: 2.3356 - val_accuracy: 0.4843
#
# Epoch 00010: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0010.hdf5
# Epoch 11/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7973 - kullback_leibler_divergence: 2.6973 - accuracy: 0.4917 - val_loss: 0.8233 - val_kullback_leibler_divergence: 2.7274 - val_accuracy: 0.4803
#
# Epoch 00011: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0011.hdf5
# Epoch 12/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7946 - kullback_leibler_divergence: 2.7379 - accuracy: 0.4903 - val_loss: 0.8206 - val_kullback_leibler_divergence: 2.5478 - val_accuracy: 0.4843
#
# Epoch 00012: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0012.hdf5
# Epoch 13/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7923 - kullback_leibler_divergence: 2.7617 - accuracy: 0.4911 - val_loss: 0.8220 - val_kullback_leibler_divergence: 2.4372 - val_accuracy: 0.4811
#
# Epoch 00013: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0013.hdf5
# Epoch 14/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7913 - kullback_leibler_divergence: 2.7984 - accuracy: 0.4940 - val_loss: 0.8197 - val_kullback_leibler_divergence: 2.4428 - val_accuracy: 0.4840
#
# Epoch 00014: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0014.hdf5
# Epoch 15/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7874 - kullback_leibler_divergence: 2.8438 - accuracy: 0.4956 - val_loss: 0.8221 - val_kullback_leibler_divergence: 2.4242 - val_accuracy: 0.4811
#
# Epoch 00015: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0015.hdf5
# Epoch 16/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7852 - kullback_leibler_divergence: 2.8578 - accuracy: 0.4968 - val_loss: 0.8261 - val_kullback_leibler_divergence: 2.3886 - val_accuracy: 0.4823
#
# Epoch 00016: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0016.hdf5
# Epoch 17/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7823 - kullback_leibler_divergence: 2.8888 - accuracy: 0.4910 - val_loss: 0.8171 - val_kullback_leibler_divergence: 2.4725 - val_accuracy: 0.4796
#
# Epoch 00017: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0017.hdf5
# Epoch 18/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7817 - kullback_leibler_divergence: 2.8804 - accuracy: 0.4921 - val_loss: 0.8273 - val_kullback_leibler_divergence: 2.6852 - val_accuracy: 0.4828
#
# Epoch 00018: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0018.hdf5
# Epoch 19/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7788 - kullback_leibler_divergence: 2.9226 - accuracy: 0.4951 - val_loss: 0.8230 - val_kullback_leibler_divergence: 2.6956 - val_accuracy: 0.4857
#
# Epoch 00019: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0019.hdf5
# Epoch 20/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7763 - kullback_leibler_divergence: 2.9507 - accuracy: 0.4963 - val_loss: 0.8281 - val_kullback_leibler_divergence: 2.9862 - val_accuracy: 0.4892
#
# Epoch 00020: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0020.hdf5
# Epoch 21/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7677 - kullback_leibler_divergence: 3.0109 - accuracy: 0.5031 - val_loss: 0.8238 - val_kullback_leibler_divergence: 2.9457 - val_accuracy: 0.4850
#
# Epoch 00021: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0021.hdf5
# Epoch 22/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7655 - kullback_leibler_divergence: 3.0576 - accuracy: 0.5054 - val_loss: 0.8225 - val_kullback_leibler_divergence: 2.8140 - val_accuracy: 0.4820
#
# Epoch 00022: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0022.hdf5
# Epoch 23/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7637 - kullback_leibler_divergence: 3.0378 - accuracy: 0.5059 - val_loss: 0.8292 - val_kullback_leibler_divergence: 3.0226 - val_accuracy: 0.4843
#
# Epoch 00023: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0023.hdf5
# Epoch 24/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7627 - kullback_leibler_divergence: 3.1042 - accuracy: 0.5103 - val_loss: 0.8246 - val_kullback_leibler_divergence: 2.9476 - val_accuracy: 0.4843
#
# Epoch 00024: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0024.hdf5
# Epoch 25/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7618 - kullback_leibler_divergence: 3.1026 - accuracy: 0.5094 - val_loss: 0.8304 - val_kullback_leibler_divergence: 3.1073 - val_accuracy: 0.4771
#
# Epoch 00025: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0025.hdf5
# Epoch 26/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7607 - kullback_leibler_divergence: 3.1447 - accuracy: 0.5082 - val_loss: 0.8281 - val_kullback_leibler_divergence: 3.0617 - val_accuracy: 0.4793
#
# Epoch 00026: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0026.hdf5
# Epoch 27/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7584 - kullback_leibler_divergence: 3.1640 - accuracy: 0.5134 - val_loss: 0.8324 - val_kullback_leibler_divergence: 3.1452 - val_accuracy: 0.4830
#
# Epoch 00027: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0027.hdf5
# Epoch 28/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7582 - kullback_leibler_divergence: 3.1901 - accuracy: 0.5104 - val_loss: 0.8425 - val_kullback_leibler_divergence: 3.3571 - val_accuracy: 0.4796
#
# Epoch 00028: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0028.hdf5
# Epoch 29/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7573 - kullback_leibler_divergence: 3.2048 - accuracy: 0.5139 - val_loss: 0.8463 - val_kullback_leibler_divergence: 3.4863 - val_accuracy: 0.4749
#
# Epoch 00029: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0029.hdf5
# Epoch 30/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7555 - kullback_leibler_divergence: 3.2486 - accuracy: 0.5132 - val_loss: 0.8411 - val_kullback_leibler_divergence: 3.2696 - val_accuracy: 0.4754
#
# Epoch 00030: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0030.hdf5
# Epoch 31/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7536 - kullback_leibler_divergence: 3.2664 - accuracy: 0.5183 - val_loss: 0.8547 - val_kullback_leibler_divergence: 3.5546 - val_accuracy: 0.4744
#
# Epoch 00031: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0031.hdf5
# Epoch 32/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7538 - kullback_leibler_divergence: 3.2600 - accuracy: 0.5187 - val_loss: 0.8388 - val_kullback_leibler_divergence: 3.2749 - val_accuracy: 0.4855
#
# Epoch 00032: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0032.hdf5
# Epoch 33/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7528 - kullback_leibler_divergence: 3.2863 - accuracy: 0.5174 - val_loss: 0.8549 - val_kullback_leibler_divergence: 3.5257 - val_accuracy: 0.4690
#
# Epoch 00033: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0033.hdf5
# Epoch 34/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7520 - kullback_leibler_divergence: 3.3201 - accuracy: 0.5202 - val_loss: 0.8415 - val_kullback_leibler_divergence: 3.2407 - val_accuracy: 0.4843
#
# Epoch 00034: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0034.hdf5
# Epoch 35/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7502 - kullback_leibler_divergence: 3.3234 - accuracy: 0.5195 - val_loss: 0.8526 - val_kullback_leibler_divergence: 3.4760 - val_accuracy: 0.4825
#
# Epoch 00035: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0035.hdf5
# Epoch 36/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7489 - kullback_leibler_divergence: 3.3837 - accuracy: 0.5241 - val_loss: 0.8580 - val_kullback_leibler_divergence: 3.5015 - val_accuracy: 0.4759
#
# Epoch 00036: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0036.hdf5
# Epoch 37/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7492 - kullback_leibler_divergence: 3.4150 - accuracy: 0.5247 - val_loss: 0.8590 - val_kullback_leibler_divergence: 3.4978 - val_accuracy: 0.4678
#
# Epoch 00037: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0037.hdf5
# Epoch 38/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7475 - kullback_leibler_divergence: 3.4002 - accuracy: 0.5261 - val_loss: 0.8565 - val_kullback_leibler_divergence: 3.5061 - val_accuracy: 0.4688
#
# Epoch 00038: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0038.hdf5
# Epoch 39/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7476 - kullback_leibler_divergence: 3.4359 - accuracy: 0.5259 - val_loss: 0.8708 - val_kullback_leibler_divergence: 3.7996 - val_accuracy: 0.4670
#
# Epoch 00039: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0039.hdf5
# Epoch 40/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7465 - kullback_leibler_divergence: 3.4583 - accuracy: 0.5285 - val_loss: 0.8680 - val_kullback_leibler_divergence: 3.7453 - val_accuracy: 0.4793
#
# Epoch 00040: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0040.hdf5
# Epoch 41/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7465 - kullback_leibler_divergence: 3.4634 - accuracy: 0.5279 - val_loss: 0.8564 - val_kullback_leibler_divergence: 3.5113 - val_accuracy: 0.4811
#
# Epoch 00041: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0041.hdf5
# Epoch 42/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7451 - kullback_leibler_divergence: 3.4694 - accuracy: 0.5283 - val_loss: 0.8691 - val_kullback_leibler_divergence: 3.7177 - val_accuracy: 0.4786
#
# Epoch 00042: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0042.hdf5
# Epoch 43/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7470 - kullback_leibler_divergence: 3.4872 - accuracy: 0.5276 - val_loss: 0.8631 - val_kullback_leibler_divergence: 3.7242 - val_accuracy: 0.4796
#
# Epoch 00043: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0043.hdf5
# Epoch 44/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7446 - kullback_leibler_divergence: 3.4813 - accuracy: 0.5285 - val_loss: 0.8697 - val_kullback_leibler_divergence: 3.8334 - val_accuracy: 0.4843
#
# Epoch 00044: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0044.hdf5
# Epoch 45/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7449 - kullback_leibler_divergence: 3.5044 - accuracy: 0.5295 - val_loss: 0.8826 - val_kullback_leibler_divergence: 3.9662 - val_accuracy: 0.4852
#
# Epoch 00045: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0045.hdf5
# Epoch 46/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7419 - kullback_leibler_divergence: 3.5278 - accuracy: 0.5327 - val_loss: 0.8807 - val_kullback_leibler_divergence: 3.9948 - val_accuracy: 0.4840
#
# Epoch 00046: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0046.hdf5
# Epoch 47/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7419 - kullback_leibler_divergence: 3.5597 - accuracy: 0.5364 - val_loss: 0.8864 - val_kullback_leibler_divergence: 3.9931 - val_accuracy: 0.4897
#
# Epoch 00047: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0047.hdf5
# Epoch 48/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7428 - kullback_leibler_divergence: 3.5282 - accuracy: 0.5373 - val_loss: 0.8869 - val_kullback_leibler_divergence: 3.9519 - val_accuracy: 0.4830
#
# Epoch 00048: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0048.hdf5
# Epoch 49/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7397 - kullback_leibler_divergence: 3.5812 - accuracy: 0.5396 - val_loss: 0.9104 - val_kullback_leibler_divergence: 4.1121 - val_accuracy: 0.4729
#
# Epoch 00049: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0049.hdf5
# Epoch 50/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7402 - kullback_leibler_divergence: 3.6007 - accuracy: 0.5372 - val_loss: 0.8827 - val_kullback_leibler_divergence: 3.9034 - val_accuracy: 0.4715
#
# Epoch 00050: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0050.hdf5
# Epoch 51/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7351 - kullback_leibler_divergence: 3.5070 - accuracy: 0.5420 - val_loss: 0.8856 - val_kullback_leibler_divergence: 3.9751 - val_accuracy: 0.4732
#
# Epoch 00051: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0051.hdf5
# Epoch 52/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7341 - kullback_leibler_divergence: 3.5758 - accuracy: 0.5438 - val_loss: 0.8888 - val_kullback_leibler_divergence: 4.0391 - val_accuracy: 0.4729
#
# Epoch 00052: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0052.hdf5
# Epoch 53/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7346 - kullback_leibler_divergence: 3.6301 - accuracy: 0.5435 - val_loss: 0.8888 - val_kullback_leibler_divergence: 4.0608 - val_accuracy: 0.4697
#
# Epoch 00053: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0053.hdf5
# Epoch 54/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7338 - kullback_leibler_divergence: 3.6542 - accuracy: 0.5464 - val_loss: 0.8910 - val_kullback_leibler_divergence: 4.0745 - val_accuracy: 0.4710
#
# Epoch 00054: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0054.hdf5
# Epoch 55/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7334 - kullback_leibler_divergence: 3.6742 - accuracy: 0.5457 - val_loss: 0.8920 - val_kullback_leibler_divergence: 4.0996 - val_accuracy: 0.4725
#
# Epoch 00055: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0055.hdf5
# Epoch 56/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7334 - kullback_leibler_divergence: 3.6807 - accuracy: 0.5423 - val_loss: 0.8937 - val_kullback_leibler_divergence: 4.1230 - val_accuracy: 0.4798
#
# Epoch 00056: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0056.hdf5
# Epoch 57/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7337 - kullback_leibler_divergence: 3.7071 - accuracy: 0.5454 - val_loss: 0.8952 - val_kullback_leibler_divergence: 4.1250 - val_accuracy: 0.4803
#
# Epoch 00057: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0057.hdf5
# Epoch 58/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7319 - kullback_leibler_divergence: 3.6954 - accuracy: 0.5487 - val_loss: 0.8951 - val_kullback_leibler_divergence: 4.1257 - val_accuracy: 0.4766
#
# Epoch 00058: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0058.hdf5
# Epoch 59/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7321 - kullback_leibler_divergence: 3.7092 - accuracy: 0.5475 - val_loss: 0.8956 - val_kullback_leibler_divergence: 4.1328 - val_accuracy: 0.4739
#
# Epoch 00059: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0059.hdf5
# Epoch 60/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7323 - kullback_leibler_divergence: 3.7232 - accuracy: 0.5463 - val_loss: 0.8992 - val_kullback_leibler_divergence: 4.1753 - val_accuracy: 0.4715
#
# Epoch 00060: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0060.hdf5
# Epoch 61/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7325 - kullback_leibler_divergence: 3.7340 - accuracy: 0.5454 - val_loss: 0.9017 - val_kullback_leibler_divergence: 4.1948 - val_accuracy: 0.4690
#
# Epoch 00061: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0061.hdf5
# Epoch 62/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7323 - kullback_leibler_divergence: 3.7387 - accuracy: 0.5478 - val_loss: 0.8990 - val_kullback_leibler_divergence: 4.1658 - val_accuracy: 0.4653
#
# Epoch 00062: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0062.hdf5
# Epoch 63/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7313 - kullback_leibler_divergence: 3.7423 - accuracy: 0.5529 - val_loss: 0.8943 - val_kullback_leibler_divergence: 4.1186 - val_accuracy: 0.4705
#
# Epoch 00063: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0063.hdf5
# Epoch 64/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7316 - kullback_leibler_divergence: 3.7644 - accuracy: 0.5485 - val_loss: 0.8968 - val_kullback_leibler_divergence: 4.1532 - val_accuracy: 0.4702
#
# Epoch 00064: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0064.hdf5
# Epoch 65/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7312 - kullback_leibler_divergence: 3.7781 - accuracy: 0.5510 - val_loss: 0.8971 - val_kullback_leibler_divergence: 4.1536 - val_accuracy: 0.4744
#
# Epoch 00065: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0065.hdf5
# Epoch 66/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7307 - kullback_leibler_divergence: 3.7752 - accuracy: 0.5508 - val_loss: 0.8933 - val_kullback_leibler_divergence: 4.1221 - val_accuracy: 0.4757
#
# Epoch 00066: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0066.hdf5
# Epoch 67/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7313 - kullback_leibler_divergence: 3.7765 - accuracy: 0.5461 - val_loss: 0.8929 - val_kullback_leibler_divergence: 4.1128 - val_accuracy: 0.4776
#
# Epoch 00067: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0067.hdf5
# Epoch 68/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7304 - kullback_leibler_divergence: 3.7933 - accuracy: 0.5508 - val_loss: 0.8960 - val_kullback_leibler_divergence: 4.1490 - val_accuracy: 0.4732
#
# Epoch 00068: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0068.hdf5
# Epoch 69/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7294 - kullback_leibler_divergence: 3.8031 - accuracy: 0.5533 - val_loss: 0.8992 - val_kullback_leibler_divergence: 4.2021 - val_accuracy: 0.4685
#
# Epoch 00069: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0069.hdf5
# Epoch 70/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7318 - kullback_leibler_divergence: 3.8091 - accuracy: 0.5498 - val_loss: 0.8964 - val_kullback_leibler_divergence: 4.1551 - val_accuracy: 0.4690
#
# Epoch 00070: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0070.hdf5
# Epoch 71/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7310 - kullback_leibler_divergence: 3.7865 - accuracy: 0.5533 - val_loss: 0.8960 - val_kullback_leibler_divergence: 4.1541 - val_accuracy: 0.4757
#
# Epoch 00071: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0071.hdf5
# Epoch 72/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7294 - kullback_leibler_divergence: 3.8066 - accuracy: 0.5466 - val_loss: 0.8994 - val_kullback_leibler_divergence: 4.2144 - val_accuracy: 0.4732
#
# Epoch 00072: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0072.hdf5
# Epoch 73/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7292 - kullback_leibler_divergence: 3.8151 - accuracy: 0.5496 - val_loss: 0.8982 - val_kullback_leibler_divergence: 4.1887 - val_accuracy: 0.4690
#
# Epoch 00073: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0073.hdf5
# Epoch 74/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7296 - kullback_leibler_divergence: 3.8128 - accuracy: 0.5544 - val_loss: 0.9062 - val_kullback_leibler_divergence: 4.2786 - val_accuracy: 0.4700
#
# Epoch 00074: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0074.hdf5
# Epoch 75/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7295 - kullback_leibler_divergence: 3.8314 - accuracy: 0.5533 - val_loss: 0.9060 - val_kullback_leibler_divergence: 4.2631 - val_accuracy: 0.4774
#
# Epoch 00075: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0075.hdf5
# Epoch 76/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7290 - kullback_leibler_divergence: 3.8263 - accuracy: 0.5531 - val_loss: 0.9061 - val_kullback_leibler_divergence: 4.2758 - val_accuracy: 0.4764
#
# Epoch 00076: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0076.hdf5
# Epoch 77/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7297 - kullback_leibler_divergence: 3.8241 - accuracy: 0.5515 - val_loss: 0.9062 - val_kullback_leibler_divergence: 4.2892 - val_accuracy: 0.4806
#
# Epoch 00077: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0077.hdf5
# Epoch 78/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7286 - kullback_leibler_divergence: 3.8398 - accuracy: 0.5513 - val_loss: 0.9074 - val_kullback_leibler_divergence: 4.3161 - val_accuracy: 0.4754
#
# Epoch 00078: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0078.hdf5
# Epoch 79/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7284 - kullback_leibler_divergence: 3.8367 - accuracy: 0.5510 - val_loss: 0.9100 - val_kullback_leibler_divergence: 4.3296 - val_accuracy: 0.4759
#
# Epoch 00079: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0079.hdf5
# Epoch 80/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7290 - kullback_leibler_divergence: 3.8447 - accuracy: 0.5516 - val_loss: 0.9089 - val_kullback_leibler_divergence: 4.3038 - val_accuracy: 0.4742
#
# Epoch 00080: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0080.hdf5
# Epoch 81/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7287 - kullback_leibler_divergence: 3.8463 - accuracy: 0.5526 - val_loss: 0.9089 - val_kullback_leibler_divergence: 4.3223 - val_accuracy: 0.4710
#
# Epoch 00081: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0081.hdf5
# Epoch 82/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7293 - kullback_leibler_divergence: 3.8541 - accuracy: 0.5527 - val_loss: 0.9050 - val_kullback_leibler_divergence: 4.2753 - val_accuracy: 0.4690
#
# Epoch 00082: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0082.hdf5
# Epoch 83/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7284 - kullback_leibler_divergence: 3.8507 - accuracy: 0.5525 - val_loss: 0.9056 - val_kullback_leibler_divergence: 4.2796 - val_accuracy: 0.4675
#
# Epoch 00083: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0083.hdf5
# Epoch 84/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7288 - kullback_leibler_divergence: 3.8547 - accuracy: 0.5535 - val_loss: 0.9077 - val_kullback_leibler_divergence: 4.3210 - val_accuracy: 0.4707
#
# Epoch 00084: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0084.hdf5
# Epoch 85/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7294 - kullback_leibler_divergence: 3.8790 - accuracy: 0.5530 - val_loss: 0.9060 - val_kullback_leibler_divergence: 4.2963 - val_accuracy: 0.4710
#
# Epoch 00085: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0085.hdf5
# Epoch 86/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7284 - kullback_leibler_divergence: 3.8472 - accuracy: 0.5501 - val_loss: 0.9091 - val_kullback_leibler_divergence: 4.3445 - val_accuracy: 0.4769
#
# Epoch 00086: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0086.hdf5
# Epoch 87/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7273 - kullback_leibler_divergence: 3.8664 - accuracy: 0.5531 - val_loss: 0.9102 - val_kullback_leibler_divergence: 4.3790 - val_accuracy: 0.4707
#
# Epoch 00087: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0087.hdf5
# Epoch 88/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7274 - kullback_leibler_divergence: 3.8708 - accuracy: 0.5553 - val_loss: 0.9097 - val_kullback_leibler_divergence: 4.3762 - val_accuracy: 0.4710
#
# Epoch 00088: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0088.hdf5
# Epoch 89/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7275 - kullback_leibler_divergence: 3.8713 - accuracy: 0.5567 - val_loss: 0.9078 - val_kullback_leibler_divergence: 4.3332 - val_accuracy: 0.4734
#
# Epoch 00089: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0089.hdf5
# Epoch 90/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7272 - kullback_leibler_divergence: 3.8804 - accuracy: 0.5533 - val_loss: 0.9078 - val_kullback_leibler_divergence: 4.3463 - val_accuracy: 0.4710
#
# Epoch 00090: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0090.hdf5
# Epoch 91/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7278 - kullback_leibler_divergence: 3.8801 - accuracy: 0.5527 - val_loss: 0.9076 - val_kullback_leibler_divergence: 4.3520 - val_accuracy: 0.4668
#
# Epoch 00091: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0091.hdf5
# Epoch 92/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7284 - kullback_leibler_divergence: 3.8938 - accuracy: 0.5548 - val_loss: 0.9067 - val_kullback_leibler_divergence: 4.3392 - val_accuracy: 0.4668
#
# Epoch 00092: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0092.hdf5
# Epoch 93/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7264 - kullback_leibler_divergence: 3.8803 - accuracy: 0.5566 - val_loss: 0.9091 - val_kullback_leibler_divergence: 4.3867 - val_accuracy: 0.4643
#
# Epoch 00093: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0093.hdf5
# Epoch 94/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7265 - kullback_leibler_divergence: 3.9008 - accuracy: 0.5554 - val_loss: 0.9076 - val_kullback_leibler_divergence: 4.3642 - val_accuracy: 0.4621
#
# Epoch 00094: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0094.hdf5
# Epoch 95/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7243 - kullback_leibler_divergence: 3.9095 - accuracy: 0.5546 - val_loss: 0.9082 - val_kullback_leibler_divergence: 4.3830 - val_accuracy: 0.4619
#
# Epoch 00095: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0095.hdf5
# Epoch 96/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7250 - kullback_leibler_divergence: 3.9392 - accuracy: 0.5575 - val_loss: 0.9082 - val_kullback_leibler_divergence: 4.3568 - val_accuracy: 0.4658
#
# Epoch 00096: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0096.hdf5
# Epoch 97/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7265 - kullback_leibler_divergence: 3.9399 - accuracy: 0.5508 - val_loss: 0.9090 - val_kullback_leibler_divergence: 4.3984 - val_accuracy: 0.4666
#
# Epoch 00097: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0097.hdf5
# Epoch 98/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7257 - kullback_leibler_divergence: 3.9264 - accuracy: 0.5569 - val_loss: 0.9116 - val_kullback_leibler_divergence: 4.4326 - val_accuracy: 0.4658
#
# Epoch 00098: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0098.hdf5
# Epoch 99/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7254 - kullback_leibler_divergence: 3.9435 - accuracy: 0.5566 - val_loss: 0.9154 - val_kullback_leibler_divergence: 4.4815 - val_accuracy: 0.4678
#
# Epoch 00099: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0099.hdf5
# Epoch 100/100
# 1045/1045 [==============================] - 47s 45ms/step - loss: 0.7266 - kullback_leibler_divergence: 3.9516 - accuracy: 0.5527 - val_loss: 0.9115 - val_kullback_leibler_divergence: 4.4232 - val_accuracy: 0.4744
#
# Epoch 00100: saving model to Benchmark/trained_models/LSTM_multivariate_classification____0100.hdf5

# %%
import pickle 
with open(f'Benchmark/trained_models/{name}____history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
if 'my_LSTM_model' not in globals():
    model_last = sorted([i for i in os.listdir('Benchmark/trained_models/') if name + '__' in i and 'hdf5' in i])[-1]
    my_LSTM_model = tf.keras.models.load_model(
        os.path.join('Benchmark/trained_models', model_last)
    )
if 'history' not in globals():
    with open(f'Benchmark/trained_models/{name}____history.pkl', 'rb') as f:
        history = pickle.load(f)
if hasattr(history, 'history'):
    history = history.history

# %%
plt.plot(history['loss'], label='train')
plt.plot(history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
my_LSTM_model.summary()
my_LSTM_model.layers[1].get_weights()[2].dtype
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128, 256)          1531904
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 256)          1024
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128, 256)          525312
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 256)          1024
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 128, 256)          525312
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128, 256)          1024
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 128, 256)          525312
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128, 256)          1024
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 128, 128)          197120
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 128, 128)          512
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 49155
# =================================================================
# Total params: 3,358,723
# Trainable params: 3,356,419
# Non-trainable params: 2,304
# _________________________________________________________________
# dtype('float32')

# %%
opt_learn_rate_plot(
    my_LSTM_model,
    X_train,
    y_train,
    10**-6,
    10**1,
    100,
    batch_size=64,
    steps_per_epoch=1,
    custom_objects={'kl_divergence': kullback_leibler_divergence}
)
